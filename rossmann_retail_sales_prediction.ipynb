# %% [markdown]
# <a href="https://colab.research.google.com/github/MonaliM5/rossmann_retail_sales_prediction/blob/main/rossmann_retail_sales_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Rossmann Retail Sales Prediction

# %% [markdown]
# ##### **Project Type**    - Regression
# ##### **Contribution**    - Individual
# ##### **Student Name**    - Monali Vijay Mhaske

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# * Rossmann is a large European drugstore chain operating over 3,000 stores across several countries. The company faces a key business challenge — accurately forecasting daily sales for each store. Reliable sales forecasts are crucial for effective inventory planning, workforce scheduling, and promotional strategy.
#
# * This project aims to predict the daily sales of Rossmann stores using historical sales data combined with store-specific information such as promotions, holidays, competition, and assortment types. By developing a predictive model, Rossmann management can make data-driven decisions to optimize operations and improve profitability.
#
# * The project will follow a structured data science life-cycle, which includes:
#
#   1. Data Understanding - Exploring the historical sales and store datasets to identify patterns, data types, and business drivers.
#
#
#   2. Data Wrangling & Cleaning - Handling missing values, correcting inconsistencies, encoding categorical variables, and preparing data for analysis.
#
#
#   3. Exploratory Data Analysis (EDA) - Performing univariate, bivariate, and multivariate analysis to uncover relationships between features such as promotions, holidays, and sales trends.
#
#
#   4. Feature Engineering - Creating new features like competition duration, promo activity flags, and temporal variables (month, week, weekday) to enhance model performance.
#
#
#   5. Model Development & Evaluation - Building regression-based machine learning models (e.g., Linear Regression, Random Forest, XGBoost) to predict sales. Model performance will be evaluated primarily using Root Mean Squared Logarithmic Error (RMSLE), a suitable metric for skewed sales data.
#
#
#   6. Model Interpretation & Business Insights - Interpreting the model results to generate actionable insights, such as how promotions or competition impact sales, and providing recommendations to management.
#
#
#
# * The expected outcome of this project is a robust, data-driven forecasting model that can accurately estimate future store sales and highlight key factors influencing them. This will help Rossmann:
#
#     * Ensure better inventory and staff management,
#
#     * Improve promotion planning and marketing effectiveness, and
#
#     * Ultimately increase overall profitability.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/MonaliM5/rossmann_retail_sales_prediction

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# * In the retail industry, accurate sales forecasting is critical for effective decision-making. Retailers like Rossmann, one of Europe's largest drugstore chains, must regularly decide how much stock to order, how to schedule employees, and how to plan promotional campaigns - all of which depend heavily on anticipated sales.
#
# * However, predicting store-level daily sales is challenging because it is influenced by multiple dynamic factors such as store location, promotions, holidays, competition, and seasonality. An incorrect forecast can lead to overstocking or understocking, resulting in financial losses and poor customer experience.
#
# * The primary objective of this project is to develop a predictive model capable of accurately estimating daily sales for each Rossmann store using historical sales and store information. The model should capture the impact of various external and internal factors - including promotions, holidays, competition distance, assortment type, and time-related variables - on store performance.
#
# * The predictive insights from this project will enable Rossmann's management to:
#
#   * Optimize inventory and staffing levels,
#
#   * Plan promotional activities more effectively,
#
#   * Improve supply chain efficiency, and
#
#   * Enhance overall business profitability.
#
#
# * The project will apply systematic data analysis and machine learning techniques to derive actionable insights that directly support Rossmann's strategic and operational decisions.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

# Data manipulation and analysis
import numpy as np
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Datetime
from datetime import datetime


# Machine learning and preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# System and warnings
import warnings
warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', None)
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ### Dataset Loading

# %%
# Mounting Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
Sales_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Module 6 - Machine Learning/Chapt 1.5 - Capstone Project Regression/Rossmann Stores Data.csv", parse_dates=['Date'])
Store_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Module 6 - Machine Learning/Chapt 1.5 - Capstone Project Regression/store.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Sales Dataset First Look
print("Sales Data First View ")
Sales_df.head()
# Out:
# Sales Data First View
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# Store Dataset First Look
print("Store Data First View ")
Store_df.head()
# Out:
# Store Data First View
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f"Sales Dataset -\n Rows Count : {Sales_df.shape[0]}  \tColumns Count : {Sales_df.shape[1]}")
print(f"Store Dataset -\n Rows Count : {Store_df.shape[0]}  \tColumns Count : {Store_df.shape[1]}")
# Out:
# Sales Dataset -
#  Rows Count : 1017209  	Columns Count : 9
# Store Dataset -
#  Rows Count : 1115  	Columns Count : 10

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Information

# Sales dataset info
print("Sales Data Information:")
Sales_df.info()
print("\n" + "="*60 + "\n")

# Store dataset info
print("Store Data Information:")
Store_df.info()
# Out:
# Sales Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  datetime64[ns]
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 69.8+ MB
#
# ...
#
# Store Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

# Sales dataset duplicates
print(f"Sales Dataset → Duplicate rows: {Sales_df.duplicated().sum()}")

if Sales_df.duplicated().sum() > 0:
    print("\nSample duplicate rows from Sales_df:")
    display(Sales_df[Sales_df.duplicated()].head())

print("\n" + "-"*60 + "\n")

# Store dataset duplicates
print(f"Store Dataset → Duplicate rows: {Store_df.duplicated().sum()}")

if Store_df.duplicated().sum() > 0:
    print("\nSample duplicate rows from Store_df:")
    display(Store_df[Store_df.duplicated()].head())
# Out:
# Sales Dataset → Duplicate rows: 0
#
# ------------------------------------------------------------
#
# Store Dataset → Duplicate rows: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

# Sales dataset nulls
print("Sales Dataset - Missing Values:\n")
print(Sales_df.isnull().sum())
print("\n" + "-"*60 + "\n")

# Store dataset nulls
print("Store Dataset - Missing Values:\n")
print(Store_df.isnull().sum())
# Out:
# Sales Dataset - Missing Values:
#
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64
#
# ------------------------------------------------------------
#
# Store Dataset - Missing Values:
#
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
# Visualizing the missing values

import missingno as msno

# Set up plot style
plt.style.use('seaborn-v0_8-whitegrid')

# Sales dataset missing values visualization
print("Sales Dataset - Missing Values Visualization:\n")
msno.matrix(Sales_df)
plt.title("Sales Dataset - Missing Values Overview")
plt.show()

# Store dataset missing values visualization
print("Store Dataset - Missing Values Visualization:\n")
msno.matrix(Store_df)
plt.title("Store Dataset - Missing Values Overview")
plt.show()
# Out:
# Sales Dataset - Missing Values Visualization:
# Store Dataset - Missing Values Visualization:

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * The Rossmann dataset consists of two main files - Sales data and Store data - that together provide a comprehensive view of the company's retail operations.
#
# 1. Sales Data (Sales_df)
#
#     * This dataset contains daily sales records for each Rossmann store.
#
#     * Each record includes store ID, sales amount, number of customers, whether the store was open, ongoing promotions, state and school holidays, and the corresponding date.
#
#     * These variables help capture short-term and seasonal trends, customer behavior, and the influence of holidays or promotions on sales.
#
#
#
# 2. Store Data (Store_df)
#
#     * This dataset provides static information about each store, such as store type, assortment level, distance to the nearest competitor, duration since the nearest competition opened, and promotional program details (e.g., whether the store runs continuous promotions).
#
#     * These variables explain store-level differences that affect long-term sales patterns.
#
#
#
# * By combining these two datasets, we obtain both temporal (daily) and structural (store-level) information. This enables a deeper understanding of how different factors — such as competition, promotions, holidays, and assortment — influence store performance.
# Such insights form the foundation for building a reliable predictive model to forecast future sales.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

# Printing list of columns in Sales Dataset
print("Columns in Sales Dataset:\n")
print(Sales_df.columns.tolist())

print("\n" + "-"*60 + "\n")

#Printing list of columns in Store Dataset
print("Columns in Store Dataset:\n")
print(Store_df.columns.tolist())
# Out:
# Columns in Sales Dataset:
#
# ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday']
#
# ------------------------------------------------------------
#
# Columns in Store Dataset:
#
# ['Store', 'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']

# %%
# Dataset Describe

# Describing the Sales Dataset
print(" Sales Data Description : \n")
display(Sales_df.describe())

print("\n" + "-"*60 + "\n")

# Describing the Store Dataset
print(" Store Data Description :\n ")
display(Store_df.describe())
# Out:
#  Sales Data Description :
#               Store     DayOfWeek                           Date  \
# count  1.017209e+06  1.017209e+06                        1017209
# mean   5.584297e+02  3.998341e+00  2014-04-11 01:30:42.846061824
# min    1.000000e+00  1.000000e+00            2013-01-01 00:00:00
# 25%    2.800000e+02  2.000000e+00            2013-08-17 00:00:00
# 50%    5.580000e+02  4.000000e+00            2014-04-02 00:00:00
# 75%    8.380000e+02  6.000000e+00            2014-12-12 00:00:00
# max    1.115000e+03  7.000000e+00            2015-07-31 00:00:00
# std    3.219087e+02  1.997391e+00                            NaN
#
#               Sales     Customers          Open         Promo  SchoolHoliday
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06   1.017209e+06
# mean   5.773819e+03  6.331459e+02  8.301067e-01  3.815145e-01   1.786467e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 📘 Sales Dataset (Sales_df) :
#
#
# |Variable|Description|
# |---|---|
# |Store|Unique identifier for each store.|
# |DayOfWeek|  Day of the week (1 = Monday, 7 = Sunday).|
# |Date| Date of the record.|
# |Sales|	Total sales made on that day — this is the target variable.|
# |Customers|	Number of customers who visited the store on that day.|
# |Open|	Indicates whether the store was open (1) or closed (0).|
# |Promo|	Indicates if a promotion was running on that day (1 = Yes, 0 = No).|
# |StateHoliday|	Denotes whether the day was a state/national/public holiday.|
# |SchoolHoliday|	Indicates if the store was affected by public-school closures.|
#
#
#
# ---
#
# 🏪 Store Dataset (Store_df)
#
# |Variable	|Description|
# |---|---|
# |Store|	Unique identifier for each store (key to merge with Sales_df).|
# |StoreType|	Type of store (a, b, c, d) — represents different business formats.|
# |Assortment|	Level of product assortment (a = basic, b = extra, c = extended).|
# |CompetitionDistance|	Distance to the nearest competitor (in meters).|
# |CompetitionOpenSinceMonth|	Month when the nearest competitor opened.|
# |CompetitionOpenSinceYear|	Year when the nearest competitor opened.|
# |Promo2|	Indicates whether the store participates in a continuing promotion (1 = Yes, 0 = No).|
# |Promo2SinceWeek|	Week when the store began participating in Promo2.|
# |Promo2SinceYear|	Year when the store began participating in Promo2.|
# |PromoInterval|	Months when Promo2 is active (e.g., Jan, Apr, Jul, Oct).|
#
#
#
# ---
#
# 💡 Insights
#
# * Sales_df provides time-based transactional information.
#
# * Store_df adds store-level context such as competition and promotions.
#
# * Together, these datasets form a powerful base to analyze sales drivers and build a predictive regression model for accurate forecasting.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# Fetching and printing number of unique values in each column of Sales Dataset.
print("Unique values in Sales Dataset : \n")
for col in Sales_df.columns :
  unique_count = Sales_df[col].nunique()
  # Fetched total number of unique values
  print(f"{col} : {unique_count} unique values")
  print(Sales_df[col].unique())
  # Printing all those unique values of each column
  print("\n")

print("\n" + "-"*60 + "\n")

# Fetching and printing number of unique values in each column of Store Dataset.
print("Unique values in Store Dataset : \n")

for col in Store_df.columns :
  unique_count = Store_df[col].nunique()
  # Fetched total number of unique values.

  print(f"{col} : {unique_count} unique values")
  print(Store_df[col].unique())
  # Printing all those unique values of each column

  print("\n")
# Out:
# Unique values in Sales Dataset :
#
# Store : 1115 unique values
# [   1    2    3 ... 1113 1114 1115]
#
#
# DayOfWeek : 7 unique values
# [5 4 3 2 1 7 6]
#
#
# Date : 942 unique values
# <DatetimeArray>
# ['2015-07-31 00:00:00', '2015-07-30 00:00:00', '2015-07-29 00:00:00',
#  '2015-07-28 00:00:00', '2015-07-27 00:00:00', '2015-07-26 00:00:00',
#  '2015-07-25 00:00:00', '2015-07-24 00:00:00', '2015-07-23 00:00:00',
#  '2015-07-22 00:00:00',
#  ...
#  '2013-01-10 00:00:00', '2013-01-09 00:00:00', '2013-01-08 00:00:00',
#  '2013-01-07 00:00:00', '2013-01-06 00:00:00', '2013-01-05 00:00:00',
#  '2013-01-04 00:00:00', '2013-01-03 00:00:00', '2013-01-02 00:00:00',
#  '2013-01-01 00:00:00']
# Length: 942, dtype: datetime64[ns]
#
#
# Sales : 21734 unique values
# [ 5263  6064  8314 ...   660 17815 23303]
#
#
# Customers : 4086 unique values
# [ 555  625  821 ... 3900   36 4065]
#
#
# Open : 2 unique values
# [1 0]
#
#
# Promo : 2 unique values
# [1 0]
#
#
# StateHoliday : 5 unique values
# ...

# %% [markdown]
# ## ***3. Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# -----------------------------
# STEP 1: MERGING BOTH DATASETS
# -----------------------------
# 📌 Copying data to preserve raw versions
sales_df = Sales_df.copy()
store_df = Store_df.copy()

# 🧩 Merging both datasets using 'Store' as the key
df = pd.merge(sales_df, store_df, on = "Store", how = "left")


#==============================================================================================#


# -----------------------------
# STEP 2 : Handle unrealistic values
# ----------------------------
# 🧠 Replacing invalid competition years (before 1970) with NaN
df.loc[df['CompetitionOpenSinceYear'] < 1970, 'CompetitionOpenSinceYear'] = np.nan

# 🏫 Handling holidays and store info columns
df['SchoolHoliday'] = df['SchoolHoliday'].astype(int)


#==============================================================================================#



# -----------------------------
# STEP 3: Missing-value indicator flags
# -----------------------------
# 🚩 Creating missing-value indicator flags to identify records with null values after imputing for the same.
df['CompetitionDistance_NA'] = df['CompetitionDistance'].isna().astype(int)
df['CompetitionOpenSince_NA'] = df[['CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear']].isna().any(axis=1).astype(int)
df['Promo2Since_NA'] = df[['Promo2SinceWeek', 'Promo2SinceYear']].isna().any(axis=1).astype(int)


#==============================================================================================#


# -----------------------------
# STEP 4 : Handle missing values
# -----------------------------
# 🎯 Handling promotion-related columns
df['Promo2SinceWeek'].fillna(0, inplace=True)
df['Promo2SinceYear'].fillna(0, inplace=True)
df['PromoInterval'].fillna('None', inplace=True)

# 🧹 Handling missing values for 'CompetitionDistance'
df['CompetitionDistance'] = df['CompetitionDistance'].fillna(df['CompetitionDistance'].median())

# 🧩 Handling missing values for competition opening details
df['CompetitionOpenSinceMonth'].fillna(0, inplace=True)
df['CompetitionOpenSinceYear'].fillna(0, inplace=True)



#==============================================================================================#


# -----------------------------
# STEP 5 : Feature extraction from date
# -----------------------------
# 🕒 Converting 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')

# 📆 Extracting useful time-based features
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month



#==============================================================================================#


# -----------------------------
# STEP 6 : Competition open duration
# -----------------------------
# 🕓 Creating 'CompetitionOpenMonths' — duration of competition presence
df['CompetitionOpenMonths'] = np.where(
    df['CompetitionOpenSince_NA'],
    0,  # Set to 0 if missing
    ((df['Year'] - df['CompetitionOpenSinceYear']) * 12 +
     (df['Month'] - df['CompetitionOpenSinceMonth']))
)

# Replacing negative values (for stores opened later) with 0
df['CompetitionOpenMonths'] = df['CompetitionOpenMonths'].apply(lambda x: x if x > 0 else 0)



#==============================================================================================#



# -----------------------------
# STEP 7 : Fixing data type issues
# -----------------------------
df['StateHoliday'] = df['StateHoliday'].astype('str').replace({'0': 'None'})
df['StoreType'] = df['StoreType'].astype('category')
df['Assortment'] = df['Assortment'].astype('category')
df['PromoInterval'] = df['PromoInterval'].astype('category')


#==============================================================================================#


# -----------------------------
# STEP 8 : Promo2 active (vectorized)
# -----------------------------
# 🧠 Creating 'IsPromo2Active' — checks if store's long-term promo is active
month_map = {'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4, 'May':5, 'Jun':6,
             'Jul':7, 'Aug':8, 'Sept':9, 'Oct':10, 'Nov':11, 'Dec':12}

# Convert to string before applying function to avoid 'unhashable list' error
df['PromoMonths'] = df['PromoInterval'].astype(str).apply(
    lambda x: [month_map[m] for m in x.split(',')] if x != 'None' else []
)


df['IsPromo2Active'] = df.apply(
    lambda row: 1 if (row['Promo2'] == 1) and
                     (row['Month'] in row['PromoMonths']) and
                     (row['Year'] > row['Promo2SinceYear']) else 0, axis=1)



#==============================================================================================#



# -----------------------------
# STEP 9 : Business logic flags
# -----------------------------
# 💰 Creating 'SalesPerCustomer' — derived metric for customer efficiency
df['SalesPerCustomer'] = np.where(df['Customers'] > 0, df['Sales'] / df['Customers'], 0)

# 💰 Creating ZeroSalesWhileOpen to check anoamlies or Unproductive Day.
df['ZeroSalesWhileOpen'] = ((df['Sales'] == 0) & (df['Open'] == 1)).astype(int)



#==============================================================================================#



# -----------------------------
# STEP 10 : Handle outliers
# -----------------------------
# Cap competition distance at 99th percentile
cap_value = df['CompetitionDistance'].quantile(0.99)
df.loc[df['CompetitionDistance'] > cap_value, 'CompetitionDistance'] = cap_value



#==============================================================================================#



# -----------------------------
# STEP 11 : Final formatting
# -----------------------------
# 🚫 Dropping redundant and unnecessary columns
df.drop(columns=[
    'Promo2SinceYear',    # Used only for IsPromo2Active
    'PromoMonths',       # Temporary calculation column
    ], inplace=True)


# 🧾 Reordering columns for better readability
df = df[['Store', 'Date', 'Year', 'Month', 'DayOfWeek', 'Open', 'Promo', 'Promo2', 'IsPromo2Active',
         'Sales', 'Customers', 'SalesPerCustomer','ZeroSalesWhileOpen', 'StateHoliday', 'SchoolHoliday',
         'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionDistance_NA',
         'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'CompetitionOpenSince_NA',
         'CompetitionOpenMonths', 'Promo2SinceWeek', 'Promo2Since_NA', 'PromoInterval']]


# Reset index and sort
df.sort_values(['Store', 'Date'], inplace=True)
df.reset_index(drop=True, inplace=True)


# ✅ Displaying final info
print("✅ Data Wrangling Completed Successfully!")
print(f"Final Dataset Shape: {df.shape}")
print("\nMissing Values After Wrangling:")
print(df.isnull().sum()[df.isnull().sum() > 0])
display(df.head(3))
# Out:
# ✅ Data Wrangling Completed Successfully!
# Final Dataset Shape: (1017209, 26)
#
# Missing Values After Wrangling:
# Series([], dtype: int64)
#    Store       Date  Year  Month  DayOfWeek  Open  Promo  Promo2  \
# 0      1 2013-01-01  2013      1          2     0      0       0
# 1      1 2013-01-02  2013      1          3     1      0       0
# 2      1 2013-01-03  2013      1          4     1      0       0
#
#    IsPromo2Active  Sales  Customers  SalesPerCustomer  ZeroSalesWhileOpen  \
# 0               0      0          0          0.000000                   0
# 1               0   5530        668          8.278443                   0
# 2               0   4327        578          7.486159                   0
#
#   StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0            a              1         c          a               1270.0
# 1         None              1         c          a               1270.0
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# * During the data wrangling phase, multiple preprocessing and feature-engineering steps were performed to clean, correct, and enhance the dataset — making it ready for meaningful analysis and modeling.
#
# * The manipulations focused on merging data, handling missing values, correcting data types, creating new features, and ensuring data consistency and reliability.
#
#
# ---
#
# 🔧 Manipulations Performed
#
# 1️⃣ Merging Datasets
#
# * The two datasets — Sales_df (daily sales data) and Store_df (store information) — were merged on the common key Store.
#
# * This merge allowed each sales record to include corresponding store-level details such as store type, assortment, and competition data.
#
#
#
# ---
#
# 2️⃣ Handling Unrealistic and Missing Values
#
# * Unrealistic competition years (before 1975) were replaced with NaN to maintain data validity.
#
# * Missing values in important fields like CompetitionDistance, CompetitionOpenSinceMonth/Year, and Promo2SinceWeek/Year were handled logically using median or zero imputation where applicable.
#
# * Additional missing-value indicator columns (CompetitionDistance_NA, CompetitionOpenSince_NA, Promo2Since_NA) were created to capture the information about missingness — since even the absence of data can be predictive.
#
#
#
# ---
#
# 3️⃣ Data Type Corrections
#
# * Columns such as StoreType, Assortment, and PromoInterval were converted to categorical data types to improve memory efficiency and interpretability.
#
# * The StateHoliday column was kept as a categorical feature to allow one-hot encoding later during the modeling phase.
#
#
#
# ---
#
# 4️⃣ Feature Extraction from Date
#
# * The Date column was transformed into datetime format, and new temporal features were extracted:
# Year, Month, and DayOfWeek.
#
# * These features will help identify seasonal trends, monthly variations, and weekday vs. weekend effects on sales.
#
#
#
# ---
#
# 5️⃣ Feature Engineering
#
# * CompetitionOpenMonths → Calculated the number of months since a competitor store opened, set to 0 for missing or invalid entries.
#
# * IsPromo2Active → A binary flag indicating if a store’s long-term promotion (Promo2) was active during the specific month, based on PromoInterval, Promo2SinceWeek, and Promo2SinceYear.
#
# * SalesPerCustomer → Derived metric showing average customer spending, helping evaluate store-level performance efficiency.
#
# * ZeroSalesWhileOpen → Business rule flag identifying anomalies where sales were 0 despite the store being open.
#
#
#
# ---
#
# 6️⃣ Outlier Treatment
#
# * Extreme values in CompetitionDistance were capped at the 99th percentile to minimize the influence of outliers and maintain stable model behavior.
#
#
#
# ---
#
# 7️⃣ Sorting, Indexing, and Final Formatting
#
# * The dataset was sorted by Store and Date to maintain chronological order.
#
# * Redundant columns like Promo2SinceYear and intermediate helper variables were dropped for clarity.
#
# * Index was reset to ensure a clean, analysis-ready DataFrame.
#
#
#
#
# ---
#
# 💡 Insights Found After Data Wrangling -
#
# 1. Several stores had missing competition details, implying that either the data was unavailable or competition was absent in that region.
#
#
# 2. Some stores have long-standing competitors, indicating that mature markets may exhibit more stable sales.
#
#
# 3. The number of active promotions (Promo2) varies by month, revealing seasonal marketing patterns.
#
#
# 4. Records with zero sales while open highlight potentially unproductive days or data inconsistencies that warrant deeper business review.
#
#
# 5. The derived feature SalesPerCustomer exposed variation in average customer spending — potentially linked to store type, assortment, or location.
#
#
#
#
# ---
#
# ✅ Outcome -
#
# * The dataset is now clean, consistent, and analysis-ready.
#
# * All missing values have been addressed, data types standardized, and new business-relevant features engineered.
#
# * Outliers were treated effectively, ensuring that the data provides a solid foundation for Exploratory Data Analysis (EDA) and predictive modeling.
#
#
#
# ---

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### **Univariate Analysis**

# %% [markdown]
# #### Chart 1 - Distribution of Daily Sales

# %%
# Chart - 1 visualization code

# Features Used - Sales

# ✅ Why this chart is important to include ?
# The entire project aims to predict daily Sales - it’s the dependent variable.
# Before building any model, we must understand how this variable behaves.
# Without this chart, we wouldn’t know if the data is balanced, skewed, or has extreme outliers.

#----------------------------------------------------------------------------------------------------------#

# Setting plot style for cleaner aesthetics
sns.set(style='whitegrid')


# Creating the figure
plt.figure(figsize=(10,6))

# Plotting histogram with KDE curve for smooth density visualization
sns.histplot(
    data=df,
    x='Sales',
    bins=50,                 # Number of bars
    kde=True,                # Add smooth density curve
    color='royalblue',       # Chart color
    alpha=0.7                # Transparency
)

# Adding titles and labels
plt.title('Distribution of Daily Sales', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Sales Amount', fontsize=12)
plt.ylabel('Number of Records', fontsize=12)

# Customizing gridlines and frame
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)  # Removes top and right border for a cleaner look

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# 1,017,209 records
#
# 17% zero sales (closed or failed days).
#
# Mean ≈ 5,774
#
# Median ≈ 5,744 → nearly balanced.
#
# Right skew (0.64) and a few high-sale outliers (up to 41,551).
#
# Suggests mostly steady performance with isolated extreme highs.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a histogram with a KDE curve to observe how daily sales are distributed across all stores.
#
# * This chart helps me identify the shape of the distribution, including skewness, zero-sales days, and extreme high-sale days, which are important for cleaning, modeling, and understanding business trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The histogram shows a moderate right-skewed distribution with most daily sales concentrated between 3,000 and 8,000.
#
# * The mean and median are almost equal (Mean = 5,774, Median = 5,744), suggesting that the majority of stores have a consistent daily sales pattern.
#
# * Around 17% of the records have Sales = 0, which occur mostly when stores are closed or during operational downtimes.
#
# * There are a few extremely high values (above 17,000), showing occasional high-performing days due to major events or promotions.
#
# * Overall, the pattern indicates that sales are mostly stable with occasional spikes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
#  * Actionable signal :
#
#       *  handle zeros carefully:
#
#       * About 17% of records have zero sales.
#
#       * Many are due to stores being closed (Open == 0), but a few are open with zero sales, which should be investigated.
#
#
#  * Modeling improvements:
#
#     * Because of moderate right skew and zeros, I should use log1p(Sales) or RMSLE during modeling to stabilize variance and reduce the impact of extreme values.
#
#
#  * High-performing days:
#
#     * I should identify top sales days (>10k) and analyze if they coincide with promotions or holidays so similar events can be replicated to boost sales in low periods.
#
#
#
#
# ---
#
# **Negative-growth / risk signals & mitigation:**
#
#  * Zero-sales while open:
#
#     * If some stores show zero sales while open, this could point to system or operational issues, leading to missed revenue.
#
#     * These cases need to be analyzed to avoid recurring negative growth.
#
#
#  * Impact of extreme outliers:
#     * A small number of very high-sale days could distort mean sales and model predictions.
#
#     * I have to cap or treat these outliers to ensure fair comparison across stores.

# %% [markdown]
# #### Chart 2 - Distribution of Customers

# %%
# Chart - 2 visualization code

# Features Used - Customers

# Why this chart is important to include ?
# The number of Customers visiting each store per day determines the overall sales potential.
# Analyzing its distribution helps us:
# Understand the footfall variation across stores and days.
# Detect outliers (extremely busy or empty days).
# Identify whether customer traffic is evenly spread or dominated by a few high-volume stores.
# This chart provides crucial insight into customer behavior trends, which can later help the company optimize
# store operations, marketing, and staffing.

#-----------------------------------------------------------------------------------------------------------------------------------#


# Setting the plot style for professional appearance
sns.set(style='whitegrid')

# Creating the figure and defining its size
plt.figure(figsize=(9,5))

# Plotting the box plot to analyze the distribution and outliers
sns.boxplot(
    data=df,
    x='Customers',          # Setting the variable to visualize
    color='mediumseagreen', # Choosing a calm, professional color
    width=0.6,              # Adjusting box width
    fliersize=3             # Adjusting outlier marker size
)

# Adding title and labels
plt.title('Box Plot of Daily Customers', fontsize=15, fontweight='bold', color='darkgreen')
plt.xlabel('Number of Customers per Day', fontsize=12)

# Customizing gridlines for cleaner presentation
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Removing unnecessary chart borders
plt.box(False)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# Median ≈ 630
#
# Mean ≈ 695 → mild right skew.
#
# IQR between 466 - 844 → consistent footfall range.
#
# A few extreme outliers (>1,700) show very high-traffic days.
#
# Mostly stable customer flow with minor anomalies that should be examined.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a boxplot because it helps me visualize the spread, median, and outliers in the number of customers visiting the stores each day.
#
# * It clearly shows the central tendency (median) and the variation in footfall between stores, while also highlighting days or stores with unusually high or low customer counts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The median customer count is around 630, while the mean is slightly higher (~695), which shows a mild right skew — indicating that a few days have exceptionally high customer numbers.
#
# * The interquartile range (IQR) lies between 466 and 844, meaning 50% of the records fall within this range.
#
# * Some extreme outliers can be observed above 1,700 customers, showing rare but very high-traffic days (possibly due to promotions or holidays).
#
# * The lower whisker shows very few days with near-zero customers — likely when the stores were closed.
#
# * Overall, the distribution looks fairly consistent with limited variability across most records.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
# 1. Workforce and resource planning:
#
#     * Since the majority of days have 400-800 customers, I can plan staff schedules, stock replenishment, and customer service levels accordingly.
#
#
# 2. Opportunity analysis for high footfall days:
#
#     * High outlier days (above 1,700 customers) can be analyzed to identify successful events, marketing campaigns, or external factors that drove higher traffic.
#
#     * Learning from these patterns can help boost regular-day sales.
#
#
# 3. Predictable customer trends:
#
#     * The compact box shape indicates a stable customer base, which is good for creating consistent marketing and forecasting models.
#
#
#
#
#
# ---
#
#
# **Negative-growth / risk signals & mitigation:**
#
# 1. Low-customer stores:
#
#     * Some stores have very low median customers, possibly due to poor location or lack of local promotion.
#
#     * I should identify and support these stores with targeted offers or awareness drives.
#
#
# 2. Zero or near-zero customer days:
#
#     * Even though few, these records should be checked for data entry issues or operational closures to prevent misinterpretation during analysis.
#
#
# 3. High outliers:
#
#     * Very large spikes in customer count may distort statistical analysis.
#
#     * I should consider capping or transforming these values during modeling to prevent bias.
#
#
#
#
# ---

# %% [markdown]
# #### Chart 3 - Violin Plot of Competition Distance

# %%
# Chart - 3 visualization code

# Features Used - CompetitionDistance

# ✅ Why this chart is important to include
# This visualization helps us understand how CompetitionDistance is distributed among all Rossmann stores.
# It reveals whether most stores face nearby competitors or if some operate in low-competition areas.
# Understanding this spread helps identify how market competition might influence overall sales and customer reach.


#-----------------------------------------------------------------------------------------------------------------------------#


# Plotting the violin plot to visualize the distribution shape and density
sns.violinplot(
    data=df,
    x='CompetitionDistance',   # Setting the variable to visualize
    color='skyblue',           # Choosing a light color for better readability
    inner='quartile',          # Showing quartiles inside the violin
    cut=0                      # Preventing density from extending beyond data range
)

# Adding title and labels
plt.title('Violin Plot of Competition Distance', fontsize=15, fontweight='bold', color='black')
plt.xlabel('Distance to Nearest Competitor (meters)', fontsize=12)

# Customizing gridlines and chart borders
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# Distribution is heavily right-skewed, most competitors within 2 km.
#
# Median ≈ 1,000 m, upper tail capped at ≈7,400 m.
#
# Few stores are isolated — potential expansion or benchmarking opportunities.
#
# High-competition zones should apply targeted promotions to avoid negative growth.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a violin plot because it helps me visualize both the distribution shape and density of the competition distance.
#
# * Unlike a boxplot, the violin plot gives me a clear idea of how the values are concentrated — for example, whether most stores are close to competitors or located farther away.
#
# * This visualization also makes it easy to identify if the distances are skewed or have multiple peaks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The plot shows a heavily right-skewed distribution, meaning that most stores are located very close to their nearest competitors, while a smaller number of stores are located much farther away.
#
# * The major concentration of competition distance lies below 2,000 meters, showing that many stores have competitors within a short distance.
#
# * The median competition distance is around 1,000 meters, and the IQR (50% of the data) lies approximately between 700-2,500 meters.
#
# * The upper tail extends toward 7,400 meters (after capping at the 99th percentile), indicating a few stores are isolated from competition.
#
# * The density curve is narrow near zero and gradually thins out, confirming that most stores are in competitive zones.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
#  * Strategic advantage for nearby competition:
#
#     * Since most stores have competitors nearby, I can analyze whether close-proximity competition correlates with higher or lower sales.
#
#     * This insight can guide store placement strategies — for instance, whether clustering stores drives demand or cannibalizes sales.
#
#
#  * Market gap identification:
#
#     * The few stores with very high competition distance (>7 km) indicate less saturated regions.
#
#     * These areas can be studied to understand if they maintain steady sales despite limited competition — such zones might represent opportunities for new stores.
#
#
#  * Targeted promotions:
#
#     * Stores with close competition might benefit from localized promotions and loyalty programs to retain customers in high-competition areas.
#
# ---
#
# **Negative-growth / risk signals & mitigation:**
#
#  * High competition density risk:
#
#     * Stores located within < 500 meters of competitors may face price pressure and customer switching, which could lead to declining margins.
#
#     * These stores should be monitored and possibly offered exclusive deals or distinct assortments to stay competitive.
#
#
#  * Uneven competition landscape:
#
#     * Since the distribution is highly skewed, modeling might overemphasize isolated stores.
#
#     * I should scale or transform this variable (e.g., log transform) to normalize its effect and avoid bias in the model.

# %% [markdown]
# #### Chart 4 - Count Plot of Promotion Activity

# %%
# Chart - 4 visualization code

# Features used :- Promo

# ✅ Why this chart is important to include ?
# Promotions have a direct and measurable impact on sales — they drive customer traffic, influence purchasing behavior,
# and affect store profitability.
# By visualizing how frequently promotions occur, we can:
#     * Understand how often Rossmann runs promotions.
#     * Check for data balance (too few or too many promo days).
#     * Prepare for later bivariate analysis, where we’ll compare promotions with sales performance.
#     * This chart helps lay the groundwork for analyzing how promotional frequency affects sales trends.



#------------------------------------------------------------------------------------------------------------------------------------#

# Creating the figure and defining its size
plt.figure(figsize=(7,5))

# Plotting the count plot to show number of promo vs non-promo days
sns.countplot(
    data=df,
    x='Promo',                 # Selecting the 'Promo' variable
    palette=['salmon', 'lightgreen'],  # Choosing contrasting colors for clarity
    edgecolor='black'          # Adding borders to bars for visual definition
)

# Adding value annotations above bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%d', label_type='edge', fontsize=10)

# Adding title and axis labels
plt.title('Count Plot of Promotion Activity', fontsize=15, fontweight='bold', color='darkred')
plt.xlabel('Promotion Active (1 = Yes, 0 = No)', fontsize=12)
plt.ylabel('Count of Days', fontsize=12)

# Customizing grid and borders
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the plot
plt.show()

# %% [markdown]
# **Sumary -**
#
#
# About 37% of days had an active promotion.
#
#
# Non-promo days (63%) dominate but still leave enough promo variety for analysis.
#
#
# Promotions appear well-balanced — neither rare nor overused.
#
#
# Insights from this will help optimize promotion frequency and timing.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a count plot because Promo is a binary categorical variable that represents whether a short-term promotion was active (1) or not (0) on a given day.
#
# * A count plot helps me clearly visualize how frequently promotions were running compared to non-promo days.
#
# * It also gives me an idea of whether the dataset is balanced or imbalanced, which is important for further analysis and modeling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart shows that the number of days with no promotion (Promo = 0) is significantly higher than days with an active promotion (Promo = 1).
#
# * Approximately 63% of the records belong to non-promo days, while only 37% are promo-active days.
#
# * This indicates that promotions are not always running — they are scheduled strategically during certain periods.
#
# * The presence of a decent proportion of promo-active days ensures that there is enough variability in data to study the impact of promotions on sales.
#
# * This balance also suggests that stores frequently rely on promotions as a sales strategy but not excessively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
#  * Promotion planning efficiency:
#
#     * Since promotions are active on about one-third of the days, I can analyze whether those days lead to significant sales lifts in bivariate analysis.
#
#     * This helps me understand the effectiveness of promotional campaigns and fine-tune their duration and timing.
#
#
#  * Balanced data for modeling:
#
#     * Having both promo and non-promo days well represented will make my models learn the true promotional impact effectively.
#
#
#  * Customer engagement strategy:
#
#     * Frequent but not continuous promotions suggest a planned approach to maintaining customer interest while avoiding “promotion fatigue.”
#
#
#
#
# ---
#
# **Negative-growth / risk signals & mitigation:**
#
#  * Limited promo days:
#
#     * Some stores might be underusing promotions. If they are located in competitive regions, fewer promo days could result in lost sales opportunities.
#
#     * I can cross-check such stores with low sales to identify if more promotional support is needed.
#
#
#  * Dependence on promotions:
#
#     * If future analysis shows that sales drop sharply when promotions are inactive, it may mean the store has become too dependent on discounts, which can hurt long-term profit margins.
#
#     * The business should ensure promotions are combined with loyalty strategies rather than price cuts alone.

# %% [markdown]
# #### Chart 5 - Pie Chart of Store Type Distribution

# %%
# Chart - 5 visualization code

# Features used - StoreType

# ✅ Why this chart is important to include
# Different store types cater to different customer segments and have varying sales capacities.
# Visualizing the proportion of store types helps us:
#     Understand Rossmann’s store structure and market distribution.
#     Identify which store type dominates the business.
#     Prepare for later analyses (e.g., which store type drives the most sales).
# This chart provides a strategic overview of Rossmann's retail landscape.


#--------------------------------------------------------------------------------------------------------#


# Setting color palette for professional appearance
colors = sns.color_palette('pastel')

# Creating the figure and defining its size
plt.figure(figsize=(7,7))

# Calculating the count of each store type
store_counts = df['StoreType'].value_counts()

# Plotting the pie chart
plt.pie(
    store_counts,
    labels=store_counts.index,             # Adding store type labels
    autopct='%1.1f%%',                     # Displaying percentage values
    startangle=90,                         # Rotating for better visual balance
    colors=colors,                         # Using soft pastel palette
    wedgeprops={'edgecolor': 'black'},     # Adding edge for clarity
    textprops={'fontsize': 11}
)

# Adding title
plt.title('Distribution of Store Types', fontsize=15, fontweight='bold', color='darkblue')

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# Store Type a = ~56%, Type d = ~22%, Type b = ~10%, Type c = ~12%.
#
# Dataset dominated by Type a stores, which strongly influence sales trends.
#
# Insight helps in resource allocation, model balancing, and expansion strategy.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a pie chart to represent the distribution of store types (StoreType).
#
# * Since this variable has only four categories (a, b, c, d), a pie chart gives a quick and clear visual of how many stores belong to each category and their proportional contribution to the total.
#
# * This helps me understand whether the dataset is dominated by a particular store type or if it is fairly balanced, which is important for sales pattern comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The pie chart shows that Store Type a occupies the largest proportion, covering around 54% of all stores.
#
# * Store Type d follows next with about 30%, while Type b and Type c make up the remaining 15% combined (roughly 13.5% and 1.6%, respectively).
#
# * This clearly shows that Type a stores dominate the dataset, meaning any overall sales trend will likely be influenced heavily by them.
#
# * The presence of multiple store types indicates diversity in business formats — for example, larger supermarkets, smaller local stores, and specialty outlets.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
#  * Understanding dominant store formats:
#
#     * Since Type a stores make up more than half the total, their operational patterns and marketing performance will have the highest influence on total sales.
#
#     * This insight helps me prioritize analysis and optimization strategies for Type a stores first.
#
#
#  * Balanced analysis approach:
#
#     * Even though Type a dominates, other store types (b, c, d) still make up nearly half of the stores combined.
#
#     * I should compare their sales trends separately later to identify which formats perform best under different conditions (e.g., promotions, holidays).
#
#
#  * Expansion insights:
#
#     * If certain smaller store types (like c or b) show high efficiency despite smaller count, it might be a good signal for scalable expansion.
#
#
#
#
# ---
#
# **Negative-growth / risk signals & mitigation:**
#
#  * Type imbalance:
#
#     * Since Type a stores dominate, there is a chance that the model could become biased toward their sales behavior.
#
#     * I should ensure that during modeling, store type effects are properly encoded so that smaller types (b, c, d) are not underrepresented.
#
#
#  * Dependence on one format:
#
#     * Heavy dependence on Type a stores for overall revenue could be risky if those stores underperform.
#
#     * The business should maintain a diverse mix of store types to balance risk across different formats and customer segments.

# %% [markdown]
# #### Chart 6 - Bar Chart of Assortment Type Distribution

# %%
# Chart - 6 visualization code

# Features used -  Assortment

# ✅ Why this chart is important to include
# Assortment type affects customer attraction and sales volume — stores with a wider assortment may appeal
# to a broader customer base but also face higher operating costs.
# Visualizing this helps in understanding:
#   The dominant assortment strategy across Rossmann stores.
#   Whether most stores carry a limited or diverse product range.
#   How product variety could influence customer footfall and revenue.
# This chart is critical for connecting product diversity with store performance in later analysis.

#------------------------------------------------------------------------------------------------------------------------------#


# Setting visual theme
sns.set(style='whitegrid')

# Creating the figure and defining its size
plt.figure(figsize=(8,5))

# Plotting horizontal bar chart for assortment type distribution
sns.countplot(
    data=df,
    y='Assortment',               # Using 'y' for horizontal layout
    order=df['Assortment'].value_counts().index,  # Sorting bars by count
    palette='coolwarm',           # Applying visually distinct color palette
    edgecolor='black'             # Adding border to bars
)

# Adding title and labels
plt.title('Distribution of Assortment Types', fontsize=15, fontweight='bold', color='darkslateblue')
plt.xlabel('Number of Stores', fontsize=12)
plt.ylabel('Assortment Type', fontsize=12)

# Adding count labels beside bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%d', label_type='edge', fontsize=10)

# Customizing grid for clean appearance
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Removing unnecessary borders
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a horizontal bar chart because Assortment is a categorical variable with three levels, and a horizontal bar chart makes the category proportions easy to read (especially with long labels or when I want to add exact percentage labels).
#
# * It clearly shows which assortment types are most common and helps me see the relative footprint of each assortment in the store network.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Counts / proportions (from the dataset):
#
#     1. Assortment a: 593 stores ≈ 53.18%
#
#     2. Assortment c: 513 stores ≈ 46.01%
#
#     3. Assortment b: 9 stores ≈ 0.81%
#
#
# * Interpretation:
#
#     * Most stores follow either basic (a) or extended (c) assortments — together they make up virtually the entire dataset.
#
#     * Assortment b is extremely rare (less than 1%), so it’s effectively negligible for aggregate analysis but may still be interesting if those 9 stores behave unusually.
#
#     * The near parity between a and c (about 53:46) means the company is split between standard and extended formats — this gives a good basis to compare performance across two roughly large groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
#  * Comparative performance analysis:
#
#     * Because a and c together represent almost all stores, I will compare their average sales, margin, and customer metrics to identify whether extended assortments (c) deliver better revenue per customer.
#
#     * If c outperforms a, I can recommend a targeted rollout of c assortments in regions with similar demographics.
#
#
#  * Resource & merchandising planning:
#
#     * Knowing the split helps me decide inventory mixes and promotional strategies tailored to each assortment type.
#
#
#  * Investigate rare cases (b):
#
#     * I will inspect those 9 b stores individually — they might be special pilot stores or data-entry anomalies; if they perform very differently, they can yield actionable lessons.
#
#
# ---
#
# **Negative-growth / risk signals & mitigation:**
#
#  * Risk of bias in aggregate metrics:
#
#     * Since a is slightly dominant, overall averages will be influenced by a stores; I must ensure store-type stratification when reporting metrics or training models so c behavior is not washed out.
#
#
#  * Neglecting tiny segments (b):
#
#     * While b is negligible numerically, if those stores show consistent underperformance it could indicate a format that doesn't work; conversely, if they overperform, they may be candidates for targeted scaling. I should not ignore them outright.

# %% [markdown]
# #### Chart 7 - Bar Chart of Day of Week Distribution

# %%
# Chart - 7 visualization code

# Features used - DayOfWeek

# ✅ Why this chart is important to include
# This visualization helps us:
#   Identify which days stores are most active.
#   Detect patterns like reduced store activity on Sundays or peak activity midweek.
#   Prepare for later bivariate analysis to see how sales vary across weekdays.
#   This chart adds valuable context about operational rhythm and customer behavior —
#   critical for both forecasting and staffing decisions.


#-------------------------------------------------------------------------------------------------#


# Creating the figure and defining its size
plt.figure(figsize=(9,5))

# Plotting bar chart showing store activity by day of the week
sns.countplot(
    data=df,
    x='DayOfWeek',                       # Selecting variable to visualize
    palette='viridis',                   # Applying color gradient
    edgecolor='black'                    # Adding border for clear separation
)

# Adding title and labels
plt.title('Distribution of Day of Week', fontsize=15, fontweight='bold', color='darkgreen')
plt.xlabel('Day of the Week (1=Mon, 7=Sun)', fontsize=12)
plt.ylabel('Number of Records', fontsize=12)

# Adding count labels on each bar
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%d', label_type='edge', fontsize=10)

# Customizing gridlines and removing borders
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# Day-of-week counts are nearly equal across 1–7 in the wrangled dataset (no big Sunday dip).
#
# This balance supports unbiased weekday-level analysis; next I should run Sales vs DayOfWeek to inspect actual sales differences by weekday.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a countplot because DayOfWeek is a discrete categorical variable (1 = Monday, 7 = Sunday).
#
# * A countplot helps me check whether the dataset has even representation across weekdays, which is important for fair time-series analysis and for avoiding weekday bias in modeling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The countplot (on the wrangled dataset) shows that all seven weekdays have almost identical record counts — there is no pronounced dip on any single weekday.
#
# * This means the dataset is evenly balanced across weekdays, so daily-seasonality patterns won't be biased by unequal day counts.
#
# * The near-uniformity arises because the dataset contains many stores across many dates; therefore, the total number of store-day records per weekday evens out.
#
# * Practically, this tells me the data collection is consistent and there isn't systematic missingness for any particular weekday.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
#  * Confidence in weekday analysis:
#
#     * Because day counts are balanced, I can compare sales across weekdays without worrying that differences are caused by record imbalance — that makes weekday-level inferences more reliable.
#
#
# * Cleaner modeling:
#
#     * I can include DayOfWeek as a feature in models without applying special weighting for under/over-sampled days. This simplifies preprocessing and reduces the risk of introducing sampling bias.
#
#
# * Operational planning:
#
#     * Since there is no underrepresented weekday, operational recommendations (staffing, promotions) drawn from weekday-level analysis will be based on equally-sampled evidence.
#
#
#
#
# ---
#
# **Negative-growth / risk signals & mitigation:**
#
#  * Watch for hidden operational differences:
#
#     * Even though counts are balanced, sales behavior can still differ by day (e.g., Monday vs Saturday). Balanced counts simply make those differences trustworthy — I still need to analyze Sales vs DayOfWeek (boxplot/violin) to detect performance gaps.
#
#
#  * Model caution for per-store trends:
#
#     * Balance at the aggregate level does not guarantee balance per-store. I should verify store-level weekday coverage for stores with sparse records before making store-level operational decisions.

# %% [markdown]
# #### Chart 8 - Count Plot of Store Opening Status

# %%
# Chart - 8 visualization code

# Features Used - Open


# ✅ Why this chart is important to include
# This chart helps identify:
#   The proportion of open vs closed days across all stores.
#   Whether missing or irregular patterns exist in store activity.
#   The operational consistency of the dataset (useful for model reliability).
# It’s a straightforward but crucial check to ensure that most data entries represent real,
# open-store scenarios contributing to actual sales.

#-------------------------------------------------------------------------------------------------#


# Creating the figure and setting its size
plt.figure(figsize=(7,5))

# Plotting count plot for store open vs closed days
sns.countplot(
    data=df,
    x='Open',                        # Selecting the variable to visualize
    palette=['tomato', 'mediumseagreen'],  # Assigning contrasting colors
    edgecolor='black'                  # Adding bar borders for definition
)

# Adding value annotations above bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%d', label_type='edge', fontsize=10)

# Adding title and axis labels
plt.title('Distribution of Store Opening Status', fontsize=15, fontweight='bold', color='darkred')
plt.xlabel('Store Open Status (1 = Open, 0 = Closed)', fontsize=12)
plt.ylabel('Count of Records', fontsize=12)

# Customizing grid and removing chart borders
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# Most records correspond to stores being open (1) — indicating normal operations and consistent data.
#
# Closure days (0) are rare and should be treated separately in modeling to avoid skewing sales predictions.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a countplot for this variable because Open is a binary categorical column (0/1).
#
# * The countplot clearly shows how many records correspond to open vs. closed stores, helping me understand if the dataset has a balanced representation of both.
#
# * This is also important for verifying whether sales = 0 corresponds to store closure or not — a crucial business sanity check.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart shows that the number of records where stores are open (1) is much higher compared to when they are closed (0).
#
# * This is expected because stores are open most days, and closure happens only on holidays or maintenance days.
#
# * This imbalance confirms that sales = 0 for closed stores is logical and not missing data.
#
# * It also indicates that most of the dataset represents normal business operation days — which is good for model learning.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
# * The high frequency of open days means the model will have sufficient data to learn real sales patterns rather than being biased by closure days.
#
# * This check ensures data validity — I can confidently remove or separately handle closed days for accurate revenue forecasting.
#
# * Understanding the distribution also helps in capacity planning — fewer closed days means better operational utilization.
#
# ---
#
# **Negative-growth / risk signals & mitigation:**
#
# * If the dataset had shown a significant number of closed days, that would have hinted at operational inefficiencies or maintenance issues — leading to revenue loss.
#
# * Fortunately, that's not the case here. Still, if some stores have unusually high closure rates, I should analyze those stores individually for possible logistical or staffing problems.

# %% [markdown]
# #### Chart 9 - Donut Chart of Promo2 (Long-Term Promotion Participation)

# %%
# Chart - 9 visualization code

# Features used - Promo2


# ✅ Why this chart is important to include ?
# The Promo2 feature indicates whether a store is enrolled in Rossmann’s long-term continuous promotion scheme.
# Visualizing this helps us:
#   Understand what portion of stores are part of ongoing promotions.
#   Identify how widespread the Promo2 program is within the business.
#   Prepare for later bivariate or multivariate analysis to compare sales behavior
#     between Promo2 and non-Promo2 stores.
#   It connects directly to strategic marketing and sales forecasting.


#------------------------------------------------------------------------------------------------------#



# Setting color palette
colors = sns.color_palette(['#66b3ff', '#ff9999'])  # Blue for active, red for not participating

# Creating count of Promo2 values
promo2_counts = df['Promo2'].value_counts()

# Creating the figure and defining its size
plt.figure(figsize=(7,7))

# Plotting the donut (pie) chart
wedges, texts, autotexts = plt.pie(
    promo2_counts,
    labels=['Participating', 'Not Participating'],
    autopct='%1.1f%%',               # Showing percentage
    startangle=90,                   # Rotating for better balance
    colors=colors,
    wedgeprops={'edgecolor': 'black', 'linewidth': 1},
    textprops={'fontsize': 11}
)

# Creating the white circle in the center to form a donut shape
centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Adding title
plt.title('Distribution of Promo2 (Long-Term Promotion Participation)', fontsize=15, fontweight='bold', color='darkblue')

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# Promo2 adoption is 50.1% vs 49.9% non-adopters — nearly balanced.
#
#
# This balance enables robust comparative analysis; next steps: test Promo2's impact on sales and customer metrics.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a donut chart because Promo2 is a binary categorical variable (1 = participating in long-term promotions, 0 = not).
#
# * The donut visually shows the proportion of stores in each group and makes it easy to spot if Promo2 is broadly adopted or limited to a subset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The dataset shows nearly half-and-half split between stores that participate in the long-term promotion program and those that do not.
#
# * This balanced adoption means I can fairly compare the two groups without worrying about severe class imbalance.
#
# * It also indicates the program is mature enough to be widespread, not just a niche pilot.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
# * Fair comparison for impact analysis:
#
#     * Since adoption is about 50:50, I can compare sales, customers, and retention between Promo2 and non-Promo2 stores with good statistical power.
#
#     * I should run Sales vs Promo2 and SalesPerCustomer vs Promo2 next to quantify uplift and ROI.
#
#
# * Segmentation & rollout strategy:
#
#     * If Promo2 is found to increase average sales, the near-equal split suggests a clear opportunity to scale the program to the remaining stores where it's not active.
#
#     * If the program is ineffective, I can focus on improving content/timing rather than rollout decisions.
#
#
#
# ---
#
#
# **Negative-growth / risk signals & mitigation:**
#
#
# * Risk of promotional dependency:
#
#     * If Promo2 stores rely on discounts to sustain sales, expansion might erode margins. I should check profitability, not only revenue uplift.
#
#
# * Heterogeneous effect risk:
#
#     * Promo2 may perform differently across store types or regions. I must analyze interaction effects (e.g., Promo2 × StoreType) before making wide rollout decisions.

# %% [markdown]
# #### Chart 10 - Area Plot of Monthly Distribution.

# %%
# Chart - 10 visualization code


# Features Used - Month

# ✅ Why this chart is important to include
# The Month column captures the temporal dimension of the data —
# which is essential for understanding seasonality in retail.
# Analyzing it helps identify:
#     Which months are busiest, indicating peak sales or promotion periods.
#     Low-activity months, which might need marketing push or inventory optimization.
#     Any missing or uneven data distribution across months (important for modeling).
#     The area plot adds visual depth, showing both trends and magnitudes over time,
#         perfect for highlighting seasonal variation.



#------------------------------------------------------------------------------------------------------#



# Creating a series of month-wise counts and ensuring months 1..12 are present
month_counts = df['Month'].value_counts().sort_index()
month_counts = month_counts.reindex(range(1,13), fill_value=0)  # Ensuring complete month index

# Creating the figure and defining its size
plt.figure(figsize=(10,6))

# Plotting the area chart using fill_between (x, y1)
# Passing x and y1 as positional arguments to satisfy matplotlib API
plt.fill_between(
    month_counts.index,            # x: month numbers 1..12
    month_counts.values,           # y1: counts for each month
    color='lightcoral',            # Choosing a soft red tone for retail theme
    alpha=0.7,                     # Adding transparency for aesthetic look
    linewidth=2,
    edgecolor='darkred'
)

# Overlaying a line for clearer trend visualization
plt.plot(
    month_counts.index,
    month_counts.values,
    marker='o',
    color='darkred',
    linewidth=1.8
)

# Adding title and axis labels
plt.title('Monthly Distribution of Records', fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Month (1 = Jan, 12 = Dec)', fontsize=12)
plt.ylabel('Number of Records', fontsize=12)

# Customizing ticks to show month numbers
plt.xticks(ticks=np.arange(1,13), labels=[str(m) for m in range(1,13)])

# Customizing grid and removing top/right borders
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the plot
plt.show()

# %% [markdown]
# Data volume is highest in Jan-Jun (About 100K records each) and drops sharply after July (~60-65K).
#
#
# This may reflect seasonality or partial data coverage and should be examined before modeling.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used an area plot because it gives a clear and continuous visualization of how the number of records varies across different months.
#
# * Since Month is a time-based feature, an area plot helps me spot seasonal activity patterns and check whether any month has missing or reduced data.
#
# * It is also more visually appealing than a simple countplot for showing monthly volume trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Exact month-wise counts (1 = Jan … 12 = Dec):
#
# Jan = 103,694   Feb = 93,660     Mar = 103,695
#
# Apr = 100,350   May = 103,695    Jun = 100,350
#
# Jul = 98,115    Aug = 63,550     Sep = 61,500
#
# Oct = 63,550    Nov = 61,500     Dec = 63,550
#
#
# * The data shows that the first half of the year (Jan - Jun) has consistently higher counts (About 100K records each) compared to the second half (Aug - Dec) (~60-64K records each).
#
# * This indicates that sales activity or data coverage is denser in the first half of the year.
#
# * Months 8 to 12 show a notable drop, which could be due to partial data capture, fewer open stores, or a natural business slowdown later in the year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
# * Seasonality awareness:
#
#     * The clear difference between the first and second half suggests seasonal variation in operations or customer flow.
#
#     * I can use this insight for better forecasting and resource planning, ensuring stock and staff allocation matches demand cycles.
#
#
#  * Data quality check:
#
#     * The even coverage in Jan-Jun confirms that the dataset is robust enough for modeling that period, helping ensure more accurate predictions for months with complete data.
#
#
# --
#
# **Negative-growth / risk signals & mitigation:**
#
#
# * The sharp decline from August onward might point to missing or incomplete data rather than true business downturns.
#
# * Before modeling, I should validate whether these months have fewer active stores or truncated data collection.
#
# * If the drop is genuine, the business can introduce targeted promotions or seasonal campaigns in late-year months to balance annual revenue.

# %% [markdown]
# #### Chart 11 -  Bar Chart of Yearly Distribution

# %%
# Chart - 11 visualization code

# Features Used - Year

# ✅ Why this chart is important to include
# Visualizing the Year variable helps:
#   Confirm that data spans multiple years and check for imbalanced coverage.
#   Reveal if certain years had more store activity or data collection (possibly due to expansion).
#   Prepare for time-based modeling by understanding how many training samples come from each period.
#   From a business perspective, it highlights growth or contraction patterns in store operations.

#------------------------------------------------------------------------------------------------------#

# Creating figure and defining its size
plt.figure(figsize=(8,5))

# Creating a year-wise count plot to see record distribution by year
sns.countplot(
    data=df,
    x='Year',                        # Selecting the 'Year' variable
    palette='coolwarm',              # Using balanced warm-cool color scheme
    edgecolor='black'                # Adding black borders for clear separation
)

# Adding title and axis labels
plt.title('Yearly Distribution of Records', fontsize=15, fontweight='bold', color='darkslateblue')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Records', fontsize=12)

# Adding count labels on each bar
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%d', label_type='edge', fontsize=10)

# Customizing gridlines and removing borders
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
#
# Yearly data shows a steady decline from 2013 → 2015 (406 K → 374 K → 236 K).
#
# This suggests either partial 2015 data or reduced store coverage — important to verify before modeling trends.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a countplot because Year is a categorical time-based feature and a countplot makes it simple to compare how many records are available for each year.
#
# * This helps me understand the data coverage over multiple years and check if there’s any imbalance that could influence long-term trend analysis or modeling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Exact year-wise counts:
#
#       2013 → 406,974 records
#
#       2014 → 373,855 records
#
#       2015 → 236,380 records
#
#
# * The chart clearly shows that the data volume decreases steadily over the years.
#
# * 2013 has the highest number of records, followed by 2014, and then a sharp drop in 2015.
#
# * This pattern indicates that the data might not cover the full year of 2015 — possibly ending mid-year.
#
# * The gradual reduction from 2013 to 2015 suggests either fewer stores recorded, data truncation, or a decline in activity in the later period.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
# * Improved modeling awareness:
#
#     * Knowing that 2015 has fewer records allows me to adjust my analysis window or weight older years appropriately so models aren't biased by underrepresented recent data.
#
#
#  * Operational benchmarking:
#
#     * 2013 can serve as a baseline year with full activity coverage.
#
#     * Comparing 2013-2015 helps identify long-term performance trends and the effect of promotions, competition, or seasonal shifts.
#
#
# ---
#
#
# **Negative-growth / risk signals & mitigation:**
#
#  * The decline in data volume after 2013 may mislead trend analysis if treated as a pure sales downturn.
#
#  * If the 2015 drop is due to incomplete data capture, not actual business decline, it must be handled carefully in forecasting — for example, excluding incomplete months or normalizing records.
#
#  * Misinterpreting this reduction as negative growth could lead to wrong strategic conclusions, so ensuring data completeness is crucial.

# %% [markdown]
# #### Chart 12 - PromoInterval (Months When Long-Term Promotions Are Active)

# %%
# Chart - 12 visualization code


# Features Used - PromoInterval

# ✅ Why this chart is important to include ?
# The PromoInterval column defines which months (e.g., "Feb,May,Aug,Nov") a store’s long-term
# promotion (Promo2) is active.
# Analyzing this helps Rossmann understand:
#   Which months are most commonly used for recurring promotions.
#   Whether promotional activity is evenly spread or clustered in specific months.
#   Seasonal promotional strategy — for instance, heavier promotions in mid-year or near holidays.
#   This chart provides clear visibility into Rossmann’s annual promotion schedule.


#--------------------------------------------------------------------------------------------------------#

# Keeping only non-null PromoInterval values
promo_df = df.dropna(subset=['PromoInterval']).copy()

# Splitting comma-separated months into lists efficiently
promo_df['PromoInterval'] = promo_df['PromoInterval'].str.split(',')

# Using explode() to create one row per month (much faster than sum())
promo_month_counts = (
    promo_df['PromoInterval']
    .explode()                              # Expanding month list into separate rows
    .value_counts()                         # Counting occurrences of each month
    .sort_index()                           # Sorting months alphabetically
)

# Creating the figure and defining its size
plt.figure(figsize=(9,5))

# Plotting bar chart for frequency of months in PromoInterval
sns.barplot(
    x=promo_month_counts.index,
    y=promo_month_counts.values,
    palette='crest',
    edgecolor='black'
)

# Adding title and labels
plt.title('Frequency of Months in PromoInterval', fontsize=15, fontweight='bold', color='darkgreen')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Number of Stores Running Promotions', fontsize=12)

# Adding count labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%d', label_type='edge', fontsize=10)

# Customizing grid and borders
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# PromoInterval months Jan, Apr, Jul, Oct (≈ 293 K each) dominate — reflecting Rossmann's quarterly promotion cycle.
#
#
# Around 508 K records have “No PromoInterval”, meaning no long-term promo was active for those periods.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a countplot because PromoInterval is a categorical column that lists the months in which recurring, long-term promotions (Promo2) are active.
#
# * The countplot helps me clearly visualize which months are most frequently used for continuous promotions, giving an overview of the marketing calendar pattern adopted by Rossmann stores.
#
# * This insight is valuable for identifying promotional clusters and understanding if the campaigns are evenly spread or concentrated in certain months.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart shows that the months January, April, July, and October have the highest frequency (≈ 293 K each) — these are the four most common intervals for recurring promotions.
#
# * This confirms that Rossmann’s long-term promotions follow a quarterly pattern, launched roughly every three months.
#
# * The large count under “None” (≈ 508 K) indicates that many records correspond to stores or periods without any long-term promo active, which aligns with about half the stores not participating in Promo2.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
# * Marketing alignment:
#
#     * The clear quarterly peaks (Jan-Apr-Jul-Oct) show a structured promotion strategy.
#
#     * Marketing and inventory teams can prepare in advance for these months with stock build-ups and staff scheduling.
#
#
# * Performance tracking:
#
#     * Knowing the typical promotion months allows comparison of sales uplift in promo vs non-promo months to quantify promotion effectiveness.
#
#
# * Opportunity for fine-tuning:
#
#     * If promotions show diminishing impact in repeated quarters, the company can test different months or product mixes to maintain customer excitement.
#
#
# ---
#
#
# **Negative-growth / risk signals & mitigation:**
#
#
# * The “None” category being the largest shows that many stores are missing out on promotional visibility.
#
# * If sales are significantly lower in “None” months, that represents a lost revenue opportunity.
#
#
# * Repetition fatigue:
#
#     * Quarterly repetition may reduce novelty; varying timing or themes could prevent customer desensitization.

# %% [markdown]
# #### Chart 13 - Distribution of Sales per Customer

# %%
# Chart - 13 visualization code

# Features Used - SalesPerCustomer

# ✅ Why this chart is important to include
# The SalesPerCustomer feature measures store efficiency and customer spending behavior —
# it tells how much each customer spends on average when visiting a store.
# Analyzing it helps us:
#   Identify high-value stores or customers.
#   Detect spending variation across stores or promotions.
#   Understand whether sales growth comes from more customers or higher spend per visit.
#   It’s one of the most actionable insights for business decision-making.


#--------------------------------------------------------------------------------------------------#


# Creating the figure and defining its size
plt.figure(figsize=(10,6))

# Plotting histogram with KDE for Sales per Customer
sns.histplot(
    data=df,
    x='SalesPerCustomer',
    bins=50,
    kde=True,
    color='mediumseagreen',
    alpha=0.7
)

# Adding title and axis labels
plt.title('Distribution of Sales per Customer', fontsize=16, fontweight='bold', color='darkgreen')
plt.xlabel('Average Sales per Customer', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Customizing grid and removing unnecessary borders
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * SalesPerCustomer shows a right-skewed distribution, with most values between 5-12 and few high-value outliers.
#
# * Indicates stable spending patterns with occasional premium purchases — ideal for targeted marketing and revenue optimization.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a histogram with KDE (Kernel Density Estimate) because it effectively displays the distribution of the continuous numeric feature SalesPerCustomer.
#
# * This chart helps me understand how much revenue each customer typically generates on average.
#
# * The combination of histogram and KDE helps to identify central tendencies, spread, and potential outliers in customer spending behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The distribution is highly right-skewed — most values are concentrated between 5 and 12, with a sharp peak near 8-9, indicating that this is the typical spending range per customer.
#
# * There is a small spike near 0, representing records where customers made minimal purchases or possibly where the store had zero or very low sales.
#
# * A few outliers can be seen beyond 20–60, but they are extremely rare, suggesting occasional high-value purchase days at some stores.
#
# * Overall, the distribution shows that most customers spend within a stable mid-range, but a small portion of high-spending customers could significantly impact total sales.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
# * Customer segmentation:
#
#     * The main cluster around 8 - 10 suggests a core customer base with predictable spending behavior.
#
#     * These insights can be used to design targeted promotions — for example, encourage frequent moderate spenders to increase their basket size.
#
#
# * Identifying premium customers:
#
#     * The long right tail represents high-spending customers.
#
#     * The company can introduce loyalty or premium programs to retain these customers and enhance their lifetime value.
#
#
# * Modeling advantage:
#
#     * The skewed shape supports applying a log transformation on SalesPerCustomer before modeling to stabilize variance and improve predictive accuracy.
#
#
#
#
# ---
#
# **Negative-growth / risk signals & mitigation:**
#
#
# * The small cluster near zero could indicate unproductive store days or low-traffic periods, which may reduce overall profitability.
#
# * I need to verify if those zero or near-zero points align with operational anomalies (e.g., staff shortages, incorrect sales logging).
#
# * Ignoring these cases might bias demand forecasts downward, so it's better to handle or investigate them separately.

# %% [markdown]
# #### Chart 14 - Zero Sales While Open

# %%
# Chart - 14 visualization code


# Features Used - ZeroSalesWhleOpen


# ✅ Why this chart is important to include
# This chart highlights how often stores were open but recorded zero sales —
# an indicator of data issues or operational inefficiency.
# It’s an excellent inclusion because it bridges the gap between data validation
# and business performance, helping Rossmann ensure model accuracy and store productivity.



#------------------------------------------------------------------------------------------------------#


# Calculating total count of such occurrences
zero_sales_counts = df['ZeroSalesWhileOpen'].value_counts()

# Setting visual theme
sns.set(style='whitegrid')

# Creating figure and defining size
plt.figure(figsize=(7,6))

# Plotting a bar chart to show count of zero sales occurrences
sns.barplot(
    x=zero_sales_counts.index.map({0: 'No', 1: 'Yes'}),
    y=zero_sales_counts.values,
    palette=['mediumseagreen', 'salmon'],
    edgecolor='black'
)

# Adding title and labels
plt.title('Occurrences of Zero Sales While Store Was Open', fontsize=15, fontweight='bold', color='darkred')
plt.xlabel('Zero Sales While Open', fontsize=12)
plt.ylabel('Number of Records', fontsize=12)

# Adding data labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%d', label_type='edge', fontsize=10)

# Customizing gridlines and removing top/right spines
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# Out of ~1 million records, only 54 cases (≈0.005%) show stores open but with zero sales — confirming excellent data integrity and very few anomalies.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a barplot because ZeroSalesWhileOpen is a binary categorical column (0 or 1).
#
# * This chart helps me verify whether there are any instances where stores were open but recorded zero sales, which can indicate operational anomalies or data entry issues.
#
# * It's an important step to validate the accuracy of the data before modeling — ensuring that zero sales only occur when stores are closed.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Exact value counts:
#
#       0 → 1,017,155 records (stores open and generated sales normally)
#
#       1 → 54 records (stores open but with zero sales)
#
#
# * The chart shows that the vast majority (≈ 99.99%) of records are normal, meaning stores reported sales when open.
#
# * Only 54 records have zero sales even though the stores were open — this is an extremely small fraction, practically negligible compared to total data volume.
#
# * These few cases might represent data logging errors, returns offsetting sales, or rare operational issues.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
# * Data quality validation:
#
#     * This check confirms that the dataset is highly reliable, as almost all records align with expected business logic (open stores have sales).
#
#
# * Operational diagnostics:
#
#     * The few exceptions (54 cases) can be investigated to find potential causes — POS system issues, refund-only days, or incorrect reporting.
#
#     * Identifying and fixing such inconsistencies improves future data accuracy and decision reliability.
#
#
# * Modeling advantage:
#
#     * Knowing that zeros are rare ensures that zero values in the Sales column truly represent closed stores, simplifying filtering before model training.
#
#
#
#
# ---
#
# **Negative-growth / risk signals & mitigation:**
#
# * Even though minimal, these 54 instances may point to lost revenue opportunities if they represent real business days with operational failures.
#
# * Continuous monitoring can prevent such cases from expanding, ensuring smooth sales recording and accurate forecasting in production systems.

# %% [markdown]
# #### Chart 15 - Distribution of Competition Open Months

# %%
# Chart - 15 visualization code


# Features Used - CompetitionOpenMonths


# ✅ Why this chart is important to include
# The CompetitionOpenMonths feature shows how long each store’s competitor has been active near it.
# Analyzing this helps us:
#   Understand how competitive exposure varies across stores.
#   Identify whether most stores are newly exposed or have been long-term competitors.
#   Anticipate how competition affects store performance over time.
#   It’s an important variable for understanding market saturation and competitive pressure.


#------------------------------------------------------------------------------------------------------#


# Setting the visual theme
sns.set(style='whitegrid')

# Creating the figure and defining its size
plt.figure(figsize=(10,6))

# Plotting histogram with KDE
sns.histplot(
    data=df,
    x='CompetitionOpenMonths',
    bins=40,
    kde=True,
    color='royalblue',
    alpha=0.7
)

# Adding title and labels
plt.title('Distribution of Competition Open Months', fontsize=16, fontweight='bold', color='navy')
plt.xlabel('Months Since Competition Opened', fontsize=12)
plt.ylabel('Number of Records', fontsize=12)

# Customizing grid and frame
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The CompetitionOpenMonths feature is heavily right-skewed, with most stores having 0–10 months of competition and very few beyond 150 months.
#
# * Indicates that Rossmann mostly operates in newly competitive environments, with limited long-term rivalry.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a histogram with KDE because CompetitionOpenMonths is a continuous numeric feature that represents the number of months since a store’s nearest competitor opened.
#
# * This chart helps visualize how long competitors have been active across all stores and whether most stores face new or established competition.
#
# * It is crucial for understanding the competitive landscape and how long-term competition might influence store sales.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The distribution is highly right-skewed, with a sharp peak near 0-10 months.
#
# * A large number of records cluster around 0, meaning many stores either have very recent competitors or no competition at all (0 indicates missing or new competition).
#
# * As months increase, the frequency drops significantly — very few stores have had competition for more than 100 months.
#
# * Beyond 200 months, the records are extremely rare, showing that long-term competition presence is uncommon.
#
# * This pattern suggests that Rossmann continuously faces emerging competition rather than long-standing rivals in most markets.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
# * Competitive readiness:
#
#     * The fact that most competitors are new gives Rossmann a first-mover advantage in many areas.
#
#     * Stores can act proactively — e.g., intensifying local marketing or customer loyalty programs before new competitors gain traction.
#
#
# * Strategic modeling:
#
#     * CompetitionOpenMonths can be a strong feature in predictive models — it captures how competition age affects sales.
#
#     * Early-stage competition (low months) may have smaller impact compared to mature competitors.
#
#
# * Regional planning:
#
#     * The data supports targeted competitive response strategies — newer competitors require defensive campaigns, while long-term competition may require differentiation strategies.
#
#
#
#
# ---
#
# **Negative-growth / risk signals & mitigation:**
#
# * The high number of zeros may indicate data gaps for stores where competition details weren't entered.
#
# * Such cases should be flagged (via CompetitionOpenSince_NA) to prevent misleading interpretation in modeling.
#
#
# * Stores with long-established competition (>150 months) might suffer from market saturation, requiring innovation or pricing adjustments to maintain sales.

# %% [markdown]
# #### Chart 16 - Distribution of Months Having Active Promo2

# %%
# Chart - 16 visualization code

# Features Used - IsPromo2Active


# ✅ Why this chart is important to include
# it’s important to understand dataset balance —  i.e., whether most stores usually have Promo2 running or not.
# This information does matter when building models or interpreting results,
# because an imbalanced distribution might reduce the effect of Promo2 during training.


#------------------------------------------------------------------------------------------------------#


# 🎨 Setting the visual style
plt.figure(figsize=(7,5))
sns.set(style="whitegrid")

# 📊 Creating a bar plot to visualize the count of stores with and without active Promo2
sns.countplot(x='IsPromo2Active', data=df, palette='Set2')

# 🏷️ Adding chart title and labels
plt.title('Distribution of Long-term Promotion Activity (IsPromo2Active)', fontsize=14, fontweight='bold')
plt.xlabel('Is Promo2 Active?', fontsize=12)
plt.ylabel('Number of Records', fontsize=12)

# 🧾 Annotating bar values
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%d', label_type='edge', fontsize=10)

# 🖼️ Displaying the plot
plt.tight_layout()
plt.show()

# %%
df['IsPromo2Active'].value_counts()
# Out:
# IsPromo2Active
# 0    880117
# 1    137092
# Name: count, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A bar chart is chosen because the variable ZeroSalesWhileOpen is binary (Yes/No).
#
# * This makes a bar chart ideal for showing how often such cases occur in the dataset.
#
# * It clearly visualizes the frequency of potential anomalies — stores open but not generating sales.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart shows that while most store records reflect sales during open hours, there are a few cases where the store was open but reported zero sales.
# * These records are rare but significant, as they could indicate:
#
#     * Data entry errors
#
#     * System outages
#
#     * Or genuinely unproductive business days.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes — this insight has strong positive business implications.
# Identifying and addressing “zero sales while open” cases ensures clean, accurate data for future modeling, leading to more reliable forecasts.
#
# * Operationally, Rossmann can investigate these instances to prevent future inefficiencies, improving store uptime and staff productivity.
#
# * If ignored, such cases could mislead analysis or mask revenue loss, leading to negative growth.

# %% [markdown]
# ### **Bivariate Analysis**

# %% [markdown]
# #### Part 1 - Analysing the Core Business KPI - Sales

# %% [markdown]
# ##### Chart 17 - Promo vs Sales

# %%
# Chart - 17 visualization code

# Features Used - Promo, Sales

# ✅ Why this chart is important to include?
# I am creating this chart to visually compare sales performance between promotional and non-promotional days.
# This helps in understanding how promotions influence daily sales levels and overall business revenue patterns.
# It also helps confirm if promotional campaigns are truly effective or just causing short-term spikes.

# ---------------------------------------------------------------------------------------------------------- #

# Setting visual style for professional presentation
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# Plotting the boxplot to compare sales distribution between promo and non-promo days
sns.boxplot(
    data=df,
    x='Promo',
    y='Sales',
    palette={'0': '#2E86C1', '1': '#E67E22'},
    showfliers=False
)

# Adding median annotations
medians = df.groupby('Promo')['Sales'].median().values
for i, median in enumerate(medians):
    plt.text(i, median + 300, f"Median = {int(median):,}",
             ha='center', fontweight='semibold', color='black')

# Adding titles and labels
plt.title('Distribution of Sales during Promo vs Non-Promo Days', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Promo (0 = No Promo, 1 = Promo)', fontsize=12)
plt.ylabel('Sales Amount', fontsize=12)

# Customizing gridlines and layout
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# 📄 Summary -
#
# Total Records: 1,017,209
#
# Promo Days: 388,080 (≈ 38.2%)
#
# Non-Promo Days: 629,129 (≈ 61.8%)
#
# Median (Promo = 0): 4,622
#
# Median (Promo = 1): 7,553 → ≈ +63.4% uplift
#
# Mean (Promo = 0): 4,406
#
# Mean (Promo = 1): 7,991 → ≈ +81.4% uplift
#
# The chart clearly shows that stores experience a substantial increase in sales during promotion periods.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a boxplot because it visually represents both the median and spread of sales values between promo and non-promo days.
#
# * It helps me see if promotions truly drive higher sales and whether the sales boost is consistent or highly variable.
#
# * Since promotions are key business levers, analyzing their impact on sales distribution is critical for campaign strategy and revenue forecasting.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * There is a clear and strong uplift in sales during promo periods — the median sales increased by 63% and mean sales increased by 81% compared to non-promo days.
#
# * The IQR (spread) during promo days is wider, indicating that some promotions perform exceptionally well while others have moderate results.
#
# * The median sales during non-promo days (₹4,622) are considerably lower than during promo days (₹7,553), confirming that promotions generally help increase sales volume.
#
# * Overall, the chart confirms that promotions have a positive impact on sales performance but with variable outcomes across stores or time periods.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impacts / What to Do:**
#
# * The data clearly shows that promotions significantly boost sales.
# → I can recommend continuing short-term promotional campaigns as they yield tangible benefits.
#
# * Since variance is high, I should focus on identifying which types of promos, months, or store types give the strongest lift and standardize those campaigns.
#
# * Promotions can also be strategically used during slower months to maintain stable cash flow.
#
# * Including Promo as a feature in modeling will improve forecast accuracy and help the business estimate campaign effects.
#
#
# ---
#
#
# **Negative-Growth / Risk Signals & Mitigation:**
#
# * The large spread in promo-day sales indicates inconsistent promo performance — some may underperform.
# → This requires better targeting, monitoring, and post-analysis to avoid wasted marketing costs.
#
# * Over-reliance on promotions can cause customer habituation (waiting for discounts) and margin erosion.
# → To mitigate this, balance promotional intensity with regular pricing strategies.

# %% [markdown]
# ##### Chart 18 - IsPromo2Active vs Sales

# %%
# Chart - 18 visualization code

# Features Used - IsPromo2Active, Sales

# ✅ Why this chart is important to include?
# I am creating this chart to understand how long-term promotions (Promo2) affect daily sales.
# This helps me identify whether stores running continuous or recurring promotions maintain higher sales levels.
# Including this chart is important to compare the effectiveness of short-term (Promo) vs long-term (Promo2) promotions.

# ---------------------------------------------------------------------------------------------------------- #

# Setting visual style for consistent aesthetics
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# Plotting the boxplot for Sales distribution based on Promo2 activity
sns.boxplot(
    data=df,
    x='IsPromo2Active',
    y='Sales',
    palette={'0': '#2980B9', '1': '#F39C12'},
    showfliers=False
)

# Adding median annotations for both groups
medians = df.groupby('IsPromo2Active')['Sales'].median().values
for i, median in enumerate(medians):
    plt.text(i, median + 300, f"Median = {int(median):,}",
             ha='center', fontweight='semibold', color='black')

# Adding titles and axis labels
plt.title('Distribution of Sales based on Long-Term Promotion (Promo2) Activity', fontsize=16, fontweight='bold', color='black')
plt.xlabel('IsPromo2Active (0 = No, 1 = Yes)', fontsize=12)
plt.ylabel('Sales Amount', fontsize=12)

# Customizing gridlines and layout
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# 📄 Summary -
#
# Median (IsPromo2Active = 0): 5,785
#
#
# Median (IsPromo2Active = 1): 5,507
#
#
# * There is a slight decline of around 4.8% in median sales when long-term promotions (Promo2) are active.
#
#
# * This indicates that continuous promotions do not necessarily boost daily sales - their effect appears neutral or slightly negative.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a boxplot to compare daily sales distributions between stores with and without long-term (Promo2) promotions.
#
# * This chart helps me visualize whether ongoing promotional campaigns help sustain higher daily sales compared to stores that are not running such programs.
#
# * It is essential to include this chart because it helps me differentiate between short-term promotional spikes (Promo) and long-term steady effects (Promo2) on store performance.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The median sales for stores without active Promo2 are ₹5,785, slightly higher than those with active Promo2 (₹5,507).
#
#
# * The difference of around -4.8% shows that long-term promotions do not guarantee higher daily sales.
#
# * Both distributions have a similar spread, which means Promo2 does not significantly increase variability in sales either.
#
# * This could imply that long-term promotions may have become normalized for customers, who no longer respond as strongly to them.
#
# * In contrast, the short-term “Promo” (Chart 1) showed a strong uplift, suggesting that limited-time campaigns create a greater sense of urgency.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impacts / What to Do:**
#
# * The finding shows that long-term promotions (Promo2) alone don't drive significant daily sales increases.
# → The company can save costs by focusing on short-term, event-based promotions that yield stronger results.
#
# * Combining long-term awareness (Promo2) with targeted short-term boosts (Promo) can help maintain both stability and growth.
#
# * The insight helps prioritize marketing budget — less on continuous discounts, more on high-impact campaigns.
#
#
# **Negative-Growth / Risk Signals & Mitigation:**
#
# * Customer fatigue — long-term exposure to promotions can make discounts feel normal, leading to reduced effectiveness over time.
# → Mitigation: Alternate promo periods, refresh offers frequently, or limit long-term promo exposure.
#
# * If Promo2 drives traffic without equivalent conversion, profit margins may shrink.
# → The team should analyze conversion rates and customer acquisition costs during these periods.

# %% [markdown]
# ##### Chart 19 - Monthly Sales Trends

# %%
# Chart - 19 visualization code

# Features Used - Month, Sales

# ✅ Why this chart is important to include ?
# This chart helps identify monthly sales trends and seasonal patterns across the year.
# Understanding which months drive higher or lower sales is crucial for inventory planning,
# staffing, and timing promotional campaigns for maximum impact.

#----------------------------------------------------------------------------------------------------------#

# Grouping data by Month to calculate average sales per month
monthly_sales = df.groupby('Month')['Sales'].mean().reset_index()

# Sorting by Month to ensure correct order (if not already sorted)
monthly_sales = monthly_sales.sort_values(by='Month')

# Setting the visual style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# ✅ Corrected area chart syntax (fill between baseline y=0 and actual sales)
plt.fill_between(
    x=monthly_sales['Month'],
    y1=monthly_sales['Sales'],
    y2=0,                       # baseline
    color='skyblue',
    alpha=0.4,
    linewidth=2,
    edgecolor='blue'
)

# Adding a smooth line on top for clarity
sns.lineplot(
    data=monthly_sales,
    x='Month',
    y='Sales',
    color='blue',
    linewidth=2.5
)

# Titles and labels
plt.title('Monthly Average Sales Trend', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Average Sales', fontsize=12)

# Customizing x-axis labels
plt.xticks(
    ticks=range(1,13),
    labels=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
)

# Gridlines and aesthetics
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Display the plot
plt.show()

# %% [markdown]
# 📄 Summary -
#
#
# * Monthly average sales gradually increase from January (~ 5,465) to March (~5,785), followed by slight dips around May (5,489).
#
# * There's a strong seasonal uplift in July (~6,065) and November-December, peaking at December (≈ 6,827).
#
# * This suggests a clear end-of-year sales spike, possibly due to holiday shopping and winter promotions.
#
# * Overall pattern: moderate mid-year fluctuations with a strong Q4 boost, indicating seasonality in demand.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I used an Area Plot because it clearly highlights the monthly trend and volume of average sales, helping visualize cumulative changes across time.
#
# * The filled area emphasizes seasonal growth and dips, making it easier to spot periods of strong vs. weak performance.
#
# * It's a better choice than a simple line plot here, since the filled space visually communicates the magnitude of change month-to-month, which is valuable for retail trend analysis.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Sales steadily climb from Q1 (Jan-Mar), dip slightly in May and Sept-Oct, and then peak in December.
#
# * December's average sales (≈ 6,827) are nearly 25 % higher than the early-year months, confirming strong seasonal influence—likely from Christmas or holiday campaigns.
#
# * July and November also show smaller surges, potentially linked to mid-year clearance and holiday prep promos.
#
# * The mid-year softness (Apr-Jun, Sept-Oct) indicates potential windows for marketing reactivation.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impacts:**
#
# * Retailers can align promotional budgets and staffing with seasonal demand spikes.
#
# * By analyzing these patterns, management can replicate December-like campaigns in slower months (e.g., May, October).
#
# * Inventory management and supply-chain planning can be optimized — ensuring high-demand months never face stockouts.
#
#
# **⚠️ Negative / Risk Insights:**
#
# * The clear volatility in monthly sales indicates dependence on external factors (holidays, weather, etc.).
#
# * Low-performing months (May-Oct) need strategic action - e.g., loyalty discounts or region-specific offers - to smooth revenue across the year.

# %% [markdown]
# ##### Chart 20 - Day of The Week vs Sales

# %%
# Chart - 20 visualization code

# Features Used - DayOfWeek, Sales

# ✅ Why this chart is important to include ?
# Weekly trends can reveal customer behavior patterns — for instance, weekends or certain weekdays may drive higher sales.
# Understanding this helps optimize staff scheduling, stock management, and promotional timing.

# ----------------------------------------------------------------------------------------------------------#

# Calculating average sales per day of week
avg_sales_dow = df.groupby('DayOfWeek')['Sales'].mean().reset_index()

# Setting plot style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# Plotting the bar chart
sns.barplot(
    data=avg_sales_dow,
    x='DayOfWeek',
    y='Sales',
    palette='crest'
)

# Adding labels and title
plt.title('Average Sales by Day of Week', fontsize=16, fontweight='bold')
plt.xlabel('Day of Week', fontsize=12)
plt.ylabel('Average Sales', fontsize=12)

# Customizing grid and frame
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# 📘 Summary -
#
# * Highest sales occur on Monday (≈ 7809), gradually declining through the week.
#
# * The lowest sales (≈ 204) are on Sunday, when most stores are closed.
#
# * A clear weekly trend is visible — strong start early in the week, tapering off towards the weekend.
#
# * Suggests strong weekday store activity and reduced weekend operations.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I used a bar plot to clearly visualize the average sales pattern across different weekdays.
#
# * This chart helps in identifying operational or behavioral trends — for instance, if customers shop more early in the week or on weekends.
#
# * Such weekly patterns are vital for forecasting, staffing, and marketing optimization.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Sales are highest on Monday (≈ 7809) and steadily decline through the week, hitting the lowest on Sunday (≈ 204).
#
# * This pattern likely reflects Rossmann’s working policy — many stores are closed or operate shorter hours on Sundays.
#
# * The weekday-to-weekend drop is significant, confirming that customer visits and sales are heavily concentrated during weekdays.
#
# * Thursday and Friday show moderate sales recovery, possibly due to pre-weekend shopping behavior.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impacts / what to do:**
#
# * Operational efficiency:
#
#     * Staff allocation can be optimized — schedule more employees early in the week and fewer on Sundays.
#
#     * Adjust inventory delivery cycles to match high-demand days (Mon-Wed).
#
#
# * Marketing opportunities:
#
#     * Launch targeted weekend promotions or online deals to drive more traffic when in-store sales are low.
#
#     * Study stores that remain open on Sundays and analyze if they perform better in specific locations.
#
#
#
# **Negative-growth / risk signals & mitigation:**
#
# * Underutilized weekends:
#
#     * Consistent drop in weekend sales might indicate untapped customer segments — online channels could help offset it.
#
#     * For open stores with low Sunday sales, re-evaluate operating costs versus profit margins.

# %% [markdown]
# ##### Chart 21 - Sales Across Different StoreTypes

# %%
# Chart - 21 Visualisation Code

# Features Used - StoreType, Sales

# ✅ Why this chart is important to include?
# This chart helps me understand how sales differ across various store types (a, b, c, d).
# Since store type represents store size, format, and regional strategy, analyzing sales variation by store type
# reveals which formats perform better, and whether certain store types underperform or overperform consistently.

# ---------------------------------------------------------------------------------------------------------- #

# Setting plot style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# Plotting the boxplot
sns.boxplot(
    data=df,
    x='StoreType',
    y='Sales',
    palette='coolwarm'
)

# Adding titles and labels
plt.title('Sales Distribution Across Different Store Types', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Store Type', fontsize=12)
plt.ylabel('Sales Amount', fontsize=12)

# Customizing gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * Store type 'b' shows the highest median and overall sales compared to other types.
#
# * Store types 'a', 'c' and 'd' have relatively lower but stable distributions.
#
# * The variance in sales within each store type indicates that performance differs even among similar formats, possibly due to location, competition, or local demand.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I have used a boxplot because it visually represents the spread, median, and outliers of sales for each store type in a compact and interpretable way.
#
# * This chart helps me compare central tendencies and variability in sales across store categories, which is essential for understanding which store format performs better on average and which ones show inconsistency.
#
# * A boxplot is ideal here since sales data is continuous and likely skewed — making it easier to detect differences in medians and dispersion between store types.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Store Type 'b' exhibits the highest median sales and the widest interquartile range, suggesting that it performs best but also shows greater variability — likely due to its larger size or location in high-traffic areas.
#
# * Store Types 'a', 'c' and 'd have lower medians and relatively similar sales distributions, indicating moderate performance.
#
# * The presence of several high-value outliers in all store types reflects occasional spikes, possibly caused by promotions or seasonal effects.
#
# * The overall sales hierarchy appears to be:
# StoreType b > d ≈ c ≈ a.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive business impacts / what to do:**
#
# * Performance segmentation: Since Store Type b generates higher sales, it can serve as a benchmark model for operational and marketing strategies across other store types.
#
# * Optimization strategy: Analyzing what differentiates Store Type b (store layout, size, or promotions) can help replicate successful elements in underperforming formats.
#
# * Targeted resource allocation: Management can focus more investments or advertising efforts on store types with high revenue potential.
#
#
# **⚠️ Negative-growth / risk signals & mitigation:**
#
# * Sales inconsistency in Type ‘b’: The wide spread implies unstable sales — potential over-dependence on promotions or regional fluctuations.
#
# * Lower-performing formats: Stores of Type a, c, and d may need restructuring or localized promotions to improve average daily sales.
#
# * Mitigation: Conduct periodic reviews of product mix and customer demographics for lower-performing store types.

# %% [markdown]
# ##### Chart 22 - Assortment Type vs Sales

# %%
# Chart - 22 Visualization Code

# Features Used - Assortment, Sales

# ✅ Why this chart is important to include?
# This chart allows me to see both the spread (like a boxplot) and the density (like a KDE).
# It helps understand not only which assortment type performs better but also how consistent their performance is.

# ---------------------------------------------------------------------------------------------------------- #

# Setting plot style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(9,6))

# Plotting violinplot to visualize sales distribution across assortment types
sns.violinplot(
    data=df,
    x='Assortment',
    y='Sales',
    palette='coolwarm',
    inner='quartile',      # Show quartile lines inside violins
    cut=0
)

# Adding title and labels
plt.title('Sales Distribution Across Assortment Types', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Assortment Type', fontsize=12)
plt.ylabel('Sales Amount', fontsize=12)

# Customizing gridlines
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)

# Displaying plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * Assortment 'b' stores show the highest median and wider spread of sales, followed by type 'c'.
#
# * Type 'a' stores record lower and tighter sales distribution.
#
# * Assortment variety clearly drives sales, with broader product range (b, c) correlating to higher average revenue.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I used a violin plot because it captures both distribution density and spread of sales across the three assortment types (a, b, c).
#
# * Unlike boxplots, the violin plot gives a smooth visual of concentration zones, helping identify which assortment categories consistently perform better or have more variability in sales.
#
# * This visual is ideal for understanding the impact of product variety on overall store sales.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Type 'b' assortment (medium variety) has the highest median and widest distribution, indicating these stores tend to attract higher sales and possibly serve a broader customer base.
#
# * Type 'c' stores (advanced assortment) also show good performance but slightly lower than type ‘b’, suggesting diminishing returns beyond a certain product variety level.
#
# * Type 'a' stores (basic assortment) have the lowest median and least variability, confirming that limited assortment leads to lower revenue potential.
#
# * Overall, assortment expansion positively correlates with sales, but over-expansion might not yield proportional growth.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impacts / Actions:**
#
# * Optimize product assortment — Stores with type 'b' or 'c' assortments outperform type 'a', suggesting Rossmann can increase sales by gradually upgrading low-assortment stores.
#
# * Targeted inventory planning — Focus more premium SKUs and wider categories in stores that can sustain higher traffic (similar to type 'b' stores).
#
# * Performance benchmarking — Identify key characteristics of high-performing 'b' stores and replicate them across similar regions.
#
#
# **⚠️ Negative Growth Signals / Risks**:
#
# * Over-assortment risk: Type 'c' doesn't always outperform 'b', indicating that excessive assortment could cause inventory holding cost or product cannibalization.
#
# * Operational cost trade-off: Expanding assortments requires more shelf space, supply chain complexity, and higher operating expenses — must be balanced against sales uplift.

# %% [markdown]
# ##### Chart 23 - Impact of Competition Distance on Sales (Binned Line Chart)

# %%
# Chart - 23 Visualisation Code

# Features Used - Sales, CompetitionDistance

# ✅ Why this chart is important to include?
# This chart helps analyze how average sales behave as the distance to the nearest
# competitor increases. By binning competition distance, we reduce noise from
# individual stores and clearly observe overall sales trends across proximity levels.
# This makes it easier to understand whether nearby competition negatively impacts sales.

# ---------------------------------------------------------------------------------------------------------- #

# Setting Seaborn style for professional aesthetics
sns.set(style='whitegrid')

# Creating competition distance bins
distance_bins = [0, 500, 1000, 3000, 10000, df['CompetitionDistance'].max()]
distance_labels = [
    'Very Close (<500m)',
    'Close (500m–1km)',
    'Moderate (1–3km)',
    'Far (3–10km)',
    'Very Far (>10km)'
]

# Assigning bins to CompetitionDistance
df['CompetitionDistanceBin'] = pd.cut(
    df['CompetitionDistance'],
    bins=distance_bins,
    labels=distance_labels,
    include_lowest=True
)

# Calculating average sales per competition distance bin
binned_sales = (
    df.groupby('CompetitionDistanceBin', observed=True)['Sales']
      .mean()
      .reset_index()
)

# Creating the figure
plt.figure(figsize=(10, 6))

# Line plot to show sales trend across competition distance bins
sns.lineplot(
    data=binned_sales,
    x='CompetitionDistanceBin',
    y='Sales',
    marker='o',
    linewidth=2,
    color='steelblue'
)

# Adding value labels on data points
for index, row in binned_sales.iterrows():
    plt.text(
        index,
        row['Sales'],
        f"{int(row['Sales'])}",
        ha='center',
        va='bottom',
        fontsize=10
    )

# Chart title and labels
plt.title(
    'Average Sales Across Competition Distance Buckets',
    fontsize=16,
    fontweight='bold'
)
plt.xlabel('Competition Distance', fontsize=12)
plt.ylabel('Average Sales', fontsize=12)

# Improving grid and layout
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart shows how average sales vary across different competition distance buckets.
#
# * Sales are highest when competitors are very close   (< 500m), drop sharply when competitors are slightly farther away (500m - 1km), and then stabilize across moderate to very far distances.
#
# * Overall, the relationship between competition distance and sales is non-linear, indicating that proximity alone does not consistently suppress sales.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * The binned line chart reduces noise from millions of individual observations.
#
# * It clearly captures macro-level sales trends across competition distance ranges.
#
# * Compared to regression/scatter plots, this chart is faster to compute and easier to interpret, making it ideal for EDA.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Stores with very close competitors (< 500m) have the highest average sales (~6307).
#
# * Sales drop significantly when competition is at a moderate proximity (500m–1km).
#
# * Beyond 1km, sales remain relatively stable, fluctuating slightly but without a strong upward or downward trend.
#
# * This suggests that store location quality and demand density may outweigh pure competition effects.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive business impact / opportunities:**
#
# * Businesses should not avoid opening stores near competitors by default.
#
# * High sales near close competition may indicate high-demand zones, making such areas strategically valuable.
#
# * Expansion decisions can focus more on market demand rather than fear of nearby competitors.
#
# **⚠️ Potential negative growth / risks:**
#
# * The sharp decline in sales from < 500m to 500m–1km indicates a potential cannibalization zone.
#
# * Stores located just outside high-demand clusters may face reduced visibility and footfall, leading to lower sales.
#
# * This highlights a risk zone where competition exists but demand density may not be sufficient to sustain strong performance.
#
# **👉 Actionable takeaway:**
#
# * If entering a competitive area, it is better to be very close (core demand zone) rather than moderately distant.

# %% [markdown]
# ##### Chart 24 - CompetitionOpenMonths vs Sales

# %%
# Chart - 24 Visualisation Code

# Features Used - CompetitionOpenMonths, Sales

# ✅ Why this chart is important to include?
# I am creating this chart to measure whether the age of the nearest competitor (in months)
# is associated with a change in average store Sales. This tests whether older competition
# has a sustained impact or whether new competition causes more short-term disruption.

# ---------------------------------------------------------------------------------------------------------- #

# Preparing the series: exclude 0 (missing / no-competition flag) because 0 does not mean '0 months of competition' in business terms
comp_mask = df['CompetitionOpenMonths'] > 0
comp_df = df.loc[comp_mask, ['CompetitionOpenMonths', 'Sales']].copy()

# If there are no records with CompetitionOpenMonths > 0, this will safely handle the case
if comp_df.empty:
    print("No records with CompetitionOpenMonths > 0. Check CompetitionOpenMonths creation.")
else:
    # Aggregating median sales by exact months-since-competition
    monthly_comp = (
        comp_df.groupby('CompetitionOpenMonths', as_index=True)['Sales']
        .median()
        .rename('median_sales')
        .reset_index()
        .sort_values('CompetitionOpenMonths')
    )

    # Smoothing the median series with a rolling median to reduce noise (window = 5 months)
    monthly_comp['rolling_median'] = monthly_comp['median_sales'].rolling(window=5, center=True, min_periods=1).median()

    # To avoid ultra-long x axes (very rare extremely large months), capping x for plotting clarity:
    max_display_month = 120   # showing first 10 years for clarity; values beyond will still be considered in stats
    monthly_comp_plot = monthly_comp[monthly_comp['CompetitionOpenMonths'] <= max_display_month]

    # Count of zero / NA-flagged competition records (for annotation)
    zero_comp_count = df.loc[df['CompetitionOpenMonths'] == 0].shape[0]
    total_count = df.shape[0]

    # Plotting
    sns.set(style='whitegrid')
    plt.figure(figsize=(11,6))

    # Scatter of raw medians (light)
    plt.scatter(
        monthly_comp_plot['CompetitionOpenMonths'],
        monthly_comp_plot['median_sales'],
        s=30,
        alpha=0.6,
        color='steelblue',
        label='Median sales (per month bin)'
    )

    # Smoothed rolling median line
    plt.plot(
        monthly_comp_plot['CompetitionOpenMonths'],
        monthly_comp_plot['rolling_median'],
        color='#E67E22',
        linewidth=2.5,
        label='Smoothed median (rolling window=5)'
    )

    # Highlight vertical line at 12, 24, 60 months for reference (1yr, 2yr, 5yr)
    for m in [12, 24, 60]:
        plt.axvline(m, color='grey', linestyle='--', alpha=0.4)

    plt.title('Impact of Competitor Age (months since opened) on Median Store Sales', fontsize=16, fontweight='bold')
    plt.xlabel('Months since nearest competitor opened', fontsize=12)
    plt.ylabel('Median Daily Sales', fontsize=12)
    plt.xlim(0, monthly_comp_plot['CompetitionOpenMonths'].max() + 2)
    plt.grid(axis='y', linestyle='--', alpha=0.6)
    plt.legend()

    # Annotating count of missing/zero competition months
    plt.gca().text(
        0.98, 0.02,
        f'Zero/NA competition records: {zero_comp_count:,} / {total_count:,}',
        ha='right', va='bottom', transform=plt.gca().transAxes,
        fontsize=10, bbox=dict(facecolor='white', alpha=0.6, edgecolor='none')
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Summary -**
#
# * Data excludes ~41% records (415,219 / 1,017,209) where competition data was missing (i.e., CompetitionOpenMonths = 0).
#
# * Median daily sales hover around ₹5,800–6,200 during the first 40 months after a competitor opens.
#
# * Between months 40–70, sales remain moderately stable but start declining sharply after ~70 months (≈ 6 years).
#
# * After 6 years, sales drop close to ₹5,400–5,500, indicating mature competition impact.
#
# * Interestingly, a slight rebound occurs between 90–110 months, possibly due to market adaptation or competitor closure.
#
# * Overall, older competitor presence appears to dampen store sales after several years.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I used a scatter + rolling median line chart because this combination effectively captures long-term, nonlinear patterns between competitor age and store performance.
#
# * A simple correlation or regression would miss these temporal shifts and nonlinear effects.
#
# * By smoothing medians, the chart shows whether competition effects are short-term shocks or long-term declines.
#
# * This visualization is critical for business teams to understand how the “age of competition” shapes store sustainability over years.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Initial stability (0–40 months): Sales remain consistent soon after competition opens — stores may retain loyal customers initially.
#
# * Gradual decline (40–70 months): Sales start declining as competitors gain market foothold and customers start shifting.
#
# * Significant drop (~70–85 months): The most visible fall — median sales drop by nearly ₹700, suggesting stronger competitor capture.
#
# * Recovery trend (90–110 months): A small upward movement implies market rebalancing — possibly from adaptation, local marketing, or competitor exit.
#
# * Plateau beyond 110 months: Sales stabilize again around ₹5,700.
#
# * Overall, competitor impact grows over time, but the decline may stabilize after stores adapt or weak competitors exit.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive business impacts / What to do:**
#
# * Strategy planning: New store openings should focus on areas where competitors are newly established (under 3 years) — minimal impact expected.
#
# * Retention programs: For stores older than 6 years with mature nearby competitors, launch loyalty campaigns or local offers to reclaim customer base.
#
# * Market adaptation: Recognize the sales dip period (~70 months) as a critical intervention window for management action.
#
# * Long-term forecasting: Insights can help improve time-based competition modeling in future demand forecasts.
#
#
# **⚠️ Negative growth / Risks:**
#
# * Old competitor markets show sustained low sales — if ignored, stores may experience permanent erosion.
#
# * If this trend continues, resource reallocation or format revamp (store type, assortment) might be needed for recovery.

# %% [markdown]
# ##### Chart 25 - StateHoliday vs Sales

# %%
# Chart - 25 Visualisation Code

# Features Used – Sales, StateHoliday


# ✅ Why this chart is important to include?
# This chart helps me compare sales between normal working days and different state holidays.
# It's important because some holidays lead to store closures and revenue drops, while others may trigger more shopping activity.

# ---------------------------------------------------------------------------------------------------- #

# Setting Seaborn style
sns.set(style="whitegrid")

# Defining the correct business order of categories
order = ['None', 'a', 'b', 'c']

# Creating the figure
plt.figure(figsize=(8, 6))

# Plotting boxplot with fixed category order
sns.boxplot(
    data=df,
    x='StateHoliday',
    y='Sales',
    order=order,  # fixing the category order
    palette=['#90CAF9', '#FFB74D', '#81C784', '#E57373'],  # pleasant color scheme
    width=0.5
)

# Adding title and axis labels
plt.title('Impact of State Holidays on Store Sales', fontsize=16, fontweight='bold')
plt.xlabel('State Holiday (None, a, b, c)', fontsize=12)
plt.ylabel('Sales Amount', fontsize=12)

# Calculating medians using same order as plotted
medians = df.groupby('StateHoliday')['Sales'].median()
for i, category in enumerate(order):
    median_val = medians[category]
    plt.text(i, median_val + 300, f'Median = {int(median_val)}',
             ha='center', fontsize=10, fontweight='bold', color='black')

# Removing chart spines for a cleaner design
sns.despine()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary –**
#
# * Median Sales on non-holiday days: ₹5,849
#
# * Median Sales on holidays (a/b/c): ₹0
#
# * This indicates that most stores remain closed on state holidays, leading to zero or negligible sales.
#
# * A few outliers on holidays reflect stores that remain open or report delayed transactions after holiday closures.
#
# * Overall, holidays negatively impact daily sales volume.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I used a boxplot because it clearly shows the central tendency and distribution differences in sales between holiday and non-holiday days.
#
# * The boxplot helps visualize how sales behave under distinct StateHoliday categories (None, a, b, c).
#
# * It also highlights whether any stores remain open on holidays and how significantly that affects the overall revenue trend.
#
# * Including this chart is important to understand holiday-induced sales downtime and to prepare accurate forecasting models.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Normal days (None): Median sales are strong (~₹5,849), representing stable daily performance.
#
# * Holiday types a, b, and c: Median sales drop to 0, implying most stores are closed during these public holidays.
#
# * Some outliers above ₹20,000 - ₹30,000 on holidays suggest that a few stores operate or record transactions later (perhaps small local deviations).
#
# * The overall distribution pattern confirms that state holidays cause complete operational halts in most stores.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive business impacts / what to do:**
#
# * These insights can help enhance forecasting accuracy — excluding holiday records prevents false low-sales predictions.
#
# * Rossmann can plan post-holiday recovery campaigns (discounts or extended store hours) to regain missed sales.
#
# * Managers can better schedule staff and inventory around known holidays to minimize operational wastage.
#
#
# **⚠️ Negative-growth / risk signals:**
#
# * Holidays directly cause revenue loss due to full store closures, resulting in sharp temporary sales dips.
#
# * If not addressed, this can mislead forecasting models or resource allocation for those periods.
#
# * To mitigate, Rossmann can strengthen online sales or pre-holiday sales drives.

# %% [markdown]
# ##### Chart 26 - SchoolHoliday vs Sales

# %%
# Chart - 26 Visualisation Code


# Features Used - Sales, SchoolHoliday

# ✅ Why this chart is important to include?
# This chart shows how school holidays affect daily sales.
# During school breaks, customer shopping patterns might change –
# families might shop more before vacations or less during the holidays.
# Understanding this helps in planning campaigns and forecasting sales accurately.

# ---------------------------------------------------------------------------------------------------------- #

# Setting plot style
sns.set(style='whitegrid')

# Defining correct logical order for the binary variable
order = [0, 1]  # 0 = No school holiday, 1 = School holiday

# Creating the figure
plt.figure(figsize=(8,6))

# Plotting boxplot
sns.boxplot(
    data=df,
    x='SchoolHoliday',
    y='Sales',
    order=order,
    palette=['#64B5F6', '#FF8A65'],
    width=0.5
)

# Adding chart titles and labels
plt.title('Impact of School Holidays on Store Sales', fontsize=16, fontweight='bold', color='black')
plt.xlabel('School Holiday (0 = No, 1 = Yes)', fontsize=12)
plt.ylabel('Sales Amount', fontsize=12)

# Calculating medians in the same order as plotted
medians = df.groupby('SchoolHoliday')['Sales'].median()
for i, val in enumerate(order):
    median_val = medians[val]
    plt.text(i, median_val + 300, f'Median = {int(median_val)}',
             ha='center', fontsize=10, fontweight='bold', color='black')

# Customizing gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * Median sales on non-school holidays (0): ₹5,642
#
# * Median sales on school holidays (1): ₹6,197
#
# * Stores perform slightly better during school holidays, showing a small positive lift of around 10% in median sales.
#
# * The spread and outliers look similar for both categories, meaning the increase is consistent and not driven by extreme values.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I used a boxplot because it clearly compares how daily sales differ on school holidays versus regular days.
#
# * It helps me see if these holidays influence shopping behavior — for example, families shopping more when kids are home.
#
# * The visual also makes it easy to spot if any store shows unusually high or low performance on holidays.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * There's a small but noticeable increase in sales during school holidays.
#
# * Median sales rise from ₹5,642 to ₹6,197, showing customers likely shop more when schools are closed.
#
# * This could be because families spend more time together and visit stores for leisure shopping, groceries, or back-to-school preparation.
#
# * The overall distribution looks similar, so this isn't a random spike — it's a consistent pattern across stores.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive business impacts / what to do:**
#
# * Rossmann can plan targeted promotions or family-oriented campaigns during school holidays to capitalize on slightly higher footfall.
#
# * Stores can adjust staff schedules and stock levels to handle the increase in demand.
#
# * The insight also helps in improving forecast accuracy, as these days consistently perform better than normal weekdays.
#
#
#
# **⚠️ Negative-growth / risk signals:**
#
#
# * If stores misinterpret this as a major sales surge, they might overstock.
#
# * The uplift is moderate, not massive — so planning should stay balanced.
#
# * Some areas may behave differently (urban vs rural), so local-level validation is still needed.

# %% [markdown]
# #### Part 2 - Customer Behavior and Traffic Patterns

# %% [markdown]
# ##### Chart 27 - Effect of Daily Promo on Customers

# %%
# Chart 27 - Visualization Code

# Features Used - Promo, Customers

# ✅ Why this chart is important to include?
# This chart helps me understand how promotions impact store footfall.
# If promotions are effective, I should see higher customer counts during promo periods.
# It’s useful for checking whether promotions drive more people into the store,
# or if they mostly affect existing customer spending (seen in sales data).

# ---------------------------------------------------------------------------------------------------------- #

# Setting consistent style
sns.set(style='whitegrid')

# Defining correct logical order for Promo variable
order = [0, 1]  # 0 = No Promo, 1 = Promo Active

# Creating the figure
plt.figure(figsize=(8,6))

# Plotting boxplot
sns.boxplot(
    data=df,
    x='Promo',
    y='Customers',
    order=order,
    palette=['#81D4FA', '#FFB74D'],
    width=0.5
)

# Adding titles and axis labels
plt.title('Effect of Promotions on Customer Footfall', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Promo (0 = No, 1 = Yes)', fontsize=12)
plt.ylabel('Number of Customers', fontsize=12)

# Adding median annotations for each category
medians = df.groupby('Promo')['Customers'].median()
for i, val in enumerate(order):
    median_val = medians[val]
    plt.text(i, median_val + 100, f'Median = {int(median_val)}',
             ha='center', fontsize=10, fontweight='bold', color='black')

# Customizing visuals
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * Median customers without promo (0): 512
#
# * Median customers with promo (1): 747
#
# * There's a clear increase in customer footfall — roughly 46% higher during promotional periods.
#
# * The spread is slightly wider during promotions, meaning some stores experience a much bigger customer boost than others.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I wanted to see if promotions actually bring more people into the stores, not just increase sales value.
#
# * The boxplot makes it easy to compare overall customer distributions during promo vs non-promo days and highlight how promotions change customer volume patterns.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The median footfall increases from 512 to 747, showing that promotions consistently draw more customers across most stores.
#
# * The range of customer counts is wider during promotions — some stores attract a massive number of shoppers, likely due to better local marketing or higher product variety.
#
# * The data confirms that promotions directly boost customer engagement, not just sales numbers.
#
# * However, the presence of outliers means not all stores benefit equally — indicating scope for regional optimization.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive business impacts / what to do:**
#
# * Promotions clearly succeed in increasing customer traffic, which in turn supports higher sales.
#
# * The insight can help Rossmann plan promo calendars strategically — scheduling them in low-traffic weeks or aligning them with key seasonal periods.
#
# * Stores performing exceptionally well during promos can be analyzed to identify best practices (product placement, local advertising, etc.).
#
#
# **⚠️ Negative-growth / risk signals:**
#
# * Some stores might see little improvement despite promotions, implying inefficient campaign execution.
#
# * Overusing promotions can train customers to wait for discounts, hurting long-term margins — so promo frequency should be balanced.

# %% [markdown]
# ##### Chart 28 - Impact of Long running Promo on Traffic

# %%
# Chart 28 - Visualization Code

# Features Used - IsPromo2Active, Customers

# ✅ Why this chart is important to include?
# I’m using this violin plot to see how long-term promotions (Promo2) affect customer traffic patterns.
# Unlike boxplots, violin plots show both spread and concentration of values,
# which helps me see not just median differences but also where most stores lie in terms of customer count.

# ---------------------------------------------------------------------------------------------------------- #

# Setting up the visual style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(9,6))

# Plotting violin plot for better distribution view
sns.violinplot(
    data=df,
    x='IsPromo2Active',
    y='Customers',
    palette=['#AED581', '#FFD54F'],
    inner='quartile',    # show quartile lines for better comparison
    linewidth=1,
    cut=0
)

# Adding chart titles and axis labels
plt.title('Customer Footfall vs Long-Term Promotion (Promo2) Activity', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Is Promo2 Active (0 = No, 1 = Yes)', fontsize=12)
plt.ylabel('Number of Customers', fontsize=12)

# Styling
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * The overall shape of both distributions is quite similar, meaning long-term promotions (Promo2) don't drastically change customer traffic.
#
# * The median and density peaks are nearly the same — around 600-700 customers per day.
#
# * This tells me that Promo2 may help maintain consistent footfall but doesn't necessarily attract a large new audience.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I used a violin plot here because it shows both the spread and the concentration of customer numbers under each promotion state.
#
# * It helps me see if the long-term recurring promotions have shifted customer distribution or if the trend stays flat.
#
# * It's also more visually informative than a simple boxplot for understanding subtle differences in density.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Both “Promo2 Active” and “Promo2 Inactive” stores have almost identical distributions of customer counts.
#
# * This means that long-term promotions don't increase daily footfall significantly, but they help maintain a steady flow of customers.
#
# * The slightly flatter spread during Promo2 active periods suggests lower volatility, meaning these campaigns keep customer engagement stable.
#
# * In contrast to short-term promos (which created strong spikes), Promo2 seems to have a more sustaining, not boosting, effect.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact/ What to do :**
#
# * Promo2 campaigns help retain customers and maintain traffic consistency over time — this is valuable for predictable operations.
#
# * Since Promo2 doesn’t create big peaks, it’s ideal for long-term stability rather than short-term gains.
#
# * Rossmann can combine Promo2 with limited-time offers (Promo1) to achieve both consistency and occasional spikes.
#
#
# **Possible risks / negative impact:**
#
# * The data shows no significant traffic increase, so these long-term campaigns may not justify their cost if they’re expensive to maintain.
#
# * Continuous promotions could also make customers less responsive over time, leading to promo fatigue.
#
# * The company might want to re-evaluate Promo2 messaging or rotate offers more frequently.

# %% [markdown]
# ##### Chart 29 - Monthwise Traffic Pattern

# %%
# Chart 29 - Visualization Code
# Features Used - Month, Customers

# ✅ Why this chart is important to include?
# This chart helps me identify monthly patterns in customer footfall across all stores.
# It shows whether there are seasonal peaks or dips in customer visits,
# which is valuable for planning staffing, promotions, and inventory during high-traffic periods.

# ---------------------------------------------------------------------------------------------------------- #

# Grouping data by month to get average number of customers
monthly_customers = (
    df.groupby('Month')['Customers']
    .mean()
    .reset_index()
    .sort_values('Month')
)

# Setting consistent style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# Plotting the filled area to show variation in customer count over months
plt.fill_between(
    x=monthly_customers['Month'],
    y1=monthly_customers['Customers'],
    y2=0,
    color='skyblue',
    alpha=0.4,
    linewidth=2,
    edgecolor='steelblue'
)

# Adding a smooth line for clarity
sns.lineplot(
    data=monthly_customers,
    x='Month',
    y='Customers',
    color='steelblue',
    linewidth=2.5,
    marker='o'
)

# Chart title and labels
plt.title('Monthly Trend of Average Customer Footfall', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Average Number of Customers', fontsize=12)

# Customizing x-axis labels
plt.xticks(
    ticks=range(1,13),
    labels=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
)

# Adding gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The average number of customers per month stays fairly stable throughout the year, between 600–670 on average.
#
# * A slight dip appears around May and August, while July and December show small peaks.
#
# * This indicates that customer visits don’t fluctuate dramatically by month — suggesting consistent year-round engagement.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I wanted to understand how customer traffic changes month to month and whether there’s any strong seasonality in visits.
#
# * An area plot clearly highlights the overall volume and flow of customer activity, making it easy to spot small ups and downs across the year.
#
# * It’s also visually consistent with my earlier “Month vs Sales” chart, helping me connect sales patterns with actual store footfall.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart shows that customer footfall remains steady all year, with no extreme spikes or drops.
#
# * Slight increases are seen in July and December, likely due to summer holidays and the end-of-year shopping period.
#
# * May and August show small declines — possibly vacation months when regular shopping frequency drops a bit.
#
# * Overall, this means Rossmann enjoys a stable customer base, which is a great sign for operational predictability.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact:**
#
# * The stability of customer traffic suggests the brand has a loyal, repeat customer base, not just seasonal buyers.
#
# * Managers can plan consistent inventory and staffing levels across months without major seasonal stress.
#
# * The minor peaks (July and December) can be used as promo opportunities to capture slightly higher demand.
#
#
# **Possible risks / negative impact:**
#
# * The small dips in May and August could indicate vacation-driven slowdowns, which can be offset with light promotional campaigns.
#
# * Since footfall doesn’t rise much seasonally, growth will depend more on spending per customer, not just more visitors.

# %% [markdown]
# ##### Chart 30 - DayOfWeek vs Customers

# %%
# Chart 30 - Visualization Code

# Features Used - DayOfWeek, Customers

# ✅ Why this chart is important to include?
# This chart helps me see on which days customers visit stores the most or the least.
# It’s useful for optimizing weekly staffing, scheduling promotions, and managing inventory restocks.
# Understanding weekday footfall patterns also helps improve store efficiency and sales strategy.

# ---------------------------------------------------------------------------------------------------------- #

# Grouping data by DayOfWeek and calculating average customer count
dow_customers = (
    df.groupby('DayOfWeek')['Customers']
    .mean()
    .reset_index()
    .sort_values('DayOfWeek')
)

# Setting consistent plot style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# Plotting the barplot for average customers by day of the week
sns.barplot(
    data=dow_customers,
    x='DayOfWeek',
    y='Customers',
    palette='crest'
)

# Adding chart titles and labels
plt.title('Average Customer Footfall by Day of the Week', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Day of the Week (1 = Monday, 7 = Sunday)', fontsize=12)
plt.ylabel('Average Number of Customers', fontsize=12)

# Annotating values on top of bars
for index, row in dow_customers.iterrows():
    plt.text(row['DayOfWeek'] - 1, row['Customers'] + 20, f"{int(row['Customers'])}",
             ha='center', fontsize=10, fontweight='semibold', color='black')

# Customizing gridlines
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * Monday has the highest average customer footfall (813 customers/day), followed by Tuesday (760) and Friday (743).
#
# * Footfall gradually declines through the week, with the lowest on Saturday (657) and almost negligible numbers on Sunday (35) — likely because most stores are closed.
#
# * The trend clearly shows that Rossmann stores are busiest at the start of the week and quietest towards the weekend.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I used a bar chart here because it’s simple and effective for comparing average customer traffic across weekdays.
#
# * It gives a clear view of how store visits fluctuate throughout the week — which is crucial for resource planning, scheduling staff, and planning restocks.
#
# * The chart also pairs well with my earlier “Sales vs DayOfWeek” visualization, helping connect customer flow to revenue patterns.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Monday is the busiest day, which could be due to people catching up on weekend purchases after stores reopen.
#
# * Tuesday and Friday also perform well, showing consistent shopping mid- and late-week.
#
# * Sundays have the lowest customer traffic — with an average of only 35 customers — confirming that most Rossmann stores remain closed.
#
# * The overall pattern suggests that weekday traffic dominates the retail cycle, with relatively moderate weekend engagement.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact:**
#
# * Knowing that Mondays and Tuesdays bring the highest traffic helps in better staff scheduling and inventory management.
#
# * Stores can plan restocking or deliveries before Monday, ensuring shelves are full when footfall is highest.
#
# * Weekend-specific online promotions could help offset the low in-store traffic on Saturdays and Sundays.
#
#
# **Possible risks / negative impact:**
#
# * Low weekend activity might indicate lost opportunities, especially if competitors operate more flexible hours.
#
# * The company could explore partial openings on Sundays in high-demand regions or run Saturday discounts to boost sales before the weekly low.

# %% [markdown]
# ##### Chart 31 - Which StoreType attracs more Customers?

# %%
# Chart 31 - Visualization Code
# Features Used - StoreType, Customers

# ✅ Why this chart is important to include?
# This chart helps me compare customer traffic across different store types (a, b, c, d).
# StoreType usually reflects the store’s size, location, and target audience.
# Understanding which types attract more customers helps guide marketing, store format strategy, and expansion decisions.

# ---------------------------------------------------------------------------------------------------------- #

# Setting a clean white grid style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(9,6))

# Plotting violin plot to show distribution and density of customers across store types
sns.violinplot(
    data=df,
    x='StoreType',
    y='Customers',
    palette='coolwarm',
    inner='quartile',
    linewidth=1.2,
    cut=0
)

# Adding titles and labels
plt.title('Customer Distribution Across Different Store Types', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Store Type', fontsize=12)
plt.ylabel('Number of Customers', fontsize=12)

# Customizing gridlines for clarity
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary –**
#
# * Store Type ‘b’ clearly attracts the most customers, with both higher density and wider spread.
#
# * Store Types ‘a’, ‘c’, and ‘d’ have comparatively lower and more compact customer distributions.
#
# * This suggests that Type ‘b’ stores are larger or located in busier areas, leading to higher daily customer footfall.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I used a violin plot here because it helps me visualize not just the median customer count but also the entire distribution pattern for each store type.
#
# * Unlike a simple boxplot, it shows where most of the customer counts are concentrated and how wide the variability is between store types.
#
# * This is important for understanding which store formats drive the most traffic and whether the customer distribution is consistent or skewed.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Type ‘b’ stores dominate in customer count — they have the broadest and tallest distribution, showing strong, consistent customer engagement.
#
# * Types ‘a’, ‘c’, and ‘d’ serve smaller, more localized audiences with fewer fluctuations in footfall.
#
# * The concentration of customers near the lower range for other types indicates smaller stores or less busy locations.
#
# * This difference highlights store format strategy — Type ‘b’ locations are likely urban or high-traffic outlets, while the others may be community or regional stores.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact:**
#
# * Type ‘b’ stores are performing well — Rossmann can use this insight to replicate their format and strategies in other regions.
#
# * This data helps in resource allocation — more staff and promotions can be directed toward high-footfall store types.
#
# * The insight can also guide future expansion plans, prioritizing the most successful store types.
#
# **Possible Risks / Negative Impact:**
#
# * Lower customer engagement in store types ‘a’, ‘c’, and ‘d’ may indicate poor location selection or smaller catchment areas.
#
# * These stores could benefit from targeted marketing or community-level promotions.
#
# * A one-size-fits-all strategy might fail — the company should customize offerings by store type to balance customer traffic and profitability.

# %% [markdown]
# ##### Chart 32 - Customer Footfall Distribution Across Assortment Types

# %%
# Chart 32 - Visualization Code

# Features Used: Assortment, Customers

# ✅ Why this chart is important to include?
# This chart is helping to understand how different assortment types
# are influencing customer footfall across stores.
# By visualizing the distribution of customers for each assortment category,
# this chart is highlighting whether broader assortments are consistently
# attracting higher customer traffic or if the impact is marginal.
# Using a strip plot with jitter is improving performance while still
# preserving the distribution insight needed for analysis.

# ---------------------------------------------------------------------------------------------------------- #

# Setting consistent visual style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(9,6))

# Plotting strip plot with jitter for faster rendering
sns.stripplot(
    data=df.sample(4000, random_state=42),   # Reducing sample size for speed
    x='Assortment',
    y='Customers',
    palette=['#64B5F6', '#81C784', '#FFB74D'],
    jitter=0.25,                              # Adding jitter to show spread
    size=3,
    alpha=0.6
)

# Adding chart title and labels
plt.title(
    'Customer Footfall Distribution Across Assortment Types',
    fontsize=16,
    fontweight='bold'
)
plt.xlabel('Assortment Type', fontsize=12)
plt.ylabel('Number of Customers', fontsize=12)

# Adding gridlines for readability
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)

# Displaying the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart is showing a wide spread of customer footfall across all three assortment types (a, b, c), indicating significant variability at the store level.
#
# * Assortment type c is visibly having a higher concentration of stores with larger customer counts, especially in the upper range (above 1500 customers).
#
# * Assortment type a is showing a dense cluster in the mid-range (around 400–1200 customers), with fewer extreme high-footfall stores.
#
# * Assortment type b is having the sparsest data points, which aligns with fewer stores belonging to this assortment type.
#
# * Zero-customer observations are still visible across all assortment types, reinforcing the importance of earlier “Zero Sales While Open” analysis.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picked this chart to visually compare how customer footfall is distributed across different assortment strategies at the store level.
#
# * I intentionally chose a strip plot with jitter instead of a swarm plot because swarm plots were taking excessive time to render on this dataset.
#
# * The strip plot is allowing faster execution while still preserving the core objective of showing dispersion, clustering, and outliers.
#
# * This chart is helping to evaluate whether richer assortments consistently translate into higher customer traffic.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Stores with assortment type c tend to attract higher customer volumes more frequently than the other assortment types.
#
# * Assortment type a appears to perform steadily but is less likely to produce very high-footfall stores.
#
# * Assortment type b is both limited in count and inconsistent in customer attraction.
#
# * The presence of many overlapping points suggests that assortment alone is not the only driver of customer traffic and must be analysed alongside other factors such as location, promotions, and competition.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * The insight supports prioritising assortment type c in high-potential locations to maximise customer traffic.
#
# * It helps merchandising teams justify investments in broader assortments where customer demand exists.
#
# * The faster-performing visualization ensures smoother analysis workflows and better productivity.
#
#
# **Possible Risks / Negative Impact:**
#
# * Simply expanding assortment without considering store context may not guarantee higher footfall.
#
# * Stores with assortment type a or b may require promotional or operational interventions rather than assortment expansion.
#
# * Ignoring execution performance (stock availability, layout, staffing) could lead to diminishing returns even with richer assortments.

# %% [markdown]
# ##### Chart 33 - ZeroSalesWhileOpen Anomaly or Poor Performance ?

# %%
# Chart - 33 Visualisation Code

# Features Used - Customers, ZeroSalesWhileOpen

# ✅ Why this chart is important to include?
# This chart helps me understand how customer footfall behaves on days where the store was open
# but sales recorded as zero. If customer count is high but sales are zero, it's a strong indicator
# of operational or data recording issues. If customer count is ~0 even when 'Open' shows 1,
# it suggests incorrect labeling or exceptional cases.
# This is crucial for identifying anomalies before modeling.

# ------------------------------------------------------------------------------------------------ #

# Setting plot style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# Plotting boxplot
sns.boxplot(
    data=df,
    x='ZeroSalesWhileOpen',
    y='Customers',
    palette=['skyblue','salmon']
)

# Adding median labels manually
medians = df.groupby('ZeroSalesWhileOpen')['Customers'].median()
positions = range(len(medians))

for pos, median_val in zip(positions, medians):
    plt.text(
        pos, median_val + 20,               # position slightly above median line
        f"Median = {int(median_val)}",      # text
        horizontalalignment='center',
        fontweight='bold',
        color='black'
    )

# Adding titles and labels
plt.title("Impact of Zero Sales While Store Was Open on Customer Footfall",
          fontsize=16, fontweight='bold')
plt.xlabel("Zero Sales While Open (0 = No, 1 = Yes)", fontsize=12)
plt.ylabel("Number of Customers", fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * When ZeroSalesWhileOpen = 0, the typical customer footfall has a median of 609 customers, showing normal store activity.
#
# * When ZeroSalesWhileOpen = 1, the median customer count drops to 0, meaning these events occur only when customer footfall was absent or extremely low.
#
# * The pattern strongly suggests that - zero-sales-while-open cases are either data labeling issues, incorrect open flag, or rare operational exceptions, not actual lost-sales events.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose this chart because ZeroSalesWhileOpen is one of the most important anomaly-flag features created during data wrangling.
#
# * To understand whether these events are due to genuine zero customer visits or due to operational failures, I need to compare customer footfall between normal days and anomaly days.
#
# * A boxplot clearly shows the difference in medians and the spread, making it easy to validate the reliability of the ZeroSalesWhileOpen flag.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * For normal days (ZeroSalesWhileOpen = 0), stores receive a median of 609 customers, with a wide spread up to even 7000+ customers.
#
# * For anomaly days (ZeroSalesWhileOpen = 1), the median customer count is 0, and almost all values are zero or extremely close to zero.
#
# * This tells me that these events are not actually “sales failure despite customers being present”.
# Rather, they look like:
#
#     * Wrongly tagged open status,
#
#     * Stores marked as open even though they were practically not operating,
#
#     * Or extremely rare edge cases with truly no footfall.
#
#
# * There is no evidence of high customer count combined with zero sales — which means no strong sign of POS failure or operational breakdown.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact :**
#
# * This analysis confirms that ZeroSalesWhileOpen does not represent revenue loss events — the stores had little to no customers anyway.
#
# * I can treat most of these records as harmless anomalies rather than true operational failures.
#
# * During modeling, I can safely keep this feature or even remove these records without worrying about losing meaningful business information.
#
# * Understanding this prevents me from falsely assuming revenue leakage or system issues.
#
#
# **Negative growth / risk signals:**
#
# * Although the count of ZeroSalesWhileOpen is extremely small, their presence suggests inconsistent data labeling of store open/close status.
#
# * If not cleaned, these anomalies could add noise to the forecasting model and slightly affect accuracy.
#
# * Ensuring correct open/closed labels would improve the dataset's long-term reliability.

# %% [markdown]
# #### Part 3 - Sales Efficiency / Profitability

# %% [markdown]
# ##### Chart 34 - Promo vs SalesPerCustomer

# %%
# Chart 34 - Visualization Code

# Features Used - Promo, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart examines whether promotions influence how much a customer spends per visit.
# It helps me understand if promotions only attract more customers or if they actually increase
# the average spending of each customer. This is key for measuring promotion profitability.

# ---------------------------------------------------------------------------------------------------------- #

# Setting consistent visual style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(8,6))

# Plotting boxplot to compare SalesPerCustomer between promo and non-promo periods
sns.boxplot(
    data=df,
    x='Promo',
    y='SalesPerCustomer',
    palette=['#AED581', '#FFB74D'],
    width=0.5
)

# Adding chart title and axis labels
plt.title('Impact of Promotions on Average Sales per Customer', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Promo (0 = No, 1 = Yes)', fontsize=12)
plt.ylabel('Average Sales per Customer', fontsize=12)

# Annotating medians for clarity
medians = df.groupby('Promo')['SalesPerCustomer'].median()
for i, val in enumerate([0, 1]):
    plt.text(i, medians[val] + 0.5, f'Median = {round(medians[val], 2)}',
             ha='center', fontsize=10, fontweight='bold', color='black')

# Grid and styling adjustments
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
#
# * Median SalesPerCustomer without promo: 7.87
#
#
# * Median SalesPerCustomer with promo: 9.87
#
#
# * Customers actually spend more per visit during promotions, showing an uplift of roughly 25%.
#
#
# * Outliers increase under promo periods, suggesting some customers make significantly larger purchases when discounts/offers are active.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose this chart because it helps me understand something very important: Do promotions change customer behavior, or do they only increase footfall?
#
# * This boxplot makes it easy to compare how much customers spend per visit both with and without promotions.
#
# * It helps me check whether promotions are genuinely increasing customer spending or if they are only driving store traffic.
#
# * Since my target variable is Sales, understanding how promotions affect “spending per customer” is crucial for modeling and business insights.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Customers spend more per visit during promo periods — the median rises from 7.87 to 9.87.
#
# * This clearly shows that promotions don’t just bring more customers (we saw that in earlier charts) — they also encourage customers to purchase more items or higher-value products.
#
# * There are more high-value outliers during promos (30+, 40+, even 50+), indicating that some customers take advantage of the discount to make bulk purchases.
#
# * Overall, promotions have a positive and consistent impact on customer spending behavior.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive business impact:**
#
# * Promotions increase the average basket size, which directly boosts revenue.
#
# * This insight helps Rossmann plan high-impact promo campaigns during months/weeks where the natural footfall is lower.
#
# * Since customers spend more during promotions, Rossmann can design combo packs or targeted offers to further increase basket value.
#
# * The strong uplift also helps in forecasting, since promo periods clearly behave differently from normal days.
#
# **⚠️ Negative or risk considerations:**
#
# * Overuse of promotions may reduce full-price purchases, training customers to wait for discounts.
#
# * If not controlled, promo-driven spikes can create inventory pressure (some stores may sell out faster).
#
# * Promotions may not uplift spending equally across all stores (urban vs rural performance can vary).

# %% [markdown]
# ##### Chart 35 - Monthly Sales Per Customer

# %%
# Chart 35 - Visualization Code
# Features Used - Month, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart helps me understand how average customer spending changes across months.
# If SalesPerCustomer increases or decreases consistently in certain months,
# it indicates seasonal shifts in how much each customer is willing to spend.
# This is useful for planning promotions, inventory, and seasonal strategies.

# ---------------------------------------------------------------------------------------------------------- #

# Grouping by month to calculate average SalesPerCustomer
monthly_spc = (
    df.groupby('Month')['SalesPerCustomer']
    .mean()
    .reset_index()
    .sort_values('Month')
)

# Setting consistent chart style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# Line plot showing month-wise changes
sns.lineplot(
    data=monthly_spc,
    x='Month',
    y='SalesPerCustomer',
    color='darkgreen',
    linewidth=2.5,
    marker='o'
)

# Adding filled area to improve readability
plt.fill_between(
    monthly_spc['Month'],
    monthly_spc['SalesPerCustomer'],
    alpha=0.2,
    color='lightgreen'
)

# Chart Title and Labels
plt.title('Monthly Trend of Average Sales per Customer', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Average Sales per Customer', fontsize=12)

# Month labels
plt.xticks(
    ticks=range(1,13),
    labels=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
)

# Final styling
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.box(False)

# Show plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * SalesPerCustomer stays fairly stable throughout the year, mostly between 7.5 and 8.1.
#
# * Slight peaks occur in February, June, and November.
#
# * Noticeable dips occur around May and October, where customers spend a little less on average.
#
# * Overall, the average value remains steady, suggesting consistent customer spending behavior despite monthly variations in traffic.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose this chart because it helps me understand whether monthly spending patterns change significantly throughout the year.
#
# * Earlier charts showed that customer footfall stays almost stable, but this chart tells me if the amount each customer spends also remains stable or if there are seasonal peaks.
#
# * A line plot smoothly highlights month-to-month changes and makes spotting subtle seasonal spending trends easier.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Customers maintain a consistent spending pattern across the year with only mild fluctuations.
#
# * The highest spending appears in February (≈8.0+), suggesting early-year campaigns or seasonal shopping influence spending.
#
# * A dip occurs in May, where average SalesPerCustomer drops to around 7.4 - 7.5, indicating a mild slowdown in customer buying behavior.
#
# * Another drop in October suggests customers may be delaying purchases until November or December promotional periods.
#
# * Peaks in June and November hint that customers may take advantage of mid-year or year-end offers.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive business impact:**
#
# * The overall stability in SalesPerCustomer gives Rossmann a predictable revenue base, which is helpful for forecasting.
#
# * Small seasonal peaks can be used strategically — for example, boosting promotions in May and October to counter the observed dips.
#
# * Since customers consistently spend around the same amount, Rossmann can focus on driving footfall rather than drastically trying to increase average spend.
#
# **⚠️ Negative or risk considerations:**
#
# * The dips in May and October could indicate lower product demand, potential store fatigue, or poorly timed promotions.
#
# * Without proactive planning, these low-spend months could result in mild revenue slowdowns.
#
# * If competitors capitalize on these periods with strong offers, Rossmann may lose some share without targeted promotions.

# %% [markdown]
# ##### Chart 36 -  DayOfWeek vs SalesPerCustomer

# %%
# Chart 36 - Visualization Code
# Features Used - DayOfWeek, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart helps me understand how average customer spending varies across the week.
# Even if customer footfall changes by day, the amount each customer spends may show a different pattern.
# Knowing which days customers spend more (or less) is useful for planning weekday promotions,
# staffing, and revenue forecasting.

# ---------------------------------------------------------------------------------------------------------- #

# Grouping by DayOfWeek to calculate average SalesPerCustomer
dow_spc = (
    df.groupby('DayOfWeek')['SalesPerCustomer']
    .mean()
    .reset_index()
    .sort_values('DayOfWeek')
)

# Setting consistent plot style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# Bar plot showing average spending per customer across weekdays
sns.barplot(
    data=dow_spc,
    x='DayOfWeek',
    y='SalesPerCustomer',
    palette='viridis'
)

# Adding chart title and axis labels
plt.title('Average Sales per Customer by Day of the Week', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Day of the Week (1 = Monday, 7 = Sunday)', fontsize=12)
plt.ylabel('Average Sales per Customer', fontsize=12)

# Adding annotations on top of bars
for index, row in dow_spc.iterrows():
    plt.text(
        row['DayOfWeek'] - 1,
        row['SalesPerCustomer'] + 0.1,
        f"{round(row['SalesPerCustomer'], 2)}",
        ha='center',
        fontsize=10,
        fontweight='semibold'
    )

# Customizing grid
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
#
# * SalesPerCustomer is consistently high across weekdays (around 8.6 to 9.5).
#
# * Tuesday has the highest average spending (9.48), followed closely by Monday (9.41).
#
# * Sunday drops sharply to 0.16, which makes sense because most stores are closed.
#
# * Overall, customers spend almost the same amount per visit from Monday to Saturday — only the footfall changes.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose this chart because even though earlier charts showed how footfall varies by weekday, I needed to understand whether customer spending follows the same pattern.
#
# * A bar chart makes the weekday comparison very easy and helps highlight subtle differences in average spending behavior.
#
# * This chart also helps confirm if weekdays with high traffic also bring in higher spending per customer — which is important for forecasting and operational planning.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Tuesday leads with the highest SalesPerCustomer (9.48), suggesting customers shop more per visit at the start of the week.
#
# * Monday, Tuesday, Wednesday, Friday, and Saturday all fall in a tight range between 9.2–9.5, showing very stable buying behavior despite changes in footfall.
#
# * Thursday dips slightly (8.64), indicating a small slowdown in spending mid-week.
#
# * Sunday averages just 0.16, which is expected since stores are mostly closed — reinforcing why Sunday appears as an outlier in many charts.
#
# * The consistency suggests customers' per-visit spending habits are stable and don’t fluctuate much across days.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact:**
#
# * The stable spending pattern across weekdays shows that Rossmann's revenue variations mainly come from changes in footfall, not changes in customer spending.
#
# * The strong performance on Monday and Tuesday suggests these are good days for launching weekly offers or new product placements.
#
# * Since SalesPerCustomer is consistent, Rossmann can forecast daily revenue more confidently using footfall as the key driver.
#
# * Thursday's slight drop can be offset with targeted small-midweek promo campaigns.
#
#
#
# **⚠️ Negative or Risk Considerations:**
#
# * Sunday's extremely low number shows a predictable revenue drop — stores needing flexibility may consider limited-hour opening in select regions if legally allowed.
#
# * Since spending doesn't fluctuate much, the business can't rely on customers spending more on specific days — growth depends more on increasing customer visits.

# %% [markdown]
# ##### Chart 37 - Impact of Long Running Promo Activity on Sales per Customer

# %%
# Chart 37 - Visualization Code
# Features Used - IsPromo2Active, SalesPerCustomer

# ✅ Why this chart is important?
# This chart helps me analyze whether long-term promotions (Promo2)
# influence how much customers spend per visit.
# Promo2 is a recurring promotion active in specific months,
# so this visualization shows if it increases basket size or not.

# ---------------------------------------------------------------------------------------------------------- #

# Setting visual style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(8,6))

# Plotting boxplot for SalesPerCustomer vs Promo2 activity
sns.boxplot(
    data=df,
    x='IsPromo2Active',
    y='SalesPerCustomer',
    palette=['#AED6F1', '#F9E79F'],
    width=0.5
)

# Adding title and labels
plt.title('Impact of Long-Term Promotion (Promo2) on Sales per Customer',
          fontsize=16, fontweight='bold', color='black')
plt.xlabel('Is Promo2 Active? (0 = No, 1 = Yes)', fontsize=12)
plt.ylabel('Average Sales per Customer', fontsize=12)

# Adding median annotations
medians = df.groupby('IsPromo2Active')['SalesPerCustomer'].median()

for i, val in enumerate([0,1]):
    plt.text(
        i,
        medians[val] + 0.4,
        f"Median = {round(medians[val], 2)}",
        ha='center',
        fontsize=10,
        fontweight='bold',
        color='black'
    )

# Styling
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)

# Show plot
plt.show()

# %% [markdown]
# **Summary —**
#
# * Median SalesPerCustomer when Promo2 is inactive: 8.61
#
# * Median SalesPerCustomer when Promo2 is active: 9.26
#
# * Promo2 causes a moderate increase in how much customers spend per visit.
#
# * The overall distributions look similar, meaning Promo2 provides steady uplift, not dramatic spikes

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I included this chart because Promo2 is a long-term, recurring promotion, and I wanted to check if it influences how much customers spend per visit.
#
# * A boxplot works perfectly here because it shows how the spending distribution shifts when Promo2 is active, along with medians and outliers.
#
# * This helps me understand whether Promo2 affects customer behaviour in a meaningful and consistent way.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Customers do spend slightly more when Promo2 is active — median increases from 8.61 to 9.26.
#
# * The uplift is not as strong as Promo1 (short-term promotions), but it is consistent, indicating Promo2 quietly encourages customers to add more items to their basket.
#
# * Outliers appear in both groups, but Promo2 has slightly more high-value purchases, which suggests that certain customers take advantage of recurring deals to make larger purchases.
#
# * The spread remains similar, meaning Promo2 influences the average customer, not just a few heavy spenders.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impacts :**
#
# * Promo2 has a steady and predictable effect on increasing customer basket size, even if the uplift is moderate.
#
# * This helps Rossmann maintain stable revenue during months when short-term promos aren’t running.
#
# * It also confirms that Promo2 contributes to customer loyalty and higher average order values, which is great for long-term revenue planning.
#
# * Actionable insight: Combine Promo2 with short-term campaigns (Promo1) to amplify sales lift while maintaining baseline engagement.
#
#
# **Negative-growth / risk signals & mitigation:**
#
# * Since the uplift is mild, Promo2 alone may not justify high promotional costs unless paired with seasonal campaigns.
#
# * If Promo2 runs too frequently, customers may begin to ignore it, reducing its long-term impact.
#
# * Stores in low-traffic areas might not see the same benefit, so Promo2 performance may vary regionally.
#
# * Recommendation: Introduce varied promo formats (e.g., bundle offers, loyalty points) instead of constant discounts to sustain interest.
#
# * Outlier check: Investigate stores showing very high per-customer sales without Promo2 — replicate their strategies in other stores.

# %% [markdown]
# #### Part 4 - Store Level Performance

# %% [markdown]
# ##### Chart 38 - Top 10 Stores By Sales

# %%
# Chart - 38 Vizualisation Code

# Features Used - Store, Sales

# ✅ Why this chart is important to include?
# I am plotting the top 10 stores by total sales with store ID on the x-axis and sales on the y-axis.
# This layout is better for ranking (left-to-right) and is easier to read when store IDs are primary labels.

# ---------------------------------------------------------------------------------------------------------- #

# Preparing the top-10 data (summing sales per store)
top10 = (
    df.groupby('Store', as_index=False)['Sales']
      .sum()
      .sort_values('Sales', ascending=False)
      .head(10)
)

# Converting Store to string (safe for plotting) and keeping current ranking order
top10['Store'] = top10['Store'].astype(str)
top10 = top10.reset_index(drop=True)

# Scale sales to millions for nicer axis ticks and annotations
top10['Sales_Million'] = top10['Sales'] / 1_000_000

# Setting the visual style
sns.set(style='whitegrid')

# Create figure (vertical bars)
plt.figure(figsize=(12,6))
ax = sns.barplot(
    data=top10,
    x='Store',
    y='Sales_Million',
    palette='Blues_d'
)

# Title and axis labels
plt.title('Top 10 Stores by Total Sales', fontsize=16, fontweight='bold')
plt.xlabel('Store ID', fontsize=12)
plt.ylabel('Total Sales (Millions)', fontsize=12)

# Rotate x labels for readability
plt.xticks(rotation=45, ha='right')

# Annotate each bar with sales value (safe offset: 1.5% of max)
max_m = top10['Sales_Million'].max()
y_offset = max_m * 0.015  # 1.5% of max value

for i, row in top10.iterrows():
    ax.text(
        i,                                 # x-position (bar index)
        row['Sales_Million'] + y_offset,   # y-position (just above the bar)
        f"{row['Sales_Million']:.2f}M",    # text
        ha='center',
        va='bottom',
        fontsize=10,
        fontweight='semibold'
    )

# Tight layout and show
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary -**
#
# * Store 262 leads with the highest total sales: ₹19.52M
#
# * Next strong performers are 817 (₹17.06M), 562 (₹16.93M), and 1114 (₹16.20M)
#
# * The top 10 stores all lie in the ₹12.9M – ₹19.5M range
#
# * These stores consistently outperform the rest of the chain and are likely located in high-traffic or high-demand regions
#
# * The gap between Rank 1 and Rank 10 is ~₹6.6M, indicating meaningful variation in store-level performance

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose a bar chart because it's the most intuitive way to show:
#
#     * which stores generate the highest total sales,
#
#     * how they rank relative to each other, and
#
#     * how big the actual difference is between them.
#
#
# * This chart makes it extremely easy to compare store-level performance and directly spot the heavy hitters in the business.
#
# * Since store IDs are categorical values, a vertical bar chart is the cleanest and most readable option.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 🔹 1. Store 262 is the clear top performer -
#
#   * It generates ₹19.52M, significantly ahead of all others.
#
#   * It alone contributes almost 6% higher sales than Store 817 (rank 2).
# This store likely benefits from strong location, customer base, promotions, or assortment mix.
#
#
# 🔹 2. The top 4 stores form a strong tier -
#
#   * Stores 817, 562, and 1114 are all in the
#    ₹16.2M - ₹17.1M range.
#   * Their performance is very consistent and slightly below Store 262.
#
# 🔹 3. Mid-top performers (Rank 5 to Rank 10)
#
#   * These stores fall between ₹12.9M and ₹14.9M:
#
#   * Stores 251, 513, 788, 733, 383, 756
# These are stable high-performing stores but not at the same level as the top 4.
#
#
#
# 🔹 4. The sales drop from rank 1 to rank 10 is ~₹6.6M -
#
# This indicates:
#
#   * performance varies meaningfully based on location, competition, and store characteristics
#
#   * there is upside potential for lower-performing stores if they adapt strategies from the top performers
#
#
# 🔹 5. Consistency across the top stores
#
#   * None of the top stores are drastically lower than others, showing a solid cluster of well-performing outlets.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  **✅ Positive Business Impact :**
#
#   1. Identify what top stores are doing right
#
# * I can analyze:
#
#     * which promotions they run,
#
#     * what store type they are,
#
#     * their assortment category,
#
#     * how intense the local competition is,
#
#     * their customer footfall patterns.
#
#
# * If I replicate those success factors in mid-tier stores, I can lift overall revenue.
#
# 2. Prioritise resource allocation
#
# * Top stores can be given:
#
#     * more optimized inventory,
#
#     * staffing support,
#
#     * targeted high-value campaigns,
#
#     * priority for new product launches.
#
#
# * This ensures higher ROI because these stores already show strong performance.
#
#
# 3. Benchmarking stores
#
# * The performance gap provides a benchmark.
#
# * If Store A is doing ₹19.5M and Store B only ₹13M, I can deep-dive into operational differences.
#
#
# ---
#
# **⚠️ Negative-Growth / Risk Signals & Mitigation:**
#
# 1. Over-dependence on a few high-performing stores
#
# * If these top 10 stores are contributing disproportionately to revenue, any disruption at these stores (renovations, local restrictions, competition openings) can impact revenue significantly.
#
# * Mitigation: Strengthen the mid-tier stores so revenue is more evenly distributed.
#
# 2. Large performance gap
#
# * A gap of ₹6.6M between Rank 1 and Rank 10 shows inconsistent store performance.
#
# * Mitigation: Evaluate weaker stores for:
#
#     * stockouts
#
#     * poor local demand
#
#     * staffing issues
#
#     * weak promotion effectiveness
#
#
# 3. Potential operational bottlenecks
#
# * If the top stores are overloaded (higher footfall), it can lead to long queues, poor service, and customer dissatisfaction.
#
# * Mitigation: audit operational capacity & optimize staffing.

# %% [markdown]
# ##### Chart 39 - Top 10 Poorly Performing Stores

# %%
# Chart - 39 Vizualisation Code

# Features Used - Store, Sales

# ✅ Why this chart is important to include?
# This chart is showing the weakest revenue-generating stores so I can pinpoint
# locations that need operational, assortment, or marketing fixes.
# By placing store ID on the x-axis and sales on the y-axis I am making the ranking
# easy to read left-to-right and directly comparable to the Top 10 chart.

# ---------------------------------------------------------------------------------------------------------- #

# Aggregating total sales per store and selecting bottom 10
bottom10 = (
    df.groupby('Store', as_index=False)['Sales']
      .sum()
      .sort_values('Sales', ascending=True)
      .head(10)
)

# Converting Store to string to ensure clean x-axis labels and resetting order
bottom10['Store'] = bottom10['Store'].astype(str)
bottom10 = bottom10.reset_index(drop=True)

# Scaling sales to millions for readable axis ticks
bottom10['Sales_Million'] = bottom10['Sales'] / 1_000_000

# Setting visual style consistent with project
sns.set(style='whitegrid')

# Creating the figure (vertical bars)
plt.figure(figsize=(12,6))
ax = sns.barplot(
    data=bottom10,
    x='Store',
    y='Sales_Million',
    palette='Blues_r'
)

# Adding title and axis labels
plt.title('Bottom 10 Stores by Total Sales', fontsize=16, fontweight='bold')
plt.xlabel('Store ID', fontsize=12)
plt.ylabel('Total Sales (Millions)', fontsize=12)

# Rotating x labels for readability
plt.xticks(rotation=45, ha='right')

# Annotating each bar with the scaled sales value (safe offset: 1.5% of max)
max_m = bottom10['Sales_Million'].max()
y_offset = max_m * 0.015

for i, row in bottom10.iterrows():
    ax.text(
        i,                                 # x-position (bar index)
        row['Sales_Million'] + y_offset,   # y-position (just above bar)
        f"{row['Sales_Million']:.2f}M",    # annotation text
        ha='center',
        va='bottom',
        fontsize=10,
        fontweight='semibold'
    )

# Tight layout and show
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart highlights the bottom 10 stores in terms of total revenue.
#
# * Their total sales range roughly between 2.11M and 2.40M, which is significantly lower than average-performing stores.
#
# * These stores consistently underperform across the entire dataset, indicating potential operational, demographic, or competitive issues.
#
# * This helps me identify locations that may need urgent attention, such as marketing reinforcement, assortment changes, or better store management.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose a vertical bar chart because it gives a very clear picture of which stores are performing the worst in terms of total revenue.
#
# * Since store-level performance is extremely important in retail analytics, plotting each store ID on the x-axis and its aggregated sales on the y-axis helps me easily spot the weakest performers.
#
# * This also creates a direct comparison with the Top 10 stores chart, making it easier to highlight the gap between high- and low-performing outlets.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * These 10 stores — including IDs 307, 543, 198, 208, 263, 841, 879, 254, 186, and 972 — have the lowest cumulative sales among all stores.
#
# * Their total sales range from 2.11M to 2.40M, which is noticeably lower compared to the overall store distribution.
#
# * The fact that the gap is relatively narrow suggests that these stores consistently perform poorly and never experience strong peak periods.
#
# * This may signal:
#
#     * Weak store location (low footfall area)
#
#     * High competitor presence nearby
#
#     * Ineffective assortment or store size
#
#     * Poor promotion execution
#
#     * Customer base limitations (e.g., rural/low-income area)

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact :**
#
# * Identifying the bottom stores allows me to target interventions instead of wasting effort on stores that are already performing well.
#
# * These stores are prime candidates for:
#
#     * Localized marketing or promotional campaigns
#
#     * Optimizing product assortment based on demand
#
#     * Re-evaluating store layout, staffing, or operations
#
# * Introducing promotional strategies that worked well for high-performing stores
#
#
# * If I improve even a few of these low-performing stores, the aggregate business uplift can be significant because these stores currently contribute very little to total revenue.
#
#
# **Negative-growth risk signals:**
#
# * If these stores are left unattended, they may drag down overall regional performance.
#
# * Chronic underperformance could signal deeper structural issues like poor store placement or low local demand.
#
# * Repeatedly low sales may cause inventory stagnation, increasing storage and operational costs.
#
# * If competitor stores are located closer or offer stronger promotions, these stores may continue losing footfall, creating a long-term negative trend.

# %% [markdown]
# ##### Chart 40 - Top 10 Stores by Customers

# %%
# Chart - 40 Visualisation Code

# Features Used - Store, Customers

# ✅ Why this chart is important to include?
# This chart is showing me which stores attract the highest number of customers.
# While sales give revenue insights, customer footfall reflects true store popularity.
# Identifying top customer-heavy stores helps in planning staffing, inventory,
# and understanding which locations consistently draw in more people.

# ---------------------------------------------------------------------------------------------------------- #

# Aggregating total customers per store and selecting the top 10 stores
top10_customers = (
    df.groupby('Store', as_index=False)['Customers']
      .sum()
      .sort_values('Customers', ascending=False)
      .head(10)
)

# Converting store IDs to string for clean x-axis labeling
top10_customers['Store'] = top10_customers['Store'].astype(str)

# Scaling total customers to thousands for cleaner plotting
top10_customers['Customers_K'] = top10_customers['Customers'] / 1_000

# Setting consistent visual style
sns.set(style='whitegrid')

# Creating the figure for vertical bar chart
plt.figure(figsize=(12,6))
ax = sns.barplot(
    data=top10_customers,
    x='Store',
    y='Customers_K',
    palette='Greens_d'
)

# Adding the title and labels
plt.title('Top 10 Stores by Total Customers', fontsize=16, fontweight='bold')
plt.xlabel('Store ID', fontsize=12)
plt.ylabel('Total Customers (in Thousands)', fontsize=12)

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Annotating values above each bar safely (1.5% offset)
max_val = top10_customers['Customers_K'].max()
y_offset = max_val * 0.015

for index, row in top10_customers.iterrows():
    plt.text(
        index,
        row['Customers_K'] + y_offset,
        f"{row['Customers_K']:.1f}K",
        ha='center',
        fontsize=10,
        fontweight='semibold'
    )

# Final layout adjustments
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary -**
#
# * The top 10 stores by customer footfall receive between 1.9K to 3.2K thousand customers in total.
#
# * Stores 733, 262, 562, and 769 lead the list with the highest footfall, showing consistently high customer attraction.
#
# * Stores like 251 and 259, although in the top 10 for customers, appear much lower when we compare them against the top 10 stores by sales.
#
# * Comparing footfall and sales reveals that some stores convert high customer visits into strong revenue (e.g., 262, 562, 1114, 817) while others underperform in sales despite high footfall — which highlights conversion efficiency differences.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I included this chart because customer footfall is one of the core indicators of store performance. While sales reflect revenue, customer count reflects store popularity, reach, and traffic strength.
#
# * Understanding which stores attract the most customers helps me identify:
#
#     * High-traffic zones
#
#     * Potential flagship or anchor stores
#
#     * Stores that might require higher staffing, more stock, or better operational planning
#
#
# * It also allows me to compare high-footfall stores with high-sales stores to understand conversion efficiency.
#
# * This chart completes the store-level performance analysis by revealing the demand-side behavior.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here are the insights derived by comparing customer footfall with sales performance:
#
# ---
#
# 🔹 High Footfall + High Sales (Strong Performing Stores)
#
# Stores 262, 562, 1114, 817 appear in both top lists —
# * They attract a lot of customers and convert that traffic into strong sales.
#
# * These are your “star performers” and likely have:
#
#     * Good location
#
#     * Effective promotions
#
#     * Strong assortment mix
#
#     * Higher store size or wider product variety
#
#
#     * These stores are important benchmarks.
#
#
# ---
#
# 🔹 High Footfall + Moderate Sales (Low Conversion Stores)
#
# * Stores like 733 and 769 rank high in customer footfall but do NOT appear in the top 10 sales list.
# This means:
#
# * These stores are getting customers but not converting visits into purchases effectively.
#
# * Possible reasons:
#
#     * Poor assortment relevance
#
#     * More window shoppers than actual buyers
#
#     * Pricing mismatch
#
#     * Strong competition nearby
#
#     * Smaller basket size per customer
#
#
# * These stores need conversion-focused interventions.
#
#
# ---
#
# 🔹 Lower Footfall in Top 10 Sales (High Efficiency Stores)
#
# * Stores like 513, 788, 383, 756 appear in top sales but NOT in top customers.
#
# * This means:
#
#     * These stores have high spending per customer
#
#     * Strong conversion efficiency
#
#     * Likely located in areas with fewer but higher-value customers
#
#     * May benefit from premium assortment or brand loyalty
#
#
# * Understanding this pattern is extremely useful for targeted strategies.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact / what can be done:**
#
# * The analysis helps identify high-traffic stores that deserve more inventory, more staff, or better promotional support to maximize revenue.
#
# * Stores with high customers but low sales (like 733 or 769) can be targeted with strategies to improve conversion such as:
#
#     * Localized promotions
#
#     * Better merchandising
#
#     * Cross-selling and up-selling
#
#     * Correcting assortment gaps
#
#
# * Stores with low footfall but high sales efficiency provide insights into premium behavior and can be used as models for strategic replication.
#
# * Retail teams can use this to plan store expansions, renovations, and resource allocation.
#
#
#
# ---
#
# **Negative-growth signals / risks identified:**
#
# * High customer stores with poor conversion represent missed revenue potential — this can directly impact profitability.
#
# * If stores are attracting traffic but not generating comparable sales, the retailer is carrying unnecessary operational costs without maximizing revenue.
#
# * Persistent low conversion may indicate deeper issues such as competition, poor store layout, or ineffective assortment alignment — all of which could lead to long-term revenue decline if not addressed.

# %% [markdown]
# ##### Chart 41 - Top 10 Stores by Conversion Rate

# %%
# Chart - 41 Visualisation Code

# Features Used - Store, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart is showing me which stores convert their customer footfall into actual revenue most effectively.
# A store might not have the highest number of customers, but still generate high revenue due to a strong conversion rate.
# Identifying such stores helps reveal operational excellence and premium customer behaviour.

# ---------------------------------------------------------------------------------------------------------- #

# Creating conversion rate metric: Total Sales / Total Customers per store
conversion_df = (
    df.groupby('Store', as_index=False)
      .agg({'Sales': 'sum', 'Customers': 'sum'})
)

# Avoiding division errors
conversion_df = conversion_df[conversion_df['Customers'] > 0]

# Calculating conversion rate
conversion_df['ConversionRate'] = conversion_df['Sales'] / conversion_df['Customers']

# Selecting top 10 stores by conversion rate
top10_conversion = (
    conversion_df.sort_values('ConversionRate', ascending=False)
                 .head(10)
)

# Converting store IDs to string for cleaner labeling
top10_conversion['Store'] = top10_conversion['Store'].astype(str)

# Setting plot style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(12,6))
ax = sns.barplot(
    data=top10_conversion,
    x='Store',
    y='ConversionRate',
    palette='Blues_d'
)

# Adding titles and labels
plt.title('Top 10 Stores by Conversion Rate (Sales per Customer)', fontsize=16, fontweight='bold')
plt.xlabel('Store ID', fontsize=12)
plt.ylabel('Conversion Rate (Sales ÷ Customers)', fontsize=12)

# Rotating x-axis labels for readability
plt.xticks(rotation=45, ha='right')

# Annotating values above each bar
max_val = top10_conversion['ConversionRate'].max()
y_offset = max_val * 0.03

for index, row in top10_conversion.iterrows():
    plt.text(
        index,
        row['ConversionRate'] + y_offset,
        f"{row['ConversionRate']:.2f}",
        ha='center',
        fontsize=10,
        fontweight='semibold'
    )

# Tight layout for cleaner appearance
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The top 10 stores with the highest conversion rate (Sales ÷ Customers) fall in the range of 14.3 to 16.3, which means these stores generate exceptionally high revenue per customer visit.
#
# * Stores 842, 612, 455, and 158 lead the list, achieving conversion rates above 15, indicating strong sales efficiency.
#
# * Many of these stores do not appear in the top 10 sales or top 10 customer traffic charts, showing that despite having moderate footfall, they excel at converting customers into buyers.
#
# * These stores represent high-efficiency units, likely serving premium customers, offering high-value assortments, or having more effective sales execution.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I included this chart because conversion rate is one of the most meaningful indicators of store-level efficiency.
#
# * While earlier charts helped identify high-traffic stores or high-revenue stores, this chart shows which stores generate the most revenue per customer.
#
# * A store might get fewer customers, but if each visitor buys more or buys higher-value items, the store becomes extremely profitable. This chart helps me detect such high-efficiency stores that were not obvious from the sales or customer charts alone.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here are the key insights based on the output:
#
# ---
#
# 🔹 1. High-conversion stores are not always high-traffic or high-sales stores
#
# * Most of these stores — including 842, 612, 455, 158, 52, and 540 — do not appear in the top 10 sales chart or the top 10 customer chart.
# This means:
#
#     * These stores have leaner traffic
#
#     * But each customer is spending significantly more
#
#     * They are efficient, high-value stores
#
#
# ---
#
#
# 🔹 2. These stores likely serve premium or high-spending customers
#
# * A conversion rate above 15 means that for every customer visiting the store, the store is generating 15 units of revenue. That's a very strong metric and often reflects:
#
#     * Higher spending patterns
#
#     * Better assortment matching customer needs
#
#     * Strong loyalty or repeat purchases
#
# ---
#
# 🔹 3. These stores may be executing merchandising and sales strategies more effectively
#
# * Stores like 842 and 612 show exceptional performance even without high footfall.
# This indicates:
#
#     * Well-curated product displays
#
#     * Effective pricing
#
#     * Better staff engagement
#
#     * Good promotional strategy at store level
#
# ---
#
# 🔹 4. These stores should be studied for “best practices”
#
# * The strategies used in these high-efficiency stores can be replicated in stores that have high footfall but poor conversion.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * These insights help identify top-performing stores from an efficiency perspective, not just from traffic or revenue.
#
# * Store managers can study the practices at these stores — assortment choices, local preferences, store layout, pricing strategy, staff behavior — to apply them to weaker stores.
#
# * By improving conversion even slightly in high-traffic stores, Rossmann can achieve a massive uplift in overall revenue.
#
# * Corporate teams can use this insight for resource prioritization, such as allocating better products or premium brands to these high-efficiency stores.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * If low-conversion stores are ignored, they will continue to underperform despite heavy footfall, leading to lost revenue potential.
#
# * These findings also highlight that Rossmann may be misallocating promotional budgets if high-efficiency stores are overlooked.
#
# * Poor-performing stores may continue draining operational resources if effective conversion strategies are not adopted.

# %% [markdown]
# ##### Chart 42 - Bottom 10 Stores by Conversion Rate

# %%
# Chart - 42 Visualisation Code

# Features Used: Store, Sales, Customers

# -------------------------------------------------------------------------------------------------
# 📌 Why this chart is important to include?
# Conversion Rate = Total Sales ÷ Total Customers
# It helps us identify stores where footfall is NOT translating into revenue.
# These stores may have:
# - poor store layout
# - weak assortment
# - inefficient pricing or promotion strategy
# - customer-service issues
# - operational inefficiencies
# Finding these underperformers is critical for business decisions and corrective actions.
# -------------------------------------------------------------------------------------------------

# 🧮 Step 1: Aggregating Sales & Customers per Store
store_perf = df.groupby('Store').agg({
    'Sales': 'sum',
    'Customers': 'sum'
}).reset_index()

# Avoiding division by zero
store_perf = store_perf[store_perf['Customers'] > 0]

# 🧮 Step 2: Calculating Conversion Rate
store_perf['ConversionRate'] = store_perf['Sales'] / store_perf['Customers']

# 🧮 Step 3: Selecting Bottom 10 Stores
bottom_10 = store_perf.nsmallest(10, 'ConversionRate')

# -------------------------------------------------------------------------------------------------
# 🎨 Visualization - Vertical Bar Chart
# -------------------------------------------------------------------------------------------------

plt.figure(figsize=(12, 6))
sns.barplot(
    data=bottom_10,
    x='Store',
    y='ConversionRate',
    palette='OrRd_r'   # reverse orange-red scale for low → very low
)

# 📌 Adding value labels
for index, row in bottom_10.iterrows():
    plt.text(
        x=index,
        y=row['ConversionRate'] + 0.05,
        s=f"{row['ConversionRate']:.2f}",
        ha='center',
        fontsize=10,
        fontweight='bold'
    )

# Titles & Labels
plt.title("Bottom 10 Stores by Conversion Rate (Sales per Customer)", fontsize=16, fontweight='bold')
plt.xlabel("Store ID", fontsize=12)
plt.ylabel("Conversion Rate (Sales ÷ Customers)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)


# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * These 10 stores have the lowest conversion efficiency—meaning customers come in, but each customer generates fewer sales compared to other stores.
#
# * Conversion rates for these stores range between 3.48 to 4.90, which is far below the best-performing stores (which are above 14+).
#
# * Store 259 is the lowest-performing store with a conversion rate of 3.48, suggesting weak sales productivity.
#
# * Some stores like 512, 676, 733 get a decent amount of footfall but still produce very low revenue per customer.
#
# * This pattern points toward assortment issues, low basket size, weak cross-selling, or ineffective in-store operations rather than footfall problems.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * This chart is essential because:
#
#     * Total sales alone don't reveal whether a store is actually efficient.
#
#     * By plotting conversion rate (Sales ÷ Customers), we quickly identify stores where customer visits don’t translate into enough sales.
#
# * It highlights operational inefficiencies and helps us find stores needing:
#
#     * layout improvements
#
#     * pricing adjustments
#
#     * better shelf placement
#
#     * stronger promotional execution
#
#     * improved staff performance
#
#
# * This chart adds a strong profitability perspective that pure footfall or pure sales charts cannot capture.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here's a clear breakdown:
#
# 1. Store 259 is the weakest performer
#
# * Conversion Rate ≈ 3.48
#
# * Indicates severe inefficiency—either customers are not buying or basket size is extremely low.
#
#
# 2. Stores 274, 335, 353 also show poor conversion
#
# * They range between 3.9-4.1, which is far below the dataset’s typical values.
#
# * Consistent issue: footfall coming in, but revenue not growing proportionately.
#
#
# 3. Stores 512, 676, and 733 stand out as mismatches
#
# * These stores appear in the top 10 stores by customer footfall in earlier charts,
# but now appear in the bottom 10 for conversion rate.
#
# * This means:
#
#     * high visitor count
#
#     * low buying behaviour
#
#     * possibly poor assortment or store-level issues
#
#
#
# 4. Stores 948 and 1097 are borderline inefficient
#
# *Conversion around 3.95-4.05, still weak.
#
# * Consistent low productivity across the month.
#
#
#
# 🔍 Key takeaway:
#
# * Low conversion = underperforming store operations, not low demand.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
#
# * This chart helps management to:
#
#   * Identify stores that need immediate operational attention (259, 274, 335, 353 are top priority).
#
#   * Improve store-level execution: better product mix, promotions, staff training, or layout optimization.
#
#   * Increase basket size through upselling and cross-selling.
#
#   * Boost profitability without increasing footfall marketing costs.
#
#
#
# **⚠️ Negative-Growth Risks -**
#
# * Stores like 259, 512, 676 may continue underperforming despite high traffic, directly hurting profit.
#
#     * Low conversion often signals:
#
#     * customer dissatisfaction
#
#     * out-of-stock issues
#
#     * poor assortment decisions
#
#     * ineffective promotions
#
#
# * If left unchecked, footfall will drop further, leading to long-term store decline.

# %% [markdown]
# #### Part 5 - Promo Behavior Analysis

# %% [markdown]
# ##### Chart 43 - Percentage of Promo Days Across Days of the Week

# %%
# Chart 43 - Vizualisation Code

# Features Used: DayOfWeek, Promo

# ✅ Why this chart is important to include?
# The earlier chart (DayOfWeek vs Promo count) showed how many promo records exist,
# but this percentage-based view helps me understand if promotions are used more
# aggressively on certain weekdays. This avoids bias caused by uneven record counts.

#----------------------------------------------------------------------------------------------------------#

# Preparing data for promo percentage per weekday
weekday_promo_rate = (
    df.groupby('DayOfWeek')['Promo'].mean().reset_index()
)

# Convert to percentage
weekday_promo_rate['PromoPercent'] = weekday_promo_rate['Promo'] * 100

# Setting style
sns.set(style="whitegrid")

# Creating the figure
plt.figure(figsize=(10,6))

# Barplot for promo % by weekday
sns.barplot(
    data=weekday_promo_rate,
    x='DayOfWeek',
    y='PromoPercent',
    palette='coolwarm'
)

# Adding labels above bars
for i, row in weekday_promo_rate.iterrows():
    plt.text(
        i,
        row['PromoPercent'] + 1,
        f"{row['PromoPercent']:.1f}%",
        ha='center',
        fontsize=10,
        fontweight='bold'
    )

# Titles and labels
plt.title("Percentage of Promo Days Across the Week", fontsize=16, fontweight='bold')
plt.xlabel("Day of the Week (1 = Monday, 7 = Sunday)", fontsize=12)
plt.ylabel("Promo Percentage (%)", fontsize=12)

# Display
plt.show()

# %% [markdown]
# **Summary -**
#
# * Promo activities remain remarkably consistent from Monday to Friday, with all five weekdays showing ~53% promo days.
#
# * Weekends (Saturday and Sunday) have 0% promo days, confirming that promotions are not scheduled on weekends.
#
# * This highlights a flat promo strategy that can be optimized for better traffic and sales uplift.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * A percentage-based bar chart makes it easy to understand how frequently promotions run on each day of the week — without being biased by differences in total record counts.
#
# * It clearly highlights promo strategy patterns, especially weekday vs weekend discrepancies.
#
# * Percentages help business teams compare promo consistency and identify whether certain weekdays are being prioritized more.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ✔ Weekdays have evenly distributed promo activity
#
# * Monday → 53.7%
#
# * Tuesday → 53.3%
#
# * Wednesday → 53.3%
#
# * Thursday → 53.2%
#
# * Friday → 53.2%
#
#
# * This shows a uniform promotion policy on weekdays.
#
#
#
# ✔ Weekends have 0% Promo Days
#
# * Saturday and Sunday = 0% promotions
#
# * This signals - Stores do not run promotions on weekends, likely due to:
#
#     * Operational guidelines
#
#     * Lower expected footfall
#
#     * Weekend closures in many stores
#
#
#
# ✔ No weekday stands out as a “special promo day”
#
# * The percentages are nearly identical → promotions are evenly spread across weekdays, not targeted.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
#
# 🔹 Operational Efficiency
#
# * Management sees that promotions are not designed around peak footfall, but evenly distributed.
#
# * If the goal is to boost lagging days (e.g., Wednesdays), targeted promo design can be introduced.
#
#
# 🔹 Sales Optimization
#
# * Since weekends have zero promotions, but customer footfall drops sharply on Sundays, introducing occasional weekend promos could boost traffic.
#
#
# 🔹 Budget & Campaign Planning
#
# * The even split suggests no experimentation — the business is missing opportunities to test:
#
#     * Promo-heavy days
#
#     * Promo-light days
#
#     * Seasonal timing strategies
#
#
#
# 🔹 Store-Level Insights
#
# * Since many stores are closed on weekends, weekend promos may make sense only for open stores — more granular analysis can follow.
#
#
#
# ---
#
#
#
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
#
# 🚩 No promotional push on weekends -
#
# * This is a lost opportunity because weekend shoppers are highly value-driven.
#
# * Even small promo activity could boost underperforming weekend sales.
#
#
# 🚩 Uniform strategy might limit learning
#
# * Running promotions equally across all weekdays prevents:
#
#     * A/B testing
#
#     * Targeted customer engagement
#
#     * Identification of weekday-specific buying behaviours

# %% [markdown]
# ##### Chart 44 - Percentage of Promo Days by Month

# %%
# Chart - 44 Visualisation Code

# Features Used: Month, Promo

# ✅ Why this chart is important to include?
# This chart shows the share (%) of days in each month where Promo = 1.
# Unlike raw counts, this reveals seasonal promotion intensity and helps
# identify strategic marketing patterns followed by the company.

#----------------------------------------------------------------------------------------------------------#

# Preparing data for percentage calculation
monthly_promo_rate = (
    df.groupby('Month')['Promo'].mean().reset_index()
)

# Converting promo rate to percentage
monthly_promo_rate['PromoPercent'] = monthly_promo_rate['Promo'] * 100

# Setting style
sns.set(style="whitegrid")

# Creating the figure
plt.figure(figsize=(10,6))

# Barplot for promo percentages
sns.barplot(
    data=monthly_promo_rate,
    x='Month',
    y='PromoPercent',
    palette='viridis'
)

# Adding labels on each bar
for idx, row in monthly_promo_rate.iterrows():
    plt.text(
        idx,
        row['PromoPercent'] + 1,
        f"{row['PromoPercent']:.1f}%",
        ha='center',
        fontsize=10,
        fontweight='bold'
    )

# Titles and labels
plt.title("Percentage of Promo Days Across Each Month", fontsize=16, fontweight='bold')
plt.xlabel("Month", fontsize=12)
plt.ylabel("Promo Percentage (%)", fontsize=12)

# Displaying
plt.show()

# %% [markdown]
# **Summary -**
#
# * Promo activity is fairly steady across the year, ranging between 32% and 41% of days per month.
#
# * March (40.9%) and April (40.0%) have the highest share of promo days — indicating a strong pre-summer push.
#
# * December (32.3%) has the lowest promo frequency despite being a high-demand month, suggesting reliance on organic seasonal demand rather than promotions.
#
# * Overall, promo planning appears consistent, with mild seasonal adjustments rather than aggressive spikes.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose this chart because raw counts of promo days (which we plotted earlier) can be misleading — months have different numbers of days.
#
# * By converting promo activity into a percentage, I can clearly understand how intensively promotions are used each month.
#
# * This helps evaluate:
#
#     * whether the company follows a seasonal promotional strategy
#
#     * if promo frequency aligns with high-sales months
#
#     * potential over- or under-utilisation of promotions
#
#
# * It’s a simple but powerful way to detect strategic patterns in marketing operations.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promotion usage is fairly stable across months, with most months having promo percentages between 36% and 40%.
#
# * The highest promo intensity occurs in:
#
#     * March: 40.9%
#
#     * April: 40.0%
#
#     * July: 38.7%
#
#
# * These peaks may correspond to seasonal marketing periods (e.g., pre-summer and mid-year sales).
#
# * December has the lowest promo rate (32.3%), yet December often shows high sales — meaning stores rely on natural festive demand rather than heavy promotions.
#
# * Months like January, June, August, September, and October also show moderate promo usage (~36–38%), indicating a consistently active promotional strategy rather than deep seasonal spikes.
#
#
# * Overall:
# 👉 Promo usage is mostly consistent, with slight seasonal boosts in March–April and July.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Identify the most effective promo seasons:
# If high-promo months also show high sales uplift, the company can replicate those strategies elsewhere.
#
# * Opportunity to optimize December strategy:
# December shows low promo % but usually high sales —
# 👉 The company might improve profit margins by reducing promos in other strong-demand periods.
#
# * Helps in campaign budgeting:
# Knowing which months already have high organic sales can help shift promotional budgets to weaker months.
#
# * Improves forecasting accuracy:
# Promo frequency is a strong predictor of sales — adding this insight improves future model performance.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Over-dependency on promotions (36–41% is quite high):
#
#     * If nearly 40% of days depend on promos, customers may become deal-dependent, harming long-term margins.
#
# * Low promo usage in competitive months:
#     * If competitors run heavy promotions in December while Rossmann does not, it might lose market share.
#
#
# * Overall:
#
#     👉 The patterns give a strong strategic foundation for improving promo planning and optimizing marketing ROI.

# %% [markdown]
# ##### Chart 45 - Percentage of Promo Days Across Store Types

# %%
# Chart - 45 Visualisation Code

# Features Used: StoreType, Promo

# ✅ Why this chart is important to include?
# This chart is showing how frequently each store type runs short-term promotions.
# Because raw counts can be misleading due to unequal store distribution,
# calculating the percentage allows us to understand each store type’s *strategic promotion intensity*.
# This helps in identifying which store formats rely heavily on promotions and which operate with fewer discounts.

# ------------------------------------------------------------------------------------------------------ #

# Preparing the data by calculating Promo percentage for each store type
promo_rate_storetype = (
    df.groupby('StoreType')['Promo']
      .mean()
      .reset_index()
      .rename(columns={'Promo': 'PromoPercent'})
)

# Converting to percentage format
promo_rate_storetype['PromoPercent'] *= 100

# Setting visualization style
sns.set(style="whitegrid")

# Creating the figure
plt.figure(figsize=(10,6))

# Creating barplot to visualize promo percentages
sns.barplot(
    data=promo_rate_storetype,
    x='StoreType',
    y='PromoPercent',
    palette='coolwarm'
)

# Adding data labels on bars
for idx, row in promo_rate_storetype.iterrows():
    plt.text(
        idx,
        row['PromoPercent'] + 1,
        f"{row['PromoPercent']:.1f}%",
        ha='center',
        fontsize=10,
        fontweight='bold'
    )

# Adding titles and labels
plt.title("Percentage of Promo Days Across Store Types", fontsize=16, fontweight='bold')
plt.xlabel("Store Type", fontsize=12)
plt.ylabel("Promo Percentage (%)", fontsize=12)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * All four store types (A, B, C, D) run promotions at almost the same intensity — around 38.2% of all operating days.
#
# * This shows that short-term promotions are being applied uniformly across store formats, meaning the company follows a standardized promotional strategy rather than tailoring promotions to store type characteristics.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I included this chart to understand whether certain store formats depend more heavily on promotions.
#
# * Instead of raw promo counts, using percentages helps compare fairly because each store type has a different number of stores and operating days.
#
# * This chart tells me whether promotions are used strategically for specific store types or distributed uniformly.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Key Insight:**
#
#
# * All four store types (a, b, c, d) have almost identical promo percentages (~38.2%).
#
#
# * What this means:
#
#   * No store type is given special promotional advantage.
#
#   * Promotions are executed uniformly, regardless of store size, assortment, or customer profile.
#
#   * Store performance differences cannot be attributed to uneven promo distribution.
#
#   * Any gap in sales between store types is likely due to other factors such as:
#
#     * location quality
#
#     * customer demographics
#
#     * assortment mix
#
#     * store operational efficiency

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Uniform promo distribution means:
#
#     * Strategy consistency: marketing teams follow a fixed promotional calendar.
#
#     * Good for forecasting: promo-driven sales behaviour will be predictable across regions.
#
#     * Fairness across stores: no store type feels under-supported.
#
#
# **⚠️ Negative-Growth Risks -**
#
# * If every store type gets the same promo intensity:
#
#     * High-performing store types (e.g., those with high conversion) could generate even more revenue with targeted promos.
#
#     * Underperforming store types may need different kinds of support, not equal promo frequency.
#
#     * A “one-size-fits-all” strategy may be leaving money on the table.
#
#     * This indicates the company may benefit from store-specific promotion strategies instead of blanket policies.

# %% [markdown]
# ##### Chart 46 - Percentage of Promo Days Across Assortment Types

# %%
# Chart - 46 Visualisation Code

# Features Used: Assortment, Promo

# ✅ Why this chart is important to include?
# This chart is helping in understanding how frequently each assortment category
# is receiving promotional support. Since assortment type reflects product depth
# and variety, comparing promo intensity across categories is helping in revealing
# whether marketing efforts are being aligned with assortment strategy.
# This is also helping in identifying if any assortment type is being over-promoted
# or under-promoted, which can influence sales planning and store performance.

# ----------------------------------------------------------------------------------------------------------- #

# Computing promo percentage per assortment type
assortment_promo_rate = (
    df.groupby('Assortment')['Promo'].mean().reset_index()
)

# Converting to percentage
assortment_promo_rate['PromoPercent'] = assortment_promo_rate['Promo'] * 100

# Setting the visual style
sns.set(style="whitegrid")

# Creating the chart container
plt.figure(figsize=(10,6))

# Plotting the bar chart
sns.barplot(
    data=assortment_promo_rate,
    x='Assortment',
    y='PromoPercent',
    palette='viridis'
)

# Adding percentage labels on bars
for idx, row in assortment_promo_rate.iterrows():
    plt.text(
        idx,
        row['PromoPercent'] + 0.5,
        f"{row['PromoPercent']:.1f}%",
        ha='center',
        fontsize=10,
        fontweight='bold'
    )

# Adding title and axis labels
plt.title("Percentage of Promo Days Across Assortment Types", fontsize=16, fontweight='bold')
plt.xlabel("Assortment Type", fontsize=12)
plt.ylabel("Promo Percentage (%)", fontsize=12)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * Assortment a, b, and c all receive nearly equal promotional focus, with promo percentages ranging between 38% and 38.1%.
#
# * Assortment c slightly leads in promotion frequency, but the difference is negligible (<1%).
#
# * This indicates a uniform promotion strategy across all assortment categories, meaning the company does not heavily prioritize one assortment type over another in terms of promotional activity.
#
# * Such consistency suggests a balanced marketing approach, likely intended to keep customer traffic and product visibility stable across all store formats.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * This chart is helping in understanding how promotions are being distributed across different assortment types (a, b, c).
#
# * Assortment reflects the depth and variety of products, so knowing whether one assortment type is being promoted more than others is helping in identifying:
#
#     * Whether the stores with broader assortments (like type c) get more marketing push
#
#     * Whether simpler assortments (like type a) are equally prioritized
#
#     * How balanced the marketing strategy is across product categories
#
#
# * This insight is essential for both strategic planning and profitability analysis, making the chart valuable for a complete EDA.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Nearly equal promo distribution
#
#     * All three assortment types (a, b, c) hover around 38% promo days, showing that promotions are almost evenly applied across assortments.
#
# * Slight leadership by assortment c
#
#   * Assortment type c has the marginally highest promo percentage (~38.1%), indicating a tiny bias but operationally insignificant.
#
# * No strong preference in promotional allocation
#
#   * The differences are too small to suggest any strategic prioritization.
#
#   * The company appears to follow a uniform promotion policy across all assortment offerings.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Balanced marketing strategy
#     * A consistent promo distribution ensures predictable customer experience, keeps footfall stable, and prevents some store formats from lagging behind.
#
# * Fair opportunity for all assortment groups
#     * Because all assortments receive equal promotion exposure, product visibility and category performance remain stable.
#
# * Useful for optimization
#     * If assortment c or b begins outperforming others in revenue or conversion, the business can experiment with targeted promos on those assortments to increase overall profitability.
#
#
# **⚠️ Negative-Growth Risks -**
#
# * Lack of targeted promotional strategy - Equal promotion distribution may seem safe, but it might not be optimal.
#
# * If one assortment type (e.g., c) performs significantly better, concentrating more promotions there could yield higher revenue.
#
# *  No differentiation based on performance
# The chart hints that promotions are assigned uniformly, not based on:
#
#     * Sales performance
#
#     * Customer demand
#
#     * Competition pressure
#
# * This might result in missed opportunities for category-specific revenue lift.

# %% [markdown]
# ##### Chart 47 - Percentage of Promo2 Active Days Across Each Month

# %%
# Chart - 47 Visualisation

# Features Used: Month, IsPromo2Active

# ✅ Why this chart is important to include?
# This chart is showing the percentage of days in each month when Promo2 is active.
# Since Promo2 is a long-term recurring promotion, understanding its monthly activation
# helps identify how often stores participate in Promo2 and whether it follows
# a seasonal pattern. This is important for analyzing long-term promotional strategy
# and its possible effect on sales trends.


# ---------------------------------------------------------------------------------------------------------- #


# Calculating the percentage of Promo2 active days per month
promo2_percentage = (
    df.groupby("Month")["IsPromo2Active"]
    .mean() * 100
)

# Setting plot style
sns.set(style="whitegrid")

# Creating the figure
plt.figure(figsize=(12, 6))

# Plotting the bar chart for Promo2 activation percentage
sns.barplot(
    x=promo2_percentage.index,
    y=promo2_percentage.values,
    palette="Blues_r"
)

# Adding labels above each bar
for i, value in enumerate(promo2_percentage.values):
    plt.text(
        i,
        value + 1,        # Positioning text slightly above the bar
        f"{value:.1f}%",
        ha="center",
        fontsize=10,
        fontweight="bold"
    )

# Setting titles and axis labels
plt.title("Percentage of Promo2 Active Days Across Each Month", fontsize=16, fontweight='bold')
plt.xlabel("Month", fontsize=12)
plt.ylabel("Promo2 Active Percentage (%)", fontsize=12)

# Adjusting the y-limit for better text visibility
plt.ylim(0, promo2_percentage.max() + 10)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * Promo2 activation is highly uneven throughout the year.
# The highest activation occurs in January (24.2%), April (24.2%), and July (23.3%), suggesting quarterly campaign cycles.
#
# * Months like February, May, August, and November show moderate activation around 8-10%.
#
# * The lowest activation appears in September (6.5%), December (6.5%), and June (7.3%), indicating intentional pauses, possibly to avoid campaign clutter or due to budget cycles.
#
# * Overall, Promo2 follows a seasonal rhythm, likely aligned with strategic long-term promotions.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picked a bar chart showing the percentage of Promo2 active days per month because Promo2 is not a one-time promotion—it’s a recurring long-term campaign that activates multiple times throughout the year.
#
# * Simply counting occurrences would not capture true “promotional intensity.”
#
# * Using percentages allows a fair comparison across months, regardless of how many total days exist in each month or how many records appear.
#
# * This visualization helps answer:
#
#   * How actively is Promo2 used across the calendar year?
#
#   * Does the company follow a seasonal or quarterly pattern for long-term promotions?
#
#   * Are there months where Promo2 influence on sales will be stronger or weaker?
#
#
# * This makes it the most sensible and impactful chart for this question.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Key Insights -**
#
# 1. Strong activation cycles in Jan, Apr, and Jul (≈24%) -
#
# * These months show the highest Promo2 activity, indicating:
#
#   * Beginning of Q1, Q2, and Q3
#
#   * Strategic timing aligned with quarterly sales targets
#
#   * Possibly long-term partnership promotions renewed at fixed intervals
#
#
# * This explains steady sales boosts in these periods.
#
#
# ---
#
# 2. Medium activation in Feb, May, Aug, and Nov (8–10%)
#
# * These mid-range levels suggest:
#
#   * Follow-up or spillover promotions
#
#   * Customer engagement being maintained without full-scale campaigns
#
#   * Controlled promotional pacing
#
#
#
# ---
#
# 3. Weak activation in Jun, Sep, and Dec (6–7%)
#
# * The lowest Promo2 activity happens here. Possible reasons:
#
#     * June: summer slump / mid-year slowdown
#
#     * September: post-vacation sales dip
#
#     * December: Christmas/New Year may use different promo types instead of Promo2
#
#
# * This may indicate months where long-term promotions are intentionally reduced.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
#
# 1. Helps identify Promo2 cycles for future planning
#
# * Stores can stock more inventory and adjust staffing during high Promo2 months (Jan, Apr, Jul).
#
#
# 2. Enables seasonal promotional optimization
#
# * Understanding when Promo2 peaks allows:
#
#     * Better marketing planning
#
#     * Improved forecasting
#
#     * More efficient budget allocation
#
#
# 3. Supports modeling and predictive accuracy
#
# * Promo2 is a strong predictor in Rossmann models.
# Knowing monthly activation patterns improves:
#
#     * Feature engineering
#
#     * Time-series modeling accuracy
#
#     * Future campaign impact assessment
#
#
# ---
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# 1. Low activation months may lead to revenue dips
#
# * If Promo2 strongly drives sales, months like June, September, December may show:
#
#     * Lower customer engagement
#
#     * Reduced basket sizes
#
#     * Higher reliance on short-term promos
#
#
# 2. Highly uneven monthly distribution
#
# * Such inconsistency may create:
#
#     * Inventory misalignment
#
#     * Staffing inefficiencies
#
#     * Prediction difficulty for store managers

# %% [markdown]
# ##### Chart 48 - Percentage of Promo2 Active Days Across Store Types

# %%
# Chart - 48 Visualisation Code

# Features Used: StoreType, IsPromo2Active

# ✅ Why this chart is important to include?
# This chart is helping in understanding how long-term promotion (Promo2) is distributed
# across different store types. Unlike short-term promos, Promo2 is recurring and strategic.
# Checking its percentage usage across store types is helping us learn whether the company
# follows a uniform strategy or prefers certain store types for long-term promotional campaigns.

# -------------------------------------------------------------------------------------------------------- #

# Calculating Promo2 activation percentage for each store type
promo2_storetype_rate = (
    df.groupby('StoreType')['IsPromo2Active']
      .mean()
      .reset_index()
)

# Converting from rate to percentage
promo2_storetype_rate['Promo2Percent'] = promo2_storetype_rate['IsPromo2Active'] * 100

# Setting visual style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# Plotting bar chart for Promo2 percentage across store types
sns.barplot(
    data=promo2_storetype_rate,
    x='StoreType',
    y='Promo2Percent',
    palette='Blues'
)

# Adding percentage labels on each bar
for idx, row in promo2_storetype_rate.iterrows():
    plt.text(
        idx,
        row['Promo2Percent'] + 0.5,
        f"{row['Promo2Percent']:.1f}%",
        ha='center',
        fontsize=10,
        fontweight='bold'
    )

# Titles and axis labels
plt.title("Percentage of Promo2 Active Days Across Store Types",pad=20, fontsize=16, fontweight='bold')
plt.xlabel("Store Type", fontsize=12)
plt.ylabel("Promo2 Active Percentage (%)", fontsize=12)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * Store Type A: Promo2 active on 12.2% of days
#
# * Store Type B: Promo2 active on 6.8% of days (lowest usage)
#
# * Store Type C: Promo2 active on 14.4% of days
#
# * Store Type D: Promo2 active on 15.7% of days (highest usage)
#
#
# * Store Types C and D are clearly receiving heavier long-term promotional support, while Type B gets the least.
#
# * This indicates that Promo2 is not uniformly applied and is strategically favored for certain store formats.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * This chart is helping us understand whether long-running promotions (Promo2) are being used consistently across different store types or selectively distributed.
#
# * Since Promo2 is not a short flash sale but a recurring, extended promotional campaign, any variation across store types can reveal strategic decisions by the company — such as favoring certain store formats for long-term marketing push.
#
# * This insight is important for modeling as well, because the impact of Promo2 will naturally differ depending on how often each store type participates in it.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Store Type D has the highest Promo2 activation (15.7%), meaning these stores get the strongest long-term promotional support.
#
# * Store Type C also receives a considerable Promo2 focus at 14.4%.
#
# * Store Type A gets moderate Promo2 exposure (12.2%).
#
# * Store Type B stands out with the lowest Promo2 activation (6.8%), almost half of Type D's exposure.
#
# * This uneven promotional distribution suggests the company is favoring C and D stores for long-term marketing initiatives — likely because these formats perform better with recurring campaigns.
#
# * Meanwhile, Type B stores appear underexplored, hinting at either structural constraints or lower performance historically.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Strategic allocation check:
#
#     * This chart helps confirm whether Promo2 resources are aligned with store types that can generate maximum returns.
#
#     * If C and D types truly convert better, this approach is valid.
#
# * Opportunity identification:
#
#     * Store Type B is a high-potential opportunity.
#
#     * If B stores show stable customer footfall or decent sales without Promo2, activating Promo2 more frequently could directly improve their performance.
#
# * Modeling accuracy:
#
#     * Since Promo2 exposure varies heavily, using store type as a feature is likely to improve predictive accuracy in sales forecasting.
#
#
#
# ---
#
# Negative-growth signals:
#
# Underutilization of Promo2 for Store Type B
# B stores are getting almost no long-term promotional support, which may be contributing to weaker engagement or lower sales uplift compared to other types.
#
# Possible over-reliance on Store Type D
# If Store Type D is not generating proportionally higher revenue despite the highest Promo2 allocation, this could be an inefficiency in promotional spend.
#
# **⚠️ Negative-Growth Risks Identified -**

# %% [markdown]
# ##### Chart 49 - Percentage of Promo2 Active Days by Assortment Type

# %%
# Chart - 49 Visualisation Code


# Features Used: Assortment, IsPromo2Active


# ✅ Why this chart is important to include?
# This chart is showing how frequently the long-term promotion (Promo2) is running
# for each assortment bucket. Promo2 is running over long windows — comparing
# its activation share across assortment types is revealing which product-mix
# segments are receiving sustained marketing support. This is helping identify
# whether Promo2 is being targeted equally across assortments or skewed to a few.

# --------------------------------------------------------------------------------------------------------- #

# Calculating percentage of Promo2 active days per assortment
promo2_by_assort = (
    df.groupby('Assortment')['IsPromo2Active']
      .mean()                    # mean is giving share (0-1) because column is 0/1
      .reset_index()
)
promo2_by_assort['Promo2Percent'] = promo2_by_assort['IsPromo2Active'] * 100

# Ensuring consistent assortment ordering (a, b, c) if present
order = ['a', 'b', 'c']
promo2_by_assort['Assortment'] = pd.Categorical(promo2_by_assort['Assortment'], categories=order, ordered=True)
promo2_by_assort = promo2_by_assort.sort_values('Assortment')

# Setting aesthetic style for plots
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(9,6))

# Drawing the barplot
sns.barplot(
    data=promo2_by_assort,
    x='Assortment',
    y='Promo2Percent',
    palette='Blues_d'
)

# Adding percentage labels above each bar
for idx, row in promo2_by_assort.iterrows():
    plt.text(
        x = list(promo2_by_assort['Assortment']).index(row['Assortment']),  # placing text at bar x-position
        y = row['Promo2Percent'] + 0.6,                                    # small offset above bar
        s = f"{row['Promo2Percent']:.1f}%",                                # formatted percentage
        ha = 'center',
        fontsize = 11,
        fontweight = 'bold'
    )

# Adding titles and axis labels
plt.title('Percentage of Promo2 Active Days Across Assortment Types', fontsize=16, fontweight='bold')
plt.xlabel('Assortment Type', fontsize=12)
plt.ylabel('Promo2 Active Percentage (%)', fontsize=12)

# Tight layout for cleaner rendering
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * Assortment c has the highest Promo2 activation rate (13.8%).
#
# * Assortment a follows closely at 13.2%.
#
# * Assortment b receives the least long-term promotion, with just 10.3% Promo2 active days.
#
# * Promo2 is unevenly distributed across assortment types, indicating selective long-term promotion strategies.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I am using a percentage-based comparison to understand how long-term promotions (Promo2) are allocated across different assortment categories.
#
# * Because Promo2 runs periodically and not daily, looking at counts alone does not give meaningful insights — percentages reveal the true intensity of long-term promotions.
#
# * This chart helps me check whether the company is giving equal long-term marketing support to all assortment types or prioritizing some categories more.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Assortment c receives the highest share of Promo2 long-term promotional days (13.8%).
#   - This suggests that stores selling assortment “c” items get slightly more consistent long-term marketing support.
#
# * Assortment a is very close (13.2%), indicating balanced but slightly lower Promo2 activity.
#
# * Assortment b receives the least Promo2 activation (10.3%).
#   → This category seems deprioritized for long-term promotions.
#
# * The gap between highest and lowest is small (around 3- 4%), which means Promo2 strategies are somewhat uniform, but still show mild preference.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Since assortment c shows highest activation, this might be tied to:
#
#     * higher demand,
#
#     * higher margin items,
#
#     * or strategic focus on these products.
#
#
# * If Promo2 is boosting then:
#
#     * Increasing Promo2 frequency for assortment b could uplift performance.
#
#     * Assortment-wise promo planning can be optimized instead of treating Promo2 uniformly.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Uneven Promo2 distribution could cause:
#
#   * Lower visibility for assortment b items.
#
#   * Missed revenue opportunities if b-category customers respond well to promotions.
#
#
# * Mitigation steps:
#
#   * Test Promo2 more frequently for b assortment stores and observe lift.
#
#   * Check whether assortment b already has lower demand — if yes, Promo2 could help revive it.

# %% [markdown]
# ### **Multivariate Analysis**

# %% [markdown]
# #### Part 1 - Promotion - Time Interactions

# %% [markdown]
# ##### Chart 50 - Impact of Promotions on Daily Sales

# %%
# Chart 51 - Visualisation Code

# Features Used: DayOfWeek, Promo, Sales

# ✅ Why this chart is important to include?
# This chart will show average sales for each day of the week separately for Promo and Non-Promo days.
# This will help in identifying which weekdays are benefiting most from promotions,
# and whether promo activity is delivering consistent uplift across the week or only on specific days.

# --------------------------------------------------------------- #


# Preparing the grouped data by DayOfWeek and Promo and calculating average sales
promo_day_sales = (
    df.groupby(['DayOfWeek', 'Promo'])['Sales']
      .mean()
      .reset_index()
      .sort_values(by='DayOfWeek')
)

# Creating a pivot table for easier line plotting (index = DayOfWeek, columns = Promo)
promo_day_pivot = promo_day_sales.pivot(
    index='DayOfWeek',
    columns='Promo',
    values='Sales'
)

# Renaming the columns for clarity (0 -> No Promo, 1 -> Promo)
promo_day_pivot.columns = ['No Promo', 'Promo']

# Ensuring day order is correct (1=Mon ... 7=Sun)
promo_day_pivot = promo_day_pivot.reindex([1,2,3,4,5,6,7])

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(12,6))

# Plotting the line for Non-Promo average sales
plt.plot(
    promo_day_pivot.index,
    promo_day_pivot['No Promo'],
    marker='o',
    linewidth=2,
    label='No Promo',
    color='#1f77b4'
)

# Plotting the line for Promo average sales
plt.plot(
    promo_day_pivot.index,
    promo_day_pivot['Promo'],
    marker='o',
    linewidth=2,
    label='Promo',
    color='#ff7f0e'
)

# Filling the area between lines to visually emphasize the uplift (Promo - No Promo)
plt.fill_between(
    promo_day_pivot.index,
    promo_day_pivot['No Promo'],
    promo_day_pivot['Promo'],
    where=(promo_day_pivot['Promo'] >= promo_day_pivot['No Promo']),
    interpolate=True,
    color='#ffbb78',
    alpha=0.12
)

# Adding plot title, labels and legend
plt.title("Average Sales by Day of the Week: Promo vs Non-Promo", fontsize=16, fontweight='bold')
plt.xlabel("Day of the Week (1 = Monday, 7 = Sunday)", fontsize=12)
plt.ylabel("Average Sales", fontsize=12)
plt.legend(title="Promo (0 = No, 1 = Yes)")

# Adding grid and readable x-ticks (Monday...Sunday)
plt.grid(alpha=0.25)
plt.xticks(ticks=[1,2,3,4,5,6,7], labels=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])

# Applying tight layout for better spacing
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart compares average sales on each weekday between promo and non-promo periods.
#
# * The gap between the two lines clearly shows how promotions lift weekday sales.
#
# * Promo sales remain consistently higher across Monday-Saturday, with Monday performing the strongest under promotions.
#
# * Sunday, however, shows zero promo activity, which explains the extremely low non-promo sales point — stores are either closed or operate under restricted hours.
#
# * Promotions appear most effective early in the week (Mon- Wed), and the uplift gradually declines toward Friday.
#
# * Saturday also shows a healthy promo uplift, suggesting weekend shopping benefits from discounts.
#
# * This chart helps evaluate when promotions produce the best return and highlights days where promo strategy might need rethinking.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I selected this chart because it helps me understand how weekday performance changes depending on whether promotions are running or not.
#
# * Since customer behaviour varies heavily by day of the week, this visualization will allow me to see which days respond strongly to promotions and which days are naturally weak or strong without promotions.
#
# * This insight will guide targeted promo planning rather than using a uniform weekly approach.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promotions increase sales significantly on every weekday from Monday to Saturday.
#
# * Monday shows the highest promo-driven boost, indicating customers respond strongly to discounting at the start of the week.
#
# * The uplift gradually declines from Tue → Wed → Thu → Fri.
#
# * Saturday also benefits from promo activity, showing solid uplift.
#
# * Sunday has no promo activity, resulting in extremely low non-promo sales — likely due to store closures or partial operations.
#
# * Since the promo uplift is not constant across days, the efficiency of running promos varies by weekday.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * The insights will help determine which weekdays deserve stronger promotional spending (Monday, Tuesday, Saturday).
#
# * Promo investment can be reduced on lower-responding days, improving ROI.
#
# * Understanding weekday responsiveness can help scheduling staff, inventory, and operational activities more effectively.
#
#
# **⚠️ Negative-Growth Risks Identified :**
#
# * Relying on promotions heavily Monday-Friday may train customers to delay purchases until promo days.
#
# * Non-promo weekday sales are significantly lower, indicating stores may be becoming promotion-dependent.
#
# * Sunday underperformance might require either policy review or operational adjustment if stores are partially open.

# %% [markdown]
# ##### Chart 51 - Impact of Promo on Daily Customer Footfall

# %%
# Chart 51 - Visualisation Code

# Features Used: DayOfWeek, Promo, Customers

# ✅ Why this chart is important to include?
# This chart will be helping to compare average customer footfall on each weekday
# This chart will be showing whether promotions are shifting customer traffic to specific weekdays
# This chart will be guiding decisions about when to schedule long/short promos to maximise footfall

# --------------------------------------------------------------- #
# Preparing data: grouping by DayOfWeek and Promo to compute average customers
# Adding groupby that is calculating mean customers per DayOfWeek x Promo pair
daily_customers_promo = (
    df.groupby(['DayOfWeek', 'Promo'])['Customers']
      .mean()
      .reset_index()
)

# Creating a pivot to get a clean table for plotting (rows = day, cols = promo flag)
# Pivoting so that column 0 -> No Promo, 1 -> Promo
customers_pivot = daily_customers_promo.pivot(
    index='DayOfWeek',
    columns='Promo',
    values='Customers'
)

# Renaming pivot columns for readability
customers_pivot.columns = ['No Promo', 'Promo']

# Ensuring days are sorted 1..7 (Mon..Sun)
customers_pivot = customers_pivot.reindex([1,2,3,4,5,6,7])


# Setting plot style
sns.set(style="whitegrid")

# Creating figure
plt.figure(figsize=(12,6))

# Plotting No Promo line
plt.plot(
    customers_pivot.index,
    customers_pivot['No Promo'],
    marker='o',
    linewidth=2,
    label='No Promo',
    color='#1f77b4'
)

# Plotting Promo line
plt.plot(
    customers_pivot.index,
    customers_pivot['Promo'],
    marker='o',
    linewidth=2,
    label='Promo',
    color='#ff7f0e'
)

# Shading area between lines to emphasise uplift in customers during promo
plt.fill_between(customers_pivot.index,
                 customers_pivot['No Promo'],
                 customers_pivot['Promo'],
                 color='#ffbb78',
                 alpha=0.12)

# Adding titles and axis labels
plt.title("Average Customers by Day of Week: Promo vs Non-Promo", fontsize=16, fontweight='bold')
plt.xlabel("Day of the Week (1 = Monday, 7 = Sunday)", fontsize=12)
plt.ylabel("Average Number of Customers", fontsize=12)

# Custom x-ticks as weekday names
plt.xticks(ticks=[1,2,3,4,5,6,7], labels=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])

# Adding legend with descriptive title
plt.legend(title="Promo (0 = No, 1 = Yes)")

# Adding grid for readability and tightening layout
plt.grid(alpha=0.25)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart clearly shows that promotions consistently increase customer footfall across all weekdays except Sunday, where stores operate very differently and promo data is practically absent.
#
# * Promo-driven uplift is strongest on Monday, where customers rise from ~670 to ~940 on promotional days.
#
# * On Thursday and Friday, the gap between promo and non-promo customers narrows, indicating reduced promo sensitivity toward the weekend.
#
# * Saturday and Sunday behave uniquely—Saturday has moderate decline from Friday, while Sunday collapses due to very low/no store operation or missing values.
#
# * Overall, the promo uplift pattern is weekday-dependent, showing clear opportunities to strategically place promotions for maximum footfall.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I selected a line chart because it is the most intuitive way to show changes and trends across ordered categories, such as days of the week.
#
# * A line plot helps highlight week-day cyclicity, footfall peaks/dips, and how promo vs non-promo patterns diverge or converge across the week.
#
# * I chose the features DayOfWeek, Promo, and Customers because this relationship is crucial for understanding when promotions work best—not just whether they work.
#
# * This chart allows me to visually inspect behavioural patterns in customer footfall and identify weekday-specific promo responsiveness.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo days always attract more customers than non-promo days, confirming that promotions are an effective footfall driver.
#
# * Monday shows the highest promo uplift, indicating customers respond strongly to beginning-of-week promotions.
#
# * Footfall gradually declines from Monday to Thursday, regardless of promo status — indicating a natural weekday cycle.
#
# * Friday sees a spike for non-promo customers, suggesting natural higher weekend-preparation shopping behaviour.
#
# * Sunday has extremely low non-promo footfall, most likely because many Rossmann stores remain closed or operate limited hours.
#
# * Promo uplift shrinks from Wednesday to Friday, meaning customers may be less promo-sensitive closer to the weekend.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * The company can schedule promotions on days where uplift is highest, especially Monday, to maximize traffic and revenue.
#
# * Promotions on Thursday and Friday may need redesigning because uplift is small—optimizing these promos can unlock hidden revenue.
#
# * The chart helps forecast weekday-wise demand, ensuring better staff planning, inventory planning, and promo budgeting.
#
# * Promos can be dynamically allocated to days where they convert best rather than spreading them uniformly.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Running promos on days with naturally high footfall (e.g., Friday) may decrease organic sales, reducing margin without gaining new customers.
#
# * Over-reliance on Monday promotions could train customers to delay purchases until discount days.
#
# * Sunday behaviour must be interpreted carefully—low sales may be due to store closures, not customer behaviour.
#
# * If promos are uniformly applied across days despite different uplift patterns, the company may waste promotional budget on low-impact days.

# %% [markdown]
# ##### Chart 52 - Impact of Promo on Daily Sales Efficiency

# %%
# Chart 51 - Promo vs DayOfWeek vs Sales Per Customer (Line Chart)

# Features Used - Promo, DayOfWeek, Sales, Customers

# ✅ Why this chart is important to include?
# This chart analyzes how customer spending efficiency (Sales per Customer)
# changes across days of the week under Promo vs Non-Promo conditions.
# A line chart is chosen because DayOfWeek is sequential and helps reveal
# weekday vs weekend trends and spendingdips or spikes caused by promotions.

# ---------------------------------------------------------------------------------------------------------- #


# Aggregating data for line plot
day_promo_trend = (
    df.groupby(['DayOfWeek', 'Promo'])['SalesPerCustomer']
      .mean()
      .reset_index()
)

# Setting consistent visual style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(12, 6))

# Plotting line chart with markers
sns.lineplot(
    data=day_promo_trend,
    x='DayOfWeek',
    y='SalesPerCustomer',
    hue='Promo',
    marker='o',
    linewidth=2.5,
    palette=['#4C72B0', '#DD8452']
)

# Adding chart title and labels
plt.title('Sales per Customer Trend by Day of Week: Promo vs Non-Promo',
          fontsize=15, fontweight='bold')
plt.xlabel('Day of Week (1 = Monday, 7 = Sunday)', fontsize=12)
plt.ylabel('Average Sales per Customer', fontsize=12)

# Legend customization
plt.legend(title='Promo Status', labels=['No Promo', 'Promo'])

# Adding gridlines and finishing touches
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * This line chart shows how average sales per customer vary across the days of the week under Promo vs Non-Promo conditions.
#
# * It highlights weekday vs weekend spending behavior and reveals how promotions impact customer spending efficiency, not just total sales.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * DayOfWeek is sequential, so a line chart is the most appropriate choice to capture trends and transitions across days.
#
# * Sales per customer is a ratio metric, and line charts make it easier to observe gradual rises, dips, and anomalies.
#
# * This visualization enables a direct comparison of Promo vs Non-Promo behavior across the week, which would be less intuitive with bar plots.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo days consistently show higher sales per customer from Monday (Day 1) to Saturday (Day 6), indicating that promotions encourage customers to spend more per visit.
#
# * Non-Promo sales per customer remain relatively stable during weekdays, peaking slightly on Friday–Saturday.
#
# * A sharp drop in Non-Promo sales per customer on Sunday (Day 7) is observed, suggesting very low customer spending efficiency on that day.
#
# * Promo data for Sunday is either absent or negligible, indicating limited or no promotional activity on Sundays.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Promotions are most effective on weekdays and Saturdays, as they increase per-customer spend, not just footfall.
#
# * This insight supports strategic promo scheduling, especially mid-week when baseline spending is moderate.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Sunday shows a severe drop in sales per customer under Non-Promo conditions, which signals poor revenue efficiency despite stores being open.
#
# * This negative trend may be due to:
#
#     * Reduced store hours
#
#     * Low-intent browsing customers
#
#     * Absence of promotions on Sundays
#
# * Without intervention (e.g., targeted Sunday promos), Sundays may continue to drag average weekly performance down.
#
# **🧠 Business Recommendation -**
#
# * Consider lightweight or targeted promotions on Sundays to stabilize sales per customer.
#
# * Re-evaluate store operations on Sundays if promotions are intentionally avoided, as the ROI appears weak.

# %% [markdown]
# ##### Chart 53 - Monthly Sales Comparison Promo vs Non-Promo

# %%
# Chart - 53 Visualization Code

# Features Used: Month, Sales, Promo

# ✅ Why this chart is important to include?
# This chart is helping in comparing average monthly sales under Promo days versus Non-Promo days.
# By separating sales trends into two lines (Promo = 1 and Promo = 0), this visualization is showing
# how promotions influence monthly sales patterns. It is helping in identifying months where promotions
# bring strong uplift and months where promo impact is weak, supporting seasonal marketing decisions.

# -------------------------------------------------------------------------------------------------------- #

# Creating month name mapping for cleaner x-axis labels
month_map = {1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',
             7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}

# Adding a MonthName column for better readability
df['MonthName'] = df['Month'].map(month_map)

# Preparing aggregated data: calculating average monthly sales separately for Promo = 0 and Promo = 1
monthly_promo_sales = (
    df.groupby(['Month', 'MonthName', 'Promo'])['Sales']
      .mean()
      .reset_index()
      .rename(columns={'Sales': 'AvgSales'})
)

# Ordering month names correctly on x-axis
ordered_months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
monthly_promo_sales['MonthName'] = pd.Categorical(monthly_promo_sales['MonthName'],
                                                  categories=ordered_months,
                                                  ordered=True)

# Setting visualization style
sns.set(style="whitegrid")

# Creating the figure
plt.figure(figsize=(12,6))

# Plotting the lineplot showing Promo vs Non-Promo monthly sales
sns.lineplot(
    data=monthly_promo_sales,
    x='MonthName',
    y='AvgSales',
    hue='Promo',
    marker='o',
    linewidth=2.5,
    palette=['#2E86C1', '#F39C12']      # Blue for No Promo, Orange for Promo
)

# Adding title and axis labels
plt.title("Average Monthly Sales: Promo vs Non-Promo", fontsize=16, fontweight='bold')
plt.xlabel("Month", fontsize=12)
plt.ylabel("Average Sales", fontsize=12)

# Customizing legend
plt.legend(title="Promo (0 = No, 1 = Yes)")

# Displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart clearly shows that sales are consistently higher on Promo days compared to Non-Promo days across all months.
#
# * The uplift is especially strong in June, July, November, and dramatically in December, where Promo sales peak sharply.
#
# * Non-Promo sales remain stable throughout the year, with minor seasonal bumps, but they never come close to Promo-day performance.
#
# * This tells us that promotions significantly boost revenue and the business relies heavily on promotion-based traffic and conversions.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose this chart because it gives a direct month-wise comparison of how promotions influence sales.
#
# * A simple Month vs Sales chart cannot reveal the difference between Promo and Non-Promo performance, so separating them into two lines helps clearly visualize uplift.
#
# * This chart is a perfect multivariate view because it shows seasonality, promotion effect, and monthly revenue behavior all in one place.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Key Insights:
#
# * Promo days generate significantly higher sales every month.
# The uplift is stable but strongest in June, July, November, and December.
#
# * December has an exponential spike, crossing 10,500 average sales, likely due to holiday shopping + promo stacking.
#
# * Non-Promo sales stay stable, ranging from ~4,100 to ~5,000 — showing limited natural demand without incentives.
#
# * Promos influence seasonality more than organic customer behaviour — the sales curve shape changes mainly on the promo line, not on the non-promo line.
#
# What this means:
#
# * The business is highly promotion-sensitive.
#
# * Promos act as the primary revenue driver, not natural footfall.
#
# * Seasonal peaks (e.g., December) become much stronger with promotions.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * The chart proves that promotions deliver strong ROI, so doubling down on:
#
#     * targeted promos
#
#     * personalized discounts
#
#     * festival-season promotions
#
#   will directly improve revenue.
#
#
# * Months with low uplift (e.g., April, September) can be optimized:
#
#     * product bundling
#
#     * Better ad placement
#
#     * Targeted messaging
#
# * Forecasting becomes easier because promo and non-promo patterns are clearly predictable.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Heavy dependence on promotions can train customers to wait for discounts, lowering long-term profitability.
#
#     * Non-promo sales staying flat means:
#
#     * weak brand pull
#
#     * weak organic demand
#
#     * less loyal customer base
#
#
# * If promotions are reduced suddenly, sales may drop sharply because core demand is not strong enough.

# %% [markdown]
# ##### Chart 54 - Impact of Promo on Monthly Customer Footfall

# %%
# Chart 54 - Visualisation Code

# Features Used: Month, Promo, Customers

# ✅ Why this chart is important to include?
# This chart will help in comparing monthly customer footfall between Promo and Non-Promo periods.
# It will reveal whether promotions are driving additional store visits or if customer traffic follows seasonal patterns.
# This will help business teams understand whether promotions are improving customer acquisition or merely boosting sales from existing visitors.

# --------------------------------------------------------------- #
# Grouping the data by Month and Promo and calculating average customers
monthly_customer_promo = (
    df.groupby(['Month', 'Promo'])['Customers']
      .mean()
      .reset_index()
)

# Creating a pivot table for easier line plotting
customer_pivot = monthly_customer_promo.pivot(
    index='Month',
    columns='Promo',
    values='Customers'
)

# Renaming the columns for clarity
customer_pivot.columns = ['No Promo', 'Promo']

# Sorting the index to ensure months appear in correct order
customer_pivot = customer_pivot.sort_index()

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(12,6))

# Plotting line for Non-Promo customer averages
plt.plot(
    customer_pivot.index,
    customer_pivot['No Promo'],
    marker='o',
    linewidth=2,
    label='No Promo',
    color='#1f77b4'
)

# Plotting line for Promo customer averages
plt.plot(
    customer_pivot.index,
    customer_pivot['Promo'],
    marker='o',
    linewidth=2,
    label='Promo',
    color='#ff7f0e'
)

# Adding title and labels
plt.title("Average Monthly Customers: Promo vs Non-Promo", fontsize=16, fontweight='bold')
plt.xlabel("Month", fontsize=12)
plt.ylabel("Average Customers", fontsize=12)

# Adding legend for clarity
plt.legend(title="Promo (0 = No, 1 = Yes)")

# Adding grid for readability
plt.grid(alpha=0.3)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * Customer footfall during Promo days is consistently higher than Non-Promo days across all months.
#
# * The uplift is very stable, indicating promotions reliably attract additional store visits.
#
# * A clear seasonal spike appears in December, where Promo-day customer traffic jumps close to 1,000 customers, the highest among all months.
#
# * Even Non-Promo traffic increases slightly in December, implying natural seasonal demand — but Promo magnifies this effect significantly.
#
# * May shows the lowest Promo-day footfall (~760), suggesting weaker promotional response in early summer.
#
#
# * Overall, Promo days clearly drive higher customer acquisition, and the effect strengthens during festive or peak-shopping months.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I included this chart to understand how customer footfall changes across months when promotions are active vs inactive.
#
# * This helps identify whether promotions truly impact traffic, and whether the effect is seasonal, consistent, or month-specific.
#
# * Without this comparison, we wouldn't know if higher sales during promos are due to increased customers or simply increased spend per customer.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo days consistently attract ~250–300 more customers than Non-Promo days in every month.
#
# * December shows the highest promotional impact, with nearly 1,000 customers on Promo days.
#
# * The lowest promo response appears in May, suggesting either weak campaign design or lower seasonal interest.
#
# * Customer footfall during Non-Promo days remains relatively stable, indicating promotions are the primary footfall driver, not natural variation.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Promotions significantly boost customer footfall, proving they are effective for increasing store visits.
#
# * December shows extremely strong promo response → company should reinforce campaigns during high-potential months.
#
# * Stable Non-Promo traffic indicates that the company has reliable baseline demand, making promo planning more predictable.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * May’s weak promo response suggests ineffective campaign timing or design, meaning promotional budget may be wasted during that period.
#
# * If promo dependency increases too much, customers may begin to wait for discounts, creating long-term margin pressure.
#
# * High December promo traffic could strain store operations → risk of service bottlenecks, stockouts, or customer dissatisfaction if not planned well.

# %% [markdown]
# ##### Chart 55 - Impact of Promo on Monthly Sales Efficiency

# %%
# Chart 53: Visualisation Code

# Features Used: Promo, Month, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart helps analyze how short-term daily promotions (Promo)
# influence customer spending behavior across different months.
# Instead of absolute sales, SalesPerCustomer highlights
# spending efficiency and customer quality over time.
# Setting visual style

#-----------------------------------------------------------------------------------#

# Setting consistent visual style
sns.set(style="whitegrid")

# Aggregating data
promo_month_spc = (
    df.groupby(['Month', 'Promo'])['SalesPerCustomer']
      .mean()
      .reset_index()
)

# Creating the plot
plt.figure(figsize=(12, 6))

ax = sns.barplot(
    data=promo_month_spc,
    x='Month',
    y='SalesPerCustomer',
    hue='Promo',
    palette=['#5DADE2', '#F5B041']
)

# Title and labels
plt.title(
    'Monthly Sales per Customer: Promo vs Non-Promo',
    fontsize=16,
    fontweight='bold'
)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Average Sales per Customer', fontsize=12)

# Legend formatting
plt.legend(
    title='Promo Status',
    labels=['No Promo', 'Promo'],
    frameon=True,
    loc = "upper center",
    bbox_to_anchor = [0.5, -0.12],
    ncols = 2
)

# Adding value labels on bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', padding=3)

# Grid and layout
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()

# Display plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * This grouped bar chart compares average sales per customer across months for Promo vs Non-Promo days.
#
# * The visualization clearly shows that Promo days consistently generate higher sales per customer than Non-Promo days across all months, indicating that daily promotions increase basket value per customer, not just footfall.
#
# * Seasonal variation is visible, with stronger promo effectiveness toward mid-year and year-end months.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart is ideal here because:
#
# * It allows direct month-wise comparison between Promo and Non-Promo days.
#
# * Exact Sales per Customer values are easy to read, which was difficult in the line plot.
#
# * It aligns well with business questions around monthly promotion efficiency.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo days outperform Non-Promo days in every month, indicating higher customer spend during promotions.
#
# * The gap between Promo and Non-Promo sales per customer remains consistently high (~3–4 units), showing sustained promo effectiveness.
#
# * Stronger promo impact is observed in months 7 and 12, hinting at seasonal or festive amplification of promotions.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Promotions clearly increase average basket value, not just traffic.
#
# * This supports continued investment in short-term daily promos, especially during peak months.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Some months (e.g., Month 5 and Month 10) show lower Promo sales per customer compared to peak months, suggesting promo fatigue or weaker demand cycles.
#
# * Running promotions uniformly without seasonality consideration may dilute returns.

# %% [markdown]
# #### Part 2 - Promotion - Store Characteristics

# %% [markdown]
# ##### Chart 56 - Average Sales by Assortment Type: Promo vs Non-Promo

# %%
# Chart 56 - Visualization Code

# Features Used: Promo, Assortment, Sales

# ✅ Why this chart is important to include?
# This chart helps analyze whether short-term daily promotions (Promo)
# perform differently across various product assortment types.
# Since assortment defines product variety and depth, promotions may
# not have a uniform impact on sales across assortments.
# A grouped bar chart enables a clear comparison of Promo vs No Promo
# within each assortment category.

# --------------------------------------------------------------- #

# Grouping data by Assortment and Promo to calculate average sales
assortment_promo_sales = (
    df.groupby(['Assortment', 'Promo'])['Sales']
      .mean()
      .reset_index()
)

# Pivoting data for grouped bar plotting
sales_pivot = assortment_promo_sales.pivot(
    index='Assortment',
    columns='Promo',
    values='Sales'
)

# Renaming columns for clarity
sales_pivot.columns = ['No Promo', 'Promo']

# --------------------------------------------------------------- #
# Visualization

plt.figure(figsize=(10, 8))

sales_pivot.plot(
    kind='bar',
    width=0.7,
    color=['#4C72B0', '#DD8452'],
    edgecolor='black'
)

# Adding value labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.0f', padding=2, fontsize=9)

# Titles and labels
plt.title(
    'Average Sales by Assortment Type: Promo vs Non-Promo',
    fontsize=15,
    fontweight='bold'
)
plt.xlabel('Assortment Type', fontsize=12)
plt.ylabel('Average Sales', fontsize=12)

# Adjusting the alignment of tick labels
plt.xticks(rotation=0, ha='center')

# Legend formatting
plt.legend(title='Promo Status', frameon=True, loc = 'upper center',ncols =2, bbox_to_anchor=(0.5, -0.2))

# Grid and layout
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.box(False)
plt.tight_layout()

# Display plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart shows that daily promotions consistently increase average sales across all assortment types, but the magnitude of uplift varies significantly by assortment.
#
# * Assortment a and c experience a strong sales jump during Promo days, indicating that daily promotions are particularly effective when product variety is either limited (a) or well-balanced (c).
#
# * Assortment b already performs well even without promotions, and Promo leads to only a marginal incremental gain, suggesting diminishing returns for heavy assortments.
#
# * Overall, the chart highlights that daily Promo effectiveness is not uniform and is strongly influenced by the underlying assortment strategy.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose a grouped bar chart because it allows a direct and intuitive comparison between Promo and Non-Promo sales within each assortment category.
#
# * This chart helps explore whether daily promotional strategies interact differently with assortment depth, rather than assuming a one-size-fits-all Promo impact.
#
# * By placing Promo and Non-Promo bars side by side, the chart clearly surfaces incremental sales lift patterns that would be harder to notice in aggregate or trend-based plots.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Assortment a shows the highest relative sales uplift during Promo, indicating that limited assortments benefit strongly from short-term discounts.
#
# * Assortment c also exhibits a substantial Promo-driven increase, suggesting that balanced assortments convert promotions into higher ticket values effectively.
#
# * Assortment b shows the smallest gap between Promo and Non-Promo sales, implying that its strong baseline performance reduces Promo dependency.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * These insights can drive more targeted daily promotion strategies, where Promo intensity is aligned with assortment type instead of being uniformly applied.
#
# * A potential negative growth signal is observed for assortment b, where Promo adds only limited incremental value.
#
# * Running frequent daily promotions on such assortments may unnecessarily erode margins without meaningful sales uplift, indicating a need for selective Promo deployment rather than blanket discounts.
#
# **⚠️ Negative-Growth Risks Identified -**

# %% [markdown]
# ##### Chart 57 - Impact of Daily Promotions on Customer Footfall Across Assortment Types

# %%
# Chart - 57 Visualisation Code

# Features Used: Promo, Assortment, Customers

# ✅ Why this chart is important to include?
# This chart will help me examine how daily promotions (Promo)
# influence customer footfall across different assortment types.
# By comparing Promo vs Non-Promo days for each assortment category,
# this visualization will allow me to explore whether promotions
# are uniformly effective or if their impact varies based on
# product assortment depth and variety.

# --------------------------------------------------------------- #

# Grouping data by Assortment and Promo to calculate average customers
assortment_promo_customers = (
    df.groupby(['Assortment', 'Promo'])['Customers']
      .mean()
      .reset_index()
)

# Creating a pivot table for grouped bar plotting
customers_pivot = assortment_promo_customers.pivot(
    index='Assortment',
    columns='Promo',
    values='Customers'
)

# Renaming columns for better readability
customers_pivot.columns = ['No Promo', 'Promo']

# Ensuring consistent order of assortment types
customers_pivot = customers_pivot.sort_index()

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(10,6))

# Plotting grouped bar chart
customers_pivot.plot(
    kind='bar',
    width=0.7,
    color=['#4C72B0', '#DD8452'],
    edgecolor='black'
)

# Adding value labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.0f', padding=1.5, fontsize=10)

# Adding title, labels, and legend
plt.title(
    "Average Customers by Assortment Type: Promo vs Non-Promo",
    fontsize=16,
    fontweight='bold'
)
plt.xlabel("Assortment Type", fontsize=12)
plt.ylabel("Average Number of Customers", fontsize=12)
plt.legend(title="Promo Status", loc = "upper right")

# Aligning tick labels
plt.xticks(rotation=0, ha='center')

# Gridlines for readability (only Y-axis as per best practice)
ax = plt.gca()
ax.yaxis.grid(True, linestyle='--', alpha=0.4)
ax.xaxis.grid(False)

# Final layout adjustment
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart shows that daily promotions consistently increase customer footfall across all assortment types, indicating that short-term promotions are effective in driving store visits.
#
# * The strongest absolute uplift is observed for assortment type b, which already has the highest baseline customers and benefits further from promotions.
#
# * Assortment types a and c show a proportionally larger lift during promo days, suggesting that promotions are especially effective for stores with limited or curated assortments.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose a grouped bar chart because it allows a direct, side-by-side comparison of Promo vs Non-Promo customer counts for each assortment type.
#
# * This chart helps clearly isolate the impact of daily promotions without temporal noise and makes differences immediately interpretable.
#
# * The selected features — Promo, Assortment, and Customers — help explore whether promotions are equally effective across different product variety strategies.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promotions increase customer footfall for all assortment types, confirming that daily promos successfully attract more visitors.
#
# * Assortment b dominates in absolute customer volume, both during Promo and Non-Promo days, highlighting its strong inherent demand.
#
# * Assortment a and c experience sharper relative gains, indicating that promotions help overcome lower baseline traffic for these store types.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * No negative growth is observed in this chart, as promotions increase customer counts across all assortments.
#
# * However, the incremental gain for assortment b is comparatively smaller in percentage terms, suggesting a diminishing return effect where already high-traffic stores benefit less from promotions.
#
# * This indicates that blanket promotion strategies may not be cost-optimal for high-volume assortment types and could be better targeted.

# %% [markdown]
# ##### Chart 58 - Average Sales per Customer by Assortment Type: Promo vs Non-Promo

# %%
# Chart 58 - Visualisation Code

# Features Used: Promo, Assortment, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart will help me understand whether daily promotions are improving
# customer quality (spend per customer) across different assortment types.
# Instead of only looking at sales or customer count independently,
# this chart will explore if promotions are leading to higher or lower
# average spending behavior per customer for each assortment category.
# Using a grouped bar chart will allow a clear side-by-side comparison
# of Promo vs Non-Promo impact within each assortment type.

# --------------------------------------------------------------- #


# Grouping by Promo and Assortment and calculating average SalesPerCustomer
assortment_promo_spc = (
    df.groupby(['Assortment', 'Promo'])['SalesPerCustomer']
      .mean()
      .reset_index()
)

# Creating pivot table for grouped bar chart
spc_pivot = assortment_promo_spc.pivot(
    index='Assortment',
    columns='Promo',
    values='SalesPerCustomer'
)

# Renaming columns for clarity
spc_pivot.columns = ['No Promo', 'Promo']

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(10,6))

# Plotting grouped bar chart
ax = spc_pivot.plot(
    kind='bar',
    width=0.7,
    color=['#4C72B0', '#DD8452'],
    edgecolor='black'
)

# Adding value labels on bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', padding=1.5, fontsize=10)

# Adding title and labels
plt.title(
    "Average Sales per Customer by Assortment Type: Promo vs Non-Promo",
    fontsize=16,
    fontweight='bold'
)
plt.xlabel("Assortment Type", fontsize=12)
plt.ylabel("Sales per Customer", fontsize=12)

# Improving legend placement
plt.legend(
    title="Promo Status",
    loc='upper center',
    frameon=False
)

# Aligning tick labels
plt.xticks(rotation=0, ha='center')

# Gridlines for readability
ax = plt.gca()
ax.yaxis.grid(True, linestyle='--', alpha=0.4)
ax.xaxis.grid(False)

# Final layout adjustments
plt.xticks(rotation=0)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart shows how average sales generated per customer change across different assortment types (a, b, c) when a daily promotion (Promo) is applied versus when it is not.
#
# * It isolates customer value (basket size) rather than total sales, helping understand whether promotions drive discount-led volume or higher spend per customer.
#
# * The pattern clearly differs by assortment type, indicating that Promo effectiveness is assortment-dependent, not uniform.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picked a grouped bar chart because it allows a clear side-by-side comparison of Promo vs Non-Promo within each assortment type.
#
# * This chart was chosen specifically to move beyond total sales and customers and focus on sales efficiency per customer, which is critical for profitability.
#
# * Using Assortment × Promo × SalesPerCustomer helps explore whether promotions increase basket value or simply attract price-sensitive customers.
#
# * This chart complements earlier Promo–Assortment–Sales and Promo–Assortment–Customers charts by answering “Are promoted customers actually spending more?”

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Assortment a
#
#     * Sales per customer increases noticeably during Promo (from ~8.6 to ~9.8).
#
#     * This indicates that promotions are not just increasing footfall but also encouraging higher spend per visit.
#
# * Assortment b
#
#     * Sales per customer remains almost unchanged (around ~4.2) with or without Promo.
#
#     * This suggests that customers buying from this assortment are highly price-anchored and promotions do not influence basket size.
#
# * Assortment c
#
#     * Promo leads to a strong uplift in sales per customer (from ~9.5 to ~10.7).
#
#     * This indicates high promo responsiveness, where customers combine discounts with higher-value purchases.
#
# * Overall, Promo effectiveness varies sharply by assortment, proving that a uniform promotion strategy may be inefficient.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Promotions are most profitable for:
#
#     * Assortment c → higher basket size + promo responsiveness.
#
#     * Assortment a → moderate but consistent increase in spend per customer.
#
# * These insights support:
#
#     * Assortment-specific promo design.
#
#     * Better margin control by prioritizing promos where customer value increases.
#
#     * The company can optimize promo ROI by focusing promotions on assortments that grow both customers and revenue per customer.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Assortment b shows almost no improvement in sales per customer during Promo.
#
# * This implies:
#
#     * Promotions may be eroding margins without increasing customer value.
#
#     * Promo spend on this assortment could be inefficient or wasteful.
#
# * Continuing blanket promotions for assortment b risks:
#
#     * Discount-driven sales with no real revenue upside.
#
#     * Long-term price sensitivity and reduced perceived value.

# %% [markdown]
# ##### Chart 59 - Impact of Daily Promotion on Average Sales across Store Types

# %%
# Chart - 59 Visualisation Code

# Features Used: StoreType, Promo, Sales

# ✅ Why this chart is important to include?
# This chart will help analyze how short-term daily promotions (Promo)
# impact average sales across different store types.
# The intention is to understand whether all store formats benefit equally
# from daily promotions or if certain store types respond more strongly.
# Using a grouped bar chart makes it easier to directly compare Promo vs
# Non-Promo performance within each store type.

# --------------------------------------------------------------- #
# Grouping the data by StoreType and Promo and calculating average sales
storetype_promo_sales = (
    df.groupby(['StoreType', 'Promo'])['Sales']
      .mean()
      .reset_index()
)

# Creating a pivot table for grouped bar plotting
sales_pivot = storetype_promo_sales.pivot(
    index='StoreType',
    columns='Promo',
    values='Sales'
)

# Renaming columns for clarity
sales_pivot.columns = ['No Promo', 'Promo']

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(10,6))

# Plotting grouped bar chart
sales_pivot.plot(
    kind='bar',
    width=0.7,
    color=['#4C72B0', '#DD8452'],
    edgecolor='black'
)

# Adding value labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.0f', fontsize=9, padding=3)

# Adding title and axis labels
plt.title(
    'Average Sales by Store Type: Promo vs Non-Promo',
    fontsize=15,
    fontweight='bold'
)
plt.xlabel('Store Type', fontsize=12)
plt.ylabel('Average Sales', fontsize=12)

# Legend placement
plt.legend(title='Promo Status')

# Grid and layout adjustments
ax = plt.gca()
ax.yaxis.grid(True, linestyle='--', alpha=0.4)
ax.xaxis.grid(False)
plt.xticks(rotation=0)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart compares average sales across different store types (a, b, c, d) between Promo and Non-Promo days.
#
# * It clearly shows that daily promotions significantly lift average sales across all store types, but the magnitude of uplift varies by store format.
#
# * The chart helps identify which store types benefit the most from promotions and where promotions might be less cost-efficient.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose a grouped bar chart because it allows direct, side-by-side comparison of Promo vs Non-Promo sales within each store type.
#
# * This chart was included to explore whether daily promotions impact all store formats equally or unevenly.
#
# * Using StoreType × Promo × Sales helps uncover store-specific promo responsiveness, which is critical for designing targeted promotional strategies instead of blanket discounts.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Store Type a
#
#     * Sales nearly double during Promo (from ~4.3k to ~8.1k).
#
#     * This indicates strong promo sensitivity, likely driven by price-conscious customers.
#
# * Store Type b
#
#     * Promo sales increase from ~9.4k to ~11.1k.
#
#     * Although uplift exists, the relative gain is smaller compared to other store types.
#
# * Store Types c and d
#
#     * Both show very strong promo impact, with sales rising from ~4.4k to ~7.8k.
#
#     * These stores appear to depend heavily on promotions to drive revenue.
#
# * Overall, daily promotions consistently boost sales, but promo efficiency differs significantly across store formats.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Promotions are highly effective for store types a, c, and d, making them strong candidates for:
#
#     * Targeted promo calendars
#
#     * Aggressive short-term discount campaigns
#
# * The insights help the business:
#
#     * Allocate promotional budgets more efficiently
#
#     * Focus discounts where sales elasticity is highest
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Store type b shows the lowest relative promo uplift, despite having the highest baseline sales.
#
# * This suggests:
#
#     * Promotions may be less cost-effective for this store type.
#
#     * Margins could be eroded without proportional revenue growth.
#
# * Applying the same promo strategy to all store types risks:
#
#     * Over-discounting high-performing stores
#
#     * Leaving profit on the table by not optimizing store-specific strategies

# %% [markdown]
# ##### Chart 60 - Impact of Daily Promotion on Average Customer Footfall by Store Type

# %%
# Chart - 60 Visualisation Code

# Features Used: StoreType, Promo, Customers

# ✅ Why this chart is important to include?
# I am including this chart to analyze how short-term daily promotions
# impact customer footfall across different store types.
# This chart will help me understand whether promotions are driving
# higher customer traffic uniformly across store formats or whether
# certain store types benefit more in terms of footfall.
# This is crucial to distinguish whether promo-driven sales growth
# is coming from increased customers or other factors like higher spend per customer.

# --------------------------------------------------------------- #
# Grouping the data by Store Type and Promo and calculating average customers
storetype_customer_promo = (
    df.groupby(['StoreType', 'Promo'])['Customers']
      .mean()
      .reset_index()
)

# Creating a pivot table for grouped bar chart
customer_pivot = storetype_customer_promo.pivot(
    index='StoreType',
    columns='Promo',
    values='Customers'
)

# Renaming columns for clarity
customer_pivot.columns = ['No Promo', 'Promo']

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(10,6))

# Plotting grouped bar chart
customer_pivot.plot(
    kind='bar',
    width=0.7,
    color=['#4C72B0', '#DD8452'],
    edgecolor='black'
)

# Adding value labels on top of bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.0f', fontsize=9)

# Adding title and labels
plt.title(
    'Average Customers by Store Type: Promo vs Non-Promo',
    fontsize=16,
    fontweight='bold'
)
plt.xlabel('Store Type', fontsize=12)
plt.ylabel('Average Number of Customers', fontsize=12)

# Adjusting legend position for clarity
plt.legend(title='Promo Status', loc='upper right')

# Adding grid only on y-axis for readability
ax = plt.gca()
ax.yaxis.grid(True, linestyle='--', alpha=0.4)
ax.xaxis.grid(False)

# Final layout adjustment
plt.xticks(rotation=0)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart analyzes how daily promotions (Promo) impact customer footfall across different store types (a, b, c, d).
#
# * Across all store types, promotional days consistently attract more customers compared to non-promotional days.
#
# * However, the magnitude of impact varies significantly by store type, indicating that customer response to daily promotions is store-format dependent, not uniform.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * A grouped bar chart is ideal here because:
#
#     * It enables direct comparison between Promo and No Promo within each store type.
#
#     * It clearly highlights incremental customer footfall driven by daily promotions.
#
# * Store Type is a categorical variable, making grouped bars more interpretable than line or distribution plots.
#
# * This visualization directly supports the objective of understanding whether daily promotions actually drive customers, and where they work best.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promotions increase customers across all store types
#
#     1. Store type a: ~528 → ~871
#
#     2. Store type b: ~1910 → ~2114
#
#     3. Store type c: ~558 → ~860
#
#     4. Store type d: ~411 → ~648
#
# * Store type b already has high baseline footfall, but promotions still add incremental customers.
#
# * Store types a, c, and d show strong relative uplift, suggesting promotions are especially effective for smaller or mid-scale stores.
#
# * The response pattern confirms that daily promo is primarily a customer acquisition lever, unlike Promo2 which struggled to pull customers.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * This chart provides actionable insights:
#
#     * Daily promotions are effective at increasing footfall, especially in store types a, c, and d.
#
#     * Marketing teams can prioritize promo budgets toward store formats where customer lift is proportionally higher.
#
#     * Supports the hypothesis that daily promos drive traffic, which can later translate into higher total sales.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Although customer counts increase, this chart alone does not guarantee higher revenue or profitability.
#
# * If increased customers come with lower sales per customer, promotions could inflate operational load without proportional revenue growth.
#
# * Hence, this chart must be interpreted alongside Promo vs StoreType vs SalesPerCustomer

# %% [markdown]
# ##### Chart 61 -Impact of Promo on Average Sales per Customer across Store Type

# %%
# Chart 61 - Visualisation Code

# Features Used - Promo, StoreType, SalesPerCustomers

# ✅ Why this chart is important to include?
# While previous charts showed that daily promotions (Promo) increase
# both sales and customer footfall across store types, this chart focuses
# on *customer-level efficiency*. It helps us understand whether promotions
# encourage customers to spend more per visit or simply attract more
# low-value transactions. This distinction is critical for evaluating
# the true profitability of short-term promotions.

# ---------------------------------------------------------------------------------------------------------- #


# Setting consistent visual style
sns.set(style='whitegrid')


# Aggregating average Sales per Customer by StoreType and Promo status
promo_storetype_spc = (
    df.groupby(['StoreType', 'Promo'])['SalesPerCustomer']
      .mean()
      .reset_index()
)

# Creating the figure
plt.figure(figsize=(10, 6))

# Plotting grouped bar chart
ax = sns.barplot(
    data=promo_storetype_spc,
    x='StoreType',
    y='SalesPerCustomer',
    hue='Promo',
    palette=['#4C72B0', '#DD8452']
)

# Chart title and axis labels
plt.title(
    'Average Sales per Customer by Store Type: Promo vs Non-Promo',
    fontsize=15,
    fontweight='bold'
)
plt.xlabel('Store Type')
plt.ylabel('Sales per Customer')

# Legend formatting
plt.legend(handles=ax.containers ,title='Promo Status', labels=['No Promo', 'Promo'])

# Adding value labels on bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', padding=3)

# Grid and layout adjustments
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.box(False)
plt.tight_layout()

# Display plot
plt.show()

# %% [markdown]
# **Summary -**

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
#
#
#
# **⚠️ Negative-Growth Risks Identified -**

# %% [markdown]
# #### Part 3 - Impact of External Factors and Promo

# %% [markdown]
# ##### Chart 62 - Average Sales by State Holiday: Promo vs Non-Promo

# %%
# Chart 62 - Visualization Code

# Features Used: Promo, StateHoliday, Sales

# ✅ Why this chart is important to include?
# This chart analyzes how short-term daily promotions (Promo)
# interact with different types of state holidays in terms of sales.
# It helps determine whether daily promos are more effective than
# long-running Promo2 during holiday periods.

# --------------------------------------------------------------- #
# Grouping data by StateHoliday and Promo to calculate average sales
promo_holiday_sales = (
    df.groupby(['StateHoliday', 'Promo'])['Sales']
      .mean()
      .reset_index()
)

# Creating pivot table for grouped bar chart
promo_holiday_pivot = promo_holiday_sales.pivot(
    index='StateHoliday',
    columns='Promo',
    values='Sales'
)

# Renaming columns for clarity
promo_holiday_pivot.columns = ['No Promo', 'Promo']

# --------------------------------------------------------------- #
# Starting visualization
plt.figure(figsize=(10,6))

# Plotting grouped bar chart
promo_holiday_pivot.plot(
    kind='bar',
    width=0.7,
    color=['#4C72B0', '#DD8452'],
    edgecolor='black'
)

# Adding titles and labels
plt.title(
    'Average Sales by State Holiday: Promo vs Non-Promo',
    fontsize=15,
    fontweight='bold'
)
plt.xlabel('State Holiday Type', fontsize=12)
plt.ylabel('Average Sales', fontsize=12)

# Formatting x-axis labels
plt.xticks(
    ticks=range(len(promo_holiday_pivot.index)),
    labels=['None', 'Public Holiday (a)', 'Easter (b)', 'Christmas (c)'],
    rotation=0
)

# Adding value labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.0f', fontsize=10, padding=3)

# Legend positioning
plt.legend(title='Promo Status', loc='upper right')

# Grid and layout
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()

# Display plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart analyzes how short-term daily promotions (Promo) interact with state holidays to influence average sales.
#
# * The results clearly show that daily promotions are highly effective on non-holiday days, but their effectiveness drops sharply during state holidays, especially Christmas, where promotional sales almost vanish.
#
# * This highlights that customer behavior during holidays is structurally different, and daily promos fail to compensate for reduced store traffic or store closures.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * A grouped bar chart is ideal here because:
#
#     * We are comparing two categorical variables simultaneously (Promo vs StateHoliday).
#
#     * It allows direct side-by-side comparison of Promo vs No Promo for each holiday type.
#
# * A line or area chart would be misleading because StateHoliday is not a continuous variable.
#
# * Features Chosen:
#
#     * Promo → short-term, daily promotion (high operational relevance).
#
#     * StateHoliday → known to drastically alter shopping behavior.
#
#     * Sales → primary business KPI.
#
# * This combination helps isolate whether daily promotions can offset holiday-driven demand drops, which is a critical retail question.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Non-holiday days (None)
#
#     * Promo increases average sales significantly
#
#         * No Promo ≈ 4546
#
#         * Promo ≈ 8209
#
#     * This confirms that daily promos are highly effective on regular days.
#
# * Public Holidays (a)
#
#     * Promo sales (455) are higher than No Promo (195)
#
#     * Indicates some uplift, but absolute sales remain very low compared to non-holidays.
#
# * Easter (b)
#
#     * Promo sales (203) are lower than No Promo (226)
#
#     * Suggests promotions fail to drive additional demand.
#
# * Christmas (c)
#
#     * Promo sales drop to 0
#
#     * Indicates stores are likely closed or customer activity is negligible.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Confirms that daily promotions should be prioritized on non-holiday days.
#
# * Helps businesses avoid wasting promotional budget on ineffective periods.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Yes, clear negative growth signals exist:
#
#     * During Easter and Christmas, promotional sales are equal to or lower than non-promo sales.
# * On Christmas, Promo sales drop to zero, indicating:
#
#     * Stores are likely closed, or
#
#     * Customers are not responsive to daily promotions at all.
#
# 📌 Justification:
#
# * Daily promotions rely on store footfall, which collapses during major state holidays.
#
# * Promotions cannot overcome structural demand constraints such as closures or holiday-driven shopping behavior.
#
# 🧠 Business Recommendation  -
#
# * Disable daily Promo campaigns on major state holidays
#
# * Shift strategy to:
#
#     * Pre-holiday promotions
#
#     * Post-holiday recovery offers
#
#     * Long-running Promo2 (if applicable)

# %% [markdown]
# ##### Chart 63 - Average Sales per Customer by State Holiday: Promo vs Non-Promo

# %%
# Chart - 63 Visualisation Code

# Features Used - Promo, StateHoliday, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart helps analyze whether daily promotions increase
# per-customer spending during different state holiday types.
# It focuses on value per customer instead of total sales or footfall,
# which is critical to understand promotion efficiency.

# ---------------------------------------------------------------------------------------------------------- #

# Setting consistent visual style
sns.set(style='whitegrid')

# Creating aggregated data
stateholiday_spc = (
    df.groupby(['StateHoliday', 'Promo'])['SalesPerCustomer']
      .mean()
      .reset_index()
)

# Creating the figure
plt.figure(figsize=(10,6))

# Plotting grouped bar chart
sns.barplot(
    data=stateholiday_spc,
    x='StateHoliday',
    y='SalesPerCustomer',
    hue='Promo',
    palette=['#4FC3F7', '#FFB74D']
)

# Adding value labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.2f', fontsize=9)

# Adding chart title and labels
plt.title(
    'Average Sales per Customer by State Holiday: Promo vs Non-Promo',
    fontsize=15,
    fontweight='bold'
)
plt.xlabel('State Holiday Type', fontsize=12)
plt.ylabel('Average Sales per Customer', fontsize=12)

# Legend positioning
plt.legend(
    handles = ax.containers,
    title='Promo Status',
    loc='upper right',
    labels=['No Promo', 'Promo'],
    frameon=True
)

# Grid styling
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart compares average sales per customer across different state holiday types under Promo vs Non-Promo conditions.
#
# * On non-holiday days (None), promo days clearly show much higher sales per customer compared to non-promo days.
#
# * During state holidays (a, b, c), sales per customer drop sharply for both promo and non-promo, indicating structural demand constraints rather than promotion inefficiency.
#
# * The impact of promo on per-customer spending is strongest on normal days, while holidays significantly suppress individual spending behavior.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * This chart was chosen to understand whether daily promotions improve customer value, not just total sales.
#
# * Sales per customer is a quality metric, showing if promotions encourage customers to spend more per visit.
#
# * Segmenting by StateHoliday helps isolate whether promotions remain effective during special calendar disruptions.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * On non-holiday days, promo increases sales per customer substantially (≈ 6.86 → 10.16), proving promotions successfully boost basket value.
#
# * During state holidays (a, b, c), sales per customer remain extremely low regardless of promo presence.
#
# * Promo provides limited uplift during holidays, suggesting customers shop with fixed intent or stores operate under restricted conditions.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Yes, the insights clearly guide when promotions should be aggressively used.
#
# * Promotions deliver strong positive impact on normal days, making them ideal for revenue maximization during regular operations.
#
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * During state holidays, promo does not increase sales per customer and in some cases performs worse (e.g., holiday b).
#
# * This likely occurs due to reduced store hours, lower footfall, urgency-driven purchases, or regulatory constraints, making promotions less effective.
#
# * Business implication: Promotions during state holidays may waste margin without increasing customer value and should be reconsidered or redesigned.

# %% [markdown]
# ##### Chart 64 - Sales Distribution by School Holiday: Promo vs Non-Promo

# %%
# Chart - 64 Visualisation Code

# Features Used - Promo, SchoolHoliday, Sales

# ✅ Why this chart is important to include?
# This chart helps analyze how daily promotions behave during school holidays
# compared to non-holiday periods.
# Instead of relying only on average sales, a box plot captures the full
# sales distribution, including median behavior, variability, and spread.
# This is critical because school holidays often introduce high volatility
# in customer behavior, and promotions may cause inconsistent sales spikes
# rather than stable growth.

# ---------------------------------------------------------------------------------------------------------- #

# Setting consistent visual style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10, 6))

# Plotting box plot to analyze sales distribution
sns.boxplot(
    data=df,
    x='SchoolHoliday',
    y='Sales',
    hue='Promo',
    palette=['#64B5F6', '#FFB74D'],
    showfliers=False  # Removing extreme outliers for better readability
)

# Adding tick labels
plt.xticks(ticks = [0,1], labels = ["No Schhol Holiday", "School Holiday"])

# Annotate median values on box plot
grouped_medians = (
    df
    .groupby(['SchoolHoliday', 'Promo'])['Sales']
    .median()
    .reset_index()
)

for i, row in grouped_medians.iterrows():
    x_pos = row['SchoolHoliday']-0.2  if row['Promo'] == 0 else row['SchoolHoliday'] +0.2
    plt.text(
        x_pos,
        row['Sales'],
        f"{int(row['Sales'])}",
        ha='center',
        va='bottom',
        fontsize=9,
        fontweight='bold',
        color='black'
    )

# Adding chart title and labels
plt.title(
    'Sales Distribution by School Holiday: Promo vs Non-Promo',
    fontsize=15,
    fontweight='bold'
)
plt.xlabel('School Holibday', fontsize=12)
plt.ylabel('Sales', fontsize=12)

# Adjusting legend placement to avoid overlap
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(
    handles,
    ['No Promo', 'Promo Active'],
    title='Promo Status',
    loc='upper right',
    frameon=True
)


# Adding gridlines and finishing touches
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * This box plot shows that Promo days consistently outperform Non-Promo days in terms of median sales, regardless of whether it is a school holiday or not.
#
# * During school holidays, both Promo and Non-Promo sales medians increase, indicating higher baseline demand driven by holiday-driven footfall.
#
# * The highest median sales (~7.5K+) occur when Promo is active, with slightly higher medians during school holidays, suggesting a compounding effect of Promo + Holiday.
#
# * Promo days also show wider interquartile ranges and longer upper whiskers, highlighting higher sales variability and occasional demand spikes.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * This box plot was chosen because it allows comparison of entire sales distributions, not just averages.
#
# * It clearly highlights median shifts, variability, and extreme values, which are critical for understanding promotion performance during holidays.
#
# * Unlike bar charts, this visualization helps identify risk and volatility, which is important for operational and inventory planning.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo increases median sales significantly in both cases:
#
#     * No School Holiday: Median rises from ~4.5K (No Promo) to ~7.5K (Promo).
#
#     * School Holiday: Median rises from ~5.2K (No Promo) to ~7.6K (Promo).
#
# * School holidays independently increase sales even without Promo, but Promo amplifies this effect.
#
# * Promo days have higher dispersion, indicating larger upside potential but less predictability.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **No direct negative growth** is observed in terms of median sales; Promo consistently improves central sales tendency.
#
# * However, higher variability during Promo days suggests potential operational risk—poor stock planning or staffing could lead to lost sales opportunities or inefficiencies.
#
# * Non-Promo days during non-holiday periods show lower medians and tighter ranges, which may indicate stable but limited revenue potential.

# %% [markdown]
# ##### Chart 65 - Impact of Promo and Competition Age on Sales

# %%
# Chart - 65 Visualisation Code

# Features Used - Promo, CompetitionOpenMonths, Sales

# ✅ Why this chart is important to include?
# This chart helps analyze how the effectiveness of daily promotions (Promo)
# varies depending on how long a competing store has been operating nearby.
# It allows us to understand whether promotions are more effective when
# competition is new, moderate, or well-established.
# ---------------------------------------------------------------------------------------------------------- #

# Creating competition age buckets (in months)
df['Competition_Age_Bucket'] = pd.cut(
    df['CompetitionOpenMonths'],
    bins=[-1, 6, 12, 24, 60, 120, np.inf],
    labels=[
        'Very New (<6m)',
        'New (6–12m)',
        'Moderate (1–2y)',
        'Old (2–5y)',
        'Very Old (5–10y)',
        'Extremely Old (>10y)'
    ]
)

# Aggregating average sales by competition age bucket and promo status
promo_comp_sales = (
    df.groupby(['Competition_Age_Bucket', 'Promo'])['Sales']
      .mean()
      .reset_index()
)

# Setting plot style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(12, 6))

# Plotting grouped bar chart
sns.barplot(
    data=promo_comp_sales,
    x='Competition_Age_Bucket',
    y='Sales',
    hue='Promo',
    palette=['#4E79A7', '#F28E2B']
)

# Adding value labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.0f', fontsize=12)

# Titles and labels
plt.title('Average Sales by Competition Age: Promo vs Non-Promo', fontsize=14)
plt.xlabel('Competition Age (Months Since Competitor Opened)', fontsize=11)
plt.ylabel('Average Sales', fontsize=11)

# Legend formatting
plt.legend(handles= ax.containers,
    title='Promo Status',
    labels=['No Promo', 'Promo'],
    loc='upper center',
    bbox_to_anchor = [0.5,-0.1],
    ncols = 2
)

# Rotating x-axis labels for readability
plt.xticks(rotation=0)

# Tight layout for clean rendering
plt.tight_layout()

# Display plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart analyzes how average sales under daily promotion (Promo) compare with non-promotional days across different competition age buckets (months since a competitor store opened).
#
# * Across all competition maturity levels, promotional days consistently generate significantly higher sales than non-promotional days.
#
# * While base sales (No Promo) slightly decline as competition ages, Promo maintains a strong and stable uplift, indicating that daily promotions remain effective even in highly competitive environments.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * A grouped bar chart is ideal here because:
# It allows direct comparison between Promo vs No Promo for each competition age bucket.
#
# * It clearly shows whether promotion effectiveness changes as competition matures.
#
# * It makes magnitude differences in sales easy to quantify and explain for business stakeholders.
#
# * This visualization directly supports strategic questions around competitive pressure and promotional resilience.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Key Insights :
#
# * Promo sales remain consistently high (~₹7.9k–₹8.2k) across all competition ages.
#
# * No Promo sales are significantly lower (~₹4.3k–₹4.6k) and show a gradual decline as competition becomes older.
#
# * The sales gap between Promo and No Promo is large and stable (≈ ₹3.4k–₹3.7k) across all buckets.
#
# * Promo effectiveness does not weaken even when competitors have been present for more than 10 years.
#
# * Interpretation: Daily promotions successfully counteract competitive pressure, preventing long-term competitors from eroding sales performance.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Confirms that Promo is a reliable lever for boosting sales regardless of competition age.
#
# * Supports continued investment in daily promotions, especially in mature and saturated markets.
#
# * Helps retailers design competition-aware pricing and promotion strategies.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Non-promotional sales decline as competition ages (from ~₹4.6k to ~₹4.3k).
#
# * This suggests that without promotions, older competitive environments slowly erode baseline demand.
#
# * Over time, stores may become over-dependent on promotions, which could impact margins if not managed carefully.
#
#
# 👉 This highlights the need for balanced strategies: promotions + assortment, loyalty, or differentiation.

# %% [markdown]
# ##### Chart 66 - Sales Distribution by Competition Distance: Promo vs Non-Promo

# %%
# Chart - 66 Visualisation Code

# Features Used - Promo, CompetitionDistance, Sales

# ✅ Why this chart is important to include?
# This chart analyzes how daily promotions impact sales distribution
# across different competition distance buckets.
# It helps identify whether Promo improves sales consistency
# or only increases upper outliers in competitive areas.
# ---------------------------------------------------------------------------------------------------------- #

# Creating competition distance buckets
df['CompetitionDistanceBucket'] = pd.cut(
    df['CompetitionDistance'],
    bins=[0, 500, 1000, 3000, 10000, df['CompetitionDistance'].max()],
    labels=[
        'Very Close (<500m)',
        'Close (500m–1km)',
        'Moderate (1–3km)',
        'Far (3–10km)',
        'Very Far (>10km)'
    ]
)

# Setting plot style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(14, 7))

# Box plot for sales distribution
sns.boxplot(
    data=df,
    x='CompetitionDistanceBucket',
    y='Sales',
    hue='Promo',
    palette={0: '#64B5F6', 1: '#FFB74D'},
    showfliers=False
)

# Labels and title
plt.title('Sales Distribution by Competition Distance: Promo vs Non-Promo', fontsize=14)
plt.xlabel('Competition Distance')
plt.ylabel('Sales')

# Legend formatting
plt.legend(handles = ax.containers ,title='Promo Status', labels=['No Promo', 'Promo Active'])

# Layout adjustment
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary -**
#
# * This box plot examines how daily promotions (Promo) influence the distribution of sales across different competition distance buckets.
#
# * Instead of averages, the chart highlights median sales, variability, and spread, allowing us to understand whether promotions consistently improve sales or only create sporadic spikes under different competitive pressures.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * Competition distance introduces high variance, making averages misleading.
#
# * A box plot is ideal to:
#
#     * Compare median sales between Promo and Non-Promo
#
#     * Observe sales stability vs volatility
#
#     * Detect whether promotions increase consistent performance or just upper outliers

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Across all competition distance buckets, Promo Active stores consistently show higher median sales than Non-Promo stores.
#
# * The largest uplift in median sales due to promotions is observed when Competition is Very Close (< 500m) and Moderate (1-3km)
#
# * Non-Promo stores show wider lower tails, indicating - higher risk of low-sales days, especially in highly competitive areas
#
# * Promo not only raises the median but also compresses the lower range, suggesting:
#
#     * More reliable sales performance during promotions
#
#     * Sales variability increases slightly with distance, but Promo maintains a clear advantage even in far-competition zones.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Promotions are most effective in high-competition areas, where baseline sales are vulnerable.
#
# * Running Promo near competitors helps:
#
#     * Protect market share
#
#     * Reduce downside risk (fewer low-sales days)
#
# * The consistency benefit suggests Promo is not just a volume booster but a risk-mitigation strategy.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * In Very Far (>10km) competition zones:
#
#     * The uplift from Promo is still present but less pronounced
#
#     * This indicates diminishing marginal returns of promotions in low-competition environments.
#
# * Blindly running promotions everywhere may reduce profitability where competition pressure is low.
#
# **👉 Business implication:**
#
# * Promotions should be strategically targeted, not uniformly applied.

# %% [markdown]
# #### Part 4 - Analysis of Promo2 - Time Interaction

# %% [markdown]
# ##### Chart 67 - Average Monthly Sales: Promo2 Active vs Not Active

# %%
# Chart - 67 Visualisation Code

# Features Used: Month, Promo2, Sales

# ✅ Why this chart is important to include?
# This chart is going to help in understanding how long-running promotions (Promo2)
# influence monthly sales trends. Unlike short promotional spikes, Promo2 is meant
# to deliver sustained improvement in revenue. By comparing Promo2-active vs
# non-active months, we are expecting to uncover whether this long-term strategy
# truly contributes to higher monthly performance or follows seasonal patterns.

# --------------------------------------------------------------- #
# Grouping the data by Month and Promo2 and calculating average sales
monthly_sales_promo2 = (
    df.groupby(['Month', 'Promo2'])['Sales']
      .mean()
      .reset_index()
)

# Creating a pivot table for line plotting
sales_pivot_promo2 = monthly_sales_promo2.pivot(
    index='Month',
    columns='Promo2',
    values='Sales'
)

# Renaming columns for clarity
sales_pivot_promo2.columns = ['No Promo2', 'Promo2 Active']

# Sorting months in chronological order
sales_pivot_promo2 = sales_pivot_promo2.sort_index()

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(12,6))

# Plotting line for months without Promo2
plt.plot(
    sales_pivot_promo2.index,
    sales_pivot_promo2['No Promo2'],
    marker='o',
    linewidth=2,
    label='No Promo2',
    color='#1f77b4'
)

# Plotting line for months with Promo2 active
plt.plot(
    sales_pivot_promo2.index,
    sales_pivot_promo2['Promo2 Active'],
    marker='o',
    linewidth=2,
    label='Promo2 Active',
    color='#ff7f0e'
)

# Adding shaded area to visualize the gap
plt.fill_between(
    sales_pivot_promo2.index,
    sales_pivot_promo2['No Promo2'],
    sales_pivot_promo2['Promo2 Active'],
    color='#ffbb78',
    alpha=0.15
)

# Adding titles, labels, and legend
plt.title("Average Monthly Sales: Promo2 Active vs Not Active", fontsize=16, fontweight='bold')
plt.xlabel("Month", fontsize=12)
plt.ylabel("Average Sales", fontsize=12)
plt.legend(title="Promo2 (0 = No, 1 = Yes)")

# Adding grid and month labels
plt.grid(alpha=0.25)
plt.xticks(
    ticks=sales_pivot_promo2.index,
    labels=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
)


# Displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary -**
#
# * Sales remain consistently higher during months without Promo2, suggesting that long-running promotions may not be delivering the intended uplift.
#
# * The average sales gap between No Promo2 vs Promo2 Active is visible in every month, showing a structurally weaker performance under long-term promotions.
#
# * The seasonal trend peaks in July and December, and even during these naturally high-demand periods, Promo2 months still underperform compared to Non-Promo2 months.
#
# * Promo2 seems to behave more like a maintenance strategy rather than a revenue-boosting strategy—customers may not be responding strongly to long-running offers.
#
# * This indicates that Promo2 may require better targeting, improved offer structure, or stronger marketing communication to be effective.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I selected this chart to evaluate whether long-running promotions (Promo2) actually improve sales performance when viewed across the monthly business cycle.
#
# * I chose a dual-line time series plot because it clearly separates two behavioral groups (Promo2 Active vs Not Active) and allows us to compare seasonal sales trajectories side by side.
#
# * A line plot is the best choice here because Promo2 runs on monthly cycles, and line charts visually capture trends, fluctuations, and gaps over time that would be missed in bar or box plots.
#
# * Using Month, Promo2, and Sales together helps uncover whether Promo2 aligns with natural demand cycles or works independently of seasonality.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Sales are consistently higher in all months when Promo2 is NOT active, showing that long-term promotions are not generating the expected uplift.
#
# * Promo2 months show a much flatter and lower sales curve, suggesting weaker customer response compared to short-term promotions or normal pricing periods.
#
# * Even high-demand months like July and December do not show strong Promo2 performance, indicating the issue is structural, not seasonal.
#
# * The revenue gap is significant—typically 400–650 units per month—implying real business impact.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * The insight allows management to reassess Promo2 strategy and redirect resources toward promotional models that deliver higher ROI.
#
# * It highlights that short-term promotions (Promo) are likely more effective and may deserve increased focus or budgets.
#
# * This chart reveals hidden inefficiencies early, helping prevent long-term revenue leakage.
#
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
#
# * Promo2 appears to be underperforming and may unintentionally depress revenue instead of boosting it.
#
# * Over-reliance on a weak long-term promotion could reduce perceived product value over time.
#
# * Ineffective long-term promotions may also mask operational or assortment issues, delaying necessary interventions.

# %% [markdown]
# ##### Chart 68 - Promo2 Impact on Customer Footfall Across Months

# %%
# Chart 68 - Visualization Code

# Features Used: Month, Promo2, Customers

# --------------------------------------------------------------- #
# Grouping data by Month and Promo2 and calculating total customers per group
monthly_customers = (
    df.groupby(['Month', 'Promo2'])['Customers']
      .sum()
      .reset_index()
)

# Calculating total customers per month
monthly_total = (
    df.groupby('Month')['Customers']
      .sum()
      .reset_index()
      .rename(columns={'Customers': 'TotalCustomers'})
)

# Merging totals back
monthly_customers = monthly_customers.merge(monthly_total, on='Month', how='left')

# Computing percentages
monthly_customers['CustomerPercent'] = (
    monthly_customers['Customers'] / monthly_customers['TotalCustomers'] * 100
)

# Pivoting for grouped bar chart
promo2_percent_pivot = monthly_customers.pivot(
    index='Month',
    columns='Promo2',
    values='CustomerPercent'
)

# Ensuring months 1–12 appear
all_months = list(range(1,13))
promo2_percent_pivot = promo2_percent_pivot.reindex(all_months).fillna(0)

# Renaming columns for readability
cols = {}
if 0 in promo2_percent_pivot.columns:
    cols[0] = 'No Promo2'
if 1 in promo2_percent_pivot.columns:
    cols[1] = 'Promo2 Active'

promo2_percent_pivot = promo2_percent_pivot.rename(columns=cols)

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(12,6))

x = np.arange(len(promo2_percent_pivot.index))
width = 0.36

# Bars for No Promo2
if 'No Promo2' in promo2_percent_pivot.columns:
    plt.bar(
        x - width/2,
        promo2_percent_pivot['No Promo2'],
        width,
        label='No Promo2',
        color='#1f77b4'
    )

# Bars for Promo2 Active
if 'Promo2 Active' in promo2_percent_pivot.columns:
    plt.bar(
        x + width/2,
        promo2_percent_pivot['Promo2 Active'],
        width,
        label='Promo2 Active',
        color='#ff7f0e'
    )

# Adding labels above each bar
for idx in range(len(x)):
    for col, shift in [('No Promo2', -width/2), ('Promo2 Active', width/2)]:
        if col in promo2_percent_pivot.columns:
            val = promo2_percent_pivot[col].iloc[idx]
            if val > 0:
                plt.text(
                    x[idx] + shift,
                    val + 0.6,
                    f"{val:.1f}%",
                    ha='center',
                    fontsize=9
                )

# Titles, labels, and ticks
plt.title("Percentage of Monthly Customer Footfall: Promo2 Active vs Non-Active", fontsize=16, fontweight='bold')
plt.xlabel("Month", fontsize=12)
plt.ylabel("Customer Percentage (%)", fontsize=12)
plt.xticks(
    ticks=x,
    labels=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
)


# Adding Legend
plt.legend(
    title="Promo2 Status",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.12),   # Moves legend below chart
    ncol=2,                        # Two columns (side-by-side)
    frameon=False,                 # Removes legend border
    fontsize=10,
    title_fontsize=11
)

# Grid
plt.grid(axis='y', alpha=0.25)
plt.tight_layout()

plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart clearly shows that across all months, a higher share of customer footfall comes from non-Promo2 days compared to Promo2 active days.
#
# * Promo2 contributes consistently lower customer percentages, typically ranging between 42%–46%, while non-Promo2 days contribute around 54%–57%.
#
# * The gap between Promo2 and non-Promo2 customer share remains stable throughout the year, indicating that Promo2 does not significantly alter customer visit behavior on a monthly basis

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose a grouped bar chart because it allows direct side-by-side comparison of customer contribution between Promo2 active and non-active days for each month.
#
# * I selected percentage of customers instead of absolute counts to avoid misleading conclusions caused by differences in total monthly traffic.
#
# * I included Month and Promo2 together because Promo2 is a long-running promotion, and this chart helps evaluate whether its presence actually shifts customer behavior over time.
#
# * This chart is specifically helping to assess whether Promo2 drives incremental footfall or merely exists alongside normal demand.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Key Insight:
#
# * Promo2 does not dominate customer footfall in any month.
#
# * Across all months, non-Promo2 days consistently attract more customers than Promo2 active days.
#
# * The relatively flat Promo2 percentage trend suggests that customers do not significantly change their visit patterns due to Promo2 being active.
#
# * Even in traditionally high-traffic months like November and December, Promo2 does not close the gap with non-Promo2 footfall.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * This insight helps the business set realistic expectations from long-term promotions.
#
# * It suggests Promo2 may be more effective for retention or basket value rather than for attracting new customers.
#
# * Marketing teams can use this finding to re-evaluate Promo2 objectives and measure it against the right KPI.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Since Promo2 does not increase customer footfall, maintaining it without improving conversion or sales per customer may erode margins.
#
# * A long-running promotion that fails to shift traffic behavior could lead to promotion fatigue.
#
# * This highlights the risk of relying on static, long-term promotions instead of adaptive, time-bound strategies.

# %% [markdown]
# ##### Chart 69 - Monthly Sales Per Customer: Promo2 Active vs Non-Active

# %%
# Chart 69 - Visualisation Code

# Features Used: Month, Promo2, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart is going to analyze how long-running promotions (Promo2) impact
# sales efficiency over time.
# Instead of looking at total sales, this chart is focusing on Sales Per Customer,
# which is going to reveal whether Promo2 is improving customer spending behavior
# or merely increasing footfall without meaningful revenue contribution.
# The month-wise trend is going to help detect seasonal patterns and long-term
# effectiveness of Promo2.

# --------------------------------------------------------------- #


# Grouping data by Month and Promo2 and calculating average Sales Per Customer
monthly_spc_promo2 = (
    df.groupby(['Month', 'Promo2'])['SalesPerCustomer']
      .mean()
      .reset_index()
)

# Creating pivot table for line plot
spc_pivot = monthly_spc_promo2.pivot(
    index='Month',
    columns='Promo2',
    values='SalesPerCustomer'
)

# Renaming columns for clarity
spc_pivot.columns = ['No Promo2', 'Promo2 Active']

# Sorting months to ensure correct order
spc_pivot = spc_pivot.sort_index()

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(12,6))

# Plotting Sales Per Customer for No Promo2
plt.plot(
    spc_pivot.index,
    spc_pivot['No Promo2'],
    marker='o',
    linewidth=2,
    label='No Promo2',
    color='#4C72B0'
)

# Plotting Sales Per Customer for Promo2 Active
plt.plot(
    spc_pivot.index,
    spc_pivot['Promo2 Active'],
    marker='o',
    linewidth=2,
    label='Promo2 Active',
    color='#DD8452'
)

# Adding filled area to emphasize gap
plt.fill_between(
    spc_pivot.index,
    spc_pivot['No Promo2'],
    spc_pivot['Promo2 Active'],
    alpha=0.12,
    color='#DD8452'
)

# Adding title and labels
plt.title(
    'Monthly Sales Per Customer: Promo2 Active vs Non-Active',
    fontsize=16,
    fontweight='bold'
)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales Per Customer', fontsize=12)

# Adding legend with improved placement
plt.legend(
    title='Promo2 Status',
    loc='upper left',
    frameon=True
)

# Adding grid and layout adjustments
plt.grid(alpha=0.25)
plt.xticks(
    ticks=spc_pivot.index,
    labels=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart shows that Sales Per Customer is consistently higher during Promo2 active periods across all months.
#
# * The gap between Promo2 Active and No Promo2 remains stable rather than spiky, indicating a sustained efficiency benefit instead of short-term distortion.
#
# * A noticeable dip in Sales Per Customer during Aug-Sep is observed for both cases, followed by a strong recovery in Nov-Dec.
#
# * December records the highest Sales Per Customer, especially under Promo2, suggesting a strong year-end compounding effect.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picked this chart to evaluate the efficiency impact of Promo2, not just its effect on total sales.
#
# * Instead of bar charts, a line plot is chosen because:
#
#     * It is better at capturing temporal trends
#
#     * It allows easy comparison of two long-running strategies over time
#
#     * It highlights seasonality and sustained effects, which is essential for Promo2 analysis.
#
#
# * Using Sales Per Customer helps move beyond volume metrics and focuses on customer spending behavior, which is critical for profitability evaluation.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo2 consistently improves Sales Per Customer across every month.
#
# * This indicates:
#
#     * customers are not just buying more frequently,
#
#     * but are spending more per visit during Promo2 periods.
#
#
# * The stable gap suggests Promo2 creates a structural uplift, not a temporary spike.
#
# * The seasonal dip in Aug–Sep affects both lines, meaning: the decline is market-driven, not promotion-driven.
#
# * The strong December peak implies Promo2 amplifies high-season behavior, rather than cannibalizing margins.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Promo2 appears to be:
#
#     * improving basket size
#
#     * encouraging higher-value purchases
#
#     * creating predictable, sustained revenue efficiency
#
#
# * This makes Promo2 a strong candidate for:
#
#     * long-term customer value strategies
#
#     * loyalty-oriented planning
#
#     * stable revenue forecasting
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Because Promo2 improves efficiency consistently:
#
#     * The cost of discounts must be monitored carefully
#
#     * Margins should be evaluated alongside Sales Per Customer.
#
#
# * Over-reliance on Promo2 could reduce full-price buying behavior if not rotated carefully.

# %% [markdown]
# #### Part 5 - Impact of Promo2 - Store Characteristics

# %% [markdown]
# ##### Chart 70 -  Sales Change by Assortment Type: Promo2 vs No Promo2

# %%
# Chart 70 - Visualisation Code

# Features Used: Assortment, Promo, Sales

# ✅ Why this chart is important to include?
# This chart is being included to compare how average sales change when promotions
# are applied across different assortment types.
# Using a slope chart is helping to clearly visualize the *direction and magnitude*
# of sales movement from No Promo to Promo for each assortment.
# This is allowing us to understand whether promotions are equally effective
# across assortment strategies or if certain assortments benefit more than others.

# --------------------------------------------------------------- #
# Grouping the data by Assortment and Promo and calculating average sales
assortment_sales_promo = (
    df.groupby(['Assortment', 'Promo'])['Sales']
      .mean()
      .reset_index()
)

# Creating a pivot table for slope chart structure
assortment_sales_pivot = assortment_sales_promo.pivot(
    index='Assortment',
    columns='Promo',
    values='Sales'
)

# Renaming columns for clarity
assortment_sales_pivot.columns = ['No Promo', 'Promo']

# Sorting assortment types for consistent ordering
assortment_sales_pivot = assortment_sales_pivot.sort_index()

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(11,6))

# Defining x-axis positions for slope lines
x_positions = [0.5, 1]

# Plotting slope lines for each assortment type
for assortment in assortment_sales_pivot.index:
    plt.plot(
        x_positions,
        assortment_sales_pivot.loc[assortment],
        marker='o',
        linewidth=2,
        label=f"Assortment {assortment}"
    )

    # Adding value labels for No Promo
    plt.text(
        x_positions[0] - 0.01,
        assortment_sales_pivot.loc[assortment, 'No Promo'],
        f"{assortment_sales_pivot.loc[assortment, 'No Promo']:.0f}",
        ha='right',
        va='center',
        fontsize=10
    )

    # Adding value labels for Promo
    plt.text(
        x_positions[1] + 0.02,
        assortment_sales_pivot.loc[assortment, 'Promo'],
        f"{assortment_sales_pivot.loc[assortment, 'Promo']:.0f}",
        ha='left',
        va='center',
        fontsize=10
    )

# Adding vertical reference lines
plt.axvline(x=x_positions[0], color='gray', linestyle='--', alpha=0.4)
plt.axvline(x=x_positions[1], color='gray', linestyle='--', alpha=0.4)

# Customizing x-axis labels
plt.xticks(x_positions, ['No Promo', 'Promo'])

# Adding titles and labels
plt.title(
    "Average Sales Change by Assortment Type: Promo vs No Promo",
    fontsize=16,
    fontweight='bold'
)
plt.xlabel("Promotion Status", fontsize=12)
plt.ylabel("Average Sales", fontsize=12)

# Adding legend
plt.legend(title="Assortment Type")

# Adding grid for readability
plt.grid(axis='y', alpha=0.3)

# Adjusting layout
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart clearly shows that promotions lead to an increase in average sales across all assortment types, but the magnitude of uplift varies significantly.
#
# * Assortment A and C experience a strong jump in sales when promotions are applied, indicating high promo responsiveness.
#
# * Assortment B already performs strongly even without promotions and shows comparatively limited incremental benefit from promos.
#
# * This indicates that promotions are not uniformly effective and should be aligned with assortment strategy.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose a slope chart because it is best suited for comparing changes between two states — No Promo and Promo — across multiple categories.
#
# * This chart helps visually emphasize both the direction and magnitude of sales change rather than just absolute values.
#
# * Using average sales instead of percentages preserves the real baseline performance and avoids misleading zero-reference distortions.
#
# * The combination of Assortment + Promo + Sales allows me to understand whether assortment strategy influences promotional effectiveness.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Assortment A shows a strong uplift from ~4,100 to ~7,700 average sales, indicating high sensitivity to promotions.
#
# * Assortment C also demonstrates a substantial gain, moving from ~4,700 to ~8,300, suggesting promotions significantly enhance its revenue potential.
#
# * Assortment B has the highest baseline sales (~8,300) but gains only a modest increase during promotions (~8,900).
#
# * This suggests that Assortment B already attracts high-paying customers and is less dependent on discounts to drive sales.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Promotions can be strategically targeted toward Assortments A and C, where they clearly generate higher incremental revenue.
#
# * Marketing budgets can be optimized by reducing aggressive promos for Assortment B, where returns are limited.
#
# * This enables data-driven assortment-level promo planning instead of blanket discounting.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Applying uniform promotions across all assortments may erode margins for Assortment B without delivering proportional gains.
#
# * Over-discounting a high-performing assortment could train customers to wait for deals, reducing long-term profitability.

# %% [markdown]
# ##### Chart 71 - Change in Average Customers by Assortment Type: Promo2 Active vs Non-Active

# %%
# Chart 71 - Visualisation Code
# Features Used: Promo2, Assortment, Customers

# ✅ Why this chart is important to include?
# This chart is helping to compare how long-running promotions (Promo2)
# know to influence customer footfall across different assortment types.
# By using a grouped bar chart, this visualization is clearly showing
# side-by-side differences between Promo2 Active and Non-Active periods
# for each assortment category, making customer impact immediately visible.

# --------------------------------------------------------------- #
# Grouping the data by Assortment and Promo2 and calculating average customers
assortment_promo2_customers = (
    df.groupby(['Assortment', 'Promo2'])['Customers']
      .mean()
      .reset_index()
)

# Creating a pivot table for grouped bar plotting
customers_pivot = assortment_promo2_customers.pivot(
    index='Assortment',
    columns='Promo2',
    values='Customers'
)

# Renaming columns for clarity
customers_pivot.columns = ['No Promo2', 'Promo2 Active']

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(10,6))

# Plotting grouped bar chart
customers_pivot.plot(
    kind='bar',
    width=0.65,
    color=['#4C72B0', '#DD8452'],
    edgecolor='black'
)

# Adding value labels on top of bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.0f', padding=3, fontsize=9)

# Adding title and axis labels
plt.title(
    "Average Customers by Assortment Type: Promo2 Active vs Non-Active",
    fontsize=16,
    fontweight='bold'
)
plt.xlabel("Assortment Type", fontsize=12)
plt.ylabel("Average Number of Customers", fontsize=12)

# Improving legend placement to avoid overlap
plt.legend(
    title="Promo2 Status",
    loc='upper right',
    frameon=True
)

# Adding grid for readability
sns.set_style('whitegrid')
ax = plt.gca()
ax.yaxis.grid(True, linestyle='--', alpha=0.4)
ax.xaxis.grid(False)

# Final layout adjustments
plt.xticks(rotation=0)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart is clearly showing that customer footfall decreases across all assortment types when Promo2 is active.
#
# * Assortment b consistently attracts the highest number of customers, both with and without Promo2.
#
# * The largest absolute drop in customers during Promo2 is observed for assortment b, indicating higher sensitivity.
#
# * Assortments a and c also show noticeable customer decline, but the magnitude is comparatively smaller.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose a grouped bar chart because it allows direct, side-by-side comparison between Promo2 Active and Non-Active periods.
#
# * This chart type is ideal when comparing discrete categories (assortment types) across binary conditions (Promo2 status).
#
# * I selected Customers instead of Sales to understand whether Promo2 is impacting store footfall behavior, not just revenue.
#
# * Using assortment as a dimension helps evaluate whether product variety influences customer response to long-running promotions.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo2 does not increase customer footfall for any assortment type.
#
# * Assortment b, despite being the strongest performer in absolute customers, shows the sharpest decline during Promo2.
#
# * The decline is consistent across all assortment types, indicating that Promo2 may not be attractive to customers, regardless of product range.
#
# * This suggests Promo2 might be designed for price retention or loyalty rather than customer acquisition.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * The business can now re-evaluate the objective of Promo2:
#
#     * If the goal is customer growth → Promo2 is ineffective.
#
#     * If the goal is margin protection or inventory control → customer drop may be acceptable.
#
#
# * Assortment b stores may require alternative engagement strategies during Promo2 to avoid losing high footfall.
#
# * Marketing teams can avoid blindly extending Promo2 across all assortment types.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Sustained customer decline during Promo2 may:
#
#     * Reduce impulse purchases.
#
#     * Lower long-term customer loyalty.
#
#     * Cause customers to shift to competitors offering short-term attractive promos.
#
# * Applying the same long-running promo across all assortment types appears suboptimal and may be hurting high-performing stores the most.

# %% [markdown]
# ##### Chart 72 - Average Sales per Customer by Assortment Type: Promo2 Active vs Non-Active

# %%
# Chart 72 - Visualization Code

# Features Used: Promo2, Assortment, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart will help in understanding whether long-running Promo2 campaigns
# are improving or hurting sales efficiency across different assortment types.
# While Promo2 may reduce overall footfall, this chart will explore if customers
# are spending more per visit, which can offset lower customer counts.
# Comparing Sales per Customer across assortment types will help in evaluating
# whether Promo2 is operationally beneficial or revenue-dilutive.

# --------------------------------------------------------------- #


# Removing infinite and missing values caused by zero customers
df_clean = df.replace([np.inf, -np.inf], np.nan).dropna(subset=['SalesPerCustomer'])

# Grouping the data by Assortment and Promo2 and calculating average Sales per Customer
assortment_promo2_spc = (
    df_clean
    .groupby(['Assortment', 'Promo2'])['SalesPerCustomer']
    .mean()
    .reset_index()
)

# Creating a pivot table for grouped bar chart
spc_pivot = assortment_promo2_spc.pivot(
    index='Assortment',
    columns='Promo2',
    values='SalesPerCustomer'
)

# Renaming columns for clarity
spc_pivot.columns = ['No Promo2', 'Promo2 Active']

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(10,6))

# Plotting grouped bar chart
spc_pivot.plot(
    kind='bar',
    width=0.7,
    ax=plt.gca()
)

# Adding value labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.2f', fontsize=10)

# Adding chart title and labels
plt.title(
    "Average Sales per Customer by Assortment Type: Promo2 Active vs Non-Active",
    fontsize=16,
    fontweight='bold'
)
plt.xlabel("Assortment Type", fontsize=12)
plt.ylabel("Sales per Customer", fontsize=12)

# Adjusting legend position for clarity
plt.legend(
    title="Promo2 Status",
    loc='upper center',
    frameon=True
)

# Adding gridlines for readability
sns.set_style('whitegrid')
ax = plt.gca()
ax.yaxis.grid(True, linestyle='--', alpha=0.4)
ax.xaxis.grid(False)

# Removing top and right borders
sns.despine()

# Displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary -**
#
# * Promo2 increases average spend per customer for assortment types a and c, even though overall customer footfall declines.
#
# * Assortment type b behaves differently — Promo2 reduces both customers and sales per customer, indicating promo fatigue or discount cannibalization.
#
# * This chart reveals that Promo2 is not uniformly bad — it is efficiency-positive for some assortments and efficiency-negative for others.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picked this chart to move beyond volume-based metrics like total sales and customers and focus on sales efficiency.
#
# * Earlier charts showed that Promo2 generally reduces customer count and total sales, but they did not explain how individual customers behave.
#
# * A grouped bar chart is chosen because:
#
#     * It allows clear side-by-side comparison between Promo2 Active vs Non-Active.
#
#     * It avoids overplotting and readability issues seen in slope and line charts.
#
#     * It makes magnitude differences in spending behavior immediately visible.
#
# * The combination of Promo2 × Assortment × Sales per Customer helps test whether long-running promos are:
#
#     * driving higher basket value, or
#
#     * simply eroding margins without customer compensation.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Key Insights:
#
# **Assortment A**
#
# * Sales per customer increases from ~8.70 → ~9.57 during Promo2.
#
# * Cross-chart insight:
#
#      * Customers decrease (Chart 61),
#
#      * Total sales decrease (Assortment × Promo2 × Sales),
#
#      * But remaining customers spend more per visit.
#
#
# * This indicates quality over quantity behavior.
#
#
# **Assortment B**
#
# * Sales per customer drops from ~4.36 → ~3.90 during Promo2.
#
# * Cross-chart insight:
#
#     * This assortment already has the highest customer base.
#
#     * Promo2 reduces customers and reduces spend per customer.
#
#
# * This strongly suggests discount dilution or promo fatigue.
#
#
# **Assortment C**
#
# * Sales per customer increases from ~9.50 → ~10.52, the highest uplift.
#
# * Even with fewer customers, this assortment becomes more profitable per visit.
#
# * Promo2 appears to attract high-intent buyers here.
#
#
# * Overall pattern:
#
#     * Promo2 shifts customer mix.
#
#     * Fewer customers, but more valuable customers for assortments a and c.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Promo2 can be strategically profitable if applied selectively.
#
# * Assortments a and c benefit from Promo2 in terms of:
#
#     * higher basket value,
#
#     * better customer quality,
#
#     * improved sales efficiency.
#
#
# * This insight supports:
#
#     * targeted Promo2 rollout,
#
#     * assortment-specific promo calendars,
#
#     * margin-aware promotional planning.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Assortment b is a clear risk zone:
#
#     * lower customers,
#
#     * lower sales per customer,
#
#     * lower total sales.
#
#
# * Continuing Promo2 for this assortment:
#
#     * erodes revenue,
#
#     * attracts price-sensitive customers,
#
#     * reduces perceived product value.
#
#
# * This suggests Promo2 may be overused or misaligned for high-volume assortments.
#
#
#
# ---
#
# 🔧 Business Recommendation (implicit from EDA)
#
#
# * Keep Promo2 enabled for assortments a and c.
#
# * Re-evaluate or redesign Promo2 strategy for assortment b:
#
#     * shorter duration promos,
#
#     * bundle-based offers,
#
#     * or non-price incentives.

# %% [markdown]
# ##### Chart 73 - Impact of Promo2 on Sales by Store Type (% Change)

# %%
# Chart 73 - Visualisation Code

# Features Used: StoreType, Promo2, Sales

# ✅ Why this chart is important to include?
# This chart is helping to understand how long-running promotions (Promo2)
# are impacting sales performance differently across store types.
# By converting absolute sales into percentage change, this chart is allowing
# fair comparison between store formats with very different baseline sales.
# This is helping to identify which store types are benefiting from Promo2
# and which store types are losing revenue due to prolonged discounting.

# --------------------------------------------------------------- #
# Grouping the data by StoreType and Promo2 and calculating average sales
storetype_promo2_sales = (
    df.groupby(['StoreType', 'Promo2'])['Sales']
      .mean()
      .reset_index()
)

# Creating a pivot table to separate Promo2 Active vs Non-Active
sales_pivot = storetype_promo2_sales.pivot(
    index='StoreType',
    columns='Promo2',
    values='Sales'
)

# Renaming columns for clarity
sales_pivot.columns = ['No Promo2', 'Promo2 Active']

# --------------------------------------------------------------- #
# Calculating percentage change due to Promo2
sales_pivot['Sales_Percent_Change'] = (
    (sales_pivot['Promo2 Active'] - sales_pivot['No Promo2'])
    / sales_pivot['No Promo2']
) * 100

# Resetting index for plotting
sales_pct_df = sales_pivot.reset_index()

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(10,6))

# Creating grouped bar chart for percentage change
sns.barplot(
    data=sales_pct_df,
    x='StoreType',
    y='Sales_Percent_Change',
    palette='coolwarm'
)

# Adding value labels on bars
for idx, row in sales_pct_df.iterrows():
    plt.text(
        idx,
        row['Sales_Percent_Change'] - 1,
        f"{row['Sales_Percent_Change']:.1f}%",
        ha='center',
        fontsize=10,
        fontweight='bold'
    )

# Adding reference line at 0%
plt.axhline(0, color='black', linewidth=1, linestyle='--')

# Adding titles and labels
plt.title(
    "Impact of Promo2 on Sales by Store Type (% Change)",
    fontsize=16,
    fontweight='bold'
)
plt.xlabel("Store Type", fontsize=12)
plt.ylabel("Sales Percentage Change (%)", fontsize=12)

# Adding grid for readability
plt.grid(axis='y', alpha=0.3)

# Displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart shows that Promo2 (long-running promotion) leads to a decline in average sales across all store types.
#
# * Store type B is the most negatively impacted, with sales dropping by nearly 27.3% when Promo2 is active.
#
# * Store types A and D experience similar moderate declines of around 8.6%, indicating partial resilience.
#
# * Store type C also shows a significant decline (~19.6%), suggesting Promo2 may be hurting profitability in medium-scale stores.
#
# * Overall, Promo2 does not appear to be driving incremental sales, and instead seems to be eroding revenue across formats.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose a percentage-based grouped bar chart because it allows fair comparison across store types with very different baseline sales volumes.
#
# * Absolute sales values could hide the real impact of Promo2, whereas percentage change clearly shows direction and magnitude of impact.
#
# * I selected Store Type, Promo2, and Sales to specifically evaluate whether long-term promotions are strategically effective across different retail formats.
#
# * This chart is helping to visually separate beneficial vs harmful promotional effects, which is critical for long-term pricing decisions.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo2 negatively impacts sales across all store types, indicating that long-running promotions may be over-discounting without increasing demand.
#
# * Store Type B is the worst performer, suggesting that customers in these stores may be highly price-sensitive or already saturated.
#
# * Store Types A and D show smaller declines, which may indicate stronger brand loyalty or better operational efficiency.
#
# * Store Type C sits in the middle, showing that Promo2 impact is not uniform and depends on store format.
#
# * The absence of any positive percentage change suggests Promo2 is not functioning as a growth lever.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * This insight strongly supports re-evaluating the Promo2 strategy, especially for Store Types B and C.
#
# * The business can move towards targeted or time-bound promotions instead of blanket long-term discounts.
#
# * Eliminating or redesigning Promo2 for underperforming store types can recover lost margins.
#
# * Store Types A and D can be tested with alternative loyalty or value-based strategies instead of discounts.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * The consistent negative percentage change across all store types clearly indicates revenue erosion due to Promo2.
#
# * Long-term promotions may be training customers to wait for discounts, reducing full-price purchases.
#
# * If left unchecked, Promo2 could lead to long-term brand dilution and profitability decline.

# %% [markdown]
# ##### Chart 74 - Average Customers by Store Type: Promo2 Active vs Non-Active

# %%
# Chart 74 - Visualisation Code

# Features Used: StoreType, Promo2, Customers

# ✅ Why this chart is important to include?
# This chart will help identify how long-running promotions (Promo2)
# are influencing customer footfall across different store formats.
# By comparing Promo2-active and non-active periods for each store type,
# this chart will explore whether Promo2 is effective in attracting customers
# uniformly or whether its impact varies by store structure and scale.
# This will support decisions on whether Promo2 strategies should be
# customized for specific store types instead of being applied universally.

# --------------------------------------------------------------- #
# Grouping data by StoreType and Promo2 and calculating average customers
storetype_customer_promo2 = (
    df.groupby(['StoreType', 'Promo2'])['Customers']
      .mean()
      .reset_index()
)

# Renaming Promo2 values for better readability
storetype_customer_promo2['Promo2Status'] = storetype_customer_promo2['Promo2'].map(
    {0: 'No Promo2', 1: 'Promo2 Active'}
)

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(10,6))

# Creating grouped bar chart for customer averages
sns.barplot(
    data=storetype_customer_promo2,
    x='StoreType',
    y='Customers',
    hue='Promo2Status',
    palette=['#4C72B0', '#DD8452']
)

# Adding value labels on top of bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.0f', padding=3, fontsize=10)

# Adding title and axis labels
plt.title(
    "Average Customers by Store Type: Promo2 Active vs Non-Active",
    fontsize=16,
    fontweight='bold'
)
plt.xlabel("Store Type", fontsize=12)
plt.ylabel("Average Number of Customers", fontsize=12)

# Adjusting legend position to avoid overlap
plt.legend(
    title="Promo2 Status",
    loc='upper right',
    frameon=True
)

# Adding grid for readability
plt.grid(axis='y', alpha=0.3)

# Tight layout for clean spacing
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * Store Type b consistently records the highest customer footfall in both Promo2-active and non-active periods, indicating its strong inherent demand.
#
# * Across all store types (a, b, c, d), customer footfall is lower during Promo2-active periods compared to when Promo2 is not active.
#
# * The largest absolute drop in customers during Promo2 is observed for Store Type b and c, while Store Type d shows the lowest overall footfall in both scenarios.
#
# * This suggests that long-running promotions (Promo2) are not acting as a traffic booster and may even be associated with customer fatigue or weak promotional appeal.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose this chart to understand how long-term promotions (Promo2) are impacting customer footfall across different store formats.
#
# * I selected a grouped bar chart because it allows a direct side-by-side comparison between Promo2-active and non-active periods for each store type.
#
# * This visualization helps in isolating whether customer behavior during Promo2 is consistent across store types or structurally different.
#
# * The chart is especially useful to evaluate whether Promo2 is fulfilling its primary objective of driving sustained customer traffic.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo2 is associated with lower customer footfall across all store types.
#
# * For every store type (a, b, c, d), the average number of customers is lower during Promo2-active periods.
#
# * Store Type b remains the strongest traffic driver despite Promo2 decline.
#
# * Even with a noticeable drop (2042 → 1852), Store Type b still outperforms all other formats.
#
# * Promo2 impact is not store-type neutral.
#
# * Store Types b and c experience larger absolute customer drops compared to a and d.
#
# * This indicates that Promo2 may be misaligned with high-volume store formats.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * These insights highlight that Promo2 should not be treated as a universal traffic strategy.
#
# * The business can:
#
#     * Re-evaluate Promo2 messaging and mechanics.
#
#     * Design store-type-specific long-term promotions.
#
# * Focus Promo2 efforts on conversion or basket size instead of footfall.
#
# * This helps optimize marketing spend and reduce ineffective promotional fatigue.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * The consistent decline in customer footfall during Promo2 suggests:
#
#     * Customers may perceive Promo2 as “always-on” and less attractive.
#
#     * Long-running promotions may be failing to create urgency.
#
#
# * If left unaddressed, this could:
#
#     * Reduce store visits over time.
#
#     * Erode brand excitement around promotions.
#
#     * Lead to declining ROI on long-term promotional campaigns.

# %% [markdown]
# ##### Chart 75 - Average Sales per Customer by Store Type: Promo2 Active vs Non-Active

# %%
# Chart - 75 Visualisation Code

# Features Used: StoreType, Promo2, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart will help me analyze whether long-running promotions (Promo2)
# influence how much each customer spends on average across different store types.
# Even if Promo2 does not increase customer footfall, it may still impact
# basket size or customer spending behavior differently depending on store format.
# By comparing Sales Per Customer across store types, this chart will explore
# whether Promo2 is effective as a value-based strategy rather than a traffic driver.

# --------------------------------------------------------------- #

# Removing infinite and missing values caused by zero customers
df_spc = df.replace([float('inf'), -float('inf')], None).dropna(subset=['SalesPerCustomer'])

# Grouping data by StoreType and Promo2 and calculating average Sales Per Customer
storetype_promo2_spc = (
    df_spc.groupby(['StoreType', 'Promo2'])['SalesPerCustomer']
          .mean()
          .reset_index()
)

# Creating pivot table for grouped bar chart
spc_pivot = storetype_promo2_spc.pivot(
    index='StoreType',
    columns='Promo2',
    values='SalesPerCustomer'
)

# Renaming columns for clarity
spc_pivot.columns = ['No Promo2', 'Promo2 Active']

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(12,7))

# Plotting grouped bar chart
spc_pivot.plot(
    kind='bar',
    width=0.65,
    color=['#4C72B0', '#DD8452'],
    edgecolor='black'
)

# Adjusting x-tick labels for better readability
plt.xticks(rotation=0, ha='center')

# Adding title and labels
plt.title(
    'Average Sales per Customer by Store Type: Promo2 Active vs Non-Active',
    fontsize=16,
    fontweight='bold',
    pad = 5
)
plt.xlabel('Store Type', fontsize=12, labelpad=2)
plt.ylabel('Sales per Customer', fontsize=12)

# Adding value labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.2f', padding=3, fontsize=10)

# Adjusting legend placement
plt.legend(title='Promo2 Status', frameon=True, loc = 'upper center',ncols = 2,  bbox_to_anchor=(0.5, -0.15))

# Adding grid for readability
plt.grid(axis='y', linestyle='--', alpha=0.4)

# Final layout adjustments
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * Promo2 does not increase customer volume, but this chart reveals how it changes customer spending behavior across store types.
#
# * Store Types A, C, and D show higher sales per customer during Promo2, indicating fewer but more valuable customers.
#
# * Store Type B behaves differently, where Promo2 leads to a drop in sales per customer, suggesting a negative efficiency impact.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I selected this chart to move beyond volume-based analysis and understand the quality of customers during Promo2.
#
# * Earlier charts indicated that Promo2 does not attract more customers, but they did not explain how much each customer is spending.
#
# * By plotting Sales per Customer across Store Types, this chart helps explore whether Promo2:
#
#   * encourages higher-value purchases, or
#
#   * simply reduces traffic without improving efficiency.
#
# * A grouped bar chart is appropriate here because it allows direct comparison of Promo2 impact within each store type, making efficiency differences easy to interpret.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Store Types A, C, and D show a clear increase in sales per customer during Promo2.
#
# * This suggests that Promo2 attracts or retains customers who spend more per visit, even if overall footfall is lower.
#
# * Store Type B shows a decline in sales per customer, indicating that Promo2 is not only failing to attract customers there but is also reducing transaction value.
#
# * The impact of Promo2 is therefore not uniform and depends strongly on store format.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * This insight allows the business to reframe Promo2 as a value-driven strategy, not a traffic-driven one.
#
# * Promo2 can be strategically retained for Store Types A, C, and D, where it improves revenue efficiency per customer.
#
# * Marketing teams can align Promo2 with premium or planned-purchase store formats rather than mass-traffic stores.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Store Type B shows a consistent decline in sales efficiency during Promo2.
#
# * Running long-term promotions in this store format may:
#     * attract discount-seeking customers,
#     * reduce basket size,
#     * hurt margins.
#
# * Applying Promo2 uniformly across all store types risks hidden profitability loss.

# %% [markdown]
# #### Part 6 -Impact of Other Factors and Promo2

# %% [markdown]
# ##### Chart 76 - Average Sales by Competition Distance: Promo2 Active vs Non-Active

# %%
# Chart 76 - Visualisation Code

# Features Used: CompetitionDistance, Promo2, Sales

# ✅ Why this chart is important to include?
# This chart is going to examine whether the negative impact of long-running promotions (Promo2)
# on sales is influenced by competitive pressure.
# By segmenting stores into competition distance buckets and comparing Promo2 active vs non-active
# sales, this chart is going to help identify whether nearby competitors amplify or mitigate
# Promo2’s effect on store performance.

# --------------------------------------------------------------- #

# Creating competition distance bins for better interpretability
df['CompetitionDistanceBucket'] = pd.cut(
    df['CompetitionDistance'],
    bins=[0, 500, 2000, 5000, df['CompetitionDistance'].max()],
    labels=['Very Close (<500)', 'Close (500–2000)', 'Moderate (2000–5000)', 'Far (>5000)']
)

# Grouping data by competition bucket and Promo2 status
competition_promo2_sales = (
    df.groupby(['CompetitionDistanceBucket', 'Promo2'])['Sales']
      .mean()
      .reset_index()
)

# Setting visualization style
sns.set(style="whitegrid")

# Creating the figure
plt.figure(figsize=(12,6))

# Creating grouped bar chart
ax = sns.barplot(
    data=competition_promo2_sales,
    x='CompetitionDistanceBucket',
    y='Sales',
    hue='Promo2',
    palette=['#4C72B0', '#DD8452']
)

# Updating legend labels for clarity
handles, labels = ax.get_legend_handles_labels()
ax.legend(
    handles,
    ['No Promo2', 'Promo2 Active'],
    title='Promo2 Status',
    loc='upper right'
)

# Adding value labels on bars
for container in ax.containers:
    ax.bar_label(
        container,
        fmt='%.0f',
        fontsize=10,
        padding=3
    )

# Adding titles and labels
plt.title(
    'Average Sales by Competition Distance: Promo2 Active vs Non-Active',
    fontsize=16,
    fontweight='bold'
)
plt.xlabel('Competition Distance Category', fontsize=12)
plt.ylabel('Average Sales', fontsize=12)

# Improving layout
plt.tight_layout()

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart is showing how average sales behave across different competition distance categories during Promo2 active and non-active periods.
#
# * Across all distance buckets, stores running Promo2 consistently record lower average sales compared to stores without Promo2.
#
# * The gap between Promo2 and non-Promo2 sales remains visible regardless of whether competitors are very close or far away.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose this grouped bar chart because it is clearly comparing two conditions (Promo2 active vs non-active) across multiple competitive environments.
#
# * Grouped bars are making it easier to visually assess differences within each competition bucket without overloading the chart.
#
# * I selected competition distance buckets to investigate whether competitive pressure explains the observed underperformance of Promo2.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo2 is associated with lower average sales across all competition distance categories.
#
# * The negative impact of Promo2 does not disappear even when competition is far away.
#
# * Competitive pressure is not the primary driver behind Promo2’s poor sales performance.
#
# * This suggests that Promo2's structure or execution may be inherently ineffective rather than context-dependent.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * This insight helps the business avoid blaming external competition for Promo2 underperformance.
#
# * It encourages a reassessment of Promo2 design instead of increasing discounts blindly.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Continuing Promo2 without redesign may consistently suppress sales across all store locations.
#
# * Long-running promotions may be causing customer fatigue or margin erosion without driving volume.

# %% [markdown]
# ##### Chart 77 - Sales Distribution (%) by Competition Age: Promo2 Active vs Non-Active

# %%
# Chart 77 - Visualisation Code

# Features Used: CompetitionOpenMonths, Promo2, Sales

# ✅ Why this chart is important to include?
# This chart will help me compare how sales change during long-running promotions (Promo2)
# across different stages of competitive pressure.
# By representing sales impact in percentage terms, this chart will allow me
# to understand whether Promo2 is relatively improving or worsening sales
# when competition is new versus when competition has existed for a longer duration.
# Using a grouped bar chart will make the comparison between Promo2 and Non-Promo2
# clear and easy to interpret across competition age buckets.

# --------------------------------------------------------------- #
# Creating competition age buckets using months since competition opened
df['CompetitionAgeBucket'] = pd.cut(
    df['CompetitionOpenMonths'],
    bins=[-1, 6, 12, 24, 60, 120, df['CompetitionOpenMonths'].max()],
    labels=[
        'Very New (<6m)',
        'New (6–12m)',
        'Moderate (1–2y)',
        'Old (2–5y)',
        'Very Old (5–10y)',
        'Extremely Old (>10y)'
    ]
)

# Calculating average sales separately for Promo2 and Non-Promo2
promo2_sales = (
    df.groupby(['CompetitionAgeBucket', 'Promo2'])['Sales']
      .mean()
      .reset_index()
)

# Creating pivot table for grouped bar plotting
sales_pivot = promo2_sales.pivot(
    index='CompetitionAgeBucket',
    columns='Promo2',
    values='Sales'
)

# Renaming columns for clarity
sales_pivot.columns = ['No Promo2', 'Promo2 Active']

# Converting absolute sales into percentage values within each competition bucket
sales_percentage = sales_pivot.div(sales_pivot.sum(axis=1), axis=0) * 100

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(12,6))

# Plotting grouped bar chart with percentage values
sales_percentage.plot(
    kind='bar',
    width=0.7,
    color=['#4C72B0', '#DD8452'],
    edgecolor='black',
    ax=plt.gca()
)

# Adding value labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.1f%%', fontsize=9, padding=3)

# Adjusting x-tick labels for better readability
plt.xticks(rotation=0, ha='center')

# Adding chart title and axis labels
plt.title(
    "Sales Distribution (%) by Competition Age: Promo2 Active vs Non-Active",
    fontsize=16,
    fontweight='bold'
)
plt.xlabel("Competition Age (Months Since Competitor Opened)", fontsize=12)
plt.ylabel("Sales Percentage (%)", fontsize=12)

# Adjusting legend position for clarity
plt.legend(
    title="Promo2 Status",
    bbox_to_anchor=(0.5, -0.15),   # Moves legend below chart
    loc='upper center',
    ncol=2,
    frameon=True
)

# Adding horizontal gridlines only
plt.grid(axis='y', linestyle='--', alpha=0.4)

# Improving layout
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart shows that across all competition age buckets, sales share remains consistently higher on Non-Promo2 days compared to Promo2 Active days.
#
# * The gap between Promo2 Active and Non-Promo2 sales percentage is remarkably stable, regardless of how long the competitor has been present.
#
# * This indicates that long-running promotions (Promo2) are not effectively countering competitive pressure, even when competition is very new or extremely old.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picked this chart to understand whether the effectiveness of long-running promotions (Promo2) changes with competitive maturity.
#
# * Using competition age buckets allows me to analyze if Promo2 performs better when competition is new versus well-established.
#
# * A grouped bar chart with percentage values was chosen because it makes relative sales contribution immediately comparable across different competition stages, avoiding scale bias from absolute sales values.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo2 consistently contributes less than 50% of sales across all competition age groups.
#
# * The sales distribution gap (~5-8%) between Promo2 and Non-Promo2 remains almost unchanged as competition ages.
#
# * This suggests Promo2 is structurally weak, not situationally weak — its underperformance is not driven by competition timing.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * This insight helps the business avoid blindly extending Promo2 as a defensive strategy against competition.
#
# * Marketing teams can redirect budgets toward more effective short-term or targeted promotions.
#
# * Strategy teams can rethink Promo2 mechanics, such as discount depth, product eligibility, or store targeting.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Continuing Promo2 without redesign may be diluting margins without improving competitive positioning.
#
# * Over-reliance on Promo2 could be masking deeper issues like assortment gaps or pricing inefficiencies.

# %% [markdown]
# ##### Chart 78 - Impact of Promo2 and Competition Age Sales Efficiency

# %%
# Chart 78 - Visualisation Chart

# Features Used - Promo2, CompetitionOpenMonths, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart helps analyze how long-running promotions (Promo2) perform
# across different stages of competition maturity. By using SalesPerCustomer
# instead of total sales, we focus on customer value rather than footfall.
# It helps identify whether Promo2 sustains or loses effectiveness as
# competition becomes older.

# ---------------------------------------------------------------------------------------------------------- #

# Setting consistent visual style
sns.set(style='whitegrid')

# Creating competition age buckets using CompetitionOpenMonths
df['Competition_Age_Bucket'] = pd.cut(
    df['CompetitionOpenMonths'],
    bins=[-1, 6, 12, 24, 60, 120, float('inf')],
    labels=[
        'Very New (<6m)',
        'New (6–12m)',
        'Moderate (1–2y)',
        'Old (2–5y)',
        'Very Old (5–10y)',
        'Extremely Old (>10y)'
    ]
)

# Aggregating average SalesPerCustomer
promo2_comp_spc = (
    df.groupby(['Competition_Age_Bucket', 'Promo2'])['SalesPerCustomer']
      .mean()
      .reset_index()
)

# Creating the figure
plt.figure(figsize=(12, 6))

# Plotting line chart to observe trend across competition age
sns.lineplot(
    data=promo2_comp_spc,
    x='Competition_Age_Bucket',
    y='SalesPerCustomer',
    hue='Promo2',
    marker='o',
    palette=['#64B5F6', '#FFB74D']
)

# Adding chart title and labels
plt.title(
    'Average Sales per Customer by Competition Age: Promo2 Active vs Non-Active',
    fontsize=14,
    fontweight='bold'
)
plt.xlabel('Competition Age (Months Since Competitor Opened)')
plt.ylabel('Average Sales per Customer')

# Formatting legend
plt.legend(
    title='Promo2 Status',
    labels=['No Promo2', 'Promo2 Active'],
    loc='best'
)

# Rotating x-axis labels for readability
plt.xticks(rotation=20)

# Removing unnecessary borders
plt.box(False)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart shows how average sales per customer changes with competition age, comparing stores with Promo2 active vs without Promo2.
#
# * Across all competition age buckets, Promo2 consistently delivers higher sales per customer, indicating that long-running promotions improve customer value rather than customer count.
#
# * However, the magnitude of Promo2’s effectiveness varies with competition maturity, peaking when competition is moderately old and softening slightly when competition becomes very old.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * A line chart is ideal here because competition age follows a natural progression over time.
#
# * It allows us to clearly track how SalesPerCustomer trends evolve as competitors age, while simultaneously comparing Promo2 active vs non-active stores across the same lifecycle.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promo2 Active stores outperform No Promo2 stores across all competition age buckets, confirming that long-running promotions increase per-customer spending.
#
# * The largest Promo2 uplift appears in the “Old (2–5y)” competition range, suggesting Promo2 is most effective once competition is established but not saturated.
#
# * For very old competition (>5 years), Promo2 still performs better, but the gap narrows slightly, indicating diminishing marginal returns over time.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * This insight helps retailers strategically deploy Promo2 where it generates maximum ROI — especially in markets with moderately aged competition.
#
# * Instead of uniformly applying long-running promotions, businesses can prioritize Promo2 for stores in competitive but stable markets, improving profitability through higher per-customer value.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * In very old competitive environments, Promo2 still improves sales per customer, but the incremental gain is smaller compared to mid-aged competition.
#
# * This suggests a potential diminishing return on long-term promotions, where continuous discounting may not proportionally increase customer value due to market saturation and price sensitivity.
#
# **👉 Business implication:**
#
# * Promo2 should be periodically reviewed and optimized, not permanently applied in highly mature markets.

# %% [markdown]
# ##### Chart 79 - Impact of Promo2 During State Holidays on Sales

# %%
# Chart 79 - Visualisation Code

# Features Used: StateHoliday, Promo2, Sales

# ✅ Why this chart is important to include?
# This chart will help me examine how long-running promotions (Promo2)
# interact with state-level holidays, which are known demand drivers.
# I am including this chart to understand whether Promo2 is amplifying,
# neutralizing, or cannibalizing the natural sales uplift that usually
# occurs during state holidays.
# This analysis will help in evaluating whether stacking long-term promotions
# with holidays is strategically beneficial or counterproductive.

# --------------------------------------------------------------- #
# Filtering out closed-store days to avoid misleading zero sales
df_holiday = df[df['Open'] == 1].copy()

# Grouping the data by StateHoliday and Promo2 and calculating average sales
holiday_promo2_sales = (
    df_holiday
    .groupby(['StateHoliday', 'Promo2'])['Sales']
    .mean()
    .reset_index()
)

# Creating a pivot table for grouped bar plotting
sales_pivot = holiday_promo2_sales.pivot(
    index='StateHoliday',
    columns='Promo2',
    values='Sales'
)

# Renaming columns for clarity
sales_pivot.columns = ['No Promo2', 'Promo2 Active']

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(12,8))

# Plotting grouped bar chart
sales_pivot.plot(
    kind='bar',
    width=0.65,
    color=['#4C72B0', '#DD8452'],
    edgecolor='black',
    ax=plt.gca()
)

# Adding value labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.0f', fontsize=10, padding=3)

# Adding chart title and axis labels
plt.title(
    'Average Sales by State Holiday: Promo2 Active vs Non-Active',
    fontsize=16,
    fontweight='bold'
)
plt.xlabel('State Holiday Type', fontsize=12)
plt.ylabel('Average Sales', fontsize=12)

# Adjusting the alignment of tick labels
plt.xticks(rotation=0, ha='center')

# Adjusting legend placement for better readability
plt.legend(
    title='Promo2 Status',
    loc='upper center',
    frameon=True,
    ncols = 2,
    bbox_to_anchor=(0.5, -0.1)
)

# Adding horizontal gridlines only
sns.set_style("whitegrid")
ax = plt.gca()
ax.yaxis.grid(True, linestyle='--', alpha=0.4)
ax.xaxis.grid(False)

# Improving layout
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * Sales are consistently higher on state holidays when Promo2 is NOT active across all holiday types.
#
# * Promo2 active days show flattened sales levels, even during high-demand state holidays.
#
# * The natural holiday-driven sales uplift appears to be suppressed when Promo2 is running.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picked this chart to understand how long-running promotions (Promo2) interact with state holidays, which are already strong demand drivers.
#
# * I specifically chose a grouped bar chart because it allows a clear side-by-side comparison of Promo2 Active vs Non-Active sales within each holiday category.
#
# * This chart helps isolate whether stacking Promo2 with holidays enhances, neutralizes, or harms sales performance.
#
# * Since both variables (StateHoliday and Promo2) are categorical, a grouped bar chart is the most interpretable and business-friendly choice.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * For all state holiday types (a, b, c) and even non-holiday days,
# sales are significantly higher when Promo2 is NOT active.
#
# * During high-impact holidays (b and c), sales without Promo2 cross 10,000+,while Promo2-active sales remain capped around ~7,000.
#
# * This suggests Promo2 is not amplifying holiday demand and may actually be cannibalizing full-price purchases.
#
# * The sales gap between Promo2 and No Promo2 widens on stronger holidays, indicating a lost revenue opportunity.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * This chart clearly signals that:
#
#     * Promo2 should not be blindly applied during state holidays.
#
#     * Holiday periods already drive strong organic demand and do not require additional long-term discounting.
#
# * The business can:
#
#     * Pause Promo2 during major state holidays
#
#     * Protect margins while still benefiting from high demand
#
#     * Redesign Promo2 calendars to avoid overlap with holidays
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Running Promo2 during state holidays:
#
#     * Reduces potential revenue
#
#     * Encourages customers to buy at discounted prices when they would have purchased anyway
#
#     * Leads to promotion cannibalization instead of incremental sales
#
# * This highlights a strategic flaw where long-running promos override smarter, event-driven pricing.

# %% [markdown]
# ##### Chart 80 - Average Customers by State Holiday: Promo2 Active vs Non-Active

# %%
# Chart 80 - Visualisation Code

# Features Used: StateHoliday, Promo2, Customers

# ✅ Why this chart is important to include?
# This chart is helping to analyze how customer footfall behaves during state holidays
# when long-running promotions (Promo2) are active versus inactive.
# By focusing on customers instead of sales, this chart will help in understanding
# whether the lower sales observed during Promo2 are driven by fewer customers
# or by changes in customer purchasing behavior during holidays.

# --------------------------------------------------------------- #
# Grouping the data by StateHoliday and Promo2 and calculating average customers
holiday_customer_promo2 = (
    df.groupby(['StateHoliday', 'Promo2'])['Customers']
      .mean()
      .reset_index()
)

# Creating a pivot table for grouped bar plotting
customer_pivot = holiday_customer_promo2.pivot(
    index='StateHoliday',
    columns='Promo2',
    values='Customers'
)

# Renaming columns for clarity
customer_pivot.columns = ['No Promo2', 'Promo2 Active']

# Sorting index to maintain logical holiday order
customer_pivot = customer_pivot.reindex(['None', 'a', 'b', 'c'])

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(12,6))

# Creating grouped bar chart
customer_pivot.plot(
    kind='bar',
    width=0.7,
    color=['#4C72B0', '#DD8452'],
    edgecolor='black'
)

# Adding data labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.0f', padding=3, fontsize=9)

# Adding titles and labels
plt.title(
    "Average Customers by State Holiday: Promo2 Active vs Non-Active",
    fontsize=16,
    fontweight='bold'
)
plt.xlabel("State Holiday Type", fontsize=12)
plt.ylabel("Average Number of Customers", fontsize=12)

# Adding legend at a clear position
plt.legend(
    title="Promo2 Status",
    loc='upper right'
)

# Adding grid only on Y-axis for readability
plt.grid(axis='y', linestyle='--', alpha=0.4)

# Rotating x-ticks for clarity
plt.xticks(rotation=0)

# Adjusting layout
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * Average customer footfall drops consistently during Promo2 Active periods, across all holiday categories.
#
# * The highest customer count is observed during non-holiday periods, regardless of Promo2 status, confirming that regular days attract more customers.
#
# * During state holidays (types a, b, c), overall traffic is low — and Promo2 fails to increase it.
#
# * This pattern implies that Promo2 promotions do not effectively draw customers even when there’s potential for increased leisure shopping time (like during holidays).
#
# * Key takeaway: customer behavior seems insensitive to long-running promotions like Promo2; store visits remain primarily driven by regular shopping routines rather than promotional influence.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I selected this chart to understand whether long-term promotions (Promo2) influence customer traffic during various state holiday types.
#
# * A grouped bar chart is ideal here since it helps compare Promo2 Active vs. Non-Active customer counts side-by-side across each holiday category.
#
# * The chosen features provide clarity on whether Promo2 increases store visits or if it’s merely affecting per-customer sales without attracting more customers.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Customer counts drop during Promo2 Active phases for every state holiday category, including regular days (None).
#
# * The largest footfall occurs on non-holiday days, confirming that everyday routines drive the majority of store visits.
#
# * Even during holidays (a, b, c), Promo2 stores show visibly lower traffic, implying reduced consumer engagement.
#
# * This further supports earlier findings that Promo2 may not be effectively marketed or fails to create urgency among customers.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Helps management realize that Promo2 should not rely solely on duration — the campaign must also include targeted engagement to drive visits.
#
# * Reveals that holidays are not automatically high-footfall opportunities — companies can reconsider promo timing or focus on short-term offers instead.
#
# * Encourages data-driven marketing calendar optimization, aligning promotions with proven footfall periods.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Continuous reliance on Promo2 without observed customer uplift indicates inefficient marketing spend.
#
# * The promo may be reducing urgency — customers perceive it as always available, leading to promotion fatigue.
#
# * Without adjustments, Promo2 could erode brand value or margins without increasing overall store visits.

# %% [markdown]
# ##### Chart 81 - Average Sales per Customer by State Holiday: Promo2 Active vs Non-Active

# %%
# Chart 81 - Promo2 × StateHoliday × Sales per Customer

# Features Used - Promo2, StateHoliday, Sales per Customer

# ---------------------------------------------------------------------------------------------------------- #
# ✅ Why this chart is important to include?
# This chart evaluates whether Promo2 improves spending efficiency (sales per customer)
# across different state holiday types.



# Calculate Sales per Customer safely
df_spc = df.copy()
df_spc['SalesPerCustomer'] = np.where(
    df_spc['Customers'] > 0,
    df_spc['Sales'] / df_spc['Customers'],
    0
)

# Aggregate data
spc_summary = (
    df_spc
    .groupby(['StateHoliday', 'Promo2'])['SalesPerCustomer']
    .mean()
    .reset_index()
)

# Plot setup
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))

ax = sns.barplot(
    data=spc_summary,
    x='StateHoliday',
    y='SalesPerCustomer',
    hue='Promo2',
    palette=['#4C72B0', '#DD8452']
)

# Titles and labels
plt.title(
    'Average Sales per Customer by State Holiday: Promo2 Active vs Non-Active',
    fontsize=15,
    fontweight='bold'
)
plt.xlabel('State Holiday Type')
plt.ylabel('Sales per Customer')

# Legend customization
plt.legend(
    title='Promo2 Status',
    labels=['No Promo2', 'Promo2 Active'],
    loc='upper right'
)

# Add value labels on bars
for p in ax.patches:
    height = p.get_height()
    ax.annotate(
        f'{height:.2f}',
        (p.get_x() + p.get_width() / 2, height),
        ha='center',
        va='bottom',
        fontsize=9,
        xytext=(0, 3),
        textcoords='offset points'
    )

# Grid & aesthetics
plt.grid(axis='y', linestyle='--', alpha=0.4)
sns.despine()

# Adjusting layout
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart analyzes how long-running promotions (Promo2) impact sales efficiency (Sales per Customer) across different state holiday types.
#
# * Unlike total sales or customer count, this view isolates customer spending behavior, making it easier to assess whether Promo2 improves basket value rather than footfall.
#
# * The chart clearly separates regular days (None) from state holidays (a, b, c), exposing a sharp contrast in customer purchasing patterns.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * This grouped bar chart is ideal for comparing two promotion states (Promo2 Active vs Non-Active) across multiple categorical holiday types.
#
# * Using Sales per Customer removes the bias introduced by fluctuating customer volumes, which we already observed in earlier Promo2 analyses.
#
# * This chart directly answers whether Promo2 changes how much a customer spends, not just how many customers visit.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * On non-holiday days, Promo2 significantly increases sales per customer, indicating higher basket value when long-running promotions are active.
#
# * During state holidays (a, b, c), sales per customer drop sharply for both Promo2 and Non-Promo2, suggesting holiday shopping is need-based rather than promotion-driven.
#
# * Promo2 does not compensate for reduced spending behavior during holidays, even though it slightly improves efficiency compared to non-promo in normal days.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Yes — this insight clarifies that Promo2’s strength lies in increasing basket size on regular days, not during holidays.
#
# * From a business standpoint, this suggests Promo2 budgets should not be heavily allocated around state holidays, where customer spending remains low regardless of promotion.
#
# * The chart also flags a negative growth signal: applying long-running promotions during holidays yields diminishing returns, making them inefficient during those periods.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * The chart clearly indicates a negative growth signal during state holidays when Promo2 is active.
#
# * During state holiday types (a, b, c), sales per customer drop sharply, even when Promo2 is running.
#
# * This means that long-running promotions fail to increase customer spending during holidays, and in some cases, the spending is even lower than non-holiday promo periods.
#
# * The key negative insight is that Promo2 does not offset holiday-driven low purchase intent, leading to poor promotion efficiency and wasted promotional spend.
#
# * From a business perspective, continuing Promo2 during state holidays results in reduced return on investment (ROI) because customers buy fewer items or cheaper baskets regardless of the promotion.

# %% [markdown]
# ##### Chart 82 -Average Sales by School Holiday: Promo2 Active vs Non-Active

# %%
# Chart 82 - Visualisation Code


# Features Used: SchoolHoliday, Promo2, Sales


# ✅ Why this chart is important to include?
# This chart will help me understand how long-running promotions (Promo2)
# are interacting with school holidays, which are known to influence family-driven shopping behavior.
# By comparing Promo2 active and non-active sales across school holiday periods,
# this chart will help explore whether Promo2 is supporting, neutralizing,
# or cannibalizing natural demand spikes created by school holidays.
# The grouped bar chart will allow clear side-by-side comparison
# and make the interaction effect easy to interpret for business stakeholders.


# --------------------------------------------------------------- #


# Grouping the data by SchoolHoliday and Promo2 and calculating average sales
schoolholiday_sales_promo2 = (
    df.groupby(['SchoolHoliday', 'Promo2'])['Sales']
      .mean()
      .reset_index()
)

# Creating a pivot table for grouped bar plotting
schoolholiday_pivot = schoolholiday_sales_promo2.pivot(
    index='SchoolHoliday',
    columns='Promo2',
    values='Sales'
)

# Renaming columns for clarity
schoolholiday_pivot.columns = ['No Promo2', 'Promo2 Active']

# --------------------------------------------------------------- #
# Starting the visualization
plt.figure(figsize=(16,12))

# Creating grouped bar chart
schoolholiday_pivot.plot(
    kind='bar',
    width=0.75,
    color=['#4C72B0', '#DD8452']
)

# Adding data labels on bars
for container in plt.gca().containers:
    plt.bar_label(container, fmt='%.0f', padding=2, fontsize=10)

# Adding titles and labels
plt.title(
    "Average Sales by School Holiday: Promo2 Active vs Non-Active",
    fontsize=16,
    fontweight='bold'
)
plt.xlabel("School Holiday (0 = No, 1 = Yes)", fontsize=12)
plt.ylabel("Average Sales", fontsize=12)

# Adjusting the alignment of tick labels
plt.xticks(rotation=0, ha='center')

# Adjusting legend position for better readability
plt.legend(
    title="Promo2 Status",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.2),
    ncols = 2,
    frameon=True
)

# Adding grid only on Y-axis for clarity
plt.grid(axis='y', linestyle='--', alpha=0.4)

# Final layout adjustments
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The chart shows that average sales are consistently higher on non-Promo2 days, regardless of whether it is a school holiday or not.
#
# * When SchoolHoliday = 1, sales increase for both Promo2 active and non-active periods, indicating a natural demand uplift driven by holidays.
#
# * However, Promo2 active sales remain lower than No-Promo2 sales even during school holidays, suggesting that Promo2 does not amplify the holiday-driven sales boost.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I chose this chart to study the interaction between long-running promotions (Promo2) and school holidays, which are strong external demand drivers.
#
# * A grouped bar chart is appropriate here because it allows a clear side-by-side comparison of Promo2 active vs non-active sales within each school holiday category.
#
# * The selected features help explore whether Promo2 complements or cannibalizes natural holiday demand, which cannot be understood by analyzing Promo2 or holidays in isolation.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * School holidays increase sales overall, confirming that holidays naturally boost customer demand.
#
# * Promo2 active sales are lower than non-Promo2 sales in both holiday and non-holiday periods.
#
# * Even during school holidays, Promo2 does not enhance sales beyond the baseline non-Promo2 performance.
#
# * This indicates that Promo2 is not synergizing with holiday demand, and may be dampening full-price purchase behavior.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * This insight helps the business avoid stacking long-running promotions on high-demand holiday periods, where discounts may be unnecessary.
#
# * It supports more efficient promotion planning, reserving Promo2 for low-demand periods instead of holidays.
#
# **⚠️ Negative-Growth Risks Identified -**
#
#
# * Running Promo2 during school holidays may reduce revenue per transaction, as customers who would buy anyway receive discounts.
#
# * This suggests potential margin leakage and inefficient use of promotional budgets.

# %% [markdown]
# ##### Chart 83 - Sales Per Customer: Promo vs Promo2

# %%
# Chart - 83 Visualisation Code

# Features Used: Promo, Promo2, SalesPerCustomer

# ✅ Why this chart is important to include?
# This chart is helping compare short-term promotions (Promo) and long-term promotions (Promo2)
# on a normalized efficiency metric — Sales Per Customer.
# By focusing on SalesPerCustomer instead of raw Sales or Customers,
# this chart is allowing a fair comparison of how each promotion strategy
# impacts customer-level revenue generation.

# ---------------------------------------------------------------------------------------------------------- #

# Preparing aggregated data for Promo and Promo2 comparison
promo_spc = (
    df.groupby(['Promo', 'Promo2'])['SalesPerCustomer']
      .mean()
      .reset_index()
)

# Converting Promo and Promo2 to readable labels
promo_spc['Promo'] = promo_spc['Promo'].map({0: 'No Promo', 1: 'Promo'})
promo_spc['Promo2'] = promo_spc['Promo2'].map({0: 'No Promo2', 1: 'Promo2'})

# Setting visualization style
sns.set(style='whitegrid')

# Creating the figure
plt.figure(figsize=(10,6))

# Creating grouped bar chart
sns.barplot(
    data=promo_spc,
    x='Promo',
    y='SalesPerCustomer',
    hue='Promo2',
    palette='Set2'
)

# Adding value labels on bars
for container in plt.gca().containers:
    plt.bar_label(
        container,
        fmt='%.2f',
        padding=3,
        fontsize=10
    )

# Adding titles and labels
plt.title(
    'Sales Per Customer: Promo vs Promo2',
    fontsize=16,
    fontweight='bold'
)
plt.xlabel('Daily Promotion (Promo)', fontsize=12)
plt.ylabel('Sales Per Customer', fontsize=12)

# Adjusting legend placement
plt.legend(
    title='Long-term Promotion (Promo2)',
    bbox_to_anchor=(1.02, 1),
    loc='upper left'
)

# Improving layout and grid
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart compares the combined and individual impact of short-term promotions (Promo) and long-term promotions (Promo2) on Sales Per Customer (SPC).
#
# * It clearly shows that Promo and Promo2 are complementary rather than redundant, and when both are active together, stores achieve the highest customer-level revenue efficiency.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# This grouped bar chart was chosen because:
#
# * It enables direct comparison between:
#
#     * Promo only
#
#     * Promo2 only
#
#     * Promo + Promo2 combined
#
# * Sales Per Customer is a normalized metric, removing bias from store size or footfall.
#
# * The grouped bar format makes it easy to visually isolate incremental gains from Promo2 when Promo is already running.
#
# * This chart acts as a decision-level visualization that helps answer whether running both promotions together makes sense.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insight 1 — Promo increases customer-level spending
#
# * Without Promo, SPC is ~ 6.37
#
# * With Promo, SPC jumps to ~ 9.37 ➡️ Daily promotions significantly increase average spend per customer.
#
# Insight 2 — Promo2 adds incremental value
#
# * Without Promo, Promo2 still increases SPC from 6.37 → 6.92 ➡️ Promo2 independently improves spending behavior, even without daily discounts.
#
# Insight 3 — Best performance occurs when Promo & Promo2 run together
#
# * Promo + Promo2 yields the highest SPC (~10.40) ➡️ Long-term promotions amplify the effectiveness of short-term promotions rather than cannibalizing them.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# Yes, absolutely:
#
# * The chart confirms that stacking Promo with Promo2 maximizes revenue per customer.
#
# * Businesses can confidently co-plan short-term offers within long-term promotional cycles.
#
# * Promo2 is validated as a supporting strategy, not a replacement for Promo.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Promo-only stores show strong SPC, but Promo2-only impact is relatively modest.
#
# * Over-reliance on Promo2 without tactical daily promotions may lead to suboptimal customer monetization.
#
# * Running Promo continuously without Promo2 support could also risk promotion fatigue over time.
#
# * The key risk is misusing Promo2 as a standalone strategy instead of a reinforcement layer.

# %% [markdown]
# #### Part 7 - Store Performance

# %% [markdown]
# ##### Chart 84 - Sales vs Customers Distribution Across Store Types

# %%
# Chart - 84 Visualisation Code

# Features Used - Sales, Customers, StoreType

# ✅ Why this chart is important to include?
# This scatter plot helps analyze the relationship between customer footfall and sales
# across different store types. It allows us to understand:
# - How efficiently each store type converts customers into sales
# - Whether certain store types generate higher sales with similar customer counts
# - Presence of clusters, overlaps, or inefficiencies across store formats

# ---------------------------------------------------------------------------------------------------------- #

# Setting visual style
sns.set(style="whitegrid")

# Creating the figure
plt.figure(figsize=(10, 6))

# Scatter plot with StoreType as hue
sns.scatterplot(
    data=df,
    x='Customers',
    y='Sales',
    hue='StoreType',
    alpha=0.6,
    palette='Set2'
)

# Chart title and labels
plt.title(
    'Sales vs Customers Distribution Across Store Types',
    fontsize=16,
    fontweight='bold'
)
plt.xlabel('Number of Customers', fontsize=12)
plt.ylabel('Sales', fontsize=12)

# Improving legend placement
plt.legend(
    title='Store Type',
    bbox_to_anchor=(1.02, 1),
    loc='upper left'
)

# Grid & layout adjustments
plt.grid(axis='both', linestyle='--', alpha=0.4)
plt.tight_layout()

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * This scatter plot clearly shows a strong positive relationship between the number of customers and sales across all store types.
#
# * However, the density, spread, and slope of the points differ by store type, indicating that different store formats convert customer footfall into revenue with varying efficiency. Some store types achieve higher sales with similar customer counts, highlighting differences in average basket value and operational performance.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * A scatter plot is ideal for understanding the direct relationship between two continuous variables—Sales and Customers.
#
# * Using StoreType as hue allows comparison of conversion patterns across store formats in a single view.
#
# * This chart helps detect:
#
#     * Clustering behavior
#
#     * Outliers
#
# * Conversion efficiency differences that aggregated bar charts cannot reveal.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Sales increase almost linearly with customers across all store types, confirming customers as a primary sales driver.
#
# * Store Type ‘b’ and ‘a’ show higher sales at similar customer levels compared to other types, indicating better sales per customer.
#
# * Store Type ‘d’ appears more dispersed, suggesting inconsistent performance—similar customer counts can lead to very different sales outcomes.
#
# * Store Type ‘c’ shows tighter clustering, indicating more predictable sales behavior.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Identifying store types with higher revenue efficiency helps prioritize:
#
#     * Expansion strategies
#
#     * Promotional investments
#
#     * Best-practice replication
#
# * Store formats that generate higher sales per customer can guide assortment and pricing decisions for other formats.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Store types with wide scatter (high variability) indicate operational inconsistency.
#
# * Some stores attract customers but fail to convert them into proportional sales, pointing to:
#
#     * Poor assortment alignment
#
#     * Pricing issues
#
#     * Ineffective in-store promotions
#
# * These inefficiencies can lead to revenue leakage if not addressed.

# %% [markdown]
# ##### Chart 85 - Average Sales by Store Type and Assortment

# %%
# Chart - 85 Visualisation Code

# Features Used - StoreType, Assortment, Sales

# ✅ Why this chart is important to include?
# This heatmap helps identify how average sales vary across different
# StoreType–Assortment combinations. Unlike grouped bar charts, a heatmap
# clearly exposes missing combinations (shown as NaN), preventing
# misleading interpretations caused by unavailable data.
# It also helps validate business logic — for example, confirming that
# certain assortment types are offered only by specific store types.

# ---------------------------------------------------------------------------------------------------------- #

# Aggregating average sales by StoreType and Assortment
heatmap_df = (
    df
    .groupby(['StoreType', 'Assortment'])['Sales']
    .mean()
    .reset_index()
    .pivot(index='StoreType', columns='Assortment', values='Sales')
)

# Creating the figure
plt.figure(figsize=(8, 6))

# Plotting heatmap
sns.heatmap(
    heatmap_df,
    annot=True,
    fmt='.0f',
    cmap='YlGnBu',
    linewidths=0.5,
    linecolor='white',
    cbar_kws={'label': 'Average Sales'}
)

# Adding chart title and labels
plt.title('Average Sales by Store Type and Assortment', fontsize=16, fontweight='bold')
plt.xlabel('Assortment Type', fontsize=12)
plt.ylabel('Store Type', fontsize=12)

# Displaying the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary -**
#
# * This heatmap visualizes average sales across StoreType - Assortment combinations and clearly reveals which combinations actually exist in the data.
#
# * It removes the confusion caused by grouped bar charts and highlights a critical structural pattern: Assortment b is exclusively associated with StoreType b, while other store types operate only with assortments a and c.
#
# * This chart validates business logic and prevents misleading cross-comparisons.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * A heatmap is ideal when:
#
#     * Two categorical variables interact (StoreType × Assortment)
#
#     * Some combinations do not exist
#
# * Unlike bar charts, the heatmap:
#
#     * Clearly shows missing combinations as blank/NaN
#
#     * Prevents false assumptions (e.g., comparing StoreType a with Assortment b)
#
# * It also makes relative sales intensity immediately visible through color gradients.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Key Insights:**
#
# * Assortment b is exclusive to StoreType b
#
# * This explains why your manual checks returned identical logic outcomes
#
# * Highest average sales occur for:
#
#     * StoreType b + Assortment c (~17,970)
#
# * Across all store types:
#
#   * Assortment c consistently outperforms Assortment a
#
# * StoreTypes a, c, and d:
#
#   * Operate only with assortments a and c
#
#   * Show moderate, stable sales levels

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Confirms assortment strategy is store-type driven
#
# * Helps avoid:
#
#   * Invalid comparisons
#
#   * Incorrect feature interactions in modeling
#
#   * Supports store-specific assortment optimization
#
#   * Especially for StoreType b, where assortment choice has massive impact
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Over-reliance on StoreType b + Assortment c
# Creates concentration risk
#
# * Any operational issue in this segment can significantly impact revenue
#
# * Limited assortment diversity for other store types may restrict growth opportunities

# %% [markdown]
# #### Part 8 - Deep Analysis

# %% [markdown]
# ##### Chart 86 - Promo × Day × Month × Sales Interaction

# %%
# Chart - 86 Visualisation Code

# Features Used - Promo, Sales, DayOfWeek, Month

# ✅ Why this chart is important to include?
# This chart is chosen to analyze the combined interaction of promotion, weekday behavior,
# and monthly seasonality on sales.
# A faceted heatmap allows us to compare Promo vs No Promo side-by-side  while simultaneously
# observing: Day-of-week patterns, Month-wise seasonality, Intensity of average sales.
# This approach avoids visual clutter and makes a 4-variable relationship interpretable.
# ---------------------------------------------------------------------------------------------------------- #

# Creating a pivot table for average sales
heatmap_data = df.groupby(['Promo', 'Month', 'DayOfWeek'])['Sales'].mean().reset_index()

# Creating two subsets for Promo and No Promo
promo_0 = heatmap_data[heatmap_data['Promo'] == 0]
promo_1 = heatmap_data[heatmap_data['Promo'] == 1]

# Pivoting data for heatmap structure
pivot_no_promo = promo_0.pivot(index='Month', columns='DayOfWeek', values='Sales')
pivot_promo = promo_1.pivot(index='Month', columns='DayOfWeek', values='Sales')

# Setting plot style
sns.set(style='white')

# Creating subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Heatmap for No Promo
sns.heatmap(
    pivot_no_promo,
    ax=axes[0],
    cmap='Blues',
    annot=False,
    fmt='.0f',
    cbar=True
)
axes[0].set_title('Average Sales (No Promo)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Day of Week')
axes[0].set_ylabel('Month')

# Heatmap for Promo
sns.heatmap(
    pivot_promo,
    ax=axes[1],
    cmap='Oranges',
    annot=False,
    fmt='.0f',
    cbar=True
)
axes[1].set_title('Average Sales (Promo Active)', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Day of Week')
axes[1].set_ylabel('')

# Final layout adjustment
plt.suptitle(
    'Promo × Sales × Day × Month Interaction',
    fontsize=16,
    fontweight='bold'
)

# Displaying the plot
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# **Summary -**
#
# * This faceted heatmap clearly highlights how promotions change sales behavior across both weekdays and months.
#
# * Promo Active days consistently generate higher sales across almost all months and weekdays.
#
# * Month-level seasonality is strong: December (Month 12) shows the highest sales intensity, especially when promotions are active.
#
# * Weekday patterns differ with and without promo:
# Without promo, sales are more evenly spread across weekdays.
#
# * With promo, early weekdays (Day 1–3) and mid-week days benefit the most.
#
# * This chart successfully uncovers hidden temporal interactions that single-variable charts cannot reveal.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picked a faceted heatmap because, This analysis involves four dimensions simultaneously: Promo status,  Month, Day of week, Sales
#
# * Heatmaps are ideal for spotting intensity patterns, seasonality, and interaction effects.
#
# * Faceting Promo vs No Promo avoids overcrowding while enabling direct visual comparison.
#
# * A simple bar or line chart would fail to capture this multi-level interaction clearly.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **🔹 Key Insights**
#
# * Promotions amplify sales across all months
# Promo-active heatmap consistently shows warmer colors than no-promo.
#
# * Confirms that promotions increase revenue beyond normal seasonality.
#
# * December (Month 12) is the strongest month
#
# * Highest sales intensity appears in Month 12, especially with promo.
#
# * Suggests strong year-end festive demand.
#
# * Promo effectiveness varies by weekday
#
# * Promo impact is strongest on Day 1–3 (early weekdays).
#
# * Weekends or late-week days show relatively lower incremental gains.
#
# * Without promo, sales are flatter
#
# * No-promo sales rely mostly on seasonality, not weekday effects.
#
# * Indicates promotions introduce behavioral demand shifts, not just volume increases.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * Run major promos in high-season months (Nov–Dec) for maximum ROI.
#
# * Schedule promos on early weekdays instead of spreading them uniformly.
#
# * Reduce promo spend during low-impact weekday–month combinations.
#
# * Improve inventory planning for promo-heavy high-demand periods.
#
# * These insights directly support revenue optimization, marketing efficiency, and demand forecasting.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Promo fatigue in certain weekday - month combinations
#
#     * Some promo cells show only marginal improvement over no-promo.
#
#     * Running promos during these periods may increase costs without proportional sales uplift.
#
# * Over-reliance on promotions
#
#     * Sales drop sharply in no-promo cells during low-demand months.
#
#     * Indicates customers may be trained to wait for discounts, hurting baseline sales.
#
# **📌 Business Risk:**
#
# * Poorly timed promos can erode margins instead of boosting profits.

# %% [markdown]
# ##### Chart 87 - Promo × Day × Month × Customers Interaction

# %%
# Chart 87 - Visualisation Code


# Features Used - Promo, Customers, DayOfWeek, Month

# ✅ Why this chart is important to include?
# This heatmap-based interaction chart helps analyze how customer footfall varies
# across different days of the week and months under Promo and Non-Promo conditions.
# It allows us to understand:
# - How daily customer patterns change month-wise during promotions
# - Whether Promo consistently increases customers across all days and months
# - Seasonal and weekday interaction effects on customer traffic

# ---------------------------------------------------------------------------------------------------------- #

# Aggregating average customers by Promo, Month, and DayOfWeek
promo_day_month_customers = (
    df.groupby(['Promo', 'Month', 'DayOfWeek'])['Customers']
      .mean()
      .reset_index()
)

# Separating Promo and No Promo data
no_promo_data = promo_day_month_customers[promo_day_month_customers['Promo'] == 0]
promo_data = promo_day_month_customers[promo_day_month_customers['Promo'] == 1]

# Creating pivot tables for heatmap
pivot_no_promo = no_promo_data.pivot(
    index='Month',
    columns='DayOfWeek',
    values='Customers'
)

pivot_promo = promo_data.pivot(
    index='Month',
    columns='DayOfWeek',
    values='Customers'
)

# Setting visual style
sns.set(style="white")

# Creating subplot layout
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Plotting No Promo heatmap
sns.heatmap(
    pivot_no_promo,
    ax=axes[0],
    cmap='Blues'
)
axes[0].set_title(
    'Average Customers (No Promo)',
    fontsize=14,
    fontweight='bold'
)
axes[0].set_xlabel('Day of Week')
axes[0].set_ylabel('Month')

# Plotting Promo Active heatmap
sns.heatmap(
    pivot_promo,
    ax=axes[1],
    cmap='Oranges'
)
axes[1].set_title(
    'Average Customers (Promo Active)',
    fontsize=14,
    fontweight='bold'
)
axes[1].set_xlabel('Day of Week')
axes[1].set_ylabel('')

# Overall chart title
plt.suptitle(
    'Promo × Customers × Day × Month Interaction',
    fontsize=16,
    fontweight='bold'
)

# Layout adjustment
plt.tight_layout(rect=[0, 0, 1, 0.95])

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart highlights how customer footfall varies across days of the week and months under Promo vs Non-Promo conditions.
#
# * A clear uplift in customer counts is visible during promotions across almost all day–month combinations.
#
# * The pattern also shows strong seasonality (month-wise) and weekday effects, with promotions amplifying existing high-traffic periods rather than changing customer behavior uniformly across time.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * This dual heatmap is chosen to capture four-dimensional interaction (Promo × Customers × Day × Month) in a compact and interpretable form.
#
# * It allows direct visual comparison between Promo and Non-Promo scenarios for the same temporal combinations.
#
# * Heatmaps are ideal here because they highlight intensity, seasonality, and consistency patterns that would be difficult to detect using grouped bars or line charts.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Promotions consistently increase customer footfall across nearly all months and weekdays compared to non-promo periods.
#
# * Month 12 (December) stands out clearly in both cases, but the promo effect is significantly stronger, indicating seasonal amplification.
#
# * Weekdays (especially Day 1–3) show higher customer density under Promo, suggesting promotions are more effective during regular shopping days than weekends.
#
# * Under No Promo, customer counts are more stable and muted, indicating that baseline demand is driven largely by seasonality rather than day-specific spikes.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# Yes, the insights from this chart can directly drive positive business impact:
#
# * Promotions consistently increase customer footfall across almost all day–month combinations.
#
#     → This confirms that promotions are effective in attracting customers, not just shifting sales value.
#
# * Seasonality amplification is evident, especially in Month 12 (December).
#
#     → Running promotions during already high-demand periods can maximize ROI, inventory turnover, and revenue density.
#
# * Weekday-focused uplift (Day 1–3) suggests promotions work better during regular shopping days.
#
#     → This helps in targeted promo scheduling, reducing wasted discounts on low-impact days.
#
# * The chart enables operational planning (staffing, inventory, logistics) by predicting promo-driven customer surges.
#
# **⚠️ Negative-Growth Risks Identified -**
#
# There are important cautionary insights that could lead to negative growth if ignored:
#
# 1.  Promo impact is not uniform across all days and months
#
#     * Some day–month cells show only marginal customer uplift under Promo.
#
#     * Running promotions in these periods may increase cost without proportional footfall gains. → Risk: Discount fatigue and reduced margins.
#
# 2. Promotions amplify seasonality but do not create demand in weak periods
#
#     * In lower-demand months, Promo increases customers slightly but does not change the overall demand pattern.
#
#         → Risk: Businesses may overestimate promo power and overspend in low-return periods.
#
#
# 3. Higher customers ≠ higher profitability
#
# * Increased footfall during Promo can lead to:
#
#     * Higher operational costs (staff, inventory handling)
#
#     * Lower per-customer margins (as seen in some SalesPerCustomer charts)
#
#         → Risk: Growth in customers but decline in profit efficiency.
#
# **🧠 Final Interpretation**
#
# * Promotions are effective demand amplifiers, not demand creators.
#
# * When used strategically, they drive strong positive business impact.
#
# * When used blindly across all time periods, they can lead to margin erosion and inefficient growth.
#
# ➡️ This chart is valuable for EDA because it highlights both opportunity and risk, enabling data-driven promo strategy rather than intuition-based decisions.

# %% [markdown]
# ##### Chart 88 - Monthly Customer Trends by Assortment Type (Promo vs Non-Promo)

# %%
# Chart - 88 Visualisation Code

# Features Used - Promo, Assortment, Month, Customers

# ✅ Why this chart is important to include?
# This chart is helping analyze how customer footfall changes across different
# assortment types and months under Promo and Non-Promo conditions.
# By combining month-wise seasonality with assortment-level behavior,
# this chart is exploring whether promotions work uniformly across assortments
# or whether certain assortments benefit more during specific months.

# ---------------------------------------------------------------------------------------------------------- #

# Grouping the data by Month, Assortment, and Promo and calculating average customers
monthly_customers_assortment_promo = (
    df.groupby(['Month', 'Assortment', 'Promo'])['Customers']
      .mean()
      .reset_index()
)

# Creating a FacetGrid to visualize Promo vs Non-Promo patterns across assortments
g = sns.FacetGrid(
    monthly_customers_assortment_promo,
    col='Assortment',
    hue='Promo',
    col_wrap=3,
    height=4,
    aspect=1.2,
    palette={0: '#1f77b4', 1: '#ff7f0e'}
)

# Mapping line plots to each facet
g.map(
    sns.lineplot,
    'Month',
    'Customers',
    marker='o'
)

# Adding a legend to differentiate Promo vs Non-Promo
g.add_legend(title='Promo (0 = No, 1 = Yes)')

# Setting axis labels and titles
g.set_axis_labels('Month', 'Average Customers')
g.set_titles('Assortment Type: {col_name}')

# Adjusting layout and overall title
plt.subplots_adjust(top=0.85)
g.fig.suptitle(
    'Monthly Customer Trends by Assortment Type (Promo vs Non-Promo)',
    fontsize=16,
    fontweight='bold'
)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart compares monthly average customer trends across assortment types (a, b, c) under Promo vs Non-Promo conditions.
#
# * It clearly highlights how promotions interact with assortment strategy and seasonality to influence customer footfall.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# This faceted line chart is chosen because:
#
# * It simultaneously captures four dimensions:
#
#     * Time (Month)
#
#     * Promotion status (Promo vs Non-Promo)
#
#     * Assortment type
#
#     * Customer footfall
#
# * Line plots are ideal for trend comparison across months, making seasonality patterns visible.
#
# * Faceting by assortment avoids clutter and allows clean, side-by-side comparison of Promo effectiveness across assortment strategies.
#
# * This chart structure makes it easier to understand where promotions work consistently and where they don’t.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 🔹 Assortment b :
#
#   * Has the highest customer footfall overall.
#
#   * Promo consistently brings additional customers every month.
#
#   * Strong seasonal uplift during mid-year and year-end months. ➡️ Indicates Promo + Assortment b is a strong traffic driver.
#
# 🔹 Assortment a
#
#   * Promo increases customers, but the absolute gain is moderate.
#
#   * Customer trends remain relatively flat across months. ➡️ Promo impact exists, but assortment limitations cap growth.
#
# 🔹 Assortment c
#
#   * Promo effect is visible but inconsistent.
#
#   * In several months, the gap between Promo and Non-Promo narrows. ➡️ Indicates promo fatigue or weaker customer appeal for this assortment.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# This chart directly supports promo optimization decisions:
#
# * Scale promotions aggressively for Assortment b, especially in peak months.
#
# * Selective or limited promos for Assortment a, focusing on cost control.
#
# * Helps align assortment planning + promotional calendar, improving ROI.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Assortment c shows weak or diminishing promo response in several months.
#
# * Running promotions here:
#
#     * Does not consistently increase customers
#
#     * Risks margin erosion without traffic growth
#
# * This suggests inefficient promo spend, which can negatively impact profitability if not corrected.
#
# **➡️ Actionable Risk Insight:**
#
# * Promotions should not be uniformly applied across all assortments.

# %% [markdown]
# ##### Chart 89 - Monthly Customer Trends by Assortment Type (Promo2 vs Non-Promo2)

# %%
# Chart - 89 Visualisation Code

# Features Used - Promo2, Assortment, Month, Customers

# ✅ Why this chart is important to include?
# This chart is helping analyze how long-running promotions (Promo2)
# influence monthly customer trends across different assortment types.
# It is allowing us to understand:
# - Whether Promo2 consistently pulls customers over time
# - Which assortment types benefit most from long-running promotions
# - How seasonality interacts with Promo2 effectiveness

# ---------------------------------------------------------------------------------------------------------- #

# Setting seaborn style for consistency
sns.set(style="whitegrid")

# Aggregating average customers by Month, Assortment, and Promo2 status
promo2_monthly_customers = (
    df.groupby(['Month', 'Assortment', 'Promo2'])['Customers']
      .mean()
      .reset_index()
)

# Creating faceted line plots by Assortment
g = sns.FacetGrid(
    promo2_monthly_customers,
    col="Assortment",
    hue="Promo2",
    col_order=['a', 'b', 'c'],
    height=4,
    aspect=1.1,
    sharey=True
)

# Plotting monthly customer trends
g.map(
    sns.lineplot,
    "Month",
    "Customers",
    marker="o"
)

# Adjusting legend labels for clarity
g.add_legend(
    title="Promo2 Status",
    label_order=[0, 1]
)

# Updating legend text manually
for text, label in zip(g._legend.texts, ["No Promo2", "Promo2 Active"]):
    text.set_text(label)

# Setting axis labels and titles
g.set_axis_labels("Month", "Average Customers")
g.set_titles("Assortment Type: {col_name}")

# Improving layout
plt.subplots_adjust(top=0.85)
g.fig.suptitle(
    "Monthly Customer Trends by Assortment Type (Promo2 vs Non-Promo2)",
    fontsize=16,
    fontweight="bold"
)

# Displaying the chart
plt.show()

# %% [markdown]
# **Summary -**
#
# * This chart analyzes monthly customer trends across different assortment types by comparing Promo2 active vs non-Promo2 stores.
#
# * The visualization clearly shows that Promo2 does not consistently increase customer footfall, and in several cases, stores without Promo2 attract more customers across months, especially for higher assortment types.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# This faceted line chart is chosen because it allows us to:
#
# * Track seasonal customer behavior month-by-month
# Compare long-running promotions (Promo2) against non-Promo2 stores
#
# * Analyze differences separately for each assortment type, avoiding visual clutter
#
# * Using separate panels for assortments helps isolate Promo2 effectiveness without confounding factors.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 🔹 Assortment a :
#
# * Customer counts remain consistently higher in non-Promo2 stores
#
# * Promo2 shows minimal uplift across all months
# Seasonal peaks (end of year) occur regardless of Promo2 ➡️ Promo2 adds no meaningful customer traction for basic assortments.
#
# 🔹 Assortment b
#
# * This category has the highest customer volume overall
# Surprisingly, non-Promo2 stores outperform Promo2 stores in every month
#
# * Even during high-season months, Promo2 fails to close the gap ➡️ Strong assortments naturally pull customers; Promo2 appears redundant here.
#
# 🔹 Assortment c
#
# * Similar pattern to assortment a
#
# * Customer trends are parallel, but non-Promo2 remains consistently higher
#
# * Promo2 does not change seasonality or trend direction ➡️ Promo2 does not act as a differentiator for premium assortments either.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * This insight helps the business avoid unnecessary long-term promotions
#
# * Resources can be reallocated to short-term, tactical promotions
#
# * Store strategy can shift focus to assortment quality and store experience, which clearly drive customers more than Promo2
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Promo2 stores consistently show lower customer counts than non-Promo2 stores
#
# * Long-running promotions may:
#
#     * Cause promotion fatigue
#
#     * Lower perceived urgency
#
#     * Reduce walk-in motivation
#
# * Continuing Promo2 without redesign may suppress natural customer traffic, especially for high-performing assortments.

# %% [markdown]
# ##### Chart 90 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Chart 90 - Correlation Heatmap (Numeric Features Only)

# Features Used - Sales, Customers, SalesPerCustomer, Promo, IsPromo2Active,
#                 SchoolHoliday, CompetitionDistance, CompetitionOpenMonths,
#                 DayOfWeek, Month

# ✅ Why this chart is important to include?
# This heatmap is helping identify linear relationships among all naturally numeric features.
# It is validating earlier EDA findings related to promotions, customer behavior,
# competition impact, and time-based effects before applying any encoding or transformations.

# ---------------------------------------------------------------------------------------------------------- #

# Selecting only numeric columns (without encoding)
numeric_df = df[
    [
        'Sales',
        'Customers',
        'SalesPerCustomer',
        'Promo',
        'IsPromo2Active',
        'SchoolHoliday',
        'CompetitionDistance',
        'CompetitionOpenMonths',
        'DayOfWeek',
        'Month'
    ]
]

# Computing correlation matrix
corr_matrix = numeric_df.corr()

# Setting visual style
sns.set(style="white")

# Creating the figure
plt.figure(figsize=(12, 8))

# Plotting correlation heatmap
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="RdBu_r",
    center=0,
    linewidths=0.4,
    cbar_kws={'shrink': 0.8}
)

# Adding title
plt.title(
    'Correlation Heatmap of Numeric Features',
    fontsize=16,
    fontweight='bold'
)

# Improving layout
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The correlation heatmap highlights how key numeric features interact with **Sales, Customers, and SalesPerCustomer**.
#
# * As expected, **Sales is strongly driven by customer footfall**, while **promotions (Promo)** show a moderate positive association with revenue-related metrics.
#
# * Temporal features like **DayOfWeek** show a notable negative correlation, capturing weekly seasonality effects.
#
# * In contrast, **Promo2 (long-term promotion)** and **competition-related variables** exhibit very weak linear correlations, indicating that their impact is **non-linear or context-dependent**, rather than directly proportional.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap was chosen because it:
#
# * Provides a high-level quantitative overview of linear relationships among all numeric features.
#
# * Helps identify strong drivers of Sales and Customers before modeling.
#
# * Assists in detecting multicollinearity risks, especially between Sales, Customers, and derived metrics like SalesPerCustomer.
#
# * Complements earlier univariate and multivariate charts by confirming patterns statistically, not visually.
#
# * This makes it a critical bridge between EDA and feature engineering.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **🔹 Strong Positive Relationships**
#
# * Sales ↔ Customers (0.89)
#
#     → Sales is primarily volume-driven; higher footfall almost directly translates into higher revenue.
#
# * Sales ↔ SalesPerCustomer (0.66)
#
#     → Basket size also plays a meaningful role, though secondary to customer count.
#
# * Promo ↔ Sales (0.45) and Promo ↔ SalesPerCustomer (0.39)
#
#
#     → Daily promotions are effective in boosting both spending per customer and total sales.
#
# **🔹 Strong Negative Relationships**
#
# * DayOfWeek ↔ Sales (-0.46)
#
# * DayOfWeek ↔ SalesPerCustomer (-0.50)
#
#     → Clear weekly seasonality exists; certain weekdays consistently underperform compared to others.
#
# **🔹 Weak or Near-Zero Relationships**
#
# * IsPromo2Active with Sales (-0.04)
#
# * CompetitionDistance & CompetitionOpenMonths with Sales (~0.00)
#
#     * → Long-term promotions and competition factors do not show linear impact, suggesting:
#
#         * delayed effects
#
#         * interaction effects
#
#         * store-type or promo-context dependence

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * The strong Sales–Customers relationship validates strategies focused on footfall generation (marketing, store visibility, short-term promos).
#
# * Promo’s moderate positive correlation confirms that daily promotions are effective revenue levers, especially when timed correctly.
#
# * Clear weekday seasonality enables:
#
#   * better promo scheduling
#
#   * staff optimization
#
#   * inventory planning
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Negative correlation with DayOfWeek signals:
#
#   * structurally weak days where sales and customer spend drop
#
#   * potential revenue leakage if promotions are not aligned with high-opportunity days
#
# * Weak correlation of Promo2 with Sales suggests:
#
#   * long-term promotions may dilute urgency
#
#   * risk of margin erosion without proportional sales uplift
#
# 👉 This implies that Promo2 should be used selectively, possibly combined with:
#
#   * store type
#
#   * seasonality
#
#   * competition intensity
#
# rather than applied uniformly.
#
# **✅ Final Verdict :**
#
# * The correlation analysis confirms that sales are primarily driven by customer volume and short-term promotions, while long-term promotions and competition effects are non-linear and context-specific.
#
# * This validates our earlier multivariate findings and guides more targeted promotion and scheduling strategies

# %% [markdown]
# ##### Chart - 91 - Pair Plot

# %%
# Pair Plot visualization code

# Features Used - Sales, Customers, SalesPerCustomer, Promo, IsPromo2Active, CompetitionDistance

# ✅ Why this chart is important to include?
# This pair plot helps visually examine relationships between key numeric variables.
# It allows us to:
# - Identify linear and non-linear relationships
# - Detect clusters and outliers
# - Validate correlation heatmap findings visually
# - Understand distribution patterns of important features

# ---------------------------------------------------------------------------------------------------------- #

# Importing required library
import seaborn as sns

# Setting visual style
sns.set(style="whitegrid")

# Sampling data to improve performance and readability
df_sample = df[
    [
        'Sales',
        'Customers',
        'SalesPerCustomer',
        'Promo',
        'IsPromo2Active',
        'CompetitionDistance'
    ]
].sample(n=5000, random_state=42)

# Creating the pair plot
sns.pairplot(
    df_sample,
    diag_kind='kde',
    corner=True,
    plot_kws={'alpha': 0.4, 's': 15}
)

# Displaying the plot
plt.show()

# %% [markdown]
# **Summary -**
#
# * The pair plot provides a visual validation of the correlation heatmap and helps uncover distribution patterns, linearity, clustering, and outliers among key numeric variables.
#
# * It clearly shows that Sales are primarily driven by Customers, while Promotions influence customer volume more than spend per customer.
#
# * Variables like Promo2 and CompetitionDistance show weaker direct relationships, indicating their effects are context-dependent rather than universally strong.

# %% [markdown]
# ###### 1. Why did you pick the specific chart?

# %% [markdown]
# * The pair plot is selected because it enables simultaneous visual analysis of multiple numeric features, helping identify:
#
#     * Linear and non-linear relationships
#
#     * Strength and direction of associations
#
#     * Distribution shapes and skewness
#
#     * Presence of clusters and outliers
#
# * This chart complements the correlation heatmap by revealing patterns that correlation values alone cannot capture, especially for large retail datasets.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Key insights:**
#
# * Sales and Customers show a strong positive linear relationship, confirming that higher footfall directly leads to higher sales.
#
# * SalesPerCustomer shows moderate spread, indicating customer spending varies but within a controlled range.
#
# * Promo creates visible clustering, showing higher sales and customer counts when promotions are active.
#
# * Promo2 (long-term promotion) shows overlapping distributions, explaining its weak correlation with Sales and Customers.
#
# * CompetitionDistance is heavily right-skewed, with no strong linear relationship with Sales, suggesting distance alone does not determine store performance.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# * The strong Sales–Customers relationship confirms that strategies focused on increasing footfall (promotions, holidays, store accessibility) will directly boost revenue.
#
# * Clear promo-based clustering shows that short-term promotions (Promo) are effective in increasing customer traffic and total sales.
#
# * Understanding the distribution of SalesPerCustomer helps design targeted pricing and bundling strategies without over-relying on discounts.
#
#
# **⚠️ Negative-Growth Risks Identified -**
#
# * Promo2 shows weak separation between active and inactive periods, indicating long-term promotions may dilute urgency, reducing their effectiveness.
#
# * CompetitionDistance does not strongly correlate with Sales, meaning relying solely on competitor proximity for expansion or pricing decisions could lead to misguided strategies.
#
# * The presence of outliers in Sales and Customers suggests operational inconsistencies (store size, data issues, regional effects) that could negatively affect forecasting if not handled properly.
#
# **✅ Final Verdict :**
#
# * The pair plot confirms that customer footfall is the primary driver of sales, while promotions influence volume more than per-customer spending.
#
# * Long-term promotions and competition proximity show limited standalone impact, highlighting the need for targeted and time-bound promotional strategies.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# * Based on the extensive univariate, bivariate, and multivariate chart experiments performed in the Exploratory Data Analysis phase, I have observed several strong patterns and relationships between sales, customers, promotions, and store characteristics.
#
# * To statistically validate whether these observed patterns are truly significant or occurred due to random variation, hypothesis testing is required.
#
# * Accordingly, I have formulated three hypothesis statements based on the most impactful and business-critical insights derived from the visual analysis.
#
# * Each hypothesis focuses on a key business question related to promotions, customer behavior, and sales efficiency.
#
# * In the following sections, appropriate statistical tests will be applied to each hypothesis to test the assumptions made during EDA and to draw data-driven conclusions with statistical confidence.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# There is a statistically significant difference in the average daily sales between promotional days (Promo = 1) and non-promotional days (Promo = 0).
#
# Let,
#
# μ₁ = Mean daily sales on promotional days
#
# μ₀ = Mean daily sales on non-promotional days
#
#
# **Null Hypothesis (H₀):**
#
# There is no statistically significant difference in the average daily sales between promotional days (Promo = 1) and non-promotional days (Promo = 0).
#
#
# H₀ : μ₀ = μ₁
#
#
# **Alternative Hypothesis (H₁):**
#
# There is a statistically significant difference in the average daily sales between promotional days (Promo = 1) and non-promotional days (Promo = 0).
#
#
# H₁ : μ₀ ≠ μ₁

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# ---------------------------------------------------------------------------------------------------------- #

# Selecting only open store days to avoid bias from closed days
promo_sales = df[(df['Promo'] == 1) & (df['Open'] == 1)]['Sales']
non_promo_sales = df[(df['Promo'] == 0) & (df['Open'] == 1)]['Sales']

# Importing required statistical function
from scipy.stats import ttest_ind

# Performing Welch’s t-test (does not assume equal variance)
t_statistic, p_value = ttest_ind(
    promo_sales,
    non_promo_sales,
    equal_var=False
)

# Displaying test results
print("Independent Two-Sample t-test (Welch’s Test) Results")
print(f"T-statistic : {t_statistic:.4f}")
print(f"P-value     : {p_value:.6f}")
# Out:
# Independent Two-Sample t-test (Welch’s Test) Results
# T-statistic : 356.6357
# P-value     : 0.000000

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# * To evaluate whether there is a statistically significant difference in average sales between promotional and non-promotional days, an Independent Two-Sample t-test (Welch's t-test) was performed.
#
# * This test compares the mean sales of two independent groups — days with promotion (Promo = 1) and days without promotion (Promo = 0).
#
# * The test calculates a t-statistic based on the difference between the sample means, adjusted for variability and sample size, and then derives the corresponding p-value to assess statistical significance.
#
# * The resulting p-value was used to determine whether the observed difference in mean sales is statistically significant or could have occurred due to random chance.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# * I chose the Independent Two-Sample t-test (Welch's t-test) because the objective was to compare the mean sales values of two independent groups — promotional days and non-promotional days.
#
# * The two groups are independent in nature, as daily sales recorded on promotional days do not influence sales on non-promotional days.
#
# * The population variance for sales is unknown, and the observed variability in sales between promo and non-promo days is not guaranteed to be equal.
#
# * Welch's t-test is well suited for such situations because it does not assume equal variances between the two groups.
#
# * Additionally, the dataset contains a large number of observations, making Welch's t-test robust even if the underlying sales distribution is not perfectly normal.
#
# * Therefore, Welch's t-test provides a reliable and statistically sound method to determine whether the observed difference in mean sales is significant.

# %% [markdown]
# **📌 Conclusion -**
#
# Decision Rule
#
# * Significance level (α) = 0.05
#
# * Obtained p-value = 0.000000
#
# Since
#
# p-value < α
#
# **Statistical Conclusion -**
#
# * The null hypothesis (**H₀**) is **rejected**.
#
# * There is **strong statistical evidence** to suggest that the mean daily sales on promotional days are significantly different from the mean daily sales on non-promotional days.
#
# **Business Interpretation -**
#
# * Promotional days generate statistically higher daily sales compared to non-promotional days.
#
# * The extremely large t-statistic (356.64) indicates that the observed difference is not due to random chance, but represents a real and consistent effect.
#
# * This confirms the patterns observed during EDA and validates the effectiveness of short-term promotions as a key revenue driver.
#
#
# **Final Statement -**
#
# * Based on the Welch's two-sample t-test results, the **null hypothesis is rejected at a 5% significance level**.
#
# * This indicates that promotions have a statistically significant impact on daily sales, confirming that promotional activities play a crucial role in driving higher revenue for Rossmann stores.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# There is a statistically significant difference in Sales Per Customer between days when Promo2 is active and when it is not active.
#
#
# Let,
#
# μ₀ : SalesPerCustomer when promo2 is not active. (IsPromo2Active = 0)
#
#
# μ₁ : SalesPerCustomer when promo2 is active. (IsPromo2Active = 1)
#
#
# **Null Hypothesis (H₀) :**
#
# Long-running promotions do not change the average sales per customer.
#
# H₀ : μ₀ = μ₁
#
#
# **Alternate Hypothesis (H₁) :**
#
# Long-running promotions significantly affect the average sales per customer.
#
# H₁ : μ₀ ≠ μ₁

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# Performing statistical test for Hypothesis Statement 2

# Comparing SalesPerCustomer between Promo2 Active and Non-Active days

from scipy import stats

# Separating the two independent samples
spc_promo2_active = df[df['IsPromo2Active'] == 1]['SalesPerCustomer']
spc_promo2_inactive = df[df['IsPromo2Active'] == 0]['SalesPerCustomer']


# Performing Welch’s Two-Sample t-test
t_statistic, p_value = stats.ttest_ind(
    spc_promo2_active,
    spc_promo2_inactive,
    equal_var=False
)

# Displaying the results
print("Welch’s Two-Sample t-test Results")
print(f"T-statistic : {t_statistic:.4f}")
print(f"P-value     : {p_value:.6f}")
# Out:
# Welch’s Two-Sample t-test Results
# T-statistic : 44.3294
# P-value     : 0.000000

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# * An Independent Two-Sample t-test (Welch’s t-test) was performed.
#
# * This test compared the mean Sales Per Customer between two independent groups:
#
#   * Days when Promo2 was active
#
#   * Days when Promo2 was not active

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# * The objective was to compare the mean Sales Per Customer across two independent conditions.
#
# * Sales Per Customer is a continuous numeric variable, making it suitable for a mean comparison test.
#
# * The variance and sample size between Promo2-active and non-active days are not guaranteed to be equal.
#
# * Welch's t-test is robust to unequal variances and large real-world datasets, making it appropriate for this analysis.

# %% [markdown]
# **🔹 Interpretation of Statistical Test Output -**
#
# * The t-statistic (44.33) is extremely large, which means the difference in Sales Per Customer between Promo2-active and Promo2-inactive days is far larger than what random variation would produce.
#
# * The p-value is effectively 0, which is much smaller than the significance level (α = 0.05).
# This provides very strong statistical evidence against the null hypothesis.
#
#
# **📈 Business Interpretation -**
#
# **✅ Positive Business Impact :**
#
# * This result confirms that long-running promotions (Promo2) materially affect sales efficiency.
#
# * The company can no longer assume Promo2 improves revenue quality simply by increasing customer volume.
#
# * Sales Per Customer is a strong profitability metric, and this finding allows:
#
#     * Better evaluation of long-term promotion ROI
#
#     * Redesigning Promo2 strategies to focus on higher-value customers
#
#     * Store-type–specific or assortment-based Promo2 targeting
#
# **⚠️ Negative Growth Risk -**
#
# * The strong statistical difference suggests that Promo2 may be attracting lower-spending customers.
#
# * If Promo2 continues without redesign:
#
#   * Revenue growth may stagnate despite higher footfall
#
#   * Profit margins may shrink due to discount-heavy behavior
#
#   * Stores may become dependent on promotions without improving efficiency
#
# * This creates a long-term revenue dilution risk if Promo2 is not optimized.
#
#
# **Final Conclusion -**
#
# **Decision: Reject the Null Hypothesis (H₀)**
#
# * Since the p-value is significantly smaller than 0.05, the null hypothesis is rejected.
#
# * There is a statistically significant difference in Sales Per Customer between Promo2-active and Promo2-inactive days.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Customer footfall varies significantly across different days of the week, indicating that customer shopping behavior is not uniform throughout the week.
#
#
# **Null Hypothesis (H₀):**
#
# There is no statistically significant difference in average customer footfall across different days of the week.
#
# H₀: μ₁ = μ₂ = μ₃ = μ₄ = μ₅ = μ₆ = μ₇
#
#
# Where:
# μ₁, μ₂, …, μ₇ :  represent the mean customer footfall for each day of the week.
#
#
# **Alternate Hypothesis (H₁):**
#
# At least one day of the week has a statistically significant difference in average customer footfall compared to the others.
#
# H₁: At least one μᵢ differs from the others

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# Performing statistical test for Hypothesis Statement 3

# Comparing average customer footfall across different days of the week

# Creating a list of customer samples for each day of the week
customers_by_day = [
    df[df['DayOfWeek'] == day]['Customers']
    for day in sorted(df['DayOfWeek'].unique())
]

# Performing One-Way ANOVA
f_statistic, p_value = stats.f_oneway(*customers_by_day)

# Displaying the results
print("One-Way ANOVA Results")
print(f"F-statistic : {f_statistic:.4f}")
print(f"P-value     : {p_value:.6f}")
# Out:
# One-Way ANOVA Results
# F-statistic : 67241.6339
# P-value     : 0.000000

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# * A One-Way Analysis of Variance (ANOVA) test was performed.
#
# * This test was used to compare the mean customer footfall across multiple groups, where each group represents a different day of the week.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# * The objective was to compare average customer footfall across more than two categories (seven weekdays).
#
# * Customer count is a continuous numeric variable, while DayOfWeek is a categorical variable with multiple levels.
#
# * A two-sample t-test is not suitable in this scenario because it can only compare two groups at a time.
#
# * One-Way ANOVA is specifically designed to test whether at least one group mean differs significantly when comparing multiple independent groups.

# %% [markdown]
# **🔹 Interpretation of Statistical Test Output -**
#
# * The F-statistic is extremely large, which indicates that the variation in average customer footfall between different weekdays is far greater than the variation within the same weekday.
#
# * The p-value is effectively 0, which is much smaller than the significance level (α = 0.05).
# This provides very strong statistical evidence against the null hypothesis.
#
#
# **Conclusion -**
#
# **Decision: Reject the Null Hypothesis (H₀)**
#
# * Since the p-value is significantly smaller than 0.05, the null hypothesis is rejected.
#
# * There is a statistically significant difference in average customer footfall across different days of the week.
#
#
#
#
# **📈 Business Interpretation -**
#
# **✅ Positive Business Impact :**
#
# * This result confirms that customer shopping behavior varies strongly by day of the week.
#
# * The business can use this insight to:
#
#   * Optimize staff scheduling on high-footfall days
#
#   * Improve inventory planning and replenishment
#
#   * Run targeted promotions on low-footfall weekdays
#
#   * Enhance customer experience during peak days
#
# * Understanding daily traffic patterns helps improve both revenue generation and cost efficiency.
#
# **⚠️ Negative Growth Risks -**
#
# * If weekday differences in footfall are ignored:
#
#   * Stores may be understaffed on peak days, leading to lost sales and poor service
#
#   * Resources may be wasted on low-traffic days, increasing operational costs
#
#   * Promotional efforts may be misaligned with actual customer behavior
#
# * This could result in inefficient operations and missed revenue opportunities over time.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# Missing values were handled during the Data Wrangling stage
# Refer to the Data Wrangling section for detailed implementation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# * Missing values were handled comprehensively during the **Data Wrangling** phase to ensure that the dataset was analysis-ready before performing exploratory analysis, visualization, and modeling.
#
# * Instead of dropping records with missing values, appropriate **domain-driven imputation strategies** were applied to preserve data integrity and avoid unnecessary data loss.
#
# * The following missing value handling techniques were used:
#
#   * **Competition-related variables :**
#
#     * CompetitionDistance was imputed using the median, as it is a continuous variable with a skewed distribution and median is robust to outliers.
#
#     * CompetitionOpenSinceMonth and CompetitionOpenSinceYear were filled with 0, indicating unknown competition opening details.
#
#     * A missing-value indicator CompetitionOpenSince_NA was created to preserve information about originally missing records.
#
#   * **Promotion-related variables :**
#
#     * Promo2SinceWeek and Promo2SinceYear were filled with 0 to indicate absence of long-term promotion history.
#
#     * PromoInterval missing values were replaced with 'None'.
#
#     * A flag Promo2Since_NA was created to track missing promotion metadata.
#
#   * **Indicator flags for missingness :**
#
#     * Binary indicators such as CompetitionDistance_NA, CompetitionOpenSince_NA, and Promo2Since_NA were created to capture the potential impact of missingness as a separate signal.
#
# * This approach ensured that:
#
#   * No meaningful rows were dropped
#
#   * Business context was preserved
#
#   * Models could later learn from both actual values and missingness patterns
#
# * As a result, the dataset contains **no unhandled missing values** and is fully prepared for downstream feature engineering and modeling tasks.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments


# Cap competition distance at 99th percentile
cap_value = df['CompetitionDistance'].quantile(0.99)
df.loc[df['CompetitionDistance'] > cap_value, 'CompetitionDistance'] = cap_value

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# * Outlier treatment was performed carefully to preserve genuine business signals while minimizing the influence of extreme and potentially noisy values.
#
# * Given the nature of the retail sales data, high values of Sales and Customers often represent legitimate high-performing stores rather than anomalies. Therefore, no outlier removal or clipping was applied to these variables to avoid losing important business information.
#
# * Outlier handling was specifically applied to **CompetitionDistance**, which exhibited extreme skewness and unusually large values likely caused by data recording inconsistencies or rare edge cases. To address this:
#
#   * CompetitionDistance values were **capped at the 99th percentile**, limiting the influence of extreme outliers while retaining the overall distribution.
#
# * Additionally, a business-rule-based anomaly flag ZeroSalesWhileOpen was created to capture cases where stores were open but recorded zero sales.
#
# * These observations were retained for analysis as they represent meaningful operational insights rather than noise.
#
# * This balanced approach ensured that:
#
#   * Genuine high-performing stores were preserved
#
#   * Extreme noise was controlled
#
#   * Model stability and interpretability were improved

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns


# ---------------------------------------------------------
# CATEGORICAL ENCODING
# ---------------------------------------------------------

from sklearn.preprocessing import LabelEncoder

# Creating a copy to preserve original dataset if needed
df_encoded = df.copy()

# -----------------------------
# 1. Encoding StateHoliday
# -----------------------------
# StateHoliday is a nominal categorical feature with low cardinality
stateholiday_encoder = LabelEncoder()
df_encoded['StateHoliday_Encoded'] = stateholiday_encoder.fit_transform(df_encoded['StateHoliday'])

# -----------------------------
# 2. Encoding StoreType
# -----------------------------
# StoreType is a nominal categorical feature
storetype_encoder = LabelEncoder()
df_encoded['StoreType_Encoded'] = storetype_encoder.fit_transform(df_encoded['StoreType'])

# -----------------------------
# 3. Encoding Assortment (Ordinal)
# -----------------------------
# Assortment has an inherent order: a < b < c
assortment_mapping = {'a': 0, 'b': 1, 'c': 2}
df_encoded['Assortment_Encoded'] = df_encoded['Assortment'].map(assortment_mapping)


# -----------------------------
# 4. Encoding PromoInterval
# -----------------------------
# PromoInterval is categorical with multiple combinations
promointerval_encoder = LabelEncoder()
df_encoded['PromoInterval_Encoded'] = promointerval_encoder.fit_transform(df_encoded['PromoInterval'])



# -----------------------------
# Dropping original categorical columns
# -----------------------------
df_encoded.drop(
    columns=['StateHoliday', 'StoreType', 'Assortment', 'PromoInterval'],
    inplace=True
)

print("✅ Categorical Encoding Completed Successfully!")
display(df_encoded[['StateHoliday_Encoded', 'StoreType_Encoded',
                     'Assortment_Encoded', 'PromoInterval_Encoded']].head())


# ---------------------------------------------------------
# Dropping EDA-only bucket columns before modeling
# ---------------------------------------------------------

bucket_columns = [
    'CompetitionDistanceBin',
    'CompetitionDistanceBucket',
    'CompetitionAgeBucket',
    'Competition_Age_Bucket',
    'MonthName'
]

df_encoded.drop(columns=bucket_columns, errors='ignore', inplace=True)

print("✅ EDA-only bucket columns dropped before modeling!")
# Out:
# ✅ Categorical Encoding Completed Successfully!
#    StateHoliday_Encoded  StoreType_Encoded Assortment_Encoded  \
# 0                     1                  2                  0
# 1                     0                  2                  0
# 2                     0                  2                  0
# 3                     0                  2                  0
# 4                     0                  2                  0
#
#    PromoInterval_Encoded
# 0                      3
# 1                      3
# 2                      3
# 3                      3
# 4                      3
# ✅ EDA-only bucket columns dropped before modeling!

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# * During the feature engineering stage, categorical encoding was performed to convert non-numeric variables into a machine-learning-friendly format.
#
# * Label encoding was used for nominal categorical features such as StateHoliday, StoreType, and PromoInterval.
#
# * This approach was chosen because these variables have a limited number of categories and the dataset size is very large. Label encoding avoids unnecessary feature expansion and keeps the feature space compact and computationally efficient.
#
# * For the Assortment feature, ordinal encoding was applied instead of one-hot encoding.
#
# * This decision was based on the business meaning of the variable, as assortment types follow a natural order from basic to extended product ranges.
#
# * Preserving this order allows the model to better capture differences in product variety.
#
# * One-hot encoding was intentionally avoided at this stage to prevent high dimensionality and sparsity, especially given the large number of records in the dataset.
#
# * Tree-based machine learning models can effectively work with label-encoded categorical features without assuming linear relationships, making label encoding a suitable choice.
#
# * Overall, the selected encoding techniques strike a balance between interpretability, computational efficiency, and model compatibility, ensuring that the dataset remains scalable and ready for further preprocessing and modeling.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# * The dataset does not contain any unstructured textual features such as descriptions, reviews, or comments. All non-numeric variables are categorical in nature and have been handled using appropriate encoding techniques.
#
# * Therefore, textual data processing is not applicable for this project.

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# ===============================
# FEATURE MANIPULATION
# ===============================
# Purpose:
# - Reducing feature redundancy
# - Handling cyclic temporal patterns
# - Stabilizing skewed numeric features
# ===============================

# Creating a copy to preserve original dataframe
df_feat = df_encoded.copy()

# ------------------------------------------------
# Dropping raw date column (time already extracted)
# ------------------------------------------------
df_feat.drop(columns=['Date'], inplace=True)

# ------------------------------------------------
# Creating cyclic features for Month
# ------------------------------------------------
df_feat['Month_sin'] = np.sin(2 * np.pi * df_feat['Month'] / 12)
df_feat['Month_cos'] = np.cos(2 * np.pi * df_feat['Month'] / 12)

# ------------------------------------------------
# Creating cyclic features for DayOfWeek
# ------------------------------------------------
df_feat['DayOfWeek_sin'] = np.sin(2 * np.pi * df_feat['DayOfWeek'] / 7)
df_feat['DayOfWeek_cos'] = np.cos(2 * np.pi * df_feat['DayOfWeek'] / 7)

# ------------------------------------------------
# Log-transforming CompetitionDistance to reduce skew
# ------------------------------------------------
df_feat['CompetitionDistance_log'] = np.log1p(df_feat['CompetitionDistance'])

print("✅ Feature manipulation completed successfully")

print("✅ Feature manipulation completed with business-aligned transformations.")
# Out:
# ✅ Feature manipulation completed successfully
# ✅ Feature manipulation completed with business-aligned transformations.

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# ===============================
# FEATURE SELECTION
# ===============================
# Purpose:
# - Removing target leakage
# - Removing redundant features
# - Keeping only prediction-safe inputs
# ===============================

df_model = df_feat.copy()

# Dropping unnecessary and leakage-prone columns
df_model.drop(columns=[
    'Store',
    'Month',
    'DayOfWeek',
    'Promo2',
    'Customers',
    'SalesPerCustomer',
    'ZeroSalesWhileOpen',
    'CompetitionDistance',
    'CompetitionDistance_NA',
    'CompetitionOpenSinceMonth',
    'CompetitionOpenSinceYear',
    'CompetitionOpenSince_NA',
    'Promo2SinceWeek',
    'Promo2Since_NA',
    'PromoInterval_Encoded'
], inplace=True)

print("✅ Feature selection completed successfully")
print("Final columns used for modeling:")
print(df_model.columns.tolist())
# Out:
# ✅ Feature selection completed successfully
# Final columns used for modeling:
# ['Year', 'Open', 'Promo', 'IsPromo2Active', 'Sales', 'SchoolHoliday', 'CompetitionOpenMonths', 'StateHoliday_Encoded', 'StoreType_Encoded', 'Assortment_Encoded', 'Month_sin', 'Month_cos', 'DayOfWeek_sin', 'DayOfWeek_cos', 'CompetitionDistance_log']

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# * Feature selection was primarily performed using domain knowledge - driven selection combined with correlation and redundancy analysis rather than automated statistical elimination techniques.
#
# * First, business understanding and real-world forecasting constraints were applied to identify features that would be available at prediction time.
#
# * Variables such as Customers, SalesPerCustomer, and ZeroSalesWhileOpen were excluded because they contain post-event information or are directly derived from the target variable, which would otherwise introduce target leakage.
#
# * Second, redundant and highly correlated features were removed to minimize multicollinearity. For example, raw temporal features (Month, DayOfWeek) were replaced by their cyclic representations (Month_sin, Month_cos, DayOfWeek_sin, DayOfWeek_cos) to better capture seasonality while avoiding duplicate information.
#
# * Third, structurally redundant competition features were eliminated.
#
# * Instead of using raw competition opening dates and missing value flags, consolidated features such as CompetitionDistance_log and CompetitionOpenMonths were retained, as they more effectively represent competitive pressure while reducing feature complexity.
#
# * Encoded categorical variables (StoreType_Encoded, Assortment_Encoded, StateHoliday_Encoded) were retained based on their strong explanatory power observed during exploratory analysis.
#
# * Overall, this hybrid approach ensured that the final feature set is leakage-free, non-redundant, interpretable, and aligned with real-world deployment scenarios, making it suitable for robust and generalizable model training.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# * The most important features identified in this project are those that directly influence daily sales while being available before the day of sale, ensuring realistic and deployable predictions.
#
# * **Promotion-related features** (Promo, IsPromo2Active) were found to be highly important, as extensive EDA showed that both short-term and long-running promotions significantly impact sales, customer behavior, and sales efficiency. These variables capture marketing-driven demand fluctuations.
#
# * **Temporal features** (Year, Month_sin, Month_cos, DayOfWeek_sin, DayOfWeek_cos) emerged as critical predictors because sales exhibit strong seasonality and weekly patterns. Cyclic encoding was used to preserve the natural continuity of time (e.g., December to January, Sunday to Monday).
#
# * **Store characteristics** (StoreType_Encoded, Assortment_Encoded) were identified as important since different store formats and assortment depths consistently showed varying sales performance and customer engagement during EDA.
#
# * **Competition-related features** (CompetitionDistance_log, CompetitionOpenMonths) were retained because they effectively represent the intensity and maturity of nearby competition. Log transformation of competition distance reduced skewness and improved its usability as a predictive signal.
#
# * **Holiday indicators** (SchoolHoliday, StateHoliday_Encoded) were also found to be important, as sales patterns differed noticeably between holiday and non-holiday periods, especially when combined with promotions.
#
# * Features such as Customers, SalesPerCustomer, and ZeroSalesWhileOpen were intentionally excluded despite their strong correlation with sales, as they contain post-event information and would cause target leakage if used for prediction.
#
# * Overall, the selected features balance **business relevance, statistical usefulness, and modeling integrity**, ensuring that the model learns from genuine demand drivers rather than artifacts of the target variable

# %% [markdown]
# ### 6. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %% [markdown]
# * Yes, data transformation was required for specific numerical features to improve model stability and performance.
#
# * During exploratory analysis, CompetitionDistance exhibited a highly right-skewed distribution with extreme values. To address this, a logarithmic transformation (log1p) was applied to compress the scale, stabilize variance, and make the feature more suitable for modeling.
#
# * Cyclic temporal features (Month_sin, Month_cos, DayOfWeek_sin, DayOfWeek_cos) were also used to transform raw time variables into a continuous and model-friendly representation, preserving the inherent periodic nature of time.
#
# * No transformation was applied to binary or encoded categorical features, as their current representations already align with modeling requirements.
#
# * The target variable (Sales) was intentionally not transformed at this stage. Any transformation of the target (such as log transformation) will be considered later during model training to avoid prematurely altering the response variable.

# %%
# Transform Your data

# ===============================
# DATA TRANSFORMATION
# ===============================
# Purpose:
# - Applying transformations where required to reduce skewness
# - Improving feature usability for downstream modeling
# ===============================

# CompetitionDistance was highly right-skewed
# A log transformation was already applied during feature manipulation
# to stabilize variance and reduce the impact of extreme values

# Verifying transformed feature distribution
df_model[['CompetitionDistance_log']].describe()
# Out:
#        CompetitionDistance_log
# count             1.017209e+06
# mean              7.641842e+00
# std               1.551936e+00
# min               3.044522e+00
# 25%               6.566672e+00
# 50%               7.754053e+00
# 75%               8.836519e+00
# max               1.050263e+01

# %% [markdown]
# ### 7. Data Scaling

# %%
# Scaling your data

# ===============================
# DATA SCALING
# ===============================
# Purpose:
# - Scaling numerical features to a common scale
# - Improving model convergence and performance
# ===============================

from sklearn.preprocessing import StandardScaler

# Creating a copy of the dataframe for scaling
df_scaled = df_model.copy()

# Selecting numerical features to scale
num_features = [
    'Year',
    'CompetitionDistance_log',
    'CompetitionOpenMonths',
    'Month_sin',
    'Month_cos',
    'DayOfWeek_sin',
    'DayOfWeek_cos'
]

# Initializing the scaler
scaler = StandardScaler()

# Applying scaling
df_scaled[num_features] = scaler.fit_transform(df_scaled[num_features])

print("✅ Data scaling completed successfully")
# Out:
# ✅ Data scaling completed successfully

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# * StandardScaler (Z-score normalization) was used to scale the numerical features in the dataset.
#
# * This method transforms features to have a mean of zero and a standard deviation of one, ensuring that variables measured on different scales contribute equally during model training.
#
# * StandardScaler was chosen because several machine learning algorithms used later in the project, such as linear models and dimensionality reduction techniques, are sensitive to feature scale.
#
# * Since skewness in highly skewed features was already handled through logarithmic transformation, StandardScaler was well-suited to standardize the remaining numerical variables.
#
# * The target variable (Sales) was intentionally not scaled at this stage, as scaling the target is handled separately during model training when required.

# %% [markdown]
# ### 8. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# * Dimensionality reduction is not strictly required for this dataset, as the number of engineered and selected features is relatively small and manageable.
#
# * Feature selection and manipulation steps already removed redundancy and reduced correlation, minimizing the risk of multicollinearity.
#
# * The PCA results show that variance is distributed across multiple components, indicating that aggressive dimensionality reduction would not significantly simplify the dataset without losing meaningful information.
#
# * Therefore, dimensionality reduction was explored for analytical purposes but was not enforced in the final modeling pipeline to preserve interpretability.

# %%
# DImensionality Reduction (If needed)

# ===============================
# DIMENSIONALITY REDUCTION (PCA)
# ===============================
# Purpose:
# - Exploring variance distribution across features
# - Evaluating whether dimensionality reduction is beneficial
# ===============================

from sklearn.decomposition import PCA
import numpy as np

# Selecting only scaled numerical features for PCA
pca_features = [
    'Year',
    'CompetitionDistance_log',
    'CompetitionOpenMonths',
    'Month_sin',
    'Month_cos',
    'DayOfWeek_sin',
    'DayOfWeek_cos'
]

X_pca_input = df_scaled[pca_features]

# Initializing PCA without limiting components
pca = PCA()

# Fitting PCA
pca.fit(X_pca_input)

# Creating explained variance dataframe
explained_variance_df = pd.DataFrame({
    'Principal Component': np.arange(1, len(pca.explained_variance_ratio_) + 1),
    'Explained Variance Ratio': pca.explained_variance_ratio_,
    'Cumulative Variance': np.cumsum(pca.explained_variance_ratio_)
})

explained_variance_df
# Out:
#    Principal Component  Explained Variance Ratio  Cumulative Variance
# 0                    1                  0.182633             0.182633
# 1                    2                  0.149212             0.331845
# 2                    3                  0.142959             0.474803
# 3                    4                  0.142896             0.617699
# 4                    5                  0.142820             0.760519
# 5                    6                  0.140788             0.901307
# 6                    7                  0.098693             1.000000

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# * Principal Component Analysis (PCA) was used as the dimensionality reduction technique.
#
# * PCA was applied to analyze how variance is distributed across features and to evaluate whether a smaller set of components could effectively represent the data.
#
# * The technique was used for exploratory analysis only, as the original feature set was already compact and interpretable.
#
# * Based on the PCA results, dimensionality reduction was not required for model training, and the original engineered features were retained.

# %% [markdown]
# ### 9. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# ======================================
# DATA SPLITTING: TRAIN & TEST SET
# ======================================
# Purpose:
# - Splitting the dataset into training and testing sets
# - Ensuring model evaluation is performed on unseen data
# ======================================

from sklearn.model_selection import train_test_split

# Defining target variable
target = 'Sales'

# Defining input features (excluding target)
X = df_scaled.drop(columns=[target])
Y = np.log1p(df_scaled[target])

# Splitting data into training and testing sets
# Using 80-20 split to ensure sufficient training data
x_train, x_test, y_train, y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42
)

# Displaying shapes to verify split
print("Training Features Shape :", x_train.shape)
print("Testing Features Shape  :", x_test.shape)
print("Training Target Shape   :", y_train.shape)
print("Testing Target Shape    :", y_test.shape)
# Out:
# Training Features Shape : (813767, 14)
# Testing Features Shape  : (203442, 14)
# Training Target Shape   : (813767,)
# Testing Target Shape    : (203442,)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# * An 80:20 train-test split was used for dividing the dataset.
#
# * 80% of the data was allocated to the training set so that the model has sufficient observations to learn complex patterns and relationships between features and sales.
#
# * 20% of the data was reserved for the testing set to evaluate the model’s performance on unseen data and to assess its generalization ability.
#
# * This ratio provides a good balance between model learning and reliable performance evaluation, especially for large datasets like the Rossmann sales data.
#
# * The 80:20 split is also an industry-standard practice, making results easier to interpret and compare across models.

# %% [markdown]
# ### 10. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# * The dataset **does not suffer from a traditional class imbalance problem** because the target variable (**Sales**) is a **continuous numerical variable**, not a categorical class label.
#
# * Imbalanced data issues typically arise in **classification problems** (for example, fraud vs non-fraud), whereas this project is a **regression problem** focused on predicting sales values.
#
# * Since the objective is to predict **continuous sales amounts**, the concept of minority and majority classes does not directly apply.
#
# * However, during EDA it was observed that **some binary indicator variables** (such as ZeroSalesWhileOpen) are **highly skewed**, but these are **input features**, not the target variable.
#
# * Such skewness in input features **does not require resampling techniques** like SMOTE or undersampling, as these techniques are designed for imbalanced classification targets.
#
# * Therefore, **no explicit imbalance-handling techniques are required** for this dataset, and the model can be trained directly on the available data.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# MODEL IMPLEMENTATION - BASELINE MODEL

# Features Used: log(Sales)

# ✅ Why this model is important to include?
# This baseline model is establishing a reference performance by predicting
# the average log-transformed sales for all test observations.
# This is helping evaluate whether machine learning models are truly
# learning meaningful patterns or merely matching a naive average prediction.

# ---------------------------------------------------------------------------------------------------------- #

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculating mean of training target
baseline_prediction = np.full(
    shape=len(y_test),
    fill_value=y_train.mean()
)

# Evaluating baseline performance
baseline_mae = mean_absolute_error(y_test, baseline_prediction)
baseline_rmse = np.sqrt(mean_squared_error(y_test, baseline_prediction))
baseline_r2 = r2_score(y_test, baseline_prediction)

# Displaying results
print("📌 Baseline Model Performance (Log-Transformed Sales)")
print(f"MAE  : {baseline_mae:.4f}")
print(f"RMSE : {baseline_rmse:.4f}")
print(f"R²   : {baseline_r2:.4f}")
# Out:
# 📌 Baseline Model Performance (Log-Transformed Sales)
# MAE  : 2.4778
# RMSE : 3.3217
# R²   : -0.0000

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# Visualizing Evaluation Metric Score Chart for Baseline Model

metrics = ['MAE', 'RMSE', 'R²']
values = [baseline_mae, baseline_rmse, baseline_r2]

plt.figure(figsize=(7,5))
sns.barplot(x=metrics, y=values, palette='Blues')

plt.title('Baseline Model Evaluation Metrics', fontsize=14, fontweight='bold')
plt.ylabel('Metric Value')
plt.xlabel('Evaluation Metrics')

# Adding value labels
for i, v in enumerate(values):
    plt.text(i, v, f"{v:.3f}", ha='center', va='bottom', fontweight='bold')

plt.show()

# %% [markdown]
# * The baseline model is a simple reference model that predicts the **mean of the target variable** (log-transformed Sales) for every observation.
#
# * This model does not learn any relationship between input features and the target.
#
# * It is used to establish a **minimum benchmark** that any machine learning model must outperform.
#
# * The purpose of this model is not accuracy, but **performance comparison**
# .
# **Performance Interpretation :**
#
# * **MAE = 2.4778**
#
#   * On average, the model's predictions deviate from the true log(Sales) values by about 2.48 units.
#
# * **RMSE = 3.3217**
#
#   * Higher RMSE indicates large errors due to inability to capture variability in sales.
#
# * **R² ≈ 0**
#
#   * An R² value close to zero means the model explains **almost none of the variance** in sales.
#
#   * This confirms that predicting the mean is not sufficient for real-world forecasting.
#
# ➡️ This validates the need for **feature-based ML models**.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Cross-Validation & Hyperparameter Tuning
# ----------------------------------------------------
# Baseline model does not support cross-validation or hyperparameter tuning
# because it does not learn any parameters from features.
# It only predicts the mean of the target variable.
# Therefore, no optimization techniques are applied here.

# %% [markdown]
# * Cross-validation and hyperparameter tuning are not applicable for the baseline model.
# * The baseline model has no trainable parameters.
#
# * It simply predicts the mean of the training target and therefore:
#
#   * Cannot be optimized
#
#   * Cannot be tuned
#
#   * Cannot benefit from cross-validation
#
# ➡️ Cross-validation will be applied starting from Model 1 (Linear Regression).

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# * No hyperparameter optimization technique was used for the baseline model.
#
# * This is because the baseline model has no hyperparameters to tune.
#
# * Optimization techniques such as GridSearchCV or RandomSearchCV are applicable only to learning-based models.
#
# * Hyperparameter tuning will be performed for subsequent machine learning models.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# * No improvement is observed in the baseline model.
#
# * This is expected because the baseline model does not learn from features.
#
# * The poor R² score (~0) confirms that meaningful improvement can only be achieved by applying machine learning algorithms.
#
# * This baseline performance will be used as a reference point to evaluate future models.

# %% [markdown]
# ### ML Model - 2

# %%
# ML Model - 2 Implementation


# ================================
# MODEL 1 - LINEAR REGRESSION
# ================================

# Features Used:
# All selected numerical and encoded features
# Target Used: Log-Transformed Sales

# ✅ Why this model is important to include?
# This model is serving as the first learnable machine learning model after baseline.
# Linear Regression is helping to establish a strong benchmark and understand
# whether linear relationships exist between engineered features and sales.
# Using log-transformed sales is stabilizing variance and reducing skewness,
# making the model assumptions more valid.

# --------------------------------------------------------------- #

# Importing required model and evaluation libraries
from sklearn.linear_model import LinearRegression


# --------------------------------------------------------------- #
# Initializing Linear Regression model
lr_model = LinearRegression()

# --------------------------------------------------------------- #
# Fit the Algorithm
lr_model.fit(x_train, y_train)

# Predict on the model
# Making predictions on test data
y_pred = lr_model.predict(x_test)

# --------------------------------------------------------------- #
# Evaluating model performance

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

# Printing evaluation results
print("📌 Linear Regression Model Performance (Log-Transformed Sales)")
print(f"MAE  : {mae:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"R²   : {r2:.4f}")
# Out:
# 📌 Linear Regression Model Performance (Log-Transformed Sales)
# MAE  : 0.2555
# RMSE : 0.3537
# R²   : 0.9887

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart


# Extracting the data for the plot
metrics = ['MAE', 'RMSE', 'R²']
values = [mae, rmse, r2]


# Creating the bar chart
plt.figure(figsize=(8,5))
sns.barplot(
    x=metrics,
    y=values,
    palette='Blues'
)

# Setting title and labels
plt.title(
    'Evaluation Metrics for Linear Regression Model',
    fontsize=16,
    fontweight='bold'
)
plt.ylabel('Metric Value')
plt.xlabel('Metric Type')
plt.grid(axis='y', linestyle='--', alpha=0.4)

# Displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# * I have used **Linear Regression** as the first learnable machine learning model after the baseline model.
#
# * Linear Regression helps in understanding whether a **linear relationship exists between the engineered features and sales**, making it a strong benchmark model.
#
# * The model was trained using **log-transformed Sales** as the target variable to reduce skewness and stabilize variance.
#
# * From the evaluation metric score chart:
#
#   * The model achieves **very low MAE and RMSE values**, indicating small prediction errors.
#
#   * The **R² score of 0.9887** shows that the model explains **nearly 99% of the variance** in sales.
#
# * Overall, the evaluation chart confirms that Linear Regression performs **exceptionally well** on the processed dataset.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)


# Cross-Validation and Hyperparameter Tuning using GridSearchCV

param_grid = {
    'fit_intercept': [True, False]
}

grid_search = GridSearchCV(
    estimator=LinearRegression(),
    param_grid=param_grid,
    cv=5,
    scoring='neg_mean_squared_error',
    n_jobs=-1
)


# Fit the Algorithm
# Fitting GridSearch on training data
grid_search.fit(x_train, y_train)


# Predict on the model
# Fetching best model
best_lr_model = grid_search.best_estimator_

# Predicting with best model
y_pred_best = best_lr_model.predict(x_test)


# Evaluating best model performance
mae_best = mean_absolute_error(y_test, y_pred_best)
rmse_best = np.sqrt(mean_squared_error(y_test, y_pred_best))
r2_best = r2_score(y_test, y_pred_best)


# Printing optimized model performance
print("\n📌 Optimized Linear Regression Model Performance")
print(f"MAE  : {mae_best:.4f}")
print(f"RMSE : {rmse_best:.4f}")
print(f"R²   : {r2_best:.4f}")
# Out:
# 📌 Optimized Linear Regression Model Performance
# MAE  : 0.2555
# RMSE : 0.3537
# R²   : 0.9887

# %% [markdown]
# * I have applied **5-fold Cross-Validation** using GridSearchCV.
#
# * Cross-validation ensures that the model performance is **stable across different subsets of the data** and not dependent on a single train-test split.
#
# * Hyperparameter tuning was performed to test different configurations of the Linear Regression model.

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# * I have used **GridSearchCV** for hyperparameter optimization.
#
# * GridSearchCV was chosen because:
#
#   * Linear Regression has **very few hyperparameters**.
#
#   * An exhaustive grid search is computationally efficient and easy to interpret.
#
#   * It ensures that the **best possible parameter combination** is tested systematically.
#
# * For this model, the parameter fit_intercept was tuned. Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# * No improvement was observed after hyperparameter tuning.
#
# * The evaluation metrics **before and after optimization remained identical**:
#
#   * MAE  : 0.2555
#
#   * RMSE : 0.3537
#
#   * R²   : 0.9887
#
# * This indicates that:
#
#   * The default Linear Regression model was already optimally configured.
#
#   * The strong performance is primarily due to **high-quality feature engineering and preprocessing**, rather than parameter tuning.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# * **MAE (Mean Absolute Error = 0.2555)**
#
#   * This indicates that, on average, the predicted log-sales deviate very little from actual log-sales.
#
#   * From a business perspective, this means **highly accurate daily sales predictions**, enabling better inventory and staffing decisions.
#
# * **RMSE (Root Mean Squared Error = 0.3537)**
#
#   * RMSE penalizes larger errors more heavily.
#
#   * The low RMSE value shows that **large prediction mistakes are rare**, which is critical for preventing major planning errors.
#
# * **R² Score (0.9887)**
#
# * An R² of 0.9887 means the model explains **~99% of the variability in sales.**
#
# * This gives strong confidence that the model has captured the **true business drivers of sales**, such as promotions, customer footfall, competition, and store characteristics.
#
# * **Overall Business Impact**
#
# * The model is highly reliable for **forecasting daily sales trends.**
#
# * It can be safely used as a **baseline predictive engine** for demand forecasting, promotional planning, and revenue estimation.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation


# 📌 Model 3 - Random Forest Regression

# Features Used - All selected input features
# Target Variable - Log-Transformed Sales

# ✅ Why this model is important to include?
# This model is helping to capture non-linear relationships between features and sales.
# Unlike Linear Regression, Random Forest does not assume linearity and can automatically
# learn complex interactions between promotions, competition, store characteristics,
# and customer behavior.
# This model is also useful to validate whether the strong performance of the linear model
# is genuine or influenced by linear correlations.

# ---------------------------------------------------------------------------------------------------------- #

# Importing required library
from sklearn.ensemble import RandomForestRegressor


# Initializing the Random Forest Regressor
rf_model = RandomForestRegressor(
       n_estimators=100,
    max_depth=15,          # limiting tree depth
    min_samples_leaf=50,   # prevents overfitting
    random_state=42,
    n_jobs=-1
)

# Fit the Algorithm
# Fitting the model on training data
rf_model.fit(x_train, y_train)


# Predict on the model
# Predicting on test data
y_pred_rf = rf_model.predict(x_test)

# Evaluating model performance
mae_rf = mean_absolute_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))
r2_rf = r2_score(y_test, y_pred_rf)

# Displaying evaluation results
print("📌 Random Forest Model Performance (Log-Transformed Sales)")
print(f"MAE  : {mae_rf:.4f}")
print(f"RMSE : {rmse_rf:.4f}")
print(f"R²   : {r2_rf:.4f}")
# Out:
# 📌 Random Forest Model Performance (Log-Transformed Sales)
# MAE  : 0.1880
# RMSE : 0.2789
# R²   : 0.9930

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# Visualizing evaluation metric score chart for Random Forest

# Creating Data for the plot
metrics = ['MAE', 'RMSE', 'R²']
scores = [mae_rf, rmse_rf, r2_rf]

# Setting figure size
plt.figure(figsize=(8,5))

# Creating bar chart
sns.barplot(x=metrics, y=scores, palette='viridis')

# Showing values on bars
for idx, value in enumerate(scores):
    plt.text(idx, value, f"{value:.3f}", ha='center', va='bottom', fontsize=11)

# Setting title and labels
plt.title("Random Forest Evaluation Metrics", fontsize=15, fontweight='bold')
plt.ylabel("Metric Value")
plt.xlabel("Evaluation Metric")

# Displaying the plot
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# * I have used a **Random Forest Regressor**, which is an ensemble-based machine learning model that combines predictions from multiple decision trees.
#
# * The model works by training each tree on a random subset of data and features and then averaging their predictions, which helps reduce variance and improve generalization.
#
# * Random Forest is particularly suitable for this problem because sales are influenced by multiple interacting factors such as promotions, competition, store type, and customer behavior, which often show non-linear relationships.
#
# * The model was trained using **log-transformed sales** as the target variable to stabilize variance and reduce the impact of extreme sales values.
#
# * Model performance was evaluated using **MAE, RMSE, and R²**, and the results were visualized using an evaluation metric score chart.
#
# **Model Performance Interpretation**
#
# * **MAE (0.1880)** indicates that, on average, the model’s predictions deviate from the actual log-sales values by a very small margin.
#
# * **RMSE (0.2789)** shows that large prediction errors are well controlled, meaning the model performs consistently even on high-sales days.
#
# * **R² (0.9930)** suggests that the model explains 99.3% of the variance in sales, which indicates an excellent fit and strong predictive capability.
#
# **What the Evaluation Metric Score Chart Shows**
#
# * The evaluation metric score chart visually confirms the strong performance of the Random Forest model.
#
# * Low error metrics (MAE and RMSE) combined with a very high R² value demonstrate that the model captures complex sales patterns effectively.
#
# * This chart helps compare performance across models later and provides a clear, interpretable summary of model accuracy for business stakeholders.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Importing necessar libraries
from sklearn.model_selection import RandomizedSearchCV

# Creating a stratified sample for hyperparameter tuning
df_sample = df_scaled.sample(300_000, random_state=42)

x_sample = df_sample[x_train.columns]
y_sample = np.log1p(df_sample['Sales'])

# Creating parameter grid for RandomSearchCV
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [10, 15, 20],
    'min_samples_leaf': [20, 50, 100]
}

# Fit the Algorithm

# Initializing the model
rf = RandomForestRegressor(random_state=42, n_jobs=-1)

# Otimizing the model by cross -validating and hyper -parameter tuning
rf_random = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_grid,
    n_iter=3,
    cv=2,
    scoring='r2',
    n_jobs = -1,
    verbose=1,
    random_state=42
)

# Fitting the model
rf_random.fit(x_sample, y_sample)

# Finding the best model
best_rf = rf_random.best_estimator_

# Predict on the model
# Predicting on test data using best estimator from RandomizedSearchCV
y_pred_best_rf = best_rf.predict(x_test)

# Calculating evaluation metrics
mae_best_rf = mean_absolute_error(y_test, y_pred_best_rf)
rmse_best_rf = np.sqrt(mean_squared_error(y_test, y_pred_best_rf))
r2_best_rf = r2_score(y_test, y_pred_best_rf)

# Displaying optimized model performance
print("📌 Optimized Random Forest Performance (After Hyperparameter Tuning)")
print(f"MAE  : {mae_best_rf:.4f}")
print(f"RMSE : {rmse_best_rf:.4f}")
print(f"R²   : {r2_best_rf:.4f}")
# Out:
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# 📌 Optimized Random Forest Performance (After Hyperparameter Tuning)
# MAE  : 0.1858
# RMSE : 0.2754
# R²   : 0.9931

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# * I have used **Randomized Search Cross-Validation (RandomizedSearchCV)** for hyperparameter optimization.
#
# * This technique randomly samples a fixed number of hyperparameter combinations from a predefined search space instead of evaluating all possible combinations.
#
# * Given the **large size of the dataset**, using exhaustive methods like GridSearchCV would be computationally expensive and time-consuming.
#
# * RandomizedSearchCV allows efficient exploration of the most impactful hyperparameters such as the number of trees, tree depth, and minimum samples per leaf.
#
# * To further reduce execution time while maintaining model reliability, cross-validation was performed using **2 folds** on a **representative sample of the dataset.**
#
# * The optimized model shows **slightly improved performance** (lower MAE and RMSE with a marginal increase in R²), confirming that the chosen optimization strategy was effective.
#
# * This approach provides a strong balance between **model performance, computational efficiency, and practical feasibility**, making it suitable for real-world deployment.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# * Yes, a measurable improvement was observed after applying cross-validation and hyperparameter tuning using RandomizedSearchCV.
#
# * The initial Random Forest model was trained with manually selected parameters, whereas the optimized model used systematically tuned hyperparameters obtained through cross-validation.
#
# * After optimization, the model demonstrated **lower error metrics** and a **slight increase in explanatory power**, confirming that the tuning process was effective.
#
# **📊 Performance Comparison**
#
# |Model Version|MAE|RMSE|R²|
# |---|---|---|---|
# |Random Forest (Before CV)|0.1880|0.2789|0.9930|
# |Random Forest (After CV)|0.1858 ↓|0.2754 ↓|0.9931 ↑|
#
# **🔍 Observed Improvements**
#
# * **MAE decreased**, indicating that average prediction errors reduced after tuning.
#
# * **RMSE decreased**, showing improved handling of larger prediction deviations.
#
# * **R² increased slightly**, meaning the optimized model explains marginally more variance in sales.
#
# * These improvements, although incremental, are meaningful given the already strong baseline performance.
#
# **📈 Evaluation Metric Score Chart Interpretation**
#
# * The updated evaluation metric score chart visually confirms the improvement across MAE, RMSE, and R².
#
# * Even small gains are significant in large-scale retail forecasting problems, as they translate into better daily sales predictions across thousands of stores.
#
# * The chart helps validate that hyperparameter tuning improved model robustness rather than overfitting.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# **Evaluation Metrics Used**
#
# * Across **all three models**, the following evaluation metrics were consistently used:
#
# **1. MAE (Mean Absolute Error)**
#
# **2. RMSE (Root Mean Squared Error)**
#
# **3. R² Score (Coefficient of Determination)**
#
# ---
#
# **Why these metrics are important from a business perspective**
#
# **1. MAE - Business Cost Accuracy**
#
# * MAE measures the average absolute prediction error
# * Directly answers: “On average, how much are we wrong in predicting sales?”
#
# **Business relevance:**
#
# * Lower MAE → more accurate daily sales forecasts
#
# * Helps in:
#
#   * Inventory planning
#
#   * Staffing decisions
#
#   * Revenue estimation
#
# **Most critical metric for operational decision-making**
#
# ---
#
# **2. RMSE - Risk Sensitivity Metric**
#
# * Penalizes large errors more heavily
#
# * Sensitive to days with unusually high or low sales
#
# **Business relevance:**
#
# * High RMSE indicates risk of:
#
#   * Overstocking
#
#   * Stockouts during promotions or holidays
#
# * Important for:
#
#   * Supply chain planning
#
#   * Promotional forecasting
#
# ---
#
# **3. R² - Overall Model Reliability**
#
# * Measures how much variance in sales is explained by the model
#
# **Business relevance:**
#
# * Higher R² → model understands sales drivers well
#
# * Indicates trustworthiness of predictions
#
# ---
#
# ***Summary -***
#
# *MAE and RMSE were prioritized for direct business impact and risk management, while R² was used to assess overall model reliability and explanatory power.*

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# **Performance Comparison Across Models**
#
# |Model|MAE|RMSE|R²|
# |---|---|---|---|
# |Baseline Model|~2.48|~3.32|~0.00|
# |Linear Regression|~0.26|~0.35|~0.99|
# |Random Forest|~0.19|~0.28|~0.993|
#
# ---
#
# **Model-wise Evaluation**
#
#
#
# **1. Baseline Model**
#
# Purpose: Reference benchmark
#
# Performance: Very poor
#
# R² ≈ 0 → No learning from data
#
# **Conclusion:**
#
# * **Not suitable** for business use
#
# * Useful only to prove improvement of advanced models
#
# ---
#
# **2. Linear Regression**
#
# * Strong performance improvement over baseline
#
# * High R² and low errors
#
# * Assumes linear relationships
#
# **Strengths:**
#
#   * Simple
#
#   * Fast
#
#   * Highly interpretable
#
# **Limitations:**
#
# * Cannot capture complex non-linear effects
#
# * Underperforms compared to Random Forest
#
# ---
#
# **3. Random Forest (Final Choice)**
#
# * Best MAE, RMSE, and R²
#
# * Captures:
#
#   * Non-linear relationships
#
#   * Feature interactions
#
#   * Complex retail dynamics
#
#
# ---
#
# **Why Random Forest was selected:**
#
# * Highest predictive accuracy
#
# * Lower business risk due to reduced error
#
# * Robust to noise and outliers
#
# * Performs best after optimization
#
# ---
#
# ***Summary -***
#
# *Among the three models evaluated, the Random Forest model was selected as the final prediction model because it consistently outperformed the Baseline and Linear Regression models across all evaluation metrics.*
#
# *Its ability to capture non-linear patterns and complex feature interactions makes it more suitable for real-world retail sales forecasting.*

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %%
# Visualizing top 15 most important features from Random Forest model

# Extracting feature importance values
feature_importance = pd.Series(
    rf_model.feature_importances_,
    index=x_train.columns
).sort_values(ascending=False)

# Selecting top 15 features
top_15_features = feature_importance.head(15)

# Setting visualization style
sns.set(style="whitegrid")

# Creating the figure
plt.figure(figsize=(10, 6))

# Plotting horizontal bar chart
ax = sns.barplot(
    x=top_15_features.values,
    y=top_15_features.index,
    palette="viridis"
)

# Adding importance score labels on bars
for i, value in enumerate(top_15_features.values):
    ax.text(
        value + 0.001,        # Slight offset for clarity
        i,
        f"{value:.4f}",
        va='center',
        fontsize=10
    )

# Adding title and labels
plt.title(
    "Top 15 Feature Importances from Optimized Random Forest Model",
    fontsize=16,
    fontweight='bold'
)
plt.xlabel("Feature Importance Score", fontsize=12)
plt.ylabel("Feature Name", fontsize=12)

# Improving layout
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **Model Used**
#
# * The final model used for prediction is an **Optimized Random Forest Regressor** trained on log-transformed sales.
#
# * Random Forest is an **ensemble learning algorithm** that builds multiple decision trees and aggregates their predictions. Each tree captures different patterns in the data, which helps:
#
#   * Reduce overfitting
#
#   * Capture non-linear relationships
#
#   * Handle complex feature interactions effectively
#
# * For model explainability, we used the **built-in feature importance mechanism of Random Forest**, which measures how much each feature contributes to reducing prediction error across all trees.
#
# ---
#
# **Understanding Feature Importance**
#
# * Feature importance scores represent the **relative contribution of each feature** in making accurate predictions.
#
# * A higher score means the model relies more heavily on that feature.
# From the chart:
#
# **1. Open (Importance ≈ 0.9934)**
#
# * This feature overwhelmingly dominates the model.
#
# * It indicates whether the store was open or closed on a given day.
#
#   **Interpretation:**
#
#     * If a store is closed, sales are zero. If it is open, sales can occur.
#
#     * Hence, this feature becomes the strongest predictor.
#
#
#   **Business Insight:**
#
#   * Store operational status is the single most critical factor influencing sales.
#
#   * Ensuring stores remain open during high-demand periods directly impacts revenue.
#
# **2. Promo (Importance ≈ 0.0023)**
#
# * Daily short-term promotions have a measurable impact on sales.
#
# * Though much smaller than Open, this feature is still the second most influential.
#
#   **Business Insight:**
#
#     * Short-term promotions effectively drive incremental sales when stores are open, validating promotional strategies.
#
#
# **3. CompetitionDistance_log (Importance ≈ 0.0020)**
#
# * Log-transformed competition distance captures diminishing effects of distance.
#
# * Nearby competition influences sales more than distant competition.
#
#   **Business Insight:**
#
#   * Stores located closer to competitors experience stronger competitive pressure, impacting sales performance.
#
# **4. CompetitionOpenMonths (Importance ≈ 0.0006)**
#
# * Measures how long a competitor has been operating nearby.
#
#   **Business Insight:**
#
#   * Long-standing competitors tend to stabilize market share, reducing sales volatility over time.
#
# **5. Temporal Features (DayOfWeek_sin, DayOfWeek_cos, Month_sin, Month_cos)**
#
# * These cyclic features capture weekly and seasonal patterns.
#
# * Individually small, but collectively meaningful.
#
#   **Business Insight:**
#
#   * Customer behavior follows predictable weekly and seasonal cycles, enabling better demand forecasting and staffing decisions.
#
# **6. Store & Assortment Characteristics**
#
# * StoreType_Encoded
#
# * Assortment_Encoded
#
#   **Business Insight:**
#
#   * Different store formats and product assortments influence sales performance, but their effect is secondary compared to operational and promotional factors.
#
# **7. Low-Impact Features**
#
# * Features such as - SchoolHoliday, StateHoliday_Encoded, IsPromo2Active
# show near-zero importance in this model.
#
#   **Interpretation:**
#
#   * These effects may already be absorbed indirectly through other variables (e.g., Promo, temporal features) or have weaker standalone influence.
#
# ---
#
# **Overall Interpretation**
#
# * The Random Forest model heavily prioritizes store availability, followed by promotions and competition-related factors.
#
# * Time-based and store-structure features act as supporting predictors.
#
# * The explainability analysis confirms that the model aligns well with real-world retail logic.
#
# ---
#
# **Conclusion -**
#
# * This feature importance analysis increases confidence in the model because:
#
#   * It is interpretable
#
#   * It highlights actionable business levers
#
#   * It avoids reliance on spurious correlations
#
# * The model not only performs exceptionally well (R² ≈ 0.993) but also provides clear strategic insights for store operations, promotions, and competition management.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# ---------------------------------------------
# Saving the Best Performing Model (Random Forest)
# ---------------------------------------------

import joblib

# Saving the optimized Random Forest model
joblib.dump(best_rf, 'random_forest_sales_model.pkl')

print("✅ Model saved successfully as random_forest_sales_model.pkl")
# Out:
# ✅ Model saved successfully as random_forest_sales_model.pkl

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# ---------------------------------------------
# Loading the Saved Model & Predicting Unseen Data
# ---------------------------------------------

# Loading the saved model
loaded_model = joblib.load('random_forest_sales_model.pkl')

# Selecting a small unseen sample
x_sample = x_test.sample(5, random_state=42)
y_sample_actual = y_test.loc[x_sample.index]

# Predicting log-transformed sales
log_predictions = loaded_model.predict(x_sample)

# Converting predictions back to original sales scale
predicted_sales = np.expm1(log_predictions)
actual_sales = np.expm1(y_sample_actual)

# Displaying comparison
comparison_df = pd.DataFrame({
    'Actual_Sales': actual_sales.values,
    'Predicted_Sales': predicted_sales
})

comparison_df
# Out:
#    Actual_Sales  Predicted_Sales
# 0           0.0         0.000000
# 1        4823.0      5284.574815
# 2           0.0         0.000000
# 3        7981.0      5396.327316
# 4        6434.0      7699.489068

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * This project aimed to build a robust and business-oriented regression model to predict daily sales for Rossmann retail stores using historical sales, promotions, competition, and store-level data.
#
# * Through extensive **data wrangling and feature engineering**, raw datasets were transformed into an analysis-ready format by handling missing values, correcting unrealistic competition timelines, creating meaningful business features (such as Sales per Customer, Competition Open Months, and IsPromo2Active), and resolving data inconsistencies.
#
# * This ensured that the modeling phase was built on reliable and well-structured data.
#
# * A comprehensive **exploratory data analysis (EDA)** was conducted using univariate, bivariate, and multivariate visualizations.
#
# * These analyses revealed strong relationships between sales and key drivers such as customer footfall, short-term promotions, seasonality, store types, and competition dynamics.
#
# * Importantly, the analysis showed that while **daily promotions significantly boost sales and customer traffic**, long-running promotions (Promo2) do not consistently translate into higher revenue, highlighting the need for more targeted promotional strategies.
#
# * To statistically validate the visual insights, **hypothesis testing** was performed using appropriate statistical tests such as Welch’s t-test and One-Way ANOVA. The results confirmed that:
#
#   * Promotional days significantly outperform non-promotional days in terms of sales and customer footfall.
#
#   * Customer behavior varies significantly across weekdays.
#
#   * Several observed patterns in EDA were statistically significant and not due to random variation.
#
# * Multiple machine learning models were implemented to predict log-transformed daily sales.
#
# * A baseline model was first established, followed by a **Linear Regression model and a Random Forest Regressor**.
#
# * While Linear Regression provided strong performance and interpretability, the Random Forest model delivered the best predictive accuracy, achieving the lowest error metrics and highest R² score after hyperparameter tuning.
#
# * Feature importance analysis further confirmed that customer count, promotions, competition distance, and store characteristics are the most influential drivers of sales.
#
# * The final trained model was saved as a reusable pickle (.pkl) file, making the solution deployment-ready and suitable for future inference on unseen data.
#
# * Overall, this project demonstrates a **complete end-to-end data science workflow** — from raw data processing and exploratory analysis to statistical validation, predictive modeling, and model deployment readiness.
#
# * The insights derived from this study can directly support **data-driven decision-making** in retail operations, promotional planning, and sales forecasting, making the solution both technically sound and business-impactful.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
